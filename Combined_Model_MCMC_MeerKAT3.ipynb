# %% [markdown]
# ## This model features a high mass Be star accelerating wind and circumstellar disc, with an elliptical orbit, a 3D coordinate system, and eclipses of a 'pseudo-signal' from a pulsar on the orbit.
# ## The main goal of this model is to see the number density, dispersion measure, optical depth and spectrum along a line of sight from a point on the orbit given an orbital phase, orbital and disc inclination, eccentricity, argument of periastron and longitude of ascending node.
# ## Stellar parameters are modelled after the star SS 2883 of the HMXB system PSR B1259-63/SS 2883. Wind terminal velocity is taken from the paper - https://arxiv.org/pdf/0806.4868, while the remaining stellar properties are taken from https://ui.adsabs.harvard.edu/abs/2011ApJ...732L..11N/abstract, https://arxiv.org/abs/1307.7083 and https://arxiv.org/pdf/1804.08402.
# ## Parameter values of the disc of SS 2883 are taken from the paper https://arxiv.org/abs/2204.08124

# %% [markdown]
# # Equations and Geometry
# ## Electron number density
# # $n_{e}(r) = \frac{\rho}{\mu_{e}m_{p}} = \frac{\dot{M}}{4\pi\mu_{e}m_{p}r^2v(r)} = \frac{k}{r^2v(r)}$
# Where
# # $\rho = \frac{\dot{M}}{4\pi r^2v(r)}$
#
# And
#
# # $k = \frac{\dot{M}}{4\pi\mu_{e}m_{p}}$
# With
#
# * $\rho$ =      Density
# * $\mu_{e}$ =   Mean molecular weight per free electron (typically set at a value of 1.2)
# * $m_{p}$ =     Proton mass
# * $\dot{M}$ =   Wind mass loss
# * $v(r)$ =     Radial wind velocity
# * $r$ =         radial distance from the center of the star
#
# ## Accelerating Wind ($\beta$ law)
# The wind velocity at a certain distance away from the star is
# # $v(r) = v_0 + (v_{\infty} - v_0)(1-\frac{R_{*}}{r})^\beta$
# with
# * $v_0$ =        The wind velocity at stellar surface
# * $v_{\infty}$ = Wind terminal velocity
# * $R_{*}$ =      Stellar radius
# * $\beta$ =      Wind acceleration exponent
#
# By placing the star and orbit at the xy plane origin, we can consider an elliptical orbit in cartesian coordinates
# # $\frac{x^2}{a^2} + \frac{y^2}{b^2} = 1$
# with
# * $a$ = Semi-major axis
# * $b$ = Semi-minor axis
# The semi-minor axis can be defined as $a\sqrt{1 - e^2}$, where $e^2$ is the eccentricity.
# In polar coordinates, the ellipse is offset along the x-axis by the focus - $f = ae$.
#
# The orbital separation in polar coordinates becomes
# # $r = \frac{a(1-e^2)}{1+ecos(\phi)}$
# Where $\phi$ is the orbital phase.
#
# The pulsar position vector along the orbit is described as
#
# # $ r_s = \begin{pmatrix} rcos(\phi + \omega) \\ rsin(\phi + \omega) \\ 0  \end{pmatrix}$
#
# Where $\omega$ is the argument of periastron. The observer unit vector (direction of signal to observer) is then defined as
#
# # $ \hat{n} = \begin{pmatrix} sin(i)cos(\Omega) \\ sin(i)sin(\Omega) \\ cos(i)  \end{pmatrix}$
#
# Where $i$ is the inclination and $\Omega$ is the longitude of ascending node.
#
# The 2D orbit is then rotated into 3D space by computing
#
# # $ r_{rot} = R_{z}(\Omega)R_{x}(i)r_s$
#
# Where
#
# # $ R_{z}(\Omega) = \begin{pmatrix} cos(\Omega) & -sin(\Omega) & 0 \\ sin(\Omega) & cos(\Omega) & 0 \\ 0 & 0 & 1  \end{pmatrix}$
#
# # $ R_{x}(i) = \begin{pmatrix} 1 & 0 & 0 \\ 0 & cos(i) & -sin(i) \\ 0 & sin(i) & cos(i)  \end{pmatrix}$
#
# Resulting in
#
# # $ r_{rot} = \begin{pmatrix} r[cos(\Omega)cos(\phi + \omega) -sin(\Omega)cos(i)sin(\phi + \omega)] \\ r[sin(\Omega)cos(\phi + \omega) + cos(\Omega)cos(i)sin(\phi + \Omega)] \\ rsin(i)sin(\phi + \omega)  \end{pmatrix}$
#
# The radial distance of the signal from the star along the path of the line of sight is computed by separating the x, y, and z components of $r_{rot} + s\hat{n}$, where $s\ge0$, is the distance along the line of sight, and comuting $r(s) = \sqrt{x_{s}^2 + y_{s}^2 + z_{s}^2}$.
#
# The number density at a specific point along the line of sight distance from the orbit can then be described as
# # $n_e(r(s)) = \frac{k}{r(s)^2v(r(s))}$
#
# From the definition of $r(s)$,
#
# ## $r(s)^2 = (r_s + s\hat{n})^2 = r^2 + 2rs [cos(\phi + \omega) sin (i)cos(\Omega) + sin(\phi + \omega)sin(i)sin(\Omega)] + s^2$
#
# ## Dispersion Measure
# # $DM(\phi,i) = \int_{0}^{\infty}n_e(r(s))ds = k\int_{0}^{\infty}\frac{ds}{v(r(s))r(s)^2}$
#
# ## Semi-major axis of PSR B1259-63
# Given that the orbital period of PSR B1259-63 is approximately 1237 days, its mass is $1.4 M_\odot$ and that the mass of SS 2883 is approximately $20 M_\odot$, using Kepler's 3rd law, the semi-major axis is
# # $a^3 = \frac{P^2G(M + m)}{4\pi^2}, a \sim 1345R_\odot$
# With
# * $P$ = Orbital period
# * $G$ = Gravitational constant
# * $M$ = Mass of SS 2883
# * $m$ = Mass of PSR B1259-63
#
# ## Free-free Absorption
# Free-free absorption causes signals to be absorbed by the stellar wind depending on its optical depth.
# # $\tau_{FFA} \approx 8.24x10^{-2}\nu^{-2.1}T_e^{-1.35}\int n_e^2ds$
#
# with
# * $\tau_{FFA}$ = The optical depth
# * $\nu$ = The signal frequency
# * $T_e$ = The stellar wind temperature
# * $n_e$ = The number density
# * $s$ = The line of sight distance
#
# ## Flux density
# The flux density of the pulsar signal is decribed as
# # $S_{\nu} = S_{psr,\nu}e^{-\tau} = \nu^{-p}e^{-\tau}$
# with
# * $S_{psr,\nu}$ = The intrinsic flux of the pulsar
# * $\nu$ = The signal frequency
# * $p$ = The power law index
# * $\tau$ = The optical depth
# When the flux density of the signal is plotted against frequency, it results in the pulsar's spectrum, which changes along eccentric orbits.
#
# ## Be Disc
# Be stars such as SS 2883 have a circumstellar disc due to the star's immense rotation rate. The disc introduces an additional desnity structure to the system, which is described as
# # $\rho(r_{disc}, z) = \rho_0(\frac{r_{disc}}{R_*})^{-\beta}e^{\frac{-z^2}{H(r_{disc})^2}}$
# with
# * $\rho_0$ = The disc desnity at stellar surface
# * $r_{disc}$ = radial distance in the disc plane
# * $R_*$ = Stellar radius
# * $\beta$ = Disc power law exponent
# * $z$ = Height above the disc plane
# * $H(r)$ = Scale height
#
# The scale height is described as
# # $H(r_{disc}) = c_s\sqrt{\frac{r_{disc}}{GM_*}}r_{disc}$
# with
# * $c_s$ = Speed of sound
# * $G$ = Gravitational constant
# * $M_*$ = Stellar mass
#
# And the speed of sound is described as
# # $c_s = \sqrt{\frac{kT}{\mu_em_p}}$
# with
# * $k$ = Boltzmann constant
# * $T$ = Disc temperature
#
# Using the disc desnity profile the number density through the disc becomes
# # $n_{e,disc} = \frac{\rho(r_{disc},z)}{\mu_em_p}$
#
# From which the DM and optical depth can be calculated
#
# Placing the disc at the xy plane along with the pulsar orbit, the pulsar position is $ r_s = \begin{pmatrix} rcos(\phi + \omega) \\ rsin(\phi + \omega) \\ 0  \end{pmatrix}$. The line of sight unit vector is $\hat{n} = (sin(i)cos(\Omega), sin(i)sin(\Omega), cos(i+\Omega))$.
#
# The pulsar position rotation onto the disc plane is described as
#
# # $r_rot = R_{z}(\Omega)R_{x}(i)R_{z}(\omega)r_s$
#
# Where
#
# # $ R_{z}(\Omega) = \begin{pmatrix} cos(\Omega) & -sin(\Omega) & 0 \\ sin(\Omega) & cos(\Omega) & 0 \\ 0 & 0 & 1  \end{pmatrix}$
#
# # $ R_{x}(i) = \begin{pmatrix} 1 & 0 & 0 \\ 0 & cos(i) & -sin(i) \\ 0 & sin(i) & cos(i)  \end{pmatrix}$
#
# # $ R_{z}(\omega) = \begin{pmatrix} cos(\omega) & -sin(\omega) & 0 \\ sin(\omega) & cos(\omega) & 0 \\ 0 & 0 & 1  \end{pmatrix}$
#
# Resulting in
#
# ### $ r_{rot} = \begin{pmatrix} r[(cos(\Omega)cos(\omega) - sin(\Omega)cos(i)sin(\omega)cos(\phi) + (-cos(\Omega)sin(\omega) - sin(\Omega)cos(i)cos(\omega))sin(\phi))] \\ r[(sin(\Omega)cos(\omega) + cos(\Omega)cos(i)sin(\omega))cos(\phi) + (-sin(\Omega)sin(\omega) + cos(\Omega)cos(i)cos(\omega))sin(\phi)] \\ rsin(i)sin(\phi + \omega)  \end{pmatrix}$
#
# The radial distance of the signal from the star along the path of the line of sight is computed by separating the x and y components of $r_{rot} + s\hat{n}$, where $s\ge0$, is the distance along the line of sight, and comuting $r_{disc} = \sqrt{x_{s}^2 + y_{s}^2}$.
#
# The disc height above its plane is described as $z = r(s)\cdot{\hat{n}_{disc}} = r_s\hat{n}_{disc} + s(\hat{n}\cdot{\hat{n}_{disc}})$. Where the line of sight unit vector is $\hat{n} = (sin(i)cos(\Omega), sin(i)sin(\Omega), cos(i+\Omega))$, and the disc normal is $\hat{n}_{disc} = (0, sin(i_{disc}), cos(i_{disc}))$, such that the disc rotates on the x-axis.
#
# ## Combined Stellar Wind and Be Disc
# Since the stellar wind and Be disc do not depend on each-other, combining their number densities is straight forward
# # $n_{e,total} = n_{e,wind} + n_{e,disc}$
# With this total number density we can calculate the dispersion measure, optical depth, transmission factor and spectrum of the entire system.

# %%
#Packages
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import astropy.units as u
import astropy.constants as con
import ipywidgets as widgets
from IPython.display import display
from scipy.optimize import curve_fit
from scipy.optimize import minimize
import emcee
import corner
from IPython.display import display, Math

# %%
#Constants in cgs units
R_sun_cgs = con.R_sun.cgs.value   #Radius of sun in cgs
M_sun_cgs = con.M_sun.cgs.value   #Mass of the sun in cgs
yr_to_sec = u.yr.to(u.s)          #Year to seconds
kms_cgs = (u.km/u.s).to(u.cm/u.s) #Kms in cgs
m_p_cgs = con.m_p.cgs.value       #Mass of proton in cgs
G_cgs = con.G.cgs.value           #Gravitational constant in cgs   
k_B_cgs = con.k_B.cgs.value       #Boltzmann constant in cgs
AU_cgs = (con.au.cgs.value)       #AU in cgs
pc_to_cm = u.pc.to(u.cm)          #PC to cm

# %%
#Number density function
def num_density(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, s, e, omega, Omega, beta, mu_e=1.2):
    '''This function calculates the number density at a specific point along an elliptical orbit within a spherically cymmetric wind 
    with accelerating velocity.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    mu_e             [float] -> Mean molecular weight per free electron
    e                [float] -> Eccentricity (0 < e < 1)
    s                [float] -> Distance along line of sight from signal (AU)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent 
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the number density [array] -> (cm^-3)'''
    a = a_Rsun * R_sun_cgs                                                                                            #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                                                                                   #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec)                                                             #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                                                                                           #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                                                                                       #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                                                                                 #Calculates the k constant (cm^-1)
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                              #Calculates the orbital separation along the orbit
    x = r*(np.cos(Omega)*np.cos(phi+omega) - np.sin(Omega)*np.cos(i)*np.sin(phi+omega)) + s*(np.sin(i)*np.cos(Omega)) #Rotated x axis
    y = r*(np.sin(Omega)*np.cos(phi+omega) + np.cos(Omega)*np.cos(i)*np.sin(phi+omega)) + s*(np.sin(i)*np.sin(Omega)) #Rotated y axis
    z = r*np.sin(i)*np.sin(phi+omega) + s*np.cos(i)                                                                   #Rotated z axis
    r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                 #Calculates the radial distance from the pulsar along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                    #Calculates the velocity of the wind 

    n_e = k/(r_s**2 * v_r_s)                                                                                          #Calculates the number density
    n_e[r_s <= R_star] = 0                                                                                            #Eclipse condition
     
    return n_e

# %%
#DM function
def dm_beta_wind(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, mu_e=1.2, s_array_cm=None):
    '''This function calculates the dispersion measure along a line of sight, given orbital phase and inclination, 
    assuming a spherically symmetric wind with an accelerating velocity.
    --------------------------------------------------------------------------------------------------------------
    Parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent 
    mu_e             [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the dispersion measure [array] -> (pc cm^-3).'''
    a = a_Rsun * R_sun_cgs                                #Converts the semi-major axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    DM_array = []

    for value in phi:
        r = a * (1 - e**2) / (1 + e * np.cos(value))                                                                             #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value+omega) - np.sin(Omega)*np.cos(i)*np.sin(value+omega)) + s*(np.sin(i)*np.cos(Omega))    #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value+omega) + np.cos(Omega)*np.cos(i)*np.sin(value+omega)) + s*(np.sin(i)*np.sin(Omega))    #Rotated y axis
        z = r*np.sin(i)*np.sin(value+omega) + s*np.cos(i)                                                                        #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/r_s)**beta                                                                     #Calculates the velocity of the wind 
        n_e = k / (r_s**2 * v_r_s)                                                                                               #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition

        DM_cgs = np.trapz(n_e, s)                                                                                                #Integrating the DM in cm^-2
        DM = (DM_cgs / pc_to_cm)                                                                                                 #Converting DM to pc cm^3
        DM_array.append(DM)

    return np.array(DM_array)

# %%
#Free-free absorption function
def ffa(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, nu, T, mu_e=1.2, s_array_cm=None):
    '''This function calculates the free-free absorption along a line of sight, given orbital phase and inclination, 
    assuming a spherically symmetric wind with an accelerating velocity.
    --------------------------------------------------------------------------------------------------------------
    Parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    nu               [float] -> Signal frequency (GHz)
    T                [float] -> Stellar wind temperature (K)
    mu_e             [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array].'''
    a = a_Rsun * R_sun_cgs                                #Converts the semi-major axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    tau_array = []

    for value in phi:
        r = a * (1 - e**2) / (1 + e * np.cos(value))                                                                             #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value+omega) - np.sin(Omega)*np.cos(i)*np.sin(value+omega)) + s*(np.sin(i)*np.cos(Omega))    #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value+omega) + np.cos(Omega)*np.cos(i)*np.sin(value+omega)) + s*(np.sin(i)*np.sin(Omega))    #Rotated y axis
        z = r*np.sin(i)*np.sin(value+omega) + s*np.cos(i)                                                                        #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/r_s)**beta                                                                     #Calculates the velocity of the wind 
        n_e = k / (r_s**2 * v_r_s)                                                                                               #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition

        tau = 8.24e-2*nu**-2.1*T**-1.35*np.trapz(n_e**2, s / pc_to_cm)                                                           #Integrating the optical depth
        tau_array.append(tau)

    return np.array(tau_array)

# %%
#Flux density function
def spectrum(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, nu, T, p, mu_e=1.2, s_array_cm=None):
    '''This function calculates the spectrum of the pulsar for a given inclination and frequency along the orbit.
    -------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    nu               [float] -> Signal frequency (GHz)
    T                [float] -> Stellar wind temperature (K)
    p                [float] -> Power law exponent
    mu_e             [float] -> Mean molecular weight per free electron
    
    -------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the pulsar spectrum [array] (Jy)'''
    a = a_Rsun * R_sun_cgs                                #Converts the semi-major axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a flux density array
    S_nu_array = []

    for value in phi:
        for freq in nu:
            r = a * (1 - e**2) / (1 + e * np.cos(value))                                                                             #Calculates the orbital separation along the orbit
            x = r*(np.cos(Omega)*np.cos(value+omega) - np.sin(Omega)*np.cos(i)*np.sin(value+omega)) + s*(np.sin(i)*np.cos(Omega))    #Rotated x axis
            y = r*(np.sin(Omega)*np.cos(value+omega) + np.cos(Omega)*np.cos(i)*np.sin(value+omega)) + s*(np.sin(i)*np.sin(Omega))    #Rotated y axis
            z = r*np.sin(i)*np.sin(value+omega) + s*np.cos(i)                                                                        #Rotated z axis
            r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
            v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/r_s)**beta                                                                     #Calculates the velocity of the wind 
            n_e = k / (r_s**2 * v_r_s)                                                                                               #Calculates the number density
            n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition

            tau = 8.24e-2*freq**-2.1*T**-1.35*np.trapz(n_e**2, s / pc_to_cm) #Integrating the optical depth
            S_nu = freq**(-p)*np.exp(-tau)                                   #Calculating the flux density
            S_nu_array.append(S_nu)
    S_nu_2D = np.array(S_nu_array).reshape(len(phi), len(nu))                #Reshaping to a 2D array
    return S_nu_2D

# %%
#Disc number density function
def disc_ne(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, s, mu_e=1.2):
    '''This function calculates the number density along the line of sight from the
    pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Argument of periastron (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    s          [array] -> Array of line of sight points (cm)
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the number desnity [array] (cm^-3)'''
    a = a_Rsun * R_sun_cgs               #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs      #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs      #Converts the stellar mass from solar mass to g
    r = a*(1 - e**2)/(1 + e*np.cos(phi)) #Calculates the orbital separation along the orbit

    # x and y rotation coordinates of the disc
    x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.cos(Omega))
    y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.sin(Omega))
        
    r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                          #Projected radius through disc plane        
    c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                  #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                      #Calculates the scale height
    z = r*np.sin(phi+omega)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc)) #Calculates the height above the disc plane
    rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                      #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                            #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                                                                   #Constraining the inner disc radius

    return ne_disc

# %%
#Disc dispersion measure function
def disc_DM(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, mu_e=1.2, s_array_cm=None):
    '''This function calculates dispersion measure along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the dispersion measure [array] (pc cm^-3)'''
    a = a_Rsun * R_sun_cgs          #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs #Converts the stellar mass from solar mass to g

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    disc_DM_array = []

    for value in phi:
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                           #Calculates the orbital separation along the orbit
        
        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane           
        c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                    #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value+omega)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc)) #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                        #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius


        disc_DM_cgs = np.trapz(ne_disc, s)                                                                               #Integrating the DM in cm^-2
        disc_DM = (disc_DM_cgs / pc_to_cm)                                                                               #Converting DM to pc cm^3
        disc_DM_array.append(disc_DM)

    return np.array(disc_DM_array)

# %%
#Disc free-free absorption function
def disc_ffa(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, nu, mu_e=1.2, s_array_cm=None):
    '''This function calculates optical depth along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    nu         [float] -> Signal frequency (GHz)
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array]'''
    a = a_Rsun * R_sun_cgs          #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs #Converts the stellar mass from solar mass to g

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    disc_tau_array = []
    
    for value in phi:
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                           #Calculates the orbital separation along the orbit
        
        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane          
        c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                    #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value+omega)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc)) #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                        #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius


        disc_tau = 8.24e-2*nu**(-2.1)*T**(-1.35)*np.trapz(ne_disc**2, s / pc_to_cm)                                      #Integrating tau
        disc_tau_array.append(disc_tau)

    return np.array(disc_tau_array)

# %%
#Disc flux density function
def disc_spectrum(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, nu, p, mu_e=1.2, s_array_cm=None):
    '''This function calculates optical depth along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    nu         [float] -> Signal frequency (GHz)
    p          [float] -> Power law exponent
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array]'''
    a = a_Rsun * R_sun_cgs          #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs #Converts the stellar mass from solar mass to g
    
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    disc_S_nu_array = []
    
    for value in phi:
        for freq in nu:
            r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                           #Calculates the orbital separation along the orbit
            
            # x and y rotation coordinates of the disc
            x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
            y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
            r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane          
            c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                    #Calculates the disc speed of sound
            H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
            z = r*np.sin(value+omega)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc)) #Calculates the height above the disc plane
            rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                        #Calculates the disc desnity profile
            ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
            ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius


            disc_tau = 8.24e-2*freq**(-2.1)*T**(-1.35)*np.trapz(ne_disc**2, s / pc_to_cm)                                    #Integrating tau
            disc_S_nu = freq**(-p)*np.exp(-disc_tau)                                                                         #Calculatinng the flux density
            disc_S_nu_array.append(disc_S_nu)
    disc_S_nu_2D = np.array(disc_S_nu_array).reshape(len(phi), len(nu))                                                      #Reshaping to a 2D array
    return np.array(disc_S_nu_2D)

# %%
#Total wind-disc number density function
def tot_num_density(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, s, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, mu_e=1.2):
    '''This function calculates the total number density at a specific point along an elliptical orbit within a spherically cymmetric wind 
    with accelerating velocity and an axisymmetric disc.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    s                [float] -> Distance along line of sight from signal (AU)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total number density [array] -> (cm^-3)'''
    #Stellar wind number density
    a = a_Rsun * R_sun_cgs                                                                                               #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                                                                                      #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec)                                                                #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                                                                                              #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                                                                                          #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                                                                                    #Calculates the k constant (cm^-1)
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                                 #Calculates the orbital separation along the orbit
    x = r*(np.cos(Omega)*np.cos(phi+omega) - np.sin(Omega)*np.cos(i)*np.sin(phi+omega)) + s*(np.sin(i)*np.cos(Omega))    #Rotated x axis
    y = r*(np.sin(Omega)*np.cos(phi+omega) + np.cos(Omega)*np.cos(i)*np.sin(phi+omega)) + s*(np.sin(i)*np.sin(Omega))    #Rotated y axis
    z = r*np.sin(i)*np.sin(phi+omega) + s*np.cos(i)                                                                      #Rotated z axis
    r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                    #Calculates the radial distance from the pulsar along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                       #Calculates the velocity of the wind 
    n_e = k/(r_s**2 * v_r_s)                                                                                             #Calculates the number density
    n_e[r_s <= R_star] = 0                                                                                               #Eclipse condition
    
    #Disc number density
    M_star = M_star_sol * M_sun_cgs                                                                                      #Converts the stellar mass from solar mass to g
    
    # x and y rotation coordinates of the disc
    x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.cos(Omega))
    y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.sin(Omega))
        
    r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                          #Projected radius through disc plane        
    c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                             #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                      #Calculates the scale height
    z = r*np.sin(phi+omega)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc)) #Calculates the height above the disc plane
    rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                 #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                            #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                                                                   #Constraining the inner disc radius

    #Total number density
    total_ne = n_e + ne_disc

    return total_ne

# %%
#Total wind-disc dispersion measure function
def tot_DM(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, mu_e=1.2, s_array_cm=None):
    '''This function calculates the dispersion measure along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total dispersion measure [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_DM_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value+omega) - np.sin(Omega)*np.cos(i)*np.sin(value+omega)) + s*(np.sin(i)*np.cos(Omega))    #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value+omega) + np.cos(Omega)*np.cos(i)*np.sin(value+omega)) + s*(np.sin(i)*np.sin(Omega))    #Rotated y axis
        z = r*np.sin(i)*np.sin(value+omega) + s*np.cos(i)                                                                        #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                           #Calculates the velocity of the wind 
        n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
        #Disc number density

        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane        
        c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value+omega)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc)) #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_DM_cgs = np.trapz(total_ne, s) #Integrating the DM in cm^-2
        total_DM = (total_DM_cgs / pc_to_cm) #Converting DM to pc cm^3
        tot_DM_array.append(total_DM)

    return np.array(tot_DM_array)

# %%
#Total wind-disc free-free absorption function
def tot_ffa(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_wind, T_disc, beta_disc, rho0, i_disc, nu, mu_e=1.2, s_array_cm=None):
    '''This function calculates the optical depth along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    T_wind           [float] -> Temperature of wind (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    nu               [float] -> Signal frequency (GHz)
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total optical depth [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_tau_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value+omega) - np.sin(Omega)*np.cos(i)*np.sin(value+omega)) + s*(np.sin(i)*np.cos(Omega))    #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value+omega) + np.cos(Omega)*np.cos(i)*np.sin(value+omega)) + s*(np.sin(i)*np.sin(Omega))    #Rotated y axis
        z = r*np.sin(i)*np.sin(value+omega) + s*np.cos(i)                                                                        #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                           #Calculates the velocity of the wind 
        n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
        #Disc number density

        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane 
        c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value+omega)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc)) #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_tau = 8.24e-2*nu**(-2.1)*((T_wind+T_disc)/2)**(-1.35)*np.trapz(total_ne**2, s / pc_to_cm) #Integrating the optical depth
        tot_tau_array.append(total_tau)

    return np.array(tot_tau_array)

# %%
#Total wind-disc flux density function
def tot_spectrum(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_wind, T_disc, beta_disc, rho0, i_disc, nu, p, mu_e=1.2, s_array_cm=None):
    '''This function calculates the flux density along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    T_wind           [float] -> Temperature of wind (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    nu               [float] -> Signal frequency (GHz)
    p                [float] -> Spectrum power law exponent
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total flux density [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_S_nu_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        for freq in nu:
            #Stellar wind number density
            r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
            x = r*(np.cos(Omega)*np.cos(value+omega) - np.sin(Omega)*np.cos(i)*np.sin(value+omega)) + s*(np.sin(i)*np.cos(Omega))    #Rotated x axis
            y = r*(np.sin(Omega)*np.cos(value+omega) + np.cos(Omega)*np.cos(i)*np.sin(value+omega)) + s*(np.sin(i)*np.sin(Omega))    #Rotated y axis
            z = r*np.sin(i)*np.sin(value+omega) + s*np.cos(i)                                                                        #Rotated z axis
            r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
            v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                           #Calculates the velocity of the wind 
            n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
            n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
            #Disc number density
            
            # x and y rotation coordinates of the disc
            x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
            y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
            r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane        
            c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
            H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
            z = r*np.sin(value+omega)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc)) #Calculates the height above the disc plane
            rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
            ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
            ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

            #Total number density
            total_ne = n_e + ne_disc

            total_tau = 8.24e-2*freq**(-2.1)*((T_wind+T_disc)/2)**(-1.35)*np.trapz(total_ne**2, s / pc_to_cm) #Integrating the DM in cm^-2
            total_S_nu = freq**(-p)*np.exp(-total_tau)                                                        #Calculatinng the flux density
            tot_S_nu_array.append(total_S_nu)
        
    tot_S_nu_2D = np.array(tot_S_nu_array).reshape(len(phi), len(nu))                                         #Reshaping to a 2D array
    return np.array(tot_S_nu_2D)

# %%
#Total wind-disc dispersion measure function
def tot_DM_mcmc(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, ISM_DM, mu_e=1.2, s_array_cm=None):
    '''This function calculates the dispersion measure along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    ISM_DM           [float] -> Interstellar medium dispersion measure (pc cm^-3)
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total dispersion measure [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_DM_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value+omega) - np.sin(Omega)*np.cos(i)*np.sin(value+omega)) + s*(np.sin(i)*np.cos(Omega))    #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value+omega) + np.cos(Omega)*np.cos(i)*np.sin(value+omega)) + s*(np.sin(i)*np.sin(Omega))    #Rotated y axis
        z = r*np.sin(i)*np.sin(value+omega) + s*np.cos(i)                                                                        #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1 - R_star/r_s)**beta                                                                         #Calculates the velocity of the wind 
        n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
        #Disc number density

        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane 
        c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value+omega)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc)) #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_DM_cgs = np.trapz(total_ne, s)          #Integrating the DM in cm^-2
        total_DM = (total_DM_cgs / pc_to_cm) + ISM_DM #Converting DM to pc cm^3
        tot_DM_array.append(total_DM)

    return np.array(tot_DM_array)

# %%
#Curve_fit DM function
def DM_curve_fit(phi, Mdot, v_inf_kms, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, ISM_DM):
    '''
    This function employs scipy's curve_fit by implementing the general tot_DM function.
    -------------------------------------------------------------------------------------
    Parameters:

    phi    [array] -> Orbital Phase (rad)
    i_orb  [float] -> Orbital Inclination (rad)
    Mdot   [float] -> Log stellar Mass Loss (solar mass per year)
    e      [float] -> Eccentricity
    omega  [float] -> Argument of Periastron (rad)
    Omega  [float] -> Longitude of Ascending Node (rad)
    rho0   [float] -> Log initial Disc Density (gcm^-3)
    i_disc [float] -> Disc Inclination (rad)
    --------------------------------------------------------------------------------------
    Returns:

    The dipersion measure curve fit.
    '''
    #Fixing the remaining parameters of the model
    i_orb_fixed = np.deg2rad(25)
    a_Rsun_fixed = 1345
    R_star_sol_fixed = 9.2
    M_star_sol_fixed = 20
    v_0_kms_fixed = 5
    e_fixed = 0.87

    return tot_DM_mcmc(phi, i_orb_fixed, a_Rsun_fixed, R_star_sol_fixed, M_star_sol_fixed, Mdot, v_0_kms_fixed, v_inf_kms, e_fixed, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, ISM_DM)

# %% [markdown]
# # Number Density

# %%
#Calculating the number density along the line of sight
i_deg = [25, 45, 60, 90]                                                                  #Inclinations in degrees
i = np.deg2rad(i_deg)                                                                     #Converting the inclinations to rad
phi_deg = [50, 150, 200, 250]                                                             #Orbital phases in degrees
phi = np.deg2rad(phi_deg)                                                                 #Converting the orbital phases to rad
om = np.deg2rad(0)                                                                        #Argument of periastron deg->rad
Om = np.deg2rad(189)                                                                      #Longitude of ascending node deg->rad
s = np.logspace(np.log10(1e12), np.log10((12 * con.au.cgs).value), 512)                   #Line of sight distance array
n_e1 = num_density(phi[0], i[0], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                   v_0_kms=5, v_inf_kms=1e3, s=s, e=0.87, omega=om, Omega=Om, beta=2)     #Number densities
n_e2 = num_density(phi[1], i[1], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                   v_0_kms=5, v_inf_kms=1e3, s=s, e=0.87, omega=om, Omega=Om, beta=2)
n_e3 = num_density(phi[2], i[2], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                   v_0_kms=5, v_inf_kms=1e3, s=s, e=0.87, omega=om, Omega=Om, beta=2)
n_e4 = num_density(phi[3], i[3], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                   v_0_kms=5, v_inf_kms=1e3, s=s, e=0.87, omega=om, Omega=Om, beta=2)

# %% [markdown]
# When plotting the number density as a function of line of sight distance, it is important to revisit the squared radial distance from the star along the line of sight:
# ## $r(s)^2 = (r_s + s\hat{n})^2 = r^2 + 2rs [cos(\phi + \omega) sin (i)cos(\Omega) + sin(\phi + \omega)sin(i)sin(\Omega)] + s^2$
# As we can see, when
# ## $r >> s$, $r(s)^2 \approx r^2$
# so
# ## $n_e(r(s)) \approx \frac{k}{r^2} = const$
# Therefore, we can only start seeing a power law relation when
# ## $r \sim s$

# %%
#Plotting the number density as a function of line of sight distance
plt.plot(s, n_e1, label = 'i = ' + str(i_deg[0]) + ', phi = ' + str(phi_deg[0]) + ' (deg)')
plt.plot(s, n_e2, label = 'i = ' + str(i_deg[1]) + ', phi = ' + str(phi_deg[1]) + ' (deg)')
plt.plot(s, n_e3, label = 'i = ' + str(i_deg[2]) + ', phi = ' + str(phi_deg[2]) + ' (deg)')
plt.plot(s, n_e4, label = 'i = ' + str(i_deg[3]) + ', phi = ' + str(phi_deg[3]) + ' (deg)')
plt.title('Number Density Vs Line of Sight Distance')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %% [markdown]
# # Dispersion Measure

# %%
#Calculating the DM
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                              #Orbital phase array in rad (redundancy removed)
DM1 = dm_beta_wind(phi, i[0], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                  v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=om, Omega=Om, beta=2) #Dispersion measure
DM2 = dm_beta_wind(phi, i[1], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                  v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=om, Omega=Om, beta=2)
DM3 = dm_beta_wind(phi, i[2], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                  v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=om, Omega=Om, beta=2)

# %%
#Plotting the DM as a function of the orbital phase
plt.plot(phi/(2*np.pi), DM1, label = 'i = ' + str(i_deg[0]) + ' (deg)')
plt.plot(phi/(2*np.pi), DM2, label = 'i = ' + str(i_deg[1]) + ' (deg)')
plt.plot(phi/(2*np.pi), DM3, label = 'i = ' + str(i_deg[2]) + ' (deg)')
plt.title('Dispersion Measure Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %% [markdown]
# # Free-free Absorption

# %%
#Calculating the optical depth
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                                                   #Orbital phase array in rad (redundancy removed)
nu = [1, 1.5, 2]                                                                                  #Signal frequency in GHz
i_deg = [25, 25, 25]                                                                                 #Orbital inclination in deg
i = np.deg2rad(i_deg)                                                                                #Orbital inclination in rad

tau1 = ffa(phi, i[0], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                  v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=om, Omega=Om, beta=2, nu=nu[0], T=2e4)     #Optical depth
tau2 = ffa(phi, i[1], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                  v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=om, Omega=Om, beta=2, nu=nu[1], T=2e4)
tau3 = ffa(phi, i[2], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                  v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=om, Omega=Om, beta=2, nu=nu[2], T=2e4)

# %%
#Plotting the optical depth as a function of the orbital phase
plt.plot(phi/(2*np.pi), tau1, label = 'i = ' + str(i_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi/(2*np.pi), tau2, label = 'i = ' + str(i_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi/(2*np.pi), tau3, label = 'i = ' + str(i_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('FFA Optical Depth Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('Optical Depth')
plt.legend()

# %% [markdown]
# # Transmission factor $e^{-\tau}$ Vs $\phi$
#
# The transmission factor $e^{-\tau}$ shows how much the flux at a given frequency is actually suppressed. It is the fraction of radiation that survives after passing though the stellar wind material with a certain optical depth.

# %%
#Plotting e^(-tau) as a function of the orbital phase
plt.plot(phi/(2*np.pi), np.exp(-tau1), label = 'i = ' + str(i_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi/(2*np.pi), np.exp(-tau2), label = 'i = ' + str(i_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi/(2*np.pi), np.exp(-tau3), label = 'i = ' + str(i_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('Transmission Factor e^(-tau) Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('e^(-tau)')
plt.yscale('log')
plt.legend()

# %% [markdown]
# # Be Disc

# %% [markdown]
# ## Be Disc Mass
# As a preliminary step of analysing the Be disc it is important to check its total mass.
#
# Using the definition of density
# ## $\rho = \frac{dM}{dV} \to dM = \rho dV \to M = \int \rho dV$
#
# With
# * $M$ = Disc mass
# * $V$ = Disc volume
#
# For discs, $dV = rdrd\phi dz$
# With
# * $dr$ = Radial change
# * $d\phi$ = Angular change
# * $dz$ = Vertical change
#
# Since $\int_0^{2\pi} rd\phi = 2\pi r$, we end up with
#
# ## $M = 2\pi \int_{R_*}^{R_{out}} \int_{-\infty}^{\infty} \rho_0 (\frac{r}{R_*})^{-\beta} e^{\frac{-z^2}{H_{r}^2}} dzdr$
# With
# * $R_*$ = Stellar radius
# * $R_{out}$ = Outer radius of disc
#
# Using the gaussian integral $\int_{-\infty}^{\infty} e^{-ax^2} = \sqrt{\frac{\pi}{a}}$, the integral of the vertical change becomes
#
# ## $\int_{-\infty}^{\infty} e^{\frac{-z^2}{H_{r}^2}}dz = \sqrt{\pi}H_{r}$
# The final expression of the disc mass is
#
# ## $M = 2\pi^{1.5} \rho_0 \int_{R_*}^{R_out} (\frac{r}{R_*})^{-\beta} H_r r dr$

# %%
#Disc parameters
rho0 = 1e-12                        #Disc density at stellar surface (g cm^-3)
R_star = (9*con.R_sun).cgs.value    #Stellar radius converted from stellar radii (cm)
R_out = (100*con.R_sun).cgs.value   #Disc outer radius converted from stellar radii (cm)
M_star = (20*con.M_sun).cgs.value   #Stellar mass converted from kg (g)
r = np.linspace(R_star, R_out, 512) #Radial integration grid of disc (cm)
T_disc = 1.2e4                      #Disc temperature (K)
mu_e = 1.2                          #Mean molecular weight per free electron
beta = 4                            #Disc density power-law exponent

c_s = np.sqrt((con.k_B*T_disc)/(mu_e*con.m_p)).cgs.value #Speed of sound through disc (cm/s)

H_r = c_s*np.sqrt(r/(con.G.cgs.value*M_star))*r          #Disc scale height (cm)  

integrand = (r/R_star)**(-beta)*H_r*r                    #Disc mass integrand

M_disc_cgs = 2*np.pi**1.5*rho0*np.trapz(integrand, r)    #Integrating the disc mass (g)

M_disc = M_disc_cgs/con.M_sun.cgs.value                  #Disc mass in solar mass

print('The mass of the disc is ' + "{:.3e}".format(M_disc) + ' solar masses')
# Out:
# The mass of the disc is 2.686e-11 solar masses

# %% [markdown]
# ## Number Density

# %%
s = np.logspace(np.log10(1e8), np.log10((12 * con.au.cgs).value), 10000)     #Line of sight distance array
i_disc_deg = [60, 65, 70, 75]                                                #Disc inclination in degrees                                                   
i_disc_rad = np.deg2rad(i_disc_deg)                                          #Disc inclination in rad
i_orb_deg = 25                                                               #Orbital inclination in deg
i_orb_rad = np.deg2rad(i_orb_deg)                                            #Orbital inclination in rad
phi_orb_deg = 100                                                            #Orbital phase in degree
phi_orb_rad = np.deg2rad(phi_orb_deg)                                        #Orbital phase in rad
om_deg = 0
om = np.deg2rad(om_deg)
Om_deg = 189
Om = np.deg2rad(Om_deg)

disc_num_den1 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,   #Number density
                       beta=3.5, rho0=-12, i_disc=i_disc_rad[0], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s)
disc_num_den2 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,        
                       beta=3.5, rho0=-12, i_disc=i_disc_rad[1], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s)
disc_num_den3 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,       
                       beta=3.5, rho0=-12, i_disc=i_disc_rad[2], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s)
disc_num_den4 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,        
                       beta=3.5, rho0=-12, i_disc=i_disc_rad[3], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s)
#Plotting
plt.plot(s, disc_num_den1, label='i disc = ' + str(int(i_disc_deg[0])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den2, label='i disc = ' + str(int(i_disc_deg[1])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den3, label='i disc = ' + str(int(i_disc_deg[2])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den4, label='i disc = ' + str(int(i_disc_deg[3])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.title('Disc Number Density Vs Line of Sight Distance')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %% [markdown]
# # Dispersion Measure

# %%
#Calculating the DM
om_deg = 0                                                            #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                                               #Orbital argument of periastron in rad
Om_deg = 189                                                          #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                                               #Longitude of ascending note in rad
i_orb_deg = 25                                                        #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                                     #Orbital inclination is rad
i_disc_deg = [60, 65, 70]                                             #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                                   #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                    #Orbital phase array in rad (redundancy removed)

disc_DM1 = disc_DM(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9, #Number density
                       beta=3.5, rho0=-12, i_disc=i_disc_rad[0], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad)
disc_DM2 = disc_DM(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,        
                       beta=3.5, rho0=-12, i_disc=i_disc_rad[1], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad)
disc_DM3 = disc_DM(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,       
                       beta=3.5, rho0=-12, i_disc=i_disc_rad[2], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad)
#Plotting
plt.plot(phi/(2*np.pi), disc_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' deg')
plt.plot(phi/(2*np.pi), disc_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' deg')
plt.plot(phi/(2*np.pi), disc_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' deg')
plt.title('Disc Dispersion Measure Vs Orbital Phase')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %%
#Calculating the DM
om_deg = 0                                                            #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                                               #Orbital argument of periastron in rad
Om_deg = 189                                                          #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                                               #Longitude of ascending note in rad
i_orb_deg = 25                                                        #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                                     #Orbital inclination is rad
i_disc_deg = [60, 65, 70]                                             #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                                   #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                    #Orbital phase array in rad (redundancy removed)

disc_DM1 = disc_DM(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9, #Number density
                       beta=3.5, rho0=-12, i_disc=i_disc_rad[0], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad)
disc_DM2 = disc_DM(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,        
                       beta=3.5, rho0=-12, i_disc=i_disc_rad[1], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad)
disc_DM3 = disc_DM(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,       
                       beta=3.5, rho0=-12, i_disc=i_disc_rad[2], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad)
#Plotting
plt.plot(phi/(2*np.pi), disc_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' deg')
plt.plot(phi/(2*np.pi), disc_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' deg')
plt.plot(phi/(2*np.pi), disc_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' deg')
plt.title('Disc Dispersion Measure Vs Orbital Phase')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.yscale('log')
plt.legend()

# %% [markdown]
# # Optical Depth

# %%
#Calculating the optical depth
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                                #Orbital phase array in rad (redundancy removed)
nu = [1.0, 1.5, 2]                                                                #Signal frequency in GHz
disc_tau1 = disc_ffa(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9, beta=3.5, #Optical depth
                  rho0=-12, i_disc=i_disc_rad[0], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad, nu=nu[0]) 
disc_tau2 = disc_ffa(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9, beta=3.5,
                  rho0=-12, i_disc=i_disc_rad[1], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad, nu=nu[1])
disc_tau3 = disc_ffa(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9, beta=3.5,
                  rho0=-12, i_disc=i_disc_rad[2], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad, nu=nu[2])

# %%
#Plotting the optical depth as a function of the orbital phase
plt.plot(phi/(2*np.pi), disc_tau1, label = ' freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi/(2*np.pi), disc_tau2, label = ' freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi/(2*np.pi), disc_tau3, label = ' freq = ' + str(nu[2]) + ' (GHz)')
plt.title('FFA Optical Depth Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('Optical Depth')
plt.legend()

# %%
#Plotting the optical depth as a function of the orbital phase
plt.plot(phi/(2*np.pi), disc_tau1, label = ' freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi/(2*np.pi), disc_tau2, label = ' freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi/(2*np.pi), disc_tau3, label = ' freq = ' + str(nu[2]) + ' (GHz)')
plt.title('FFA Optical Depth Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('Optical Depth')
plt.yscale('log')
plt.legend()

# %% [markdown]
# # Transmission Factor $e^{-\tau}$ Vs $\phi$

# %%
#Plotting e^(-tau) as a function of the orbital phase
plt.plot(phi/(2*np.pi), np.exp(-disc_tau1), label = ' freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi/(2*np.pi), np.exp(-disc_tau2), label = ' freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi/(2*np.pi), np.exp(-disc_tau3), label = ' freq = ' + str(nu[2]) + ' (GHz)')
plt.title('Disc Transmission Factor e^(-tau) Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('e^(-tau)')
plt.legend()

# %%
#Plotting e^(-tau) as a function of the orbital phase
plt.plot(phi/(2*np.pi), np.exp(-disc_tau1), label = ' freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi/(2*np.pi), np.exp(-disc_tau2), label = ' freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi/(2*np.pi), np.exp(-disc_tau3), label = ' freq = ' + str(nu[2]) + ' (GHz)')
plt.title('Disc Transmission Factor e^(-tau) Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('e^(-tau)')
plt.yscale('log')
plt.legend()

# %% [markdown]
# ## Combined Stellar Wind and Disk

# %% [markdown]
# ## Number Density Vs Line of Sight Distance

# %%
s = np.logspace(np.log10(1e8), np.log10((12 * con.au.cgs).value), 10000)     #Line of sight distance array
i_disc_deg = [60, 65, 70, 75]                                                #Disc inclination in degrees                                                   
i_disc_rad = np.deg2rad(i_disc_deg)                                          #Disc inclination in rad
i_orb_deg = 25                                                               #Orbital inclination in deg
i_orb_rad = np.deg2rad(i_orb_deg)                                            #Orbital inclination in rad
phi_orb_deg =  0                                                             #Orbital phase in degree
phi_orb_rad = np.deg2rad(phi_orb_deg)                                        #Orbital phase in rad
om_deg = 0
om = np.deg2rad(om_deg)
Om_deg = 189
Om = np.deg2rad(Om_deg)

tot_ne1 = tot_num_density(phi=phi_orb_rad, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3,
                          s=s, e=0.87, omega=om, Omega=Om, beta=2, T_disc=1.2e4, beta_disc=3.5, rho0=-12, i_disc=i_disc_rad[0])
tot_ne2 = tot_num_density(phi=phi_orb_rad, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3,
                          s=s, e=0.87, omega=om, Omega=Om, beta=2, T_disc=1.2e4, beta_disc=3.5, rho0=-12, i_disc=i_disc_rad[1])
tot_ne3 = tot_num_density(phi=phi_orb_rad, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3,
                          s=s, e=0.87, omega=om, Omega=Om, beta=2, T_disc=1.2e4, beta_disc=3.5, rho0=-12, i_disc=i_disc_rad[2])
tot_ne4 = tot_num_density(phi=phi_orb_rad, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3,
                          s=s, e=0.87, omega=om, Omega=Om, beta=2, T_disc=1.2e4, beta_disc=3.5, rho0=-12, i_disc=i_disc_rad[3])

#Plotting
plt.plot(s, tot_ne1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg)')
plt.plot(s, tot_ne2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg)')
plt.plot(s, tot_ne3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg)')
plt.plot(s, tot_ne4, label='i disc = ' + str(int(i_disc_deg[3])) + ' (deg)')
plt.title('Total Number Density Vs Line of Sight Distance')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.legend()

# %%
#Plotting
plt.plot(s, tot_ne1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg)')
plt.plot(s, tot_ne2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg)')
plt.plot(s, tot_ne3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg)')
plt.plot(s, tot_ne4, label='i disc = ' + str(int(i_disc_deg[3])) + ' (deg)')
plt.title('Total Number Density Vs Line of Sight Distance')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %% [markdown]
# ## Dispersion Measure Vs Orbital Phase

# %%
#Calculating the DM
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)

tot_DM1 = tot_DM(phi=phi, i=np.deg2rad(25), a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(0), Omega=np.deg2rad(189), beta=2, T_disc=1.2e4, beta_disc=3.5, rho0=-12, i_disc=np.deg2rad(60))
tot_DM2 = tot_DM(phi=phi, i=np.deg2rad(25), a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(0), Omega=np.deg2rad(189), beta=2, T_disc=1.2e4, beta_disc=3.5, rho0=-12, i_disc=np.deg2rad(65))
tot_DM3 = tot_DM(phi=phi, i=np.deg2rad(25), a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(0), Omega=np.deg2rad(189), beta=2, T_disc=1.2e4, beta_disc=3.5, rho0=-12, i_disc=np.deg2rad(70))

#Plotting
plt.plot(phi/(2*np.pi), tot_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg)')
plt.plot(phi/(2*np.pi), tot_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg)')
plt.plot(phi/(2*np.pi), tot_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg)')
plt.title('Total Dispersion Measure Vs Orbital Phase')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %%
#Plotting
plt.plot(phi/(2*np.pi), tot_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg)')
plt.plot(phi/(2*np.pi), tot_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg)')
plt.plot(phi/(2*np.pi), tot_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg)')
plt.title('Total Dispersion Measure Vs Orbital Phase')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.yscale('log')
plt.legend()

# %% [markdown]
# ## Optical Depth Vs Orbital Phase

# %%
#Calculating the optical depth
i_disc_deg = [60, 65, 70]                          #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                #Disc inclinations in rad
nu = [1, 1.5, 2]                                   #Signal frequency in GHz
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)

tot_tau1 = tot_ffa(phi=phi, i=np.deg2rad(25), a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(0), Omega=np.deg2rad(189), beta=2, T_wind=2e4, T_disc=1.2e4, beta_disc=3.5, rho0=-12, i_disc=i_disc_rad[0], nu=nu[0])
tot_tau2 = tot_ffa(phi=phi, i=np.deg2rad(25), a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(0), Omega=np.deg2rad(189), beta=2, T_wind=2e4, T_disc=1.2e4, beta_disc=3.5, rho0=-12, i_disc=i_disc_rad[1], nu=nu[1])
tot_tau3 = tot_ffa(phi=phi, i=np.deg2rad(25), a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(0), Omega=np.deg2rad(189), beta=2, T_wind=2e4, T_disc=1.2e4, beta_disc=3.5, rho0=-12, i_disc=i_disc_rad[2], nu=nu[2])

#Plotting
plt.plot(phi/(2*np.pi), tot_tau1, label=' freq = ' + str(int(nu[0])) + ' (GHz)')
plt.plot(phi/(2*np.pi), tot_tau2, label=' freq = ' + str(int(nu[1])) + ' (GHz)')
plt.plot(phi/(2*np.pi), tot_tau3, label=' freq = ' + str(int(nu[2])) + ' (GHz)')
plt.title('FFA Optical Depth Vs Orbital Phase')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Optical Depth')
plt.legend()

# %%
#Plotting
plt.plot(phi/(2*np.pi), tot_tau1, label=' freq = ' + str(int(nu[0])) + ' (GHz)')
plt.plot(phi/(2*np.pi), tot_tau2, label=' freq = ' + str(int(nu[1])) + ' (GHz)')
plt.plot(phi/(2*np.pi), tot_tau3, label=' freq = ' + str(int(nu[2])) + ' (GHz)')
plt.title('FFA Optical Depth Vs Orbital Phase')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Optical Depth')
plt.yscale('log')
plt.legend()

# %% [markdown]
# ## Transmission Factor $e^{-\tau}$ Vs Orbital Phase

# %%
#Plotting e^(-tau) as a function of the orbital phase
plt.plot(phi/(2*np.pi), np.exp(-tot_tau1), label = ' freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi/(2*np.pi), np.exp(-tot_tau2), label = ' freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi/(2*np.pi), np.exp(-tot_tau3), label = ' freq = ' + str(nu[2]) + ' (GHz)')
plt.title('Total Transmission Factor e^(-tau) Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('e^(-tau)')
plt.legend()

# %%
#Plotting e^(-tau) as a function of the orbital phase
plt.plot(phi/(2*np.pi), np.exp(-tot_tau1), label = ' freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi/(2*np.pi), np.exp(-tot_tau2), label = ' freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi/(2*np.pi), np.exp(-tot_tau3), label = ' freq = ' + str(nu[2]) + ' (GHz)')
plt.title('Total Transmission Factor e^(-tau) Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('e^(-tau)')
plt.yscale('log')
plt.legend()

# %% [markdown]
# # MeerKAT 2024 Periastron Passage

# %%
#Generating the MeerKAT data 
meerkatdata = np.genfromtxt('DM_lit.txt')

# %%
#Seperating the 2024 periastron datapoints
meerkat2024 = meerkatdata[38:109,:]
meerkat2024.shape
# Out:
# (71, 3)

# %%
#Separating the days, DM, and error values
days2024 = meerkat2024[:, 0]
DM2024 = meerkat2024[:, 1]
error2024 = meerkat2024[:, 2]

# %%
#Plotting the data over the entire orbital phase
plt.errorbar(days2024, DM2024,yerr=error2024, fmt='o')
plt.axvline(x=-77, color='magenta', label='pre-periastron crossing')
plt.axvline(x=35, color='purple', label='post-periastron crossing')
plt.title('MeerKAT 2024 Periastron Passage')
plt.xlabel('Days')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.xlim(-618.5, 618.5)
plt.legend()

# %%
#Plotting the data over the data orbital phase
plt.errorbar(days2024, DM2024,yerr=error2024, fmt='o')
plt.axvline(x=-77, color='magenta', label='pre-periastron crossing')
plt.axvline(x=35, color='purple', label='post-periastron crossing')
plt.title('MeerKAT 2024 Periastron Passage')
plt.xlabel('Days')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %% [markdown]
# # Comparing our Model with Results of Past Periastron Passages of PSR B1259-63
# Since most available papers only report $\Delta DM$ - the difference in dispersion measure from periastron, with locations of the pulsar in terms of days from or to periastron, the orbital phases need to be translated as
# ## $\phi = 2\pi(\frac{\Delta t}{P}) = 2\pi(\frac{\Delta t}{1237 days})$

# %%
phi2024 = []

for i in days2024:
    if i < 0:
        phi_min = 2*np.pi*((i)/1237)
        phi2024.append(phi_min)
    if i > 0:
        phi_pl = 2*np.pi*((i)/1237)
        phi2024.append(phi_pl)

# %%
plt.scatter(phi2024, DM2024)
plt.axvline(x=-0.391, color='magenta', label='pre-periastron crossing')
plt.axvline(x=0.177, color='purple', label='post-periastron crossing')
plt.title('MeerKAT 2024 Periastron Passage')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.minorticks_on()
plt.grid(True, which='major', linestyle='-', linewidth=0.7)
plt.grid(True, which='minor', linestyle='--', linewidth=0.4)
plt.xlim(-np.pi, np.pi)
plt.legend()

# %% [markdown]
# # Curvefit Fit

# %%
#Fitting the 2024 data
p0_2024 = [-10, 1000, np.deg2rad(5), np.deg2rad(180), 1, 12000, 3.5, -13, np.deg2rad(60), 146] #Parameter guess values

#Setting lower and upper parameter bounds
lower = [-15, 800, np.deg2rad(0), np.deg2rad(0), 0.5, 9000, 2, -13, np.deg2rad(0), 145]
upper = [-8, 3000, np.deg2rad(120), np.deg2rad(200), 3, 30000, 6, -10, np.deg2rad(90), 146]

#Fitting the model
params_opt, cov = curve_fit(DM_curve_fit, phi2024, DM2024, p0=p0_2024, sigma=error2024, bounds=(lower, upper), maxfev=200000)
print('Fitted Stellar Mass Loss: 1e' + str(params_opt[0]) + ' Solar Mass Per Year')
print('Fitted Wind Terminal Velocity: ' + str(params_opt[1]) + ' km/s')
print('Fitted Argument of Periastron:' + str(np.rad2deg(params_opt[2])) + ' Degrees = ' + str(params_opt[2]) + ' rad')
print('Fitted Longitude of Ascending Node:' + str(np.rad2deg(params_opt[3])) + ' Degrees = ' + str(params_opt[3]) + ' rad')
print('Fitted Wind beta: ' + str(params_opt[4]))
print('Fitted Disc Temperature: ' + str(params_opt[5]) + ' K')
print('Fitted Disc beta: ' + str(params_opt[6]))
print('Fitted Initial Disc Density: 1e' + str(params_opt[7]) + ' gcm^-3')
print('Fitted Disc Inclination:' + str(np.rad2deg(params_opt[8])) + ' Degrees = ' + str(params_opt[8]) + ' rad')
print('Fitted ISM dispersion measure: ' + str(params_opt[9]) + ' pc cm^-3')
# Out:
# Fitted Stellar Mass Loss: 1e-8.920025705342894 Solar Mass Per Year
# Fitted Wind Terminal Velocity: 943.0831858335534 km/s
# Fitted Argument of Periastron:7.177939131878701e-35 Degrees = 1.252786713590268e-36 rad
# Fitted Longitude of Ascending Node:180.27847979596135 Degrees = 3.1464530429296005 rad
# Fitted Wind beta: 0.5000000000000001
# Fitted Disc Temperature: 11415.187697151106 K
# Fitted Disc beta: 5.05349332153398
# Fitted Initial Disc Density: 1e-10.587573660062255 gcm^-3
# Fitted Disc Inclination:86.20187887587161 Degrees = 1.504506607789308 rad
# Fitted ISM dispersion measure: 145.54539476274456 pc cm^-3

# %%
phi_fit_2024 = np.linspace(min(phi2024), max(phi2024), 512)
DM_fit_2024 = DM_curve_fit(phi_fit_2024, *params_opt)

#Plotting the fit  
plt.plot(phi_fit_2024, DM_fit_2024, color='red', label='Fit')
plt.scatter(phi2024, DM2024, color='cyan', label='Data Points')
plt.title('Fitted Dispersion Measure 2024 Periastron Vs Orbital Phase')
plt.xlabel('Orbital phase (rad)')
plt.ylabel('DM (pc cm^-3)')
plt.legend()
plt.show()

# %% [markdown]
# # MCMC Fits
#
# The MCMC code is based on the example provided at https://emcee.readthedocs.io/en/stable/tutorials/line/

# %%
#Fixed parameter values
i = np.deg2rad(25)
a_Rsun = 1345
R_star_sol = 9.2
M_star_sol = 20
Mdot_Msun_per_yr = -8.92
v_0_kms = 5
v_inf_kms = 943
e = 0.87
omega = np.deg2rad(0)
Omega = np.deg2rad(180)
beta = 0.5
rho0 = -10.58
i_disc = np.deg2rad(86.2)
T_disc = 11405
beta_disc = 5.053
ISM_DM = 145.54

# %% [markdown]
# # 2024 Periastron Passage

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %%
#Maximum likelihood function
def log_likelihood3(theta, phi_data, DM_data, DM_err, i, a_Rsun, R_star_sol, M_star_sol, v_0_kms, e):
    '''
    This function calculates the log maximum likelihood for the fitted parameters.
    ------------------------------------------------------------------------------
    parameters:

    theta            [array] -> Fitted parameters
    phi_data         [array] -> Orbital Phase from literature (rad)
    DM_data          [array] -> Dispersion meausre from literature (pccm^-3)
    DM_err           [array] -> Dispersion measure error values from literature (pccm^-3)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    ISM_DM           [float] -> Interstellar medium dispersion measure
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    --------------------------------------------------------------------------------
    Returns:

    The log maximum likelihood for the fitted parameters.
    '''
    
    Mdot_Msun_per_yr, v_inf_kms, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, ISM_DM = theta   #Parameters to fit
    model = tot_DM_mcmc(phi_data, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, 
                   v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, ISM_DM) #Model DM values
    
    #Likelihood calculation
    sigma = DM_err**2
    return -0.5 * np.sum((DM_data - model)**2 / sigma + np.log(sigma))

# %%
#Prior function
def log_prior3(theta):
    '''
    This function calculates the priors.
    -------------------------------------
    parameters:

    theta [array] -> Fitted parameters
    -------------------------------------
    Returns:

    The priors of the fitted parameters.
    '''
    Mdot_Msun_per_yr, v_inf_kms, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, ISM_DM = theta
    if -15 < Mdot_Msun_per_yr < -8 and 100 < v_inf_kms < 2000 and np.deg2rad(0) < omega < np.deg2rad(120) and np.deg2rad(0) < Omega < np.deg2rad(360) and 0.5 < beta < 3 and 9000 < T_disc < 30000 and 2 < beta_disc < 6 and -13 < rho0 < -10 and np.deg2rad(0) < i_disc < np.deg2rad(90) and 144 < ISM_DM < 148:
        return 0.0
    return -np.inf

# %%
#Probability function
def log_probability3(theta, phi_data, DM_data, DM_err, i, a_Rsun, R_star_sol, M_star_sol, v_0_kms, e):
    '''
    This function calcultes the log probability of the fitted parameters.
    ---------------------------------------------------------------------
    parameters:

    theta            [array] -> Fitted parameters
    phi_data         [array] -> Orbital Phase from literature (rad)
    DM_data          [array] -> Dispersion meausre from literature (pccm^-3)
    DM_err           [array] -> Dispersion measure error values from literature (pccm^-3)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    --------------------------------------------------------------------------
    Returns:

    The log probability of the fitted parameters.
    '''
    lp = log_prior3(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood3(theta, phi_data, DM_data, DM_err, i, a_Rsun, R_star_sol, M_star_sol, v_0_kms, e)

# %%
#Computing the maximum likelihood estimates
np.random.seed(42)                                                          #Random seed
nll = lambda *args: -log_likelihood3(*args)                                 #Negative log likelihood
initial_Mdot = -10                                                          #Guess for stellar mass loss
initial_v_inf_kms = 1000                                                    #Guess for wind terminal velocity
initial_omega = np.deg2rad(5)                                               #Guess for argument of periastron
initial_Omega = np.deg2rad(60)                                              #Guess for longitude of ascending node
initial_beta = 1                                                            #Guess for wind beta
initial_T_disc = 12000                                                      #Guess for disc temp
initial_beta_disc = 3.5                                                     #Guess for disc beta
initial_rho0 = -12.169                                                      #Guess for initial disc density
initial_i_disc = np.deg2rad(60)                                             #Guess for disc inclination
initial_ISM_DM = 146                                                        #Guess for ISM DM

initial = np.array([initial_Mdot, initial_v_inf_kms, initial_omega, initial_Omega, initial_beta, initial_T_disc, initial_beta_disc, initial_rho0, initial_i_disc, initial_ISM_DM]) + 0.1 * np.random.randn(10) #Initial guess array
bounds = [(-15, -8), (100, 2000), (np.deg2rad(0), np.deg2rad(120)), (np.deg2rad(0), np.deg2rad(360)), (0.5, 3), (9000, 30000), (2, 6), (-13, -10), (np.deg2rad(0), np.deg2rad(90)), (144, 148)]                #Setting parameter bounds

soln3_2024 = minimize(nll, initial, args=(phi2024, DM2024, error2024, i, a_Rsun, R_star_sol, M_star_sol, v_0_kms, e), bounds=bounds)
Mdot_ml_2024, v_inf_kms_ml_2024, omega_ml_2024, Omega_ml_2024, beta_ml_2024, T_disc_ml_2024, beta_disc_ml_2024, rho0_ml_2024, i_disc_ml_2024, ISM_DM_ml_2024 = soln3_2024.x

print("Maximum likelihood estimates 2024:")
print("Mass loss = {0:.3f}".format(Mdot_ml_2024))
print("Wind terminal velocity = {0:.3f}".format(v_inf_kms_ml_2024))
print("omega = {0:.3f}".format(omega_ml_2024))
print("Omega = {0:.3f}".format(Omega_ml_2024))
print("Wind beta = {0:.3f}".format(beta_ml_2024))
print("Disc temp = {0:.3f}".format(T_disc_ml_2024))
print("Disc beta = {0:.3f}".format(beta_disc_ml_2024))
print("rho0 = {0:.3f}".format(rho0_ml_2024))
print("Disc i = {0:.3f}".format(i_disc_ml_2024))
print("ISM_DM = {0:.3f}".format(ISM_DM_ml_2024))
# Out:
# Maximum likelihood estimates 2024:
# Mass loss = -8.909
# Wind terminal velocity = 999.192
# omega = 0.000
# Omega = 0.144
# Wind beta = 0.500
# Disc temp = 12001.258
# Disc beta = 5.094
# rho0 = -10.550
# Disc i = 1.570
# ISM_DM = 145.579

# %% [markdown]
# ## MCMC for all Parameters

# %%
#Running the MCMC

pos3_2024 = soln3_2024.x + 1e-3 * np.random.randn(32, 10)
nwalkers, ndim = pos3_2024.shape

sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability3, args=(phi2024, DM2024, error2024, i, a_Rsun, R_star_sol, M_star_sol, v_0_kms, e)
)
sampler.run_mcmc(pos3_2024, 5000, progress=True)
# Out:
#   0%|                                                                                         | 0/5000 [00:00<?, ?it/s]C:\Users\david\anaconda3\lib\site-packages\emcee\moves\red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# 100%|██████████████████████████████████████████████████████████████████████████████| 5000/5000 [11:46<00:00,  7.08it/s]
# State([[-8.94300904e+00  8.08021879e+02  4.79324147e-05  1.08553318e-01
#    5.78474231e-01  1.16692297e+04  5.30494499e+00 -1.02223045e+01
#    1.55520817e+00  1.45448969e+02]
#  [-8.85434132e+00  1.13486315e+03  2.15481630e-05  6.16378133e-02
#    5.41986664e-01  1.14816806e+04  5.06334296e+00 -1.05804715e+01
#    1.53358056e+00  1.45582448e+02]
#  [-8.71503012e+00  1.38722990e+03  7.33960454e-05  1.41242832e-01
#    8.01263925e-01  1.20154482e+04  5.23243476e+00 -1.03543437e+01
#    1.56830689e+00  1.45450962e+02]
# ...

# %%
#Positions of each walker as a function of the number of steps in the chain
fig, axes = plt.subplots(10, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["Mdot", "Wind-v", "om", "Om", "beta", "T-disc", "Beta-disc", "rho0", "i-disc", "ISM-DM"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number")
# Out:
# Text(0.5, 0, 'step number')

# %%
#Flat samples
flat_samples = sampler.get_chain(discard=1000, thin=15, flat=True)
print(flat_samples.shape)
# Out:
# (8512, 10)

# %%
#Plotting the corner plot
fig = corner.corner(
    flat_samples, labels=labels, truths=[-10, 1000, np.deg2rad(5), np.deg2rad(180), 1, 12000, 4, -12.169, np.deg2rad(60), 146]
)

# %%
#Best fit results
for i in range(ndim):
    mcmc = np.percentile(flat_samples[:, i], [16, 50, 84])
    q = np.diff(mcmc)
    txt = "\mathrm{{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{{2:.3f}}}"
    txt = txt.format(mcmc[1], q[0], q[1], labels[i])
    display(Math(txt))
# Out:
# $\displaystyle \mathrm{Mdot} = -8.909_{-0.068}^{0.066}$
# $\displaystyle \mathrm{Wind-v} = 999.192_{-130.465}^{154.217}$
# $\displaystyle \mathrm{om} = 0.000_{-0.001}^{0.000}$
# $\displaystyle \mathrm{Om} = 0.089_{-0.064}^{0.055}$
# $\displaystyle \mathrm{beta} = 0.623_{-0.123}^{0.312}$
# $\displaystyle \mathrm{T-disc} = 11988.888_{-746.957}^{58.343}$
# $\displaystyle \mathrm{Beta-disc} = 5.094_{-0.104}^{0.063}$
# $\displaystyle \mathrm{rho0} = -10.550_{-0.133}^{0.100}$
# $\displaystyle \mathrm{i-disc} = 1.546_{-0.029}^{0.024}$
# $\displaystyle \mathrm{ISM-DM} = 145.578_{-0.076}^{0.054}$

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %%
#DM plot with the fitted values

phi = np.linspace(-np.pi, np.pi, 512)
DM_2024 = tot_DM_mcmc(phi=phi, i=np.deg2rad(25), a_Rsun=1345, R_star_sol=9.2, M_star_sol=20, Mdot_Msun_per_yr=-8.909, v_0_kms=5, v_inf_kms=999.192, e=0.87, omega=np.deg2rad(0), Omega=np.deg2rad(5.099), beta=0.623, T_disc=11988, beta_disc=5.094, rho0=-10.55, i_disc=np.deg2rad(88.579), ISM_DM=145.578)

plt.plot(phi, DM_2024, label='MCMC plot')
plt.scatter(phi2024, DM2024, color='r', label='2024 datapoints')
plt.title('MCMC Best Fit Plot Vs 2024 Data Points')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (rad)')
plt.legend()
