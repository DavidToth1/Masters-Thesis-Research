# %% [markdown]
# ## This model features a high mass Be star accelerating wind and circumstellar disc, with an elliptical orbit, a 3D coordinate system, and eclipses of a 'pseudo-signal' from a pulsar on the orbit.
# ## The main goal of this model is to see the number density, dispersion measure, optical depth and spectrum along a line of sight from a point on the orbit given an orbital phase, orbital and disc inclination, eccentricity, argument of periastron and longitude of ascending node.
# ## Stellar parameters are modelled after the star SS 2883 of the HMXB system PSR B1259-63/SS 2883. Wind terminal velocity is taken from the paper - https://arxiv.org/pdf/0806.4868, while the remaining stellar properties are taken from https://ui.adsabs.harvard.edu/abs/2011ApJ...732L..11N/abstract, https://arxiv.org/abs/1307.7083 and https://arxiv.org/pdf/1804.08402.
# ## Parameter values of the disc of SS 2883 are taken from the paper https://arxiv.org/abs/2204.08124

# %% [markdown]
# # Equations and Geometry
# ## Electron number density
# # $n_{e}(r) = \frac{\rho}{\mu_{e}m_{p}} = \frac{\dot{M}}{4\pi\mu_{e}m_{p}r^2v(r)} = \frac{k}{r^2v(r)}$
# Where
# # $\rho = \frac{\dot{M}}{4\pi r^2v(r)}$
#
# And
#
# # $k = \frac{\dot{M}}{4\pi\mu_{e}m_{p}}$
# With
#
# * $\rho$ =      Density
# * $\mu_{e}$ =   Mean molecular weight per free electron (typically set at a value of 1.2)
# * $m_{p}$ =     Proton mass
# * $\dot{M}$ =   Wind mass loss
# * $v(r)$ =     Radial wind velocity
# * $r$ =         radial distance from the center of the star
#
# ## Accelerating Wind ($\beta$ law)
# The wind velocity at a certain distance away from the star is
# # $v(r) = v_0 + (v_{\infty} - v_0)(1-\frac{R_{*}}{r})^\beta$
# with
# * $v_0$ =        The wind velocity at stellar surface
# * $v_{\infty}$ = Wind terminal velocity
# * $R_{*}$ =      Stellar radius
# * $\beta$ =      Wind acceleration exponent
#
# By placing the star and orbit at the xy plane origin, we can consider an elliptical orbit in cartesian coordinates
# # $\frac{x^2}{a^2} + \frac{y^2}{b^2} = 1$
# with
# * $a$ = Semi-major axis
# * $b$ = Semi-minor axis
# The semi-minor axis can be defined as $a\sqrt{1 - e^2}$, where $e^2$ is the eccentricity.
# In polar coordinates, since the ellipse is offset by along the x-axis by the focus - $f = ae$, the coordinates relative to the star are
# ## $x = rcos(\phi) - ae$, $y = bsin(\phi)$, and $r = \sqrt{x^2 + y^2}$
# The orbital separation in polar coordinates becomes
# # $r = \frac{a(1-e^2)}{1+ecos(\phi)}$
# Where $\phi$ is the true anomaly.
# The signal position in polar coordinates is defined as $r_s = r(cos(\phi + \omega),sin(\phi + \omega),0)$, where $\omega$ is the argument of periastron. The observer unit vector (direction of signal to observer) is then defined as $\hat{n} = (sin(i)cos(\Omega), sin(i)sin(\Omega), cos(i))$, where $i$ is the inclination and $\Omega$ is the longitude of ascending node. The radial distance of the signal from the star along the path of the line of sight becomes $r(s) = r_s + s\hat{n}$, where $s\ge0$, is the distance along the line of sight.
#
# The number density at a specific point along the line of sight distance from the orbit can then be described as
# # $n_e(r(s)) = \frac{k}{r(s)^2v(r(s))}$
#
# From the definition of $r(s)$,
#
# ## $r(s)^2 = (r_s + s\hat{n})^2 = r^2 + 2rs [cos(\phi + \omega) sin (i)cos(\Omega) + sin(\phi + \omega)sin(i)sin(\Omega)] + s^2$
#
# ## Dispersion Measure
# # $DM(\phi,i) = \int_{0}^{\infty}n_e(r(s))ds = k\int_{0}^{\infty}\frac{ds}{v(r(s))r(s)^2}$
#
# ## Semi-major axis of PSR B1259-63
# Given that the orbital period of PSR B1259-63 is approximately 1237 days, its mass is $1.4 M_\odot$ and that the mass of SS 2883 is approximately $20 M_\odot$, using Kepler's 3rd law, the semi-major axis is
# # $a^3 = \frac{P^2G(M + m)}{4\pi^2}, a \sim 1345R_\odot$
# With
# * $P$ = Orbital period
# * $G$ = Gravitational constant
# * $M$ = Mass of SS 2883
# * $m$ = Mass of PSR B1259-63
#
# ## Free-free Absorption
# Free-free absorption causes signals to be absorbed by the stellar wind depending on its optical depth.
# # $\tau_{FFA} \approx 8.24x10^{-2}\nu^{-2.1}T_e^{-1.35}\int n_e^2ds$
#
# with
# * $\tau_{FFA}$ = The optical depth
# * $\nu$ = The signal frequency
# * $T_e$ = The stellar wind temperature
# * $n_e$ = The number density
# * $s$ = The line of sight distance
#
# ## Flux density
# The flux density of the pulsar signal is decribed as
# # $S_{\nu} = S_{psr,\nu}e^{-\tau} = \nu^{-p}e^{-\tau}$
# with
# * $S_{psr,\nu}$ = The intrinsic flux of the pulsar
# * $\nu$ = The signal frequency
# * $p$ = The power law index
# * $\tau$ = The optical depth
# When the flux density of the signal is plotted against frequency, it results in the pulsar's spectrum, which changes along eccentric orbits.
#
# ## Be Disc
# Be stars such as SS 2883 have a circumstellar disc due to the star's immense rotation rate. The disc introduces an additional desnity structure to the system, which is described as
# # $\rho(r_{disc}, z) = \rho_0(\frac{r_{disc}}{R_*})^{-\beta}e^{\frac{-z^2}{H(r_{disc})^2}}$
# with
# * $\rho_0$ = The disc desnity at stellar surface
# * $r_{disc}$ = radial distance in the disc plane
# * $R_*$ = Stellar radius
# * $\beta$ = Disc power law exponent
# * $z$ = Height above the disc plane
# * $H(r)$ = Scale height
#
# The scale height is described as
# # $H(r_{disc}) = c_s\sqrt{\frac{r_{disc}}{GM_*}}r_{disc}$
# with
# * $c_s$ = Speed of sound
# * $G$ = Gravitational constant
# * $M_*$ = Stellar mass
#
# And the speed of sound is described as
# # $c_s = \sqrt{\frac{kT}{\mu_em_p}}$
# with
# * $k$ = Boltzmann constant
# * $T$ = Disc temperature
#
# The disc temperature $T$ drops off exponentially further out the disc, and is described as $T = T_{0}(\frac{r_{disc}}{R_*})^{-\alpha}$, where $T_{0}$ is the disc temperature at its innermost radius, and $\alpha$ is the temperature gradient exponent.
#
# Using the disc desnity profile the number density through the disc becomes
# # $n_{e,disc} = \frac{\rho(r_{disc},z)}{\mu_em_p}$
#
# From which the DM and optical depth can be calculated
#
# Placing the disc at the xy plane along with the pulsar orbit allows the radial distance from the pulsar to the observer $r(s)$ serve as the radial distance from the pulsar that passes through the wind to the observer $r(s) = r_{disc}$.
#
# The disc height above its plane is described as $z = r(s)\cdot{\hat{n}_{disc}} = r_s\hat{n}_{disc} + s(\hat{n}\cdot{\hat{n}_{disc}})$. Where an azimuthal component is added to the line of sight unit vector $\hat{n} = (sin(i+\Omega)cos(\Omega), sin(i+\Omega)sin(\Omega), cos(i+\Omega))$, and the disc normal is $\hat{n}_{disc} = (0, sin(i_{disc}), cos(i_{disc}))$, such that the disc rotates on the x-axis.
#
# ## Combined Stellar Wind and Be Disc
# Since the stellar wind and Be disc do not depend on each-other, combining their number densities is straight forward
# # $n_{e,total} = n_{e,wind} + n_{e,disc}$
# With this total number density we can calculate the dispersion measure, optical depth, transmission factor and spectrum of the entire system.
#
# ## Rotation Measure
# The rotation measure shows how much the plane of polarisation of the signal has rotated as a result of traveling through magnetised plasma such as the stellar wind and circumstellar disc. It depends on the number desnity and magnetic field strength along the line of sight. Higher rotation measure occurs when the polarisation rotates more at longer wavelengths, also known as Faraday rotation.
#
# The magnetic field of the star is described as
# # $B = B_0(\frac{R_*}{r(s)})$
#
# With $B_0$, the magnetic field at the stelllar surface assumed to be $0.8 G$ (Johnston et al., 1996 https://ui.adsabs.harvard.edu/abs/1996MNRAS.279.1026J/abstract).
#
# The magnetic field parallel to the line of sight is described as
# # $B_{\parallel} = B(\hat{r}\cdot\hat{n})$
#
# Where $\hat{r} = (cos(\phi + \omega), sin(\phi + \omega), 0)$ is the radial unit vector from the star to the signal source, and $\hat{n} = (sin(i)cos(\Omega), sin(i)sin(\Omega), cos(i))$ is the line of sight unit vector from the signal to the observer.
#
# The rotation measure is described as
# # $\Delta RM = 8.1x10^5 \int_{LOS} n_eB_{\parallel}ds$
# (Melatos et al., 1995, https://academic.oup.com/mnras/article/275/2/381/2896129?login=false)

# %%
#Packages
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import astropy.units as u
import astropy.constants as con
import ipywidgets as widgets
from IPython.display import display
from scipy.optimize import curve_fit
from scipy.signal import find_peaks

# %%
#Constants in cgs units
R_sun_cgs = con.R_sun.cgs.value   #Radius of sun in cgs
M_sun_cgs = con.M_sun.cgs.value   #Mass of the sun in cgs
yr_to_sec = u.yr.to(u.s)          #Year to seconds
kms_cgs = (u.km/u.s).to(u.cm/u.s) #Kms in cgs
m_p_cgs = con.m_p.cgs.value       #Mass of proton in cgs
G_cgs = con.G.cgs.value           #Gravitational constant in cgs   
k_B_cgs = con.k_B.cgs.value       #Boltzmann constant in cgs
AU_cgs = (con.au.cgs.value)       #AU in cgs
pc_to_cm = u.pc.to(u.cm)          #PC to cm

# %%
#Number density function
def num_density(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, s, e, omega, Omega, beta, mu_e=1.2):
    '''This function calculates the number density at a specific point along an elliptical orbit within a spherically cymmetric wind 
    with accelerating velocity.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    mu_e             [float] -> Mean molecular weight per free electron
    e                [float] -> Eccentricity (0 < e < 1)
    s                [float] -> Distance along line of sight from signal (AU)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent 
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the number density [array] -> (cm^-3)'''
    a = a_Rsun * R_sun_cgs                                                                                               #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                                                                                      #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec)                                                                #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                                                                                              #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                                                                                          #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                                                                                    #Calculates the k constant (cm^-1)
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                                 #Calculates the orbital separation along the orbit
    r_s_sqrd = r**2 + 2*r*s*(np.cos(phi+omega)*np.sin(i)*np.cos(Omega)+np.sin(phi+omega)*np.sin(i)*np.sin(Omega)) + s**2 #Calculates the squared radial distance from the star along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                         #Calculates the velocity of the wind 

    n_e = k/(r_s_sqrd*v_r_s)                                                                                             #Calculates the number density
    n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                                                                 #Eclipse condition
     
    return n_e

# %%
#DM function
def dm_beta_wind(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, mu_e=1.2, s_array_cm=None):
    '''This function calculates the dispersion measure along a line of sight, given orbital phase and inclination, 
    assuming a spherically symmetric wind with an accelerating velocity.
    --------------------------------------------------------------------------------------------------------------
    Parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent 
    mu_e             [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the dispersion measure [array] -> (pc cm^-3).'''
    a = a_Rsun * R_sun_cgs                                #Converts the semi-major axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    DM_array = []

    for value in phi:
        r = a * (1 - e**2) / (1 + e * np.cos(value))                                 #Calculates the orbital separation along the orbit
        r_s_sqrd = r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega) +       #Calculates the squared radial distance from the star along the line of sight
                                 np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2
        v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/np.sqrt(r_s_sqrd))**beta           #Calculates the velocity of the wind 
        n_e = k / (r_s_sqrd * v_r_s)                                                 #Calculates the number density
        n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                         #Eclipse condition

        DM_cgs = np.trapz(n_e, s)                                                    #Integrating the DM in cm^-2
        DM = (DM_cgs / pc_to_cm)                                                     #Converting DM to pc cm^3
        DM_array.append(DM)

    return np.array(DM_array)

# %%
#Free-free absorption function
def ffa(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, nu, T, mu_e=1.2, s_array_cm=None):
    '''This function calculates the free-free absorption along a line of sight, given orbital phase and inclination, 
    assuming a spherically symmetric wind with an accelerating velocity.
    --------------------------------------------------------------------------------------------------------------
    Parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    nu               [float] -> Signal frequency (GHz)
    T                [float] -> Stellar wind temperature (K)
    mu_e             [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array].'''
    a = a_Rsun * R_sun_cgs                                #Converts the semi-major axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    tau_array = []

    for value in phi:
        r = a * (1 - e**2) / (1 + e * np.cos(value))                                 #Calculates the orbital separation along the orbit
        r_s_sqrd = r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega) +       #Calculates the squared radial distance from the star along the line of sight
                                 np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2
        v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/np.sqrt(r_s_sqrd))**beta           #Calculates the velocity of the wind 
        n_e = k / (r_s_sqrd * v_r_s)                                                 #Calculates the number density
        n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                         #Eclipse condition

        tau = 8.24e-2*nu**-2.1*T**-1.35*np.trapz(n_e**2, s / pc_to_cm)               #Integrating the optical depth
        tau_array.append(tau)

    return np.array(tau_array)

# %%
#Flux density function
def spectrum(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, nu, T, p, mu_e=1.2, s_array_cm=None):
    '''This function calculates the spectrum of the pulsar for a given inclination and frequency along the orbit.
    -------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    nu               [float] -> Signal frequency (GHz)
    T                [float] -> Stellar wind temperature (K)
    p                [float] -> Power law exponent
    mu_e             [float] -> Mean molecular weight per free electron
    
    -------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the pulsar spectrum [array] (Jy)'''
    a = a_Rsun * R_sun_cgs                                #Converts the semi-major axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a flux density array
    S_nu_array = []

    for value in phi:
        for freq in nu:
            r = a * (1 - e**2) / (1 + e * np.cos(value))                                 #Calculates the orbital separation along the orbit
            r_s_sqrd = r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega) +       #Calculates the squared radial distance from the star along the line of sight
                                     np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2
            v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/np.sqrt(r_s_sqrd))**beta           #Calculates the velocity of the wind 
            n_e = k / (r_s_sqrd * v_r_s)                                                 #Calculates the number density
            n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                         #Eclipse condition

            tau = 8.24e-2*freq**-2.1*T**-1.35*np.trapz(n_e**2, s / pc_to_cm)             #Integrating the optical depth
            S_nu = freq**(-p)*np.exp(-tau)                                               #Calculating the flux density
            S_nu_array.append(S_nu)
    S_nu_2D = np.array(S_nu_array).reshape(len(phi), len(nu))                            #Reshaping to a 2D array
    return S_nu_2D

# %%
#Disc number density function
def disc_ne(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, s, alpha, mu_e=1.2):
    '''This function calculates the number density along the line of sight from the
    pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Argument of periastron (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    s          [array] -> Array of line of sight points (cm)
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the number desnity [array] (cm^-3)'''
    a = a_Rsun * R_sun_cgs               #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs      #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs      #Converts the stellar mass from solar mass to g
    r = a*(1 - e**2)/(1 + e*np.cos(phi)) #Calculates the orbital separation along the orbit

    r_disc = np.sqrt(r**2 + 2*r*s*(np.cos(phi+omega)*np.sin(i)*np.cos(Omega)+np.sin(phi+omega)*np.sin(i)*np.sin(Omega)) + s**2) #Projected radius through disc plane   
    c_s = np.sqrt((k_B_cgs * T*(r_disc/R_star)**(-alpha))/(mu_e * m_p_cgs))                                                     #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                                   #Calculates the scale height
    z = r*np.sin(phi+omega)*np.sin(i_disc) + s*(np.sin(i+Omega)*np.sin(Omega)*np.sin(i_disc) + np.cos(i+Omega)*np.cos(i_disc))  #Calculates the height above the disc plane
    rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                                   #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                                         #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                                                                                #Constraining the inner disc radius

    return ne_disc

# %%
#Disc dispersion measure function
def disc_DM(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, alpha, mu_e=1.2, s_array_cm=None):
    '''This function calculates dispersion measure along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the dispersion measure [array] (pc cm^-3)'''
    a = a_Rsun * R_sun_cgs          #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs #Converts the stellar mass from solar mass to g

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    disc_DM_array = []

    for value in phi:
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                          #Calculates the orbital separation along the orbit
        r_disc = np.sqrt(r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega)+np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2) #Projected radius through disc plane        
        c_s = np.sqrt((k_B_cgs * T*(r_disc/R_star)**(-alpha))/(mu_e * m_p_cgs))                                                         #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                                       #Calculates the scale height
        z = r*np.sin(value+omega)*np.sin(i_disc) + s*(np.sin(i+Omega)*np.sin(Omega)*np.sin(i_disc) + np.cos(i+Omega)*np.cos(i_disc))    #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                                       #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                                             #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                                    #Constraining the inner disc radius


        disc_DM_cgs = np.trapz(ne_disc, s)                                                                                              #Integrating the DM in cm^-2
        disc_DM = (disc_DM_cgs / pc_to_cm)                                                                                              #Converting DM to pc cm^3
        disc_DM_array.append(disc_DM)

    return np.array(disc_DM_array)

# %%
#Disc free-free absorption function
def disc_ffa(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, nu, alpha, mu_e=1.2, s_array_cm=None):
    '''This function calculates optical depth along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    nu         [float] -> Signal frequency (GHz)
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array]'''
    a = a_Rsun * R_sun_cgs          #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs #Converts the stellar mass from solar mass to g

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    disc_tau_array = []
    
    for value in phi:
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                          #Calculates the orbital separation along the orbit
        r_disc = np.sqrt(r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega)+np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2) #Projected radius through disc plane         
        c_s = np.sqrt((k_B_cgs * T*(r_disc/R_star)**(-alpha))/(mu_e * m_p_cgs))                                                         #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                                       #Calculates the scale height
        z = r*np.sin(value+omega)*np.sin(i_disc) + s*(np.sin(i+Omega)*np.sin(Omega)*np.sin(i_disc) + np.cos(i+Omega)*np.cos(i_disc))    #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                                       #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                                             #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                                    #Constraining the inner disc radius


        disc_tau = 8.24e-2*nu**(-2.1)*T**(-1.35)*np.trapz(ne_disc**2, s / pc_to_cm)                                                     #Integrating tau
        disc_tau_array.append(disc_tau)

    return np.array(disc_tau_array)

# %%
#Disc flux density function
def disc_spectrum(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, nu, p, alpha, mu_e=1.2, s_array_cm=None):
    '''This function calculates optical depth along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    nu         [float] -> Signal frequency (GHz)
    p          [float] -> Power law exponent
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array]'''
    a = a_Rsun * R_sun_cgs          #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs #Converts the stellar mass from solar mass to g
    
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    disc_S_nu_array = []
    
    for value in phi:
        for freq in nu:
            r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                          #Calculates the orbital separation along the orbit
            r_disc = np.sqrt(r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega)+np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2) #Projected radius through disc plane             
            c_s = np.sqrt((k_B_cgs * T*(r_disc/R_star)**(-alpha))/(mu_e * m_p_cgs))                                                         #Calculates the disc speed of sound
            H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                                       #Calculates the scale height
            z = r*np.sin(value+omega)*np.sin(i_disc) + s*(np.sin(i+Omega)*np.sin(Omega)*np.sin(i_disc) + np.cos(i+Omega)*np.cos(i_disc))    #Calculates the height above the disc plane
            rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                                       #Calculates the disc desnity profile
            ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                                             #Calculates the number density
            ne_disc[r_disc < R_star] = 0                                                                                                    #Constraining the inner disc radius


            disc_tau = 8.24e-2*freq**(-2.1)*T**(-1.35)*np.trapz(ne_disc**2, s / pc_to_cm)                                                   #Integrating tau
            disc_S_nu = freq**(-p)*np.exp(-disc_tau)                                                                                        #Calculatinng the flux density
            disc_S_nu_array.append(disc_S_nu)
    disc_S_nu_2D = np.array(disc_S_nu_array).reshape(len(phi), len(nu))                                                                     #Reshaping to a 2D array
    return np.array(disc_S_nu_2D)

# %%
#Total wind-disc number density function
def tot_num_density(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, s, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, alpha, mu_e=1.2):
    '''This function calculates the total number density at a specific point along an elliptical orbit within a spherically cymmetric wind 
    with accelerating velocity and an axisymmetric disc.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    s                [float] -> Distance along line of sight from signal (AU)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total number density [array] -> (cm^-3)'''
    #Stellar wind number density
    a = a_Rsun * R_sun_cgs                                                                                               #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                                                                                      #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec)                                                                #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                                                                                              #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                                                                                          #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                                                                                    #Calculates the k constant (cm^-1)
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                                 #Calculates the orbital separation along the orbit
    r_s_sqrd = r**2 + 2*r*s*(np.cos(phi+omega)*np.sin(i)*np.cos(Omega)+np.sin(phi+omega)*np.sin(i)*np.sin(Omega)) + s**2 #Calculates the squared radial distance from the star along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                         #Calculates the velocity of the wind 
    n_e = k/(r_s_sqrd*v_r_s)                                                                                             #Calculates the number density
    n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                                                                 #Eclipse condition
    
    #Disc number density
    M_star = M_star_sol * M_sun_cgs                                                                                            #Converts the stellar mass from solar mass to g
    r_disc = np.sqrt(r_s_sqrd)                                                                                                 #Projected radius through disc plane   
    c_s = np.sqrt((k_B_cgs * T_disc*(r_disc/R_star)**(-alpha))/(mu_e * m_p_cgs))                                               #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                                  #Calculates the scale height
    z = r*np.sin(phi+omega)*np.sin(i_disc) + s*(np.sin(i+Omega)*np.sin(Omega)*np.sin(i_disc) + np.cos(i+Omega)*np.cos(i_disc)) #Calculates the height above the disc plane
    rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                             #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                                        #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                                                                               #Constraining the inner disc radius

    #Total number density
    total_ne = n_e + ne_disc

    return total_ne

# %%
#Total wind-disc dispersion measure function
def tot_DM(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, alpha, mu_e=1.2, s_array_cm=None):
    '''This function calculates the dispersion measure along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total dispersion measure [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_DM_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        r_s_sqrd = r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega)+np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2 #Calculates the squared radial distance from the star along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                             #Calculates the velocity of the wind 
        n_e = k/(r_s_sqrd*v_r_s)                                                                                                 #Calculates the number density
        n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                                                                     #Eclipse condition
    
        #Disc number density
        r_disc = np.sqrt(r_s_sqrd)                                                                                                   #Projected radius through disc plane   
        c_s = np.sqrt((k_B_cgs * T_disc*(r_disc/R_star)**(-alpha))/(mu_e * m_p_cgs))                                                 #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                                    #Calculates the scale height
        z = r*np.sin(value+omega)*np.sin(i_disc) + s*(np.sin(i+Omega)*np.sin(Omega)*np.sin(i_disc) + np.cos(i+Omega)*np.cos(i_disc)) #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                               #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                                          #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                                 #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_DM_cgs = np.trapz(total_ne, s) #Integrating the DM in cm^-2
        total_DM = (total_DM_cgs / pc_to_cm) #Converting DM to pc cm^3
        tot_DM_array.append(total_DM)

    return np.array(tot_DM_array)

# %%
#Total wind-disc free-free absorption function
def tot_ffa(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_wind, T_disc, beta_disc, rho0, i_disc, nu, alpha, mu_e=1.2, s_array_cm=None):
    '''This function calculates the optical depth along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    T_wind           [float] -> Temperature of wind (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    nu               [float] -> Signal frequency (GHz)
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total optical depth [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_tau_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        r_s_sqrd = r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega)+np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2 #Calculates the squared radial distance from the star along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                             #Calculates the velocity of the wind 
        n_e = k/(r_s_sqrd*v_r_s)                                                                                                 #Calculates the number density
        n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                                                                     #Eclipse condition
    
        #Disc number density
        r_disc = np.sqrt(r_s_sqrd)                                                                                                   #Projected radius through disc plane   
        c_s = np.sqrt((k_B_cgs * T_disc*(r_disc/R_star)**(-alpha))/(mu_e * m_p_cgs))                                                 #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                                    #Calculates the scale height
        z = r*np.sin(value+omega)*np.sin(i_disc) + s*(np.sin(i+Omega)*np.sin(Omega)*np.sin(i_disc) + np.cos(i+Omega)*np.cos(i_disc)) #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                               #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                                          #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                                 #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_tau = 8.24e-2*nu**(-2.1)*((T_wind+T_disc)/2)**(-1.35)*np.trapz(total_ne**2, s / pc_to_cm) #Integrating the optical depth
        tot_tau_array.append(total_tau)

    return np.array(tot_tau_array)

# %%
#Total wind-disc flux density function
def tot_spectrum(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_wind, T_disc, beta_disc, rho0, i_disc, nu, p, alpha, mu_e=1.2, s_array_cm=None):
    '''This function calculates the flux density along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    T_wind           [float] -> Temperature of wind (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    nu               [float] -> Signal frequency (GHz)
    p                [float] -> Spectrum power law exponent
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total flux density [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_S_nu_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        for freq in nu:
            #Stellar wind number density
            r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
            r_s_sqrd = r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega)+np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2 #Calculates the squared radial distance from the star along the line of sight
            v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                             #Calculates the velocity of the wind 
            n_e = k/(r_s_sqrd*v_r_s)                                                                                                 #Calculates the number density
            n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                                                                     #Eclipse condition
    
            #Disc number density
            r_disc = np.sqrt(r_s_sqrd)                                                                                                   #Projected radius through disc plane   
            c_s = np.sqrt((k_B_cgs * T_disc*(r_disc/R_star)**(-alpha))/(mu_e * m_p_cgs))                                                 #Calculates the disc speed of sound
            H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                                    #Calculates the scale height
            z = r*np.sin(value+omega)*np.sin(i_disc) + s*(np.sin(i+Omega)*np.sin(Omega)*np.sin(i_disc) + np.cos(i+Omega)*np.cos(i_disc)) #Calculates the height above the disc plane
            rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                               #Calculates the disc desnity profile
            ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                                          #Calculates the number density
            ne_disc[r_disc < R_star] = 0                                                                                                 #Constraining the inner disc radius

            #Total number density
            total_ne = n_e + ne_disc

            total_tau = 8.24e-2*freq**(-2.1)*((T_wind+T_disc)/2)**(-1.35)*np.trapz(total_ne**2, s / pc_to_cm) #Integrating the DM in cm^-2
            total_S_nu = freq**(-p)*np.exp(-total_tau)                                                        #Calculatinng the flux density
            tot_S_nu_array.append(total_S_nu)
        
    tot_S_nu_2D = np.array(tot_S_nu_array).reshape(len(phi), len(nu))                                         #Reshaping to a 2D array
    return np.array(tot_S_nu_2D)

# %%
#Total rotation measure
def tot_RM(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, alpha, mu_e=1.2, s_array_cm=None):
    '''
    This function calculates the rotation measure of the signal through the stellar wind and circumstellar disc.
    ------------------------------------------------------------------------------------------------------------
    Parameters:

    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total rotation measure of the signal [array] -> (rad cm^-2).
    '''
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an RM array
    tot_RM_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = (M_star_sol * M_sun_cgs)                     #Converts the stellar mass from solar mass to g
    B0 = 0.8                                              #Magnetic field at the stellar surface in G

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        r_s_sqrd = r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega)+np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2 #Calculates the squared radial distance from the star along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                             #Calculates the velocity of the wind 
        n_e = k/(r_s_sqrd*v_r_s)                                                                                                 #Calculates the number density
        n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                                                                     #Eclipse condition
    
        #Disc number density
        r_disc = np.sqrt(r_s_sqrd)                                                                                                   #Projected radius through disc plane   
        c_s = np.sqrt((k_B_cgs * T_disc*(r_disc/R_star)**(-alpha))/(mu_e * m_p_cgs))                                                 #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                                    #Calculates the scale height
        z = r*np.sin(value+omega)*np.sin(i_disc) + s*(np.sin(i+Omega)*np.sin(Omega)*np.sin(i_disc) + np.cos(i+Omega)*np.cos(i_disc)) #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                               #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                                          #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                                 #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        #Wind magnetic field
        B = B0 * (R_star/np.sqrt(r_s_sqrd))                                                                          #Total magnetic field
        B_parallel = B * (np.sin(i)*np.cos(Omega)*np.cos(value+omega) + np.sin(i)*np.sin(Omega)*np.sin(value+omega)) #Magnetic field parallel to line of sight
        RM_integrand = total_ne*B_parallel

        total_RM_cgs = 8.1e5 * np.trapz(RM_integrand, s / pc_to_cm)  #Integrating the RM in rad m^-2
        tot_RM_array.append(total_RM_cgs)

    return np.array(tot_RM_array)

# %%
#Curve_fit DM function
def DM_curve_fit(phi, i_orb, Mdot, omega, Omega, rho0, i_disc, e):
    '''
    This function employs scipy's curve_fit by implementing the general tot_DM function.
    -------------------------------------------------------------------------------------
    Parameters:

    phi    [array] -> Orbital Phase (rad)
    i_orb  [float] -> Orbital Inclination (rad)
    Mdot   [float] -> Log stellar Mass Loss (solar mass per year)
    e      [float] -> Eccentricity
    omega  [float] -> Argument of Periastron (rad)
    Omega  [float] -> Longitude of Ascending Node (rad)
    rho0   [float] -> Log initial Disc Density (gcm^-3)
    i_disc [float] -> Disc Inclination (rad)
    --------------------------------------------------------------------------------------
    Returns:

    The dipersion measure curve fit.
    '''
    #Fixing the remaining parameters of the model
    a_Rsun_fixed = 1091
    R_star_sol_fixed = 6
    M_star_sol_fixed = 10
    v_0_kms_fixed = 5
    v_inf_kms_fixed = 1e3
    beta_fixed = 2
    T_disc_fixed = 1.2e4
    beta_disc_fixed = 4
    alpha_fixed = 0.5

    return tot_DM(phi, i_orb, a_Rsun_fixed, R_star_sol_fixed, M_star_sol_fixed, Mdot, v_0_kms_fixed, v_inf_kms_fixed, e, omega, Omega, beta_fixed, T_disc_fixed, beta_disc_fixed, rho0, i_disc, alpha_fixed)

# %%
#Wind only curve_fit DM function
def wind_only_DM_fit(phi, i_orb, Mdot, omega, Omega):
    '''
    This function employs scipy's curve_fit by implementing the general dm_beta_wind function.
    -------------------------------------------------------------------------------------
    Parameters:

    phi    [array] -> True Anomaly (rad)
    i_orb  [float] -> Orbital Inclination (rad)
    Mdot   [float] -> Log stellar Mass Loss (solar mass per year)
    e      [float] -> Eccentricity
    omega  [float] -> Argument of Periastron (rad)
    Omega  [float] -> Longitude of Ascending Node (rad)
    --------------------------------------------------------------------------------------
    Returns:

    The dipersion measure curve fit from the wind model only.
    '''
    #Fixing the remaining parameters of the model
    a_Rsun_fixed = 1091
    R_star_sol_fixed = 6
    v_0_kms_fixed = 10
    v_inf_kms_fixed = 1e3
    beta_fixed = 2
    e_fixed = 0.87

    return dm_beta_wind(phi, i_orb, a_Rsun_fixed, R_star_sol_fixed, Mdot, v_0_kms_fixed, v_inf_kms_fixed, e_fixed, omega, Omega, beta_fixed)

# %% [markdown]
# # Number Density

# %%
#Calculating the number density along the line of sight
i_deg = [25, 45, 60, 90]                                                                  #Inclinations in degrees
i = np.deg2rad(i_deg)                                                                     #Converting the inclinations to rad
phi_deg = [50, 150, 200, 250]                                                             #Orbital phases in degrees
phi = np.deg2rad(phi_deg)                                                                 #Converting the orbital phases to rad
om = np.deg2rad(138)                                                                      #Argument of periastron deg->rad
Om = np.deg2rad(189)                                                                      #Longitude of ascending node deg->rad
s = np.logspace(np.log10(1e12), np.log10((12 * con.au.cgs).value), 512)                    #Line of sight distance array
n_e1 = num_density(phi[0], i[0], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                   v_0_kms=5, v_inf_kms=1e3, s=s, e=0.87, omega=om, Omega=Om, beta=2)     #Number densities
n_e2 = num_density(phi[1], i[1], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                   v_0_kms=5, v_inf_kms=1e3, s=s, e=0.87, omega=om, Omega=Om, beta=2)
n_e3 = num_density(phi[2], i[2], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                   v_0_kms=5, v_inf_kms=1e3, s=s, e=0.87, omega=om, Omega=Om, beta=2)
n_e4 = num_density(phi[3], i[3], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                   v_0_kms=5, v_inf_kms=1e3, s=s, e=0.87, omega=om, Omega=Om, beta=2)

# %% [markdown]
# When plotting the number density as a function of line of sight distance, it is important to revisit the squared radial distance from the star along the line of sight:
# ## $r(s)^2 = (r_s + s\hat{n})^2 = r^2 + 2rs [cos(\phi + \omega) sin (i)cos(\Omega) + sin(\phi + \omega)sin(i)sin(\Omega)] + s^2$
# As we can see, when
# ## $r >> s$, $r(s)^2 \approx r^2$
# so
# ## $n_e(r(s)) \approx \frac{k}{r^2} = const$
# Therefore, we can only start seeing a power law relation when
# ## $r \sim s$

# %%
#Plotting the number density as a function of line of sight distance
plt.plot(s, n_e1, label = 'i = ' + str(i_deg[0]) + ', phi = ' + str(phi_deg[0]) + ' (deg)')
plt.plot(s, n_e2, label = 'i = ' + str(i_deg[1]) + ', phi = ' + str(phi_deg[1]) + ' (deg)')
plt.plot(s, n_e3, label = 'i = ' + str(i_deg[2]) + ', phi = ' + str(phi_deg[2]) + ' (deg)')
plt.plot(s, n_e4, label = 'i = ' + str(i_deg[3]) + ', phi = ' + str(phi_deg[3]) + ' (deg)')
plt.title('Number Density Vs Line of Sight Distance')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %% [markdown]
# # Number Density Vs Line of Sight Distance GIF

# %%
phi_deg_array = np.linspace(0, 360, 180)   #Orbital phases in deg
phi_array = np.deg2rad(phi_deg_array)      #Orbital phases in rad
i_gif_deg = 25                             #Inclination in deg
i_gif = np.deg2rad(i_gif_deg)              #Inclination in rad

#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1e12, (12 * con.au.cgs).value)
ax.set_ylim(1e2, 1e8) 
ax.set_xlabel('Line of Sight Distance (cm)')
ax.set_ylabel('Number Density (cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    phi = phi_array[frame]
    n_e = num_density(phi, i_gif, a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                      v_0_kms=5, v_inf_kms=1e3, s=s, e=0.87, omega=om, Omega=Om, beta=2)
    line.set_data(s, n_e)
    title.set_text('Number Density Vs LoS Distance, i = ' + str(int(i_gif_deg)) + ' (deg) \nphi = ' + str(int(phi_deg_array[frame])) + ' deg')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(phi_array), blit=False, interval=100)
#Saving GIF
ani.save("num_density_evolution.gif", writer="pillow", fps=10)
plt.show()

# %% [markdown]
# # Interactive Number Density Vs Line of Sight Distance Widget

# %%
#Orbital phase slider
phi_slider = widgets.IntSlider(
    value=0,
    min=0,
    max=360,
    step=1,
    description='Phi (deg)',
    continuous_update=True,
    layout=widgets.Layout(width='80%')
)

#Interactive plotting function
def plot_n_e(phi_deg):
    phi_rad = np.deg2rad(phi_deg)
    n_e_plot = num_density(phi_rad, i_gif, a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                           v_0_kms=5, v_inf_kms=1e3, s=s, e=0.87, omega=om, Omega=Om, beta=2) #Number density
    
    plt.plot(s, n_e_plot)
    plt.title('Number Density Vs Line of Sight Distance, i = ' + str(int(i_gif_deg)) + ' (deg)\nat Orbital Phase = ' + str(int(phi_deg))+ ' deg')
    plt.xlabel('Line of Sight Distance (cm)')
    plt.ylabel('Number Density (cm^-3)')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(1e12, (3 * con.au.cgs).value)
    plt.show()

#Linking slider to plot function
widgets.interact(plot_n_e, phi_deg=phi_slider)
# Out:
# interactive(children=(IntSlider(value=0, description='Phi (deg)', layout=Layout(width='80%'), max=360), Output…
# <function __main__.plot_n_e(phi_deg)>

# %% [markdown]
# # Eclipsing Cases of Orbital Phases
#
# Even at an orbital inclination of $i = 90^\circ$, there are no eclipsing cases for the signal.

# %%
i_deg_ec_sig = 90                       #Eclipsing inclination in deg
i_ec_sig = np.deg2rad(i_deg_ec_sig)     #Eclipsing inclination in rad
phi_deg_ec_sig = 231                    #Eclipsing orbital phase in deg
phi_ec_sig = np.deg2rad(phi_deg_ec_sig) #Eclipsing orbital phase in rad

n_e_ec_sig = num_density(phi_ec_sig, i_ec_sig, a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                   v_0_kms=5, v_inf_kms=1e3, s=s, e=0.87, omega=om, Omega=Om, beta=2)           #Number density

#Plotting
plt.plot(s, n_e_ec_sig, label = 'i = ' + str(i_deg_ec_sig) + ', phi = ' + str(phi_deg_ec_sig) + ' (deg)')
plt.title('Number Density Vs Line of Sight Distance')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.xscale('log')
plt.yscale('log')
plt.xlim(1e12, 4.5e13)
plt.legend()

# %% [markdown]
# # Dispersion Measure

# %%
#Calculating the DM
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                              #Orbital phase array in rad (redundancy removed)
DM1 = dm_beta_wind(phi, i[0], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                  v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=om, Omega=Om, beta=2) #Dispersion measure
DM2 = dm_beta_wind(phi, i[1], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                  v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=om, Omega=Om, beta=2)
DM3 = dm_beta_wind(phi, i[2], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                  v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=om, Omega=Om, beta=2)

# %%
#Plotting the DM as a function of the orbital phase
plt.plot(phi, DM1, label = 'i = ' + str(i_deg[0]) + ' (deg)')
plt.plot(phi, DM2, label = 'i = ' + str(i_deg[1]) + ' (deg)')
plt.plot(phi, DM3, label = 'i = ' + str(i_deg[2]) + ' (deg)')
plt.title('Dispersion Measure Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %%
#Plotting the DM as a function of the orbital phase
plt.plot(phi/(2*np.pi)*1237, DM1, label = 'i = ' + str(i_deg[0]) + ' (deg)')
plt.plot(phi/(2*np.pi)*1237, DM2, label = 'i = ' + str(i_deg[1]) + ' (deg)')
plt.plot(phi/(2*np.pi)*1237, DM3, label = 'i = ' + str(i_deg[2]) + ' (deg)')
plt.title('Dispersion Measure Vs Time')
plt.xlabel('Time From Periastron (Days)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %% [markdown]
# # Consistency Check
# For parameter values relevant to 1994 papers, Simon Johnston et al. find the dispersion measure of PSR B1259-63 to be in the range of 146 - 158 $pc cm^{-3}$ around periastron (including the ISM DM value of 146.7 $pc cm^{-3}$). https://academic.oup.com/mnras/article/279/3/1026/967531

# %%
#Calculating the DM
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                                  #Orbital phase array in rad (redundancy removed)
DM_1994 = dm_beta_wind(phi, i=np.deg2rad(35), a_Rsun=1091, R_star_sol=6, Mdot_Msun_per_yr=-9,
                  v_0_kms=5, v_inf_kms=1000, e=0.9, omega=om, Omega=Om, beta=2)     #Dispersion measure

# %%
#Plotting the DM as a function of the orbital phase
plt.plot(phi, DM_1994, label = 'i = 35 (deg)')
plt.title('Dispersion Measure Vs Orbital Phase 1994')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %%
#Plotting the DM as a function of the orbital phase
plt.plot(phi/(2*np.pi)*1237, DM_1994, label = 'i = 35 (deg)')
plt.title('Dispersion Measure Vs Time 1994')
plt.xlabel('Time From Periastron (Days)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %% [markdown]
# # Free-free Absorption

# %%
#Calculating the optical depth
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                                                   #Orbital phase array in rad (redundancy removed)
nu = [1.5, 1.75, 2]                                                                                  #Signal frequency in GHz
tau1 = ffa(phi, i[0], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                  v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=om, Omega=Om, beta=2, nu=nu[0], T=2e4)     #Optical depth
tau2 = ffa(phi, i[1], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                  v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=om, Omega=Om, beta=2, nu=nu[1], T=2e4)
tau3 = ffa(phi, i[2], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                  v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=om, Omega=Om, beta=2, nu=nu[2], T=2e4)

# %%
#Plotting the optical depth as a function of the orbital phase
plt.plot(phi, tau1, label = 'i = ' + str(i_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, tau2, label = 'i = ' + str(i_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, tau3, label = 'i = ' + str(i_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('FFA Optical Depth Vs True Anomaly')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('Optical Depth')
plt.legend()

# %%
#Plotting the optical depth as a function of the orbital phase
plt.plot(phi/(2*np.pi)*1237, tau1, label = 'i = ' + str(i_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi/(2*np.pi)*1237, tau2, label = 'i = ' + str(i_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi/(2*np.pi)*1237, tau3, label = 'i = ' + str(i_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('FFA Optical Depth Vs Time')
plt.xlabel('Time From Periastron (Days)')
plt.ylabel('Optical Depth')
plt.legend()

# %% [markdown]
# # Transmission factor $e^{-\tau}$ Vs $\phi$
#
# The transmission factor $e^{-\tau}$ shows how much the flux at a given frequency is actually suppressed. It is the fraction of radiation that survives after passing though the stellar wind material with a certain optical depth.

# %%
#Plotting e^(-tau) as a function of the orbital phase
plt.plot(phi, np.exp(-tau1), label = 'i = ' + str(i_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, np.exp(-tau2), label = 'i = ' + str(i_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, np.exp(-tau3), label = 'i = ' + str(i_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('Transmission Factor e^(-tau) Vs True Anomaly')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('e^(-tau)')
plt.ylim(0.995, 1)
plt.yscale('log')
plt.legend()

# %% [markdown]
# # Pulsar Spectrum Evolution Along the Orbit GIF

# %%
phi_deg_array = np.linspace(0, 360, 180)   #Orbital phases in deg
phi_array = np.deg2rad(phi_deg_array)      #Orbital phases in rad
i_gif = np.deg2rad(i_gif_deg)              #Inclination in rad
nu_array = np.linspace(1, 8.4, 512)        #Frequency array

#Computing the spectra for all orbital phases
S_nu = spectrum(phi=phi_array, i=i_gif, a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=-9,
                v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=om, Omega=Om, beta=2, nu=nu_array, T=2e4, p=1.3)         

#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1, 8.4)
ax.set_ylim(1e-5, 1)
ax.set_xlabel('Frequency (GHz)')
ax.set_ylabel('Flux density (Jy)')
title = ax.set_title('')

#Frame update function
def update(frame):
    line.set_data(nu_array, S_nu[frame, :])
    title.set_text('Spectrum Evolution at Inclination i = ' + str(int(i_gif_deg)) + '(deg)\n at Orbital Phase = ' + str(int(phi_deg_array[frame])) + ' deg')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(phi_array), blit=False, interval=100)
#Saving GIF
ani.save("spectrum_evolution.gif", writer="pillow", fps=10)
plt.show()

# %% [markdown]
# # Be Disc

# %% [markdown]
# ## Be Disc Mass
# As a preliminary step of analysing the Be disc it is important to check its total mass.
#
# Using the definition of density
# ## $\rho = \frac{dM}{dV} \to dM = \rho dV \to M = \int \rho dV$
#
# With
# * $M$ = Disc mass
# * $V$ = Disc volume
#
# For discs, $dV = rdrd\phi dz$
# With
# * $dr$ = Radial change
# * $d\phi$ = Angular change
# * $dz$ = Vertical change
#
# Since $\int_0^{2\pi} rd\phi = 2\pi r$, we end up with
#
# ## $M = 2\pi \int_{R_*}^{R_{out}} \int_{-\infty}^{\infty} \rho_0 (\frac{r}{R_*})^{-\beta} e^{\frac{-z^2}{H_{r}^2}} dzdr$
# With
# * $R_*$ = Stellar radius
# * $R_{out}$ = Outer radius of disc
#
# Using the gaussian integral $\int_{-\infty}^{\infty} e^{-ax^2} = \sqrt{\frac{\pi}{a}}$, the integral of the vertical change becomes
#
# ## $\int_{-\infty}^{\infty} e^{\frac{-z^2}{H_{r}^2}}dz = \sqrt{\pi}H_{r}$
# The final expression of the disc mass is
#
# ## $M = 2\pi^{1.5} \rho_0 \int_{R_*}^{R_out} (\frac{r}{R_*})^{-\beta} H_r r dr$

# %%
#Disc mass function
def discmass(R_star_sol, R_out_sol, M_star_sol, T_disc, beta_disc, rho0, mu_e=1.2):
    ''' This function calculates the mass of a circumstellar disc.
    ----------------------------------------------------------------
    Parameters:

    R_star_sol [float] -> #Stellar radius in solar radii (cm)
    R_out_sol  [float] -> #Disc outer radius in solar radii (cm)
    M_star_sol [float] -> #Stellar mass in solar mass (g)
    T_disc     [float] -> #Disc temperature (K)
    beta_disc  [float] -> #Disc density power-law exponent
    rho0       [float] -> #Disc density at stellar surface (g cm^-3)
    mu_e       [float] -> #Mean molecular weight per free electron
    -----------------------------------------------------------------
    Returns:

    The circumstellar disc mass in solar masses [float]
    '''


    R_star = R_star_sol * R_sun_cgs
    R_out = R_out_sol * R_sun_cgs
    M_star = M_star_sol * M_sun_cgs
    
    r = np.linspace(R_star, R_out, 512)

    c_s = np.sqrt((k_B_cgs*T_disc)/(mu_e*m_p_cgs))        #Speed of sound through disc (cm/s)

    H_r = c_s*np.sqrt(r/(G_cgs*M_star))*r                 #Disc scale height (cm)  

    integrand = (r/R_star)**(-beta_disc)*H_r*r            #Disc mass integrand

    M_disc_cgs = 2*np.pi**1.5*rho0*np.trapz(integrand, r) #Integrating the disc mass (g)

    M_disc = M_disc_cgs/M_sun_cgs                         #Disc mass in solar mass

    return M_disc

# %% [markdown]
# # Disc Mass Comparison with https://arxiv.org/abs/1704.08133v1

# %%
#Disc mass model Vs literature values
HD10144 = discmass(R_star_sol=3.56, R_out_sol=21.36, M_star_sol=5.17, T_disc=8280, beta_disc=3, rho0=7.5e-12)
HD35165 = discmass(R_star_sol=5.33, R_out_sol=66.625, M_star_sol=9.11, T_disc=12540, beta_disc=2, rho0=5e-11)
HD37795 = discmass(R_star_sol=2.7, R_out_sol=135, M_star_sol=3.29, T_disc=6360, beta_disc=3, rho0=2.5e-10)
HD42167 = discmass(R_star_sol=2.7, R_out_sol=16.2, M_star_sol=3.29, T_disc=6360, beta_disc=2, rho0=2.5e-10)
HD45725 = discmass(R_star_sol=4.32, R_out_sol=108, M_star_sol=6.62, T_disc=10080, beta_disc=2, rho0=5e-12)
HD48917 = discmass(R_star_sol=5.33, R_out_sol=133.25, M_star_sol=9.11, T_disc=12540, beta_disc=2, rho0=5e-12)
HD56014 = discmass(R_star_sol=4.8, R_out_sol=28.8, M_star_sol=7.6, T_disc=11280, beta_disc=2.5, rho0=1e-11)
HD56139 = discmass(R_star_sol=5.33, R_out_sol=133.25, M_star_sol=9.11, T_disc=12540, beta_disc=2, rho0=2.5e-11)
HD57150 = discmass(R_star_sol=5.33, R_out_sol=266.5, M_star_sol=9.11, T_disc=12540, beta_disc=2, rho0=5e-12)
HD58343 = discmass(R_star_sol=5.33, R_out_sol=133.25, M_star_sol=9.11, T_disc=12540, beta_disc=2.5, rho0=7.5e-11)
HD58715 = discmass(R_star_sol=3, R_out_sol=75, M_star_sol=3.8, T_disc=6840, beta_disc=3.5, rho0=2.5e-10)
HD60606 = discmass(R_star_sol=5.33, R_out_sol=133.25, M_star_sol=9.11, T_disc=12540, beta_disc=3, rho0=1e-10)
HD58423 = discmass(R_star_sol=3.56, R_out_sol=178, M_star_sol=5.17, T_disc=8280, beta_disc=2, rho0=2.5e-10)
HD68980 = discmass(R_star_sol=5.87, R_out_sol=293.5, M_star_sol=11.04, T_disc=13800, beta_disc=2, rho0=5e-12)
HD75311 = discmass(R_star_sol=4.8, R_out_sol=240, M_star_sol=7.6, T_disc=11280, beta_disc=3, rho0=7.5e-11)
HD78764 = discmass(R_star_sol=5.33, R_out_sol=66.625, M_star_sol=9.11, T_disc=12540, beta_disc=2.5, rho0=7.5e-11)
HD89080 = discmass(R_star_sol=3, R_out_sol=75, M_star_sol=3.8, T_disc=6840, beta_disc=2, rho0=2.5e-12)
HD91465 = discmass(R_star_sol=4.32, R_out_sol=108, M_star_sol=6.62, T_disc=10080, beta_disc=2, rho0=5e-12)
HD93563 = discmass(R_star_sol=2.7, R_out_sol=135, M_star_sol=3.29, T_disc=6360, beta_disc=3.5, rho0=1e-10)
HD102776 = discmass(R_star_sol=4.8, R_out_sol=240, M_star_sol=7.6, T_disc=11280, beta_disc=3, rho0=5e-11)
HD103192 = discmass(R_star_sol=2.7, R_out_sol=135, M_star_sol=3.29, T_disc=6360, beta_disc=3, rho0=7.5e-12)
HD105435 = discmass(R_star_sol=5.33, R_out_sol=266.5, M_star_sol=9.11, T_disc=12540, beta_disc=2.5, rho0=1e-10)
HD107348 = discmass(R_star_sol=3, R_out_sol=75, M_star_sol=3.8, T_disc=6840, beta_disc=3, rho0=2.5e-10)
HD110335 = discmass(R_star_sol=3.56, R_out_sol=89, M_star_sol=5.17, T_disc=8280, beta_disc=3, rho0=2.5e-10)
HD120324 = discmass(R_star_sol=5.33, R_out_sol=133.25, M_star_sol=9.11, T_disc=12540, beta_disc=2, rho0=5e-11)
HD124367 = discmass(R_star_sol=4.32, R_out_sol=216, M_star_sol=6.62, T_disc=10080, beta_disc=2, rho0=5e-12)
HD127972 = discmass(R_star_sol=5.33, R_out_sol=66.625, M_star_sol=9.11, T_disc=12540, beta_disc=2.5, rho0=7.5e-12)
HD131492 = discmass(R_star_sol=4.32, R_out_sol=25.92, M_star_sol=6.62, T_disc=10080, beta_disc=3, rho0=1e-11)
HD148184 = discmass(R_star_sol=5.33, R_out_sol=133.25, M_star_sol=9.11, T_disc=12540, beta_disc=2, rho0=1e-11)
HD157042 = discmass(R_star_sol=5.33, R_out_sol=66.625, M_star_sol=9.11, T_disc=12540, beta_disc=2.5, rho0=2.5e-11)
HD158427 = discmass(R_star_sol=5.33, R_out_sol=133.25, M_star_sol=9.11, T_disc=12540, beta_disc=2, rho0=5e-12)
HD167128 = discmass(R_star_sol=4.8, R_out_sol=240, M_star_sol=7.6, T_disc=11280, beta_disc=3.5, rho0=7.5e-11)
HD205637 = discmass(R_star_sol=4.8, R_out_sol=28.8, M_star_sol=7.6, T_disc=11280, beta_disc=2, rho0=1e-11)
HD209014 = discmass(R_star_sol=3, R_out_sol=37.5, M_star_sol=3.8, T_disc=6840, beta_disc=2, rho0=2.5e-10)
HD209409 = discmass(R_star_sol=3.28, R_out_sol=164, M_star_sol=4.45, T_disc=7440, beta_disc=2, rho0=5e-12)
HD212076 = discmass(R_star_sol=5.33, R_out_sol=133.25, M_star_sol=9.11, T_disc=12540, beta_disc=2, rho0=2.5e-11)
HD212571 = discmass(R_star_sol=6.42, R_out_sol=80.25, M_star_sol=13.21, T_disc=15240, beta_disc=2.5, rho0=1e-11)
HD214748 = discmass(R_star_sol=3, R_out_sol=37.5, M_star_sol=3.8, T_disc=6840, beta_disc=3.5, rho0=2.5e-10)
HD217891 = discmass(R_star_sol=3.56, R_out_sol=178, M_star_sol=5.17, T_disc=8280, beta_disc=2, rho0=5e-11)
HD224686 = discmass(R_star_sol=3, R_out_sol=18, M_star_sol=3.8, T_disc=6840, beta_disc=2, rho0=2.5e-10)

# %%
print('The mass of the disc of HD10144 is ' + '{:.3e}'.format(HD10144) + ' solar masses')
print('The mass of the disc of HD35165 is ' + '{:.3e}'.format(HD35165) + ' solar masses')
print('The mass of the disc of HD37795 is ' + '{:.3e}'.format(HD37795) + ' solar masses')
print('The mass of the disc of HD42167 is ' + '{:.3e}'.format(HD42167) + ' solar masses')
print('The mass of the disc of HD45725 is ' + '{:.3e}'.format(HD45725) + ' solar masses')
print('The mass of the disc of HD48917 is ' + '{:.3e}'.format(HD48917) + ' solar masses')
print('The mass of the disc of HD56014 is ' + '{:.3e}'.format(HD56014) + ' solar masses')
print('The mass of the disc of HD56139 is ' + '{:.3e}'.format(HD56139) + ' solar masses')
print('The mass of the disc of HD57150 is ' + '{:.3e}'.format(HD57150) + ' solar masses')
print('The mass of the disc of HD58343 is ' + '{:.3e}'.format(HD58343) + ' solar masses')
print('The mass of the disc of HD58715 is ' + '{:.3e}'.format(HD58715) + ' solar masses')
print('The mass of the disc of HD60606 is ' + '{:.3e}'.format(HD60606) + ' solar masses')
print('The mass of the disc of HD58423 is ' + '{:.3e}'.format(HD58423) + ' solar masses')
print('The mass of the disc of HD68980 is ' + '{:.3e}'.format(HD68980) + ' solar masses')
print('The mass of the disc of HD75311 is ' + '{:.3e}'.format(HD75311) + ' solar masses')
print('The mass of the disc of HD78764 is ' + '{:.3e}'.format(HD78764) + ' solar masses')
print('The mass of the disc of HD89080 is ' + '{:.3e}'.format(HD89080) + ' solar masses')
print('The mass of the disc of HD91465 is ' + '{:.3e}'.format(HD91465) + ' solar masses')
print('The mass of the disc of HD93563 is ' + '{:.3e}'.format(HD93563) + ' solar masses')
print('The mass of the disc of HD102776 is ' + '{:.3e}'.format(HD102776) + ' solar masses')
print('The mass of the disc of HD103192 is ' + '{:.3e}'.format(HD103192) + ' solar masses')
print('The mass of the disc of HD105435 is ' + '{:.3e}'.format(HD105435) + ' solar masses')
print('The mass of the disc of HD107348 is ' + '{:.3e}'.format(HD107348) + ' solar masses')
print('The mass of the disc of HD110335 is ' + '{:.3e}'.format(HD110335) + ' solar masses')
print('The mass of the disc of HD120324 is ' + '{:.3e}'.format(HD120324) + ' solar masses')
print('The mass of the disc of HD124367 is ' + '{:.3e}'.format(HD124367) + ' solar masses')
print('The mass of the disc of HD127972 is ' + '{:.3e}'.format(HD127972) + ' solar masses')
print('The mass of the disc of HD131492 is ' + '{:.3e}'.format(HD131492) + ' solar masses')
print('The mass of the disc of HD148184 is ' + '{:.3e}'.format(HD148184) + ' solar masses')
print('The mass of the disc of HD157042 is ' + '{:.3e}'.format(HD157042) + ' solar masses')
print('The mass of the disc of HD158427 is ' + '{:.3e}'.format(HD158427) + ' solar masses')
print('The mass of the disc of HD167128 is ' + '{:.3e}'.format(HD167128) + ' solar masses')
print('The mass of the disc of HD205637 is ' + '{:.3e}'.format(HD205637) + ' solar masses')
print('The mass of the disc of HD209014 is ' + '{:.3e}'.format(HD209014) + ' solar masses')
print('The mass of the disc of HD209409 is ' + '{:.3e}'.format(HD209409) + ' solar masses')
print('The mass of the disc of HD212076 is ' + '{:.3e}'.format(HD212076) + ' solar masses')
print('The mass of the disc of HD212571 is ' + '{:.3e}'.format(HD212571) + ' solar masses')
print('The mass of the disc of HD214748 is ' + '{:.3e}'.format(HD214748) + ' solar masses')
print('The mass of the disc of HD217891 is ' + '{:.3e}'.format(HD217891) + ' solar masses')
print('The mass of the disc of HD224686 is ' + '{:.3e}'.format(HD224686) + ' solar masses')
# Out:
# The mass of the disc of HD10144 is 2.653e-11 solar masses
# The mass of the disc of HD35165 is 6.687e-09 solar masses
# The mass of the disc of HD37795 is 1.546e-09 solar masses
# The mass of the disc of HD42167 is 1.163e-09 solar masses
# The mass of the disc of HD45725 is 9.679e-10 solar masses
# The mass of the disc of HD48917 is 1.920e-09 solar masses
# The mass of the disc of HD56014 is 1.671e-10 solar masses
# The mass of the disc of HD56139 is 9.599e-09 solar masses
# The mass of the disc of HD57150 is 5.458e-09 solar masses
# The mass of the disc of HD58343 is 8.360e-09 solar masses
# The mass of the disc of HD58715 is 5.718e-10 solar masses
# The mass of the disc of HD60606 is 3.716e-09 solar masses
# The mass of the disc of HD58423 is 7.169e-08 solar masses
# The mass of the disc of HD68980 is 7.291e-09 solar masses
# The mass of the disc of HD75311 is 3.044e-09 solar masses
# The mass of the disc of HD78764 is 4.006e-09 solar masses
# ...

# %%
model = [HD10144, HD35165, HD37795, HD42167, HD45725, HD48917, HD56014, HD56139, HD57150, HD58343, HD58715, HD60606, HD58423, HD68980, HD75311, HD78764, HD89080, HD91465, HD93563, HD102776, HD103192, HD105435, HD107348, HD110335, HD120324, HD124367, HD127972, HD131492, HD148184, HD157042, HD158427, HD167128, HD205637, HD209014, HD209409, HD212076, HD212571, HD214748, HD217891, HD224686]
model = np.array(model)

literature = [9.3e-11, 7.65e-9, 1.31e-9, 1.9e-9, 1.39e-8, 3e-8, 2.28e-9, 8.29e-8, 6.19e-8, 7e-8, 4.56e-9, 2.91e-8, 5.68e-8, 1.21e-7, 2.12e-8, 3.27e-8, 3.34e-9, 1.58e-8, 2e-10, 7.29e-9, 1.51e-9, 9.11e-8, 5.7e-9, 1e-8, 6.92e-8, 9.26e-9, 2.73e-8, 9.26e-9, 2.18e-7, 1.45e-8, 6.83e-8, 2.35e-8, 6.68e-9, 4.18e-9, 3.51e-9, 2.82e-8, 1.22e-8, 1e-8, 8.78e-8, 1e-8]
literature = np.array(literature)

# %%
for m, lit in zip(model, literature):
    print(lit/m)
# Out:
# 3.5059755365746055
# 1.1439333464862755
# 0.8474157911257807
# 1.6343891136780626
# 14.361445549832554
# 15.626588801732607
# 13.641136139581699
# 8.63629474442422
# 11.340457868077332
# 8.372757417111016
# 7.974675059761876
# 7.831429212981468
# 0.7923338193372909
# 16.59479000959067
# 6.963884540993762
# 8.162658411116428
# 22.745398983268593
# 16.32452084081686
# 1.0037317275663278
# 3.5919847856493767
# 32.559741592873515
# 4.002812715037505
# 4.011040545557848
# 4.0982453115391735
# 3.604533150266321
# 3.365048695517632
# 68.14696471666008
# 136.4107785125491
# 56.77660597962848
# 10.858582290017265
# 35.57653383861124
# 23.95553940996119
# 21.884167490552272
# 0.8171837646864224
# 3.1916624412722947
# 2.93779869472573
# 13.008466487447665
# 22.288622689826855
# 6.123847652976596
# 6.1651691883743975

# %%
model_x = np.arange(len(model))
literature_x = np.arange(len(literature))
plt.bar(model_x, model, color='blue', alpha=0.8, label='Model')
plt.bar(literature_x, literature, color='red', alpha=0.5, label='Literature')
plt.title('Model Vs Literature Disc Masses')
plt.xlabel('Discs')
plt.ylabel('Disc Mass (solar mass)')
plt.legend()

# %%
clean_model = []
clean_literature = []

for m, lit in zip(model, literature):
    if lit / m <= 10: 
        clean_model.append(m)
        clean_literature.append(lit)
    else:
        clean_model.append(0)
        clean_literature.append(0)

# %%
clean_model_x = np.arange(len(clean_model))
clean_literature_x = np.arange(len(clean_literature))

plt.bar(clean_model_x, clean_model, color='blue', alpha=0.8, label='Model')
plt.bar(clean_literature_x, clean_literature, color='red', alpha=0.5, label='Literature')
plt.title('Model Vs Literature Disc Masses - 1 order of magnitude accuracy')
plt.xlabel('Discs')
plt.ylabel('Disc Mass (solar mass)')
plt.legend()

# %% [markdown]
# ## Number Density

# %% [markdown]
# # Looking at the Paper by Chen et al. (2019)
# https://arxiv.org/abs/1904.07527v2
#
# Parameter Values:
# * Orbit Inclination - $26^\circ$
# * Eccentricity - 0.87
# * Stellar Mass - $20 M_{\odot}$
# * Stellar Radius - $9.2 R_{\odot}$
# * Argument of Periastron - $138^\circ$
# * Disc Inclination - $45^\circ$
# * Initial disc density - $10^{-12} g cm^{-3}$
# * Disc Temperature - $1.45e4 K$
# * Orbital phase - $90^\circ$
#
# Chen et al. Claim that PSR B1259-63 passes through the disk at distances of $1.8e13 cm - 2.4e13 cm$

# %%
s = np.logspace(np.log10(1e12), np.log10((12 * con.au.cgs).value), 10000)#Line of sight distance array
i_disc_deg = [35, 40, 45, 50]                                            #Disc inclination in degrees                                                   
i_disc_rad = np.deg2rad(i_disc_deg)                                      #Disc inclination in rad
i_orb_deg = 26                                                           #Orbital inclination in deg
i_orb_rad = np.deg2rad(i_orb_deg)                                        #Orbital inclination in rad
phi_orb_deg = 90                                                         #Orbital phase in degree
phi_orb_rad = np.deg2rad(phi_orb_deg)                                    #Orbital phase in rad
om_deg = 138
om = np.deg2rad(om_deg)
Om_deg = 0
Om = np.deg2rad(Om_deg)

disc_num_den1 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9.2, #Number density
                       beta=4, rho0=-12, i_disc=i_disc_rad[0], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s, alpha=0.5)
disc_num_den2 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9.2,        
                       beta=4, rho0=-12, i_disc=i_disc_rad[1], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s, alpha=0.5)
disc_num_den3 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9.2,       
                       beta=4, rho0=-12, i_disc=i_disc_rad[2], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s, alpha=0.5)
disc_num_den4 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9.2,        
                       beta=4, rho0=-12, i_disc=i_disc_rad[3], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s, alpha=0.5)
#Plotting
plt.plot(s, disc_num_den1, label='i disc = ' + str(int(i_disc_deg[0])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den2, label='i disc = ' + str(int(i_disc_deg[1])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den3, label='i disc = ' + str(int(i_disc_deg[2])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den4, label='i disc = ' + str(int(i_disc_deg[3])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.title('Disc Number Density Vs Line of Sight Distance at Periastron (Chen et al., 2019)')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.legend()

# %%
s = np.logspace(np.log10(1e5), np.log10((12 * con.au.cgs).value), 10000) #Line of sight distance array
i_disc_deg = [40, 45, 50, 55]                                            #Disc inclination in degrees                                                   
i_disc_rad = np.deg2rad(i_disc_deg)                                      #Disc inclination in rad
i_orb_deg = 36                                                           #Orbital inclination in deg
i_orb_rad = np.deg2rad(i_orb_deg)                                        #Orbital inclination in rad
phi_orb_deg = 0                                                          #Orbital phase in degree
phi_orb_rad = np.deg2rad(phi_orb_deg)                                    #Orbital phase in rad
om_deg = 138
om = np.deg2rad(om_deg)
Om_deg = 189
Om = np.deg2rad(Om_deg)

disc_num_den1 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,   #Number density
                       beta=4, rho0=-12, i_disc=i_disc_rad[0], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s, alpha=0.5)
disc_num_den2 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,        
                       beta=4, rho0=-12, i_disc=i_disc_rad[1], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s, alpha=0.5)
disc_num_den3 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,       
                       beta=4, rho0=-12, i_disc=i_disc_rad[2], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s, alpha=0.5)
disc_num_den4 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,        
                       beta=4, rho0=-12, i_disc=i_disc_rad[3], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s, alpha=0.5)
#Plotting
plt.plot(s, disc_num_den1, label='i disc = ' + str(int(i_disc_deg[0])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den2, label='i disc = ' + str(int(i_disc_deg[1])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den3, label='i disc = ' + str(int(i_disc_deg[2])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den4, label='i disc = ' + str(int(i_disc_deg[3])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.title('Disc Number Density Vs Line of Sight Distance')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.legend()

# %%
s = np.logspace(np.log10(1e8), np.log10((12 * con.au.cgs).value), 10000) #Line of sight distance array
i_disc_deg = [40, 45, 50, 55]                                            #Disc inclination in degrees                                                   
i_disc_rad = np.deg2rad(i_disc_deg)                                      #Disc inclination in rad
i_orb_deg = 25                                                           #Orbital inclination in deg
i_orb_rad = np.deg2rad(i_orb_deg)                                        #Orbital inclination in rad
phi_orb_deg = 100                                                        #Orbital phase in degree
phi_orb_rad = np.deg2rad(phi_orb_deg)                                    #Orbital phase in rad
om_deg = 138
om = np.deg2rad(om_deg)
Om_deg = 189
Om = np.deg2rad(Om_deg)

disc_num_den1 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,   #Number density
                       beta=4, rho0=-12, i_disc=i_disc_rad[0], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s, alpha=0.5)
disc_num_den2 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,        
                       beta=4, rho0=-12, i_disc=i_disc_rad[1], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s, alpha=0.5)
disc_num_den3 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,       
                       beta=4, rho0=-12, i_disc=i_disc_rad[2], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s, alpha=0.5)
disc_num_den4 = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,        
                       beta=4, rho0=-12, i_disc=i_disc_rad[3], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s, alpha=0.5)
#Plotting
plt.plot(s, disc_num_den1, label='i disc = ' + str(int(i_disc_deg[0])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den2, label='i disc = ' + str(int(i_disc_deg[1])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den3, label='i disc = ' + str(int(i_disc_deg[2])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den4, label='i disc = ' + str(int(i_disc_deg[3])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.title('Disc Number Density Vs Line of Sight Distance')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %% [markdown]
# # Disc Number Density Vs Line of Sight Distance GIF

# %%
phi_deg_array = np.linspace(0, 360, 360)   #Orbital phases in deg
phi_array = np.deg2rad(phi_deg_array)      #Orbital phases in rad
disc_i_gif_deg = 60                        #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)    #Inclination in rad

#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(1e2, (3 * con.au.cgs).value)
ax.set_ylim(0, 2e7)
ax.set_xlabel('Line of Sight Distance (cm)')
ax.set_ylabel('Number Density (cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    s = np.logspace(np.log10(1e2), np.log10((12 * con.au.cgs).value), 10000) #Line of sight distance array
    orb_i_deg = 25
    i_rad = np.deg2rad(orb_i_deg)
    Om_deg = 189
    Om = np.deg2rad(Om_deg)
    om_deg = 138
    om = np.deg2rad(om_deg)
    phi = phi_array[frame]
    disc_n_e = disc_ne(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,  
                       beta=4, rho0=-12, i_disc=disc_i_gif, phi=phi, omega=om, Omega=Om, e=0.87, i=i_rad, s=s, alpha=0.5)
    line.set_data(s, disc_n_e)
    title.set_text('Number Density Vs LoS Distance,disc i = ' + str(int(disc_i_gif_deg)) + ' (deg) \nphi = ' + str(int(phi_deg_array[frame])) + ' deg')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(phi_array), blit=False, interval=100)
#Saving GIF
ani.save("disc_num_density_evolution.gif", writer="pillow", fps=10)
plt.show()

# %% [markdown]
# # Dispersion Measure

# %%
#Calculating the DM
om_deg = 138                                                          #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                                               #Orbital argument of periastron in rad
Om_deg = 189                                                          #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                                               #Longitude of ascending note in rad
i_orb_deg = 25                                                        #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                                     #Orbital inclination is rad
i_disc_deg = [40, 45, 50]                                             #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                                   #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                    #Orbital phase array in rad (redundancy removed)

disc_DM1 = disc_DM(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9, #Number density
                       beta=4, rho0=-12, i_disc=i_disc_rad[0], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad, alpha=0.5)
disc_DM2 = disc_DM(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,        
                       beta=4, rho0=-12, i_disc=i_disc_rad[1], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad, alpha=0.5)
disc_DM3 = disc_DM(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,       
                       beta=4, rho0=-12, i_disc=i_disc_rad[2], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad, alpha=0.5)
#Plotting
plt.plot(phi, disc_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' deg')
plt.plot(phi, disc_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' deg')
plt.plot(phi, disc_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' deg')
plt.title('Disc Dispersion Measure Vs Orbital Phase')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %%
#Plotting
plt.plot(phi/(2*np.pi)*1237, disc_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' deg')
plt.plot(phi/(2*np.pi)*1237, disc_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' deg')
plt.plot(phi/(2*np.pi)*1237, disc_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' deg')
plt.title('Disc Dispersion Measure Vs Time')
plt.xlabel('Time From Periastron (Days)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %%
peaks, _ = find_peaks(disc_DM3)
DM_peaks = disc_DM3[peaks]
phi_peaks = phi[peaks]

print('The dispersion measure values of the first and second disc intersections are: ' + str(DM_peaks))
print('And their respective orbital phase values are: ' + str(phi_peaks))
# Out:
# The dispersion measure values of the first and second disc intersections are: [0.99796446]
# And their respective orbital phase values are: [0.67495155]

# %%
#Calculating the DM
om_deg = 138                                                          #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                                               #Orbital argument of periastron in rad
Om_deg = 189                                                          #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                                               #Longitude of ascending note in rad
i_orb_deg = 25                                                        #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                                     #Orbital inclination is rad
i_disc_deg = [40, 45, 50]                                             #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                                   #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                    #Orbital phase array in rad (redundancy removed)

disc_DM1 = disc_DM(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9, #Number density
                       beta=4, rho0=-12, i_disc=i_disc_rad[0], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad, alpha=0.5)
disc_DM2 = disc_DM(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,        
                       beta=4, rho0=-12, i_disc=i_disc_rad[1], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad, alpha=0.5)
disc_DM3 = disc_DM(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,       
                       beta=4, rho0=-12, i_disc=i_disc_rad[2], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad, alpha=0.5)
#Plotting
plt.plot(phi, disc_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' deg')
plt.plot(phi, disc_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' deg')
plt.plot(phi, disc_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' deg')
plt.title('Disc Dispersion Measure Vs True Anomaly')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.yscale('log')
plt.legend()

# %% [markdown]
# # Dispersion Measure Vs True Anomaly GIF

# %%
#Varying disc inclination GIF
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad
disc_i_gif_deg = np.linspace(0, 90, 90)            #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad
orb_i_deg = 25                                     #Orbital inclination in degrees
i_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad
Om_deg = 189                                       #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad
om_deg = 138                                       #Argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Argumnet of periastron in rad


#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(None, 0.6e2)
ax.set_xlabel('Orbital Phase (rad)')
ax.set_ylabel('Dispersion Measure (pc cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    disc_i = disc_i_gif[frame]
    disc_DM_gif = disc_DM(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,   
                       beta=4, rho0=-12, i_disc=disc_i, phi=phi, omega=om, Omega=Om, e=0.87, i=i_rad, alpha=0.5)
    line.set_data(phi, disc_DM_gif)
    title.set_text('Disc Dispersion Measure Vs Orbital Phase \ndisc i = ' + str(int(disc_i_gif_deg[frame])) + ' (deg)')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(disc_i_gif), blit=False, interval=100)
#Saving GIF
ani.save("disc_DM_evolution_varying_disc_i.gif", writer="pillow", fps=10)
plt.show()

# %%
#Varying orbital inclination GIF
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad
disc_i_gif_deg = 60                                #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad
orb_i_deg = np.linspace(0, 90, 90)                 #Orbital inclination in degrees
i_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad
Om_deg = 189                                       #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad
om_deg = 138                                       #Argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Argumnet of periastron in rad


#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(None, 1e2)
ax.set_xlabel('Orbital Phase (rad)')
ax.set_ylabel('Dispersion Measure (pc cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    orb_i_gif = i_rad[frame]
    disc_DM_gif = disc_DM(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,   
                       beta=4, rho0=-12, i_disc=disc_i_gif, phi=phi, omega=om, Omega=Om, e=0.87, i=orb_i_gif, alpha=0.5)
    line.set_data(phi, disc_DM_gif)
    title.set_text('Disc Dispersion Measure Vs Orbital Phase \norbital i = ' + str(int(orb_i_deg[frame])) + ' (deg)')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(i_rad), blit=False, interval=100)
#Saving GIF
ani.save("disc_DM_evolution_varying_orb_i.gif", writer="pillow", fps=10)
plt.show()

# %%
#Varying argument of periastron GIF
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad
disc_i_gif_deg = 60                                #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad
orb_i_deg = 25                                     #Orbital inclination in degrees
i_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad
Om_deg = 189                                       #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad
om_gif_deg = np.linspace(0, 360, 180)              #Argument of periastron in degrees
om_gif_rad = np.deg2rad(om_gif_deg)                #Argumnet of periastron in rad


#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(None, 1e2)
ax.set_xlabel('Orbital Phase (rad)')
ax.set_ylabel('Dispersion Measure (pc cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    om = om_gif_rad[frame]
    disc_DM_gif = disc_DM(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9,   
                       beta=4, rho0=-12, i_disc=disc_i_gif, phi=phi, omega=om, Omega=Om, e=0.87, i=i_rad, alpha=0.5)
    line.set_data(phi, disc_DM_gif)
    title.set_text('Disc Dispersion Measure Vs Orbital Phase \nomega = ' + str(int(om_gif_deg[frame])) + ' (deg)')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(om_gif_rad), blit=False, interval=100)
#Saving GIF
ani.save("disc_DM_evolution_varying_omega.gif", writer="pillow", fps=10)
plt.show()

# %% [markdown]
# # Optical Depth

# %%
#Calculating the optical depth
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                              #Orbital phase array in rad (redundancy removed)
nu = [1.5, 1.75, 2]                                                             #Signal frequency in GHz
disc_tau1 = disc_ffa(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9, beta=4, #Optical depth
                  rho0=-12, i_disc=i_disc_rad[0], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad, nu=nu[0], alpha=0.5) 
disc_tau2 = disc_ffa(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9, beta=4,
                  rho0=-12, i_disc=i_disc_rad[1], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad, nu=nu[1], alpha=0.5)
disc_tau3 = disc_ffa(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9, beta=4,
                  rho0=-12, i_disc=i_disc_rad[2], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad, nu=nu[2], alpha=0.5)

# %%
#Plotting the optical depth as a function of the orbital phase
plt.plot(phi, disc_tau1, label = 'i disc = ' + str(i_disc_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, disc_tau2, label = 'i disc = ' + str(i_disc_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, disc_tau3, label = 'i disc = ' + str(i_disc_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('FFA Optical Depth Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('Optical Depth')
plt.legend()

# %%
#Plotting the optical depth as a function of the orbital phase
plt.plot(phi/(2*np.pi)*1237, disc_tau1, label = 'i disc = ' + str(i_disc_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi/(2*np.pi)*1237, disc_tau2, label = 'i disc = ' + str(i_disc_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi/(2*np.pi)*1237, disc_tau3, label = 'i disc = ' + str(i_disc_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('FFA Optical Depth Vs Time')
plt.xlabel('Time From Periastron (Days)')
plt.ylabel('Optical Depth')
plt.legend()

# %%
#Plotting the optical depth as a function of the orbital phase
plt.plot(phi, disc_tau1, label = 'i disc = ' + str(i_disc_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, disc_tau2, label = 'i disc = ' + str(i_disc_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, disc_tau3, label = 'i disc = ' + str(i_disc_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('FFA Optical Depth Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('Optical Depth')
plt.yscale('log')
plt.legend()

# %% [markdown]
# # Transmission Factor $e^{-\tau}$ Vs $\phi$

# %%
#Plotting e^(-tau) as a function of the orbital phase
plt.plot(phi, np.exp(-disc_tau1), label = 'i disc = ' + str(i_disc_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, np.exp(-disc_tau2), label = 'i disc = ' + str(i_disc_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, np.exp(-disc_tau3), label = 'i disc = ' + str(i_disc_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('Disc Transmission Factor e^(-tau) Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('e^(-tau)')
plt.ylim(0.7, None)
plt.legend()

# %%
#Plotting e^(-tau) as a function of the orbital phase
plt.plot(phi, np.exp(-disc_tau1), label = 'i disc = ' + str(i_disc_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, np.exp(-disc_tau2), label = 'i disc = ' + str(i_disc_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, np.exp(-disc_tau3), label = 'i disc = ' + str(i_disc_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('Disc Transmission Factor e^(-tau) Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('e^(-tau)')
plt.yscale('log')
plt.ylim(0.7, None)
plt.legend()

# %% [markdown]
# # Pulsar spectrum evolution through the disc along the orbit GIF

# %%
phi_deg_array = np.linspace(0, 360, 512)   #Orbital phases in deg
phi_array = np.deg2rad(phi_deg_array)      #Orbital phases in rad
disc_i_gif_deg = 60                        #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)    #Inclination in rad
nu_array = np.linspace(1, 8.4, 512)        #Frequency array

#Computing the spectra for all orbital phases
disc_S_nu = disc_spectrum(a_Rsun=1345, T=1.2e4, M_star_sol=20, R_star_sol=9, beta=3.5, 
                  rho0=-12, i_disc=disc_i_gif, phi=phi_array, omega=om, Omega=Om, e=0.87, i=i_orb_rad, nu=nu_array, p=1.3, alpha=0.5)         

#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1, 8.4)
ax.set_ylim(1e-5, 1)
ax.set_xlabel('Frequency (GHz)')
ax.set_ylabel('Flux density (Jy)')
title = ax.set_title('')

#Frame update function
def update(frame):
    line.set_data(nu_array, disc_S_nu[frame, :])
    title.set_text('Spectrum Evolution at Inclination i = ' + str(int(disc_i_gif_deg)) + '(deg)\n at Orbital Phase = ' + str(int(phi_deg_array[frame])) + ' deg')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(phi_array), blit=False, interval=100)
#Saving GIF
ani.save("disc_spectrum_evolution.gif", writer="pillow", fps=10)
plt.show()

# %% [markdown]
# ## Combined Stellar Wind and Disk

# %% [markdown]
# ## Number Density Vs Line of Sight Distance

# %%
s = np.logspace(np.log10(1e8), np.log10((12 * con.au.cgs).value), 10000)     #Line of sight distance array
i_disc_deg = [40, 45, 50, 55]                                                #Disc inclination in degrees                                                   
i_disc_rad = np.deg2rad(i_disc_deg)                                          #Disc inclination in rad
i_orb_deg = 25                                                               #Orbital inclination in deg
i_orb_rad = np.deg2rad(i_orb_deg)                                            #Orbital inclination in rad
phi_orb_deg = 100                                                            #Orbital phase in degree
phi_orb_rad = np.deg2rad(phi_orb_deg)                                        #Orbital phase in rad
om_deg = 138
om = np.deg2rad(om_deg)
Om_deg = 189
Om = np.deg2rad(Om_deg)

tot_ne1 = tot_num_density(phi=phi_orb_rad, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3,
                          s=s, e=0.87, omega=om, Omega=Om, beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=i_disc_rad[0], alpha=0.5)
tot_ne2 = tot_num_density(phi=phi_orb_rad, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3,
                          s=s, e=0.87, omega=om, Omega=Om, beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=i_disc_rad[1], alpha=0.5)
tot_ne3 = tot_num_density(phi=phi_orb_rad, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3,
                          s=s, e=0.87, omega=om, Omega=Om, beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=i_disc_rad[2], alpha=0.5)
tot_ne4 = tot_num_density(phi=phi_orb_rad, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3,
                          s=s, e=0.87, omega=om, Omega=Om, beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=i_disc_rad[3], alpha=0.5)

#Plotting
plt.plot(s, tot_ne1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg)')
plt.plot(s, tot_ne2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg)')
plt.plot(s, tot_ne3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg)')
plt.plot(s, tot_ne4, label='i disc = ' + str(int(i_disc_deg[3])) + ' (deg)')
plt.title('Total Number Density Vs Line of Sight Distance')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.legend()

# %%
#Plotting
plt.plot(s, tot_ne1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg)')
plt.plot(s, tot_ne2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg)')
plt.plot(s, tot_ne3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg)')
plt.plot(s, tot_ne4, label='i disc = ' + str(int(i_disc_deg[3])) + ' (deg)')
plt.title('Total Number Density Vs Line of Sight Distance')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %% [markdown]
# ## Total Number Density Vs Line of Sight Distance GIF

# %%
phi_deg_array = np.linspace(0, 360, 360)   #Orbital phases in deg
phi_array = np.deg2rad(phi_deg_array)      #Orbital phases in rad
disc_i_gif_deg = 60                        #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)    #Inclination in rad

#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(1e2, (3 * con.au.cgs).value)
ax.set_ylim(0, 1e9)
ax.set_xlabel('Line of Sight Distance (cm)')
ax.set_ylabel('Number Density (cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    s = np.logspace(np.log10(1e2), np.log10((3 * con.au.cgs).value), 10000) #Line of sight distance array
    orb_i_deg = 25
    i_rad = np.deg2rad(orb_i_deg)
    Om_deg = 189
    Om = np.deg2rad(Om_deg)
    om_deg = 138
    om = np.deg2rad(om_deg)
    phi = phi_array[frame]
    tot_ne = tot_num_density(phi=phi, i=i_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3,
                          s=s, e=0.87, omega=om, Omega=Om, beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=disc_i_gif, alpha=0.5)
    line.set_data(s, tot_ne)
    title.set_text('Total Number Density Vs LoS Distance,disc i = ' + str(int(disc_i_gif_deg)) + ' (deg) \nphi = ' + str(int(phi_deg_array[frame])) + ' deg')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(phi_array), blit=False, interval=100)
#Saving GIF
ani.save("total_num_density_evolution.gif", writer="pillow", fps=10)
plt.show()

# %% [markdown]
# ## Dispersion Measure Vs Orbital Phase

# %%
#Calculating the DM
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)

tot_DM1 = tot_DM(phi=phi, i=np.deg2rad(25), a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(138), Omega=np.deg2rad(189), beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=np.deg2rad(40), alpha=0.5)
tot_DM2 = tot_DM(phi=phi, i=np.deg2rad(25), a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(138), Omega=np.deg2rad(189), beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=np.deg2rad(45), alpha=0.5)
tot_DM3 = tot_DM(phi=phi, i=np.deg2rad(25), a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(138), Omega=np.deg2rad(189), beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=np.deg2rad(50), alpha=0.5)

#Plotting
plt.plot(phi, tot_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg)')
plt.plot(phi, tot_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg)')
plt.plot(phi, tot_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg)')
plt.title('Total Dispersion Measure Vs Orbital Phase')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %%
#Plotting
plt.plot(phi/(2*np.pi)*1237, tot_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg)')
plt.plot(phi/(2*np.pi)*1237, tot_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg)')
plt.plot(phi/(2*np.pi)*1237, tot_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg)')
plt.title('Total Dispersion Measure Vs Time')
plt.xlabel('Time From Periastron (Days)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %%
#Plotting
plt.plot(phi, tot_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg)')
plt.plot(phi, tot_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg)')
plt.plot(phi, tot_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg)')
plt.title('Total Dispersion Measure Vs Orbital Phase')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.yscale('log')
plt.legend()

# %% [markdown]
# ## Total Dispersion Measure Vs Orbital Phase GIF

# %%
#Varying disc inclination GIF
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad
disc_i_gif_deg = np.linspace(0, 90, 90)            #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad
orb_i_deg = 25                                     #Orbital inclination in degrees
i_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad
Om_deg = 189                                       #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad
om_deg = 138                                       #Argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Argumnet of periastron in rad


#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(None, 5e2)
ax.set_xlabel('Orbital Phase (rad)')
ax.set_ylabel('Dispersion Measure (pc cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    disc_i = disc_i_gif[frame]
    tot_DM_disc_i = tot_DM(phi=phi, i=i_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=disc_i, alpha=0.5)
    line.set_data(phi, tot_DM_disc_i)
    title.set_text('Total Dispersion Measure Vs Orbital Phase \ndisc i = ' + str(int(disc_i_gif_deg[frame])) + ' (deg)')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(disc_i_gif), blit=False, interval=100)
#Saving GIF
ani.save("total_DM_evolution_varying_disc_i.gif", writer="pillow", fps=10)
plt.show()

# %%
#Varying orbital inclination GIF
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad
disc_i_gif_deg = 60                                #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad
orb_i_deg = np.linspace(0, 90, 90)                 #Orbital inclination in degrees
i_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad
Om_deg = 189                                       #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad
om_deg = 138                                       #Argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Argumnet of periastron in rad


#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(None, 5e2)
ax.set_xlabel('Orbital Phase (rad)')
ax.set_ylabel('Dispersion Measure (pc cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    orb_i_gif = i_rad[frame]
    tot_DM_orb_i = tot_DM(phi=phi, i=orb_i_gif, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=disc_i_gif, alpha=0.5)
    line.set_data(phi, tot_DM_orb_i)
    title.set_text('Total Dispersion Measure Vs Orbital Phase \norbital i = ' + str(int(orb_i_deg[frame])) + ' (deg)')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(i_rad), blit=False, interval=100)
#Saving GIF
ani.save("total_DM_evolution_varying_orb_i.gif", writer="pillow", fps=10)
plt.show()

# %%
#Varying argument of periastron GIF
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad
disc_i_gif_deg = 60                                #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad
orb_i_deg = 25                                     #Orbital inclination in degrees
i_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad
Om_deg = 189                                       #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad
om_gif_deg = np.linspace(0, 360, 180)              #Argument of periastron in degrees
om_gif_rad = np.deg2rad(om_gif_deg)                #Argumnet of periastron in rad


#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(None, 5e2)
ax.set_xlabel('Orbital Phase (rad)')
ax.set_ylabel('Dispersion Measure (pc cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    om = om_gif_rad[frame]
    tot_DM_om = tot_DM(phi=phi, i=i_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=disc_i_gif, alpha=0.5)
    line.set_data(phi, tot_DM_om)
    title.set_text('Total Dispersion Measure Vs Orbital Phase \nomega = ' + str(int(om_gif_deg[frame])) + ' (deg)')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(om_gif_rad), blit=False, interval=100)
#Saving GIF
ani.save("total_DM_evolution_varying_omega.gif", writer="pillow", fps=10)
plt.show()

# %% [markdown]
# ## Optical Depth Vs Orbital Phase

# %%
#Calculating the optical depth
i_disc_deg = [40, 45, 50]                          #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                #Disc inclinations in rad
nu = [1.5, 1.75, 2]                                #Signal frequency in GHz
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)

tot_tau1 = tot_ffa(phi=phi, i=np.deg2rad(25), a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(138), Omega=np.deg2rad(189), beta=2, T_wind=2e4, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=i_disc_rad[0], nu=nu[0], alpha=0.5)
tot_tau2 = tot_ffa(phi=phi, i=np.deg2rad(25), a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(138), Omega=np.deg2rad(189), beta=2, T_wind=2e4, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=i_disc_rad[1], nu=nu[1], alpha=0.5)
tot_tau3 = tot_ffa(phi=phi, i=np.deg2rad(25), a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(138), Omega=np.deg2rad(189), beta=2, T_wind=2e4, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=i_disc_rad[2], nu=nu[2], alpha=0.5)

#Plotting
plt.plot(phi, tot_tau1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg), freq = ' + str(int(nu[0])) + ' (GHz)')
plt.plot(phi, tot_tau2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg), freq = ' + str(int(nu[1])) + ' (GHz)')
plt.plot(phi, tot_tau3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg), freq = ' + str(int(nu[2])) + ' (GHz)')
plt.title('FFA Optical Depth Vs Orbital Phase')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Optical Depth')
plt.legend()

# %%
#Plotting
plt.plot(phi/(2*np.pi)*1237, tot_tau1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg), freq = ' + str(int(nu[0])) + ' (GHz)')
plt.plot(phi/(2*np.pi)*1237, tot_tau2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg), freq = ' + str(int(nu[1])) + ' (GHz)')
plt.plot(phi/(2*np.pi)*1237, tot_tau3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg), freq = ' + str(int(nu[2])) + ' (GHz)')
plt.title('FFA Optical Depth Vs Orbital Phase')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Optical Depth')
plt.legend()

# %%
#Plotting
plt.plot(phi, tot_tau1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg), freq = ' + str(int(nu[0])) + ' (GHz)')
plt.plot(phi, tot_tau2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg), freq = ' + str(int(nu[1])) + ' (GHz)')
plt.plot(phi, tot_tau3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg), freq = ' + str(int(nu[2])) + ' (GHz)')
plt.title('FFA Optical Depth Vs Orbital Phase')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Optical Depth')
plt.yscale('log')
plt.legend()

# %% [markdown]
# ## Transmission Factor $e^{-\tau}$ Vs True Anomaly

# %%
#Plotting e^(-tau) as a function of the orbital phase
plt.plot(phi, np.exp(-tot_tau1), label = 'i disc = ' + str(i_disc_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, np.exp(-tot_tau2), label = 'i disc = ' + str(i_disc_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, np.exp(-tot_tau3), label = 'i disc = ' + str(i_disc_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('Total Transmission Factor e^(-tau) Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('e^(-tau)')
plt.legend()

# %%
#Plotting e^(-tau) as a function of the orbital phase
plt.plot(phi, np.exp(-tot_tau1), label = 'i disc = ' + str(i_disc_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, np.exp(-tot_tau2), label = 'i disc = ' + str(i_disc_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, np.exp(-tot_tau3), label = 'i disc = ' + str(i_disc_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('Total Transmission Factor e^(-tau) Vs Orbital Phase')
plt.xlabel('Orbital Phase (Rad)')
plt.ylabel('e^(-tau)')
plt.ylim(8e-1, None)
plt.yscale('log')
plt.legend()

# %% [markdown]
# ## Total Pulsar Spectrum Through the Disk and Stellar Wind GIF

# %%
i_orb_deg = 25                             #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)          #Orbital inclination in rad
phi_deg_array = np.linspace(0, 360, 512)   #Orbital phases in deg
phi_array = np.deg2rad(phi_deg_array)      #Orbital phases in rad
disc_i_gif_deg = 60                        #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)    #Inclination in rad
om_deg = 138                               #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                    #Orbital argument of periastron in rad
Om_deg = 189                               #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                    #Longitude of ascending note in rad
nu_array = np.linspace(1, 8.4, 512)        #Frequency array

#Computing the spectra for all orbital phases
total_S_nu = tot_spectrum(phi=phi_array, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=2, T_wind=2e4, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=disc_i_gif, nu=nu_array, p=1.3, alpha=0.5) 
                      

#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1, 8.4)
ax.set_ylim(1e-5, 1)
ax.set_xlabel('Frequency (GHz)')
ax.set_ylabel('Flux density (Jy)')
title = ax.set_title('')

#Frame update function
def update(frame):
    line.set_data(nu_array, total_S_nu[frame, :])
    title.set_text('Total Spectrum Evolution at Inclination i = ' + str(int(disc_i_gif_deg)) + '(deg)\n at Orbital Phase = ' + str(int(phi_deg_array[frame])) + ' deg')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(phi_array), blit=False, interval=100)
#Saving GIF
ani.save("total_spectrum_evolution.gif", writer="pillow", fps=10)
plt.show()

# %% [markdown]
# # Parameter Studies

# %%
#DM function for parameter studies
def tot_DM_map(phi, i, i_disc, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, alpha, mu_e=1.2, s_array_cm=None):
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)
    
    M_star = M_star_sol * M_sun_cgs                                   #Converts the stellar mass from solar mass to g
    P = 1.068e8                                                       #Orbital period in seconds (1237 days)
    a = ((P**2*G_cgs*(M_star_sol+1.4)*M_sun_cgs)/(4*np.pi**2))**(1/3) #Semi-mmajor axis (cm)
    R_star = R_star_sol * R_sun_cgs                                   #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec)             #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                                           #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                                       #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                                 #Calculates the k constant (cm^-1)

    #Stellar wind number density
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                                 #Calculates the orbital separation along the orbit
    r_s_sqrd = r**2 + 2*r*s*(np.cos(phi+omega)*np.sin(i)*np.cos(Omega)+np.sin(phi+omega)*np.sin(i)*np.sin(Omega)) + s**2 #Calculates the squared radial distance from the star along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                         #Calculates the velocity of the wind 
    n_e = k/(r_s_sqrd*v_r_s)                                                                                             #Calculates the number density
    n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                                                                 #Eclipse condition
    
    #Disc number density
    r_disc = np.sqrt(r_s_sqrd)                                                     #Projected radius through disc plane   
    c_s = np.sqrt((k_B_cgs * T_disc*(r_disc/R_star)**(-alpha))/(mu_e * m_p_cgs))   #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                      #Calculates the scale height
    z = (r*np.sin(phi+omega)*np.sin(i_disc) + s*np.cos(i)*np.cos(i_disc))          #Calculates the height above the disc plane
    rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2) #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * m_p_cgs)                                            #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                                   #Constraining the inner disc radius

    #Total number density
    total_ne = n_e + ne_disc
    
    total_DM = np.trapz(total_ne, s) / pc_to_cm #Integrating the DM 

    return total_DM

# %%
#Free-free absorption function for parameter studies
def tot_ffa_map(phi, i, i_disc, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_wind, T_disc, beta_disc, rho0, nu, alpha, mu_e=1.2, s_array_cm=None):
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)
  
    M_star = M_star_sol * M_sun_cgs                                   #Converts the stellar mass from solar mass to g
    P = 1.068e8                                                       #Orbital period in seconds (1237 days)
    a = ((P**2*G_cgs*(M_star_sol+1.4)*M_sun_cgs)/(4*np.pi**2))**(1/3) #Semi-mmajor axis (cm)
    R_star = R_star_sol * R_sun_cgs                                   #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec)             #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                                           #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                                       #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                                 #Calculates the k constant (cm^-1)

    #Stellar wind number density
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                                 #Calculates the orbital separation along the orbit
    r_s_sqrd = r**2 + 2*r*s*(np.cos(phi+omega)*np.sin(i)*np.cos(Omega)+np.sin(phi+omega)*np.sin(i)*np.sin(Omega)) + s**2 #Calculates the squared radial distance from the star along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                         #Calculates the velocity of the wind 
    n_e = k/(r_s_sqrd*v_r_s)                                                                                             #Calculates the number density
    n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                                                                 #Eclipse condition
    
    #Disc number density
    r_disc = np.sqrt(r_s_sqrd)                                                     #Projected radius through disc plane   
    c_s = np.sqrt((k_B_cgs * T_disc*(r_disc/R_star)**(-alpha))/(mu_e * m_p_cgs))   #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                      #Calculates the scale height
    z = (r*np.sin(phi+omega)*np.sin(i_disc) + s*np.cos(i)*np.cos(i_disc))          #Calculates the height above the disc plane
    rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2) #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * m_p_cgs)                                            #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                                   #Constraining the inner disc radius

    #Total number density
    total_ne = n_e + ne_disc

    total_tau = 8.24e-2*nu**(-2.1)*((T_wind+T_disc)/2)**(-1.35)*np.trapz(total_ne**2, s / pc_to_cm) #Integrating the optical depth

    return total_tau

# %%
#DM Vs i disc and orb phase
i_disc_array_deg = np.linspace(0, 90, 50)       #Disc inclinations in degrees
i_disc_array_rad = np.deg2rad(i_disc_array_deg) #Disc inclinations in rad
phi_array_deg = np.linspace(0, 360, 50)         #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg)       #Orbital degrees in rad
i_orb_deg = 25                                  #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)               #Orbital inclination in rad
om_deg = 138                                    #Argument of periastron in degrees
om_rad = np.deg2rad(om_deg)                     #Argument of periastron in rad
Om_deg = 189                                    #Longitude of ascending node in degrees
Om_rad = np.deg2rad(Om_deg)                     #Longitude of ascending node in rad

#Initialising a DM 2D array
DM_map = np.zeros((len(i_disc_array_rad), len(phi_array_rad)))

#Filling the DM map 
for i_idx, i_disc in enumerate(i_disc_array_rad):
    for phi_idx, phi in enumerate(phi_array_rad):
        DM_map[i_idx, phi_idx] = tot_DM_map(phi=phi, i=i_orb_rad, i_disc=i_disc, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, 
                                               v_inf_kms=1e3, e=0.87, omega=om_rad, Omega=Om_rad, beta=2, T_disc=1.2e4, beta_disc=3.5, rho0=-12, alpha=0.5)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(DM_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], i_disc_array_deg[0], i_disc_array_deg[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Disc Inclination (deg)')
plt.title('Dispersion Measure Vs Orbital Phase and Disc Inclination')
plt.show()

# %%
#DM Vs M_star_sol and orb phase
i_disc_deg = 40                           #Disc inclination in degrees
i_disc_rad = np.deg2rad(i_disc_deg)       #Disc inclination in rad
phi_array_deg = np.linspace(0, 360, 50)   #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg) #Orbital degrees in rad
M_star_array = np.linspace(10, 30, 50)    #Stellar mass array

#Initialising a DM 2D array
DM_map = np.zeros((len(M_star_array), len(phi_array_rad)))

#Filling the DM map 
for m_idx, m_star in enumerate(M_star_array):
    for phi_idx, phi in enumerate(phi_array_rad):
        DM_map[m_idx, phi_idx] = tot_DM_map(phi=phi, i=i_orb_rad, i_disc=i_disc_rad, R_star_sol=9, M_star_sol=m_star, Mdot_Msun_per_yr=-9, v_0_kms=5, 
                                               v_inf_kms=1e3, e=0.87, omega=om_rad, Omega=Om_rad, beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, alpha=0.5)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(DM_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], M_star_array[0], M_star_array[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Stellar Mass (solar mass)')
plt.title('Dispersion Measure Vs Orbital Phase and Stellar Mass')
plt.show()

# %%
#DM Vs v_0 and orb phase
phi_array_deg = np.linspace(0, 360, 50)   #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg) #Orbital degrees in rad
v_0_array = np.linspace(5, 15, 50)        #Initial stellar wind velocity array

#Initialising a DM 2D array
DM_map = np.zeros((len(v_0_array), len(phi_array_rad)))

#Filling the DM map 
for v_idx, v_wind in enumerate(v_0_array):
    for phi_idx, phi in enumerate(phi_array_rad):
        DM_map[v_idx, phi_idx] = tot_DM_map(phi=phi, i=i_orb_rad, i_disc=i_disc_rad, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=v_wind, 
                                               v_inf_kms=1e3, e=0.87, omega=om_rad, Omega=Om_rad, beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, alpha=0.5)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(DM_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], v_0_array[0], v_0_array[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Initial Stellar Wind Velocity (km/s)')
plt.title('Dispersion Measure Vs Orbital Phase and Initial Stellar Wind Velocity')
plt.show()

# %%
#DM Vs v_inf and orb phase
phi_array_deg = np.linspace(0, 360, 50)   #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg) #Orbital degrees in rad
v_inf_array = np.linspace(1e3, 2e3, 50)   #Stellar wind terminal velocity array

#Initialising a DM 2D array
DM_map = np.zeros((len(v_inf_array), len(phi_array_rad)))

#Filling the DM map 
for v_idx, v_wind in enumerate(v_inf_array):
    for phi_idx, phi in enumerate(phi_array_rad):
        DM_map[v_idx, phi_idx] = tot_DM_map(phi=phi, i=i_orb_rad, i_disc=i_disc_rad, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, 
                                               v_inf_kms=v_wind, e=0.87, omega=om_rad, Omega=Om_rad, beta=2, T_disc=1.2e4, beta_disc=3.5, rho0=-12, alpha=0.5)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(DM_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], v_inf_array[0], v_inf_array[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Stellar Wind Terminal Velocity (km/s)')
plt.title('Dispersion Measure Vs Orbital Phase and Stellar Wind Terminal Velocity')
plt.show()

# %%
#DM Vs T_disc and orb phase
phi_array_deg = np.linspace(0, 360, 50)    #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg)  #Orbital degrees in rad
T_disc_array = np.linspace(0.5e4, 2e4, 50) #Disc Temperature array

#Initialising a DM 2D array
DM_map = np.zeros((len(T_disc_array), len(phi_array_rad)))

#Filling the DM map 
for T_idx, T_disc in enumerate(T_disc_array):
    for phi_idx, phi in enumerate(phi_array_rad):
        DM_map[T_idx, phi_idx] = tot_DM_map(phi=phi, i=i_orb_rad, i_disc=i_disc_rad, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, 
                                               v_inf_kms=1e3, e=0.87, omega=om_rad, Omega=Om_rad, beta=2, T_disc=T_disc, beta_disc=4, rho0=-12, alpha=0.5)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(DM_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], T_disc_array[0], T_disc_array[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Disc Temperature (K)')
plt.title('Dispersion Measure Vs Orbital Phase and Disc Temperature')
plt.show()

# %%
#DM Vs rho0 and orb phase
phi_array_deg = np.linspace(0, 360, 50)    #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg)  #Orbital degrees in rad
rho0_array = np.linspace(-13, -10, 50)     #Disc density at stellar surface array

#Initialising a DM 2D array
DM_map = np.zeros((len(rho0_array), len(phi_array_rad)))

#Filling the DM map 
for rho0_idx, rho0 in enumerate(rho0_array):
    for phi_idx, phi in enumerate(phi_array_rad):
        DM_map[rho0_idx, phi_idx] = tot_DM_map(phi=phi, i=i_orb_rad, i_disc=i_disc_rad, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, 
                                               v_inf_kms=1e3, e=0.87, omega=om_rad, Omega=Om_rad, beta=2, T_disc=1.2e4, beta_disc=4, rho0=rho0, alpha=0.5)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(DM_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], rho0_array[0], rho0_array[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Disc Intrinsic Density (gcm^-3)')
plt.title('Dispersion Measure Vs Orbital Phase and Disc Intrinsic Density')
plt.show()

# %%
#DM Vs mass loss and orb phase
phi_array_deg = np.linspace(0, 360, 50)        #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg)      #Orbital degrees in rad
Mdot_Msun_array = np.linspace(-10, -8, 50)     #Stellar mass loss per year array

#Initialising a DM 2D array
DM_map = np.zeros((len(rho0_array), len(phi_array_rad)))

#Filling the DM map 
for Mdot_idx, Mdot in enumerate(Mdot_Msun_array):
    for phi_idx, phi in enumerate(phi_array_rad):
        DM_map[Mdot_idx, phi_idx] = tot_DM_map(phi=phi, i=i_orb_rad, i_disc=i_disc_rad, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=Mdot, v_0_kms=5, 
                                               v_inf_kms=1e3, e=0.87, omega=om_rad, Omega=Om_rad, beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, alpha=0.5)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(DM_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], Mdot_Msun_array[0], Mdot_Msun_array[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Stellar Mass Loss (solar mass/ yr)')
plt.title('Dispersion Measure Vs Orbital Phase and Stellar Mass Loss')
plt.show()

# %%
#Optical depth Vs wind temperature and orbital phase
phi_array_deg = np.linspace(0, 360, 50)   #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg) #Orbital degrees in rad
T_wind_array = np.linspace(1e4, 4e4, 50)  #Wind temperature array
nu = 1.5                                  #Signal frequency (GHz)

#Initialising an optical depth 2D array
tau_map = np.zeros((len(T_wind_array), len(phi_array_rad)))

#Filling the optical depth map 
for T_idx, T_wind in enumerate(T_wind_array):
    for phi_idx, phi in enumerate(phi_array_rad):
        tau_map[T_idx, phi_idx] = tot_ffa_map(phi=phi, i=i_orb_rad, i_disc=i_disc_rad, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=-9, v_0_kms=5, 
                                               v_inf_kms=1e3, e=0.87, omega=om_rad, Omega=Om_rad, beta=2, T_wind=T_wind, T_disc=1.2e4, beta_disc=4, rho0=-12, nu=nu, alpha=0.5)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(tau_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], T_wind_array[0], T_wind_array[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Optical Depth')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Wind Temperature (K)')
plt.title('Optical Depth Vs Orbital Phase and Wind Temperature, nu = ' + str(nu) + ' (GHz)')
plt.show()

# %% [markdown]
# # Rotation Measure

# %%
#Calculating the RM
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)

tot_RM1 = tot_RM(phi=phi, i=np.deg2rad(36), a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(138), Omega=np.deg2rad(189), beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=np.deg2rad(40), alpha=0.5)
tot_RM2 = tot_RM(phi=phi, i=np.deg2rad(36), a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(138), Omega=np.deg2rad(189), beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=np.deg2rad(45), alpha=0.5)
tot_RM3 = tot_RM(phi=phi, i=np.deg2rad(36), a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(138), Omega=np.deg2rad(189), beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=np.deg2rad(50), alpha=0.5)

#Plotting
plt.plot(phi, tot_RM1, label='i disc = 60 (deg)')
plt.plot(phi, tot_RM2, label='i disc = 65 (deg)')
plt.plot(phi, tot_RM3, label='i disc = 70 (deg)')
plt.title('Total Rotation Measure Vs Orbital Phase')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Rotation Measure (rad m^-2)')
plt.legend()

# %%
#Calculating the RM
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)

tot_RM1 = tot_RM(phi=phi, i=np.deg2rad(36), a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(138), Omega=np.deg2rad(189), beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=np.deg2rad(40), alpha=0.5)
tot_RM2 = tot_RM(phi=phi, i=np.deg2rad(36), a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(138), Omega=np.deg2rad(189), beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=np.deg2rad(45), alpha=0.5)
tot_RM3 = tot_RM(phi=phi, i=np.deg2rad(36), a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=-9, v_0_kms=5, v_inf_kms=1e3, e=0.87, omega=np.deg2rad(138), Omega=np.deg2rad(189), beta=2, T_disc=1.2e4, beta_disc=4, rho0=-12, i_disc=np.deg2rad(50), alpha=0.5)

#Plotting
plt.plot(phi, -tot_RM1, label='i disc = 60 (deg)')
plt.plot(phi, -tot_RM2, label='i disc = 65 (deg)')
plt.plot(phi, -tot_RM3, label='i disc = 70 (deg)')
plt.title('Total Rotation Measure Vs Orbital Phase')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Rotation Measure (rad m^-2)')
plt.legend()

# %%
#Stellar magnetic field
B = 0.8 * (1/23)                                                                                                                                                   #Total magnetic field at periastron (G)
B_parallel = B * (np.sin(np.deg2rad(35))*np.cos(np.deg2rad(189))*np.cos(np.deg2rad(138)) + np.sin(np.deg2rad(35))*np.sin(np.deg2rad(189))*np.sin(np.deg2rad(138))) #Magnetic field parallel to line of sight

print('Stellar magnetic field at periastron: ' + str(B_parallel) + ' Gauss')

#Disc magnetic field - https://arxiv.org/abs/1706.09732
mu_e = 1.2
rho_disc = 1e6 * (mu_e * con.m_p).cgs.value
B_disc = 0.8*(rho_disc/1e-12)**0.44
B_disc_parallel = B_disc * (np.sin(np.deg2rad(35))*np.cos(np.deg2rad(189))*np.cos(np.deg2rad(138)) + np.sin(np.deg2rad(35))*np.sin(np.deg2rad(189))*np.sin(np.deg2rad(138)))

print('Disc magnetic field at periastron: ' + str(B_disc_parallel) + ' Gauss')

print('The stellar magnetic field is ' + str(B_parallel/B_disc_parallel) + ' times larger than the disc magnetic field')
# Out:
# Stellar magnetic field at periastron: 0.012555246859875219 Gauss
# Disc magnetic field at periastron: 0.0008988513309691624 Gauss
# The stellar magnetic field is 13.968101761987556 times larger than the disc magnetic field
