# %% [markdown]
# ## This model features a high mass Be star accelerating wind and circumstellar disc, with an elliptical orbit, a 3D coordinate system, and eclipses of a 'pseudo-signal' from a pulsar on the orbit.
# ## The main goal of this model is to see the number density, dispersion measure, optical depth and spectrum along a line of sight from a point on the orbit given an orbital phase, orbital and disc inclination, eccentricity, argument of periastron and longitude of ascending node.
# ## Stellar parameters are modelled after the star SS 2883 of the HMXB system PSR B1259-63/SS 2883. Wind terminal velocity is taken from the paper - https://arxiv.org/pdf/0806.4868, while the remaining stellar properties are taken from https://ui.adsabs.harvard.edu/abs/2011ApJ...732L..11N/abstract, https://arxiv.org/abs/1307.7083 and https://arxiv.org/pdf/1804.08402.
# ## Parameter values of the disc of SS 2883 are taken from the paper https://arxiv.org/abs/2204.08124

# %% [markdown]
# # Equations and Geometry
# ## Electron number density
# # $n_{e}(r) = \frac{\rho}{\mu_{e}m_{p}} = \frac{\dot{M}}{4\pi\mu_{e}m_{p}r^2v(r)} = \frac{k}{r^2v(r)}$
# Where
# # $\rho = \frac{\dot{M}}{4\pi r^2v(r)}$
#
# And
#
# # $k = \frac{\dot{M}}{4\pi\mu_{e}m_{p}}$
# With
#
# * $\rho$ =      Density
# * $\mu_{e}$ =   Mean molecular weight per free electron (typically set at a value of 1.2)
# * $m_{p}$ =     Proton mass
# * $\dot{M}$ =   Wind mass loss
# * $v(r)$ =     Radial wind velocity
# * $r$ =         radial distance from the center of the star
#
# ## Accelerating Wind ($\beta$ law)
# The wind velocity at a certain distance away from the star is
# # $v(r) = v_0 + (v_{\infty} - v_0)(1-\frac{R_{*}}{r})^\beta$
# with
# * $v_0$ =        The wind velocity at stellar surface
# * $v_{\infty}$ = Wind terminal velocity
# * $R_{*}$ =      Stellar radius
# * $\beta$ =      Wind acceleration exponent
#
# By placing the star and orbit at the xy plane origin, we can consider an elliptical orbit in cartesian coordinates
# # $\frac{x^2}{a^2} + \frac{y^2}{b^2} = 1$
# with
# * $a$ = Semi-major axis
# * $b$ = Semi-minor axis
# The semi-minor axis can be defined as $a\sqrt{1 - e^2}$, where $e^2$ is the eccentricity.
# In polar coordinates, the ellipse is offset along the x-axis by the focus - $f = ae$.
#
# The orbital separation in polar coordinates becomes
# # $r = \frac{a(1-e^2)}{1+ecos(\phi)}$
# Where $\phi$ is the orbital phase.
#
# The pulsar position vector along the orbit is described as
#
# # $ r_s = \begin{pmatrix} rcos(\phi) \\ rsin(\phi) \\ 0  \end{pmatrix}$
#
# Where $\omega$ is the argument of periastron. The observer unit vector (direction of signal to observer) is then defined as
#
# # $ \hat{n} = \begin{pmatrix} sin(i)cos(\Omega) \\ sin(i)sin(\Omega) \\ cos(i)  \end{pmatrix}$
#
# Where $i$ is the inclination and $\Omega$ is the longitude of ascending node.
#
# The 2D orbit is then rotated into 3D space by computing
#
# # $ r_{rot} = R_{z}(\Omega)R_{x}(i)r_s$
#
# Where
#
# # $ R_{z}(\Omega) = \begin{pmatrix} cos(\Omega) & -sin(\Omega) & 0 \\ sin(\Omega) & cos(\Omega) & 0 \\ 0 & 0 & 1  \end{pmatrix}$
#
# # $ R_{x}(i) = \begin{pmatrix} 1 & 0 & 0 \\ 0 & cos(i) & -sin(i) \\ 0 & sin(i) & cos(i)  \end{pmatrix}$
#
# Resulting in
#
# # $ r_{rot} = \begin{pmatrix} r[cos(\Omega)cos(\phi) -sin(\Omega)cos(i)sin(\phi)] \\ r[sin(\Omega)cos(\phi) + cos(\Omega)cos(i)sin(\phi)] \\ rsin(i)sin(\phi)  \end{pmatrix}$
#
# The radial distance of the signal from the star along the path of the line of sight is computed by separating the x, y, and z components of $r_{rot} + s\hat{n}$, where $s\ge0$, is the distance along the line of sight, and comuting $r(s) = \sqrt{x_{s}^2 + y_{s}^2 + z_{s}^2}$.
#
# The number density at a specific point along the line of sight distance from the orbit can then be described as
# # $n_e(r(s)) = \frac{k}{r(s)^2v(r(s))}$
#
# From the definition of $r(s)$,
#
# ## $r(s)^2 = (r_s + s\hat{n})^2 = r^2 + 2rs [cos(\phi) sin (i)cos(\Omega) + sin(\phi)sin(i)sin(\Omega)] + s^2$
#
# ## Dispersion Measure
# # $DM(\phi,i) = \int_{0}^{\infty}n_e(r(s))ds = k\int_{0}^{\infty}\frac{ds}{v(r(s))r(s)^2}$
#
# ## Semi-major axis of PSR B1259-63
# Given that the orbital period of PSR B1259-63 is approximately 1237 days, its mass is $1.4 M_\odot$ and that the mass of SS 2883 is approximately $20 M_\odot$, using Kepler's 3rd law, the semi-major axis is
# # $a^3 = \frac{P^2G(M + m)}{4\pi^2}, a \sim 1345R_\odot$
# With
# * $P$ = Orbital period
# * $G$ = Gravitational constant
# * $M$ = Mass of SS 2883
# * $m$ = Mass of PSR B1259-63
#
# ## Free-free Absorption
# Free-free absorption causes signals to be absorbed by the stellar wind depending on its optical depth.
# # $\tau_{FFA} \approx 8.24x10^{-2}\nu^{-2.1}T_e^{-1.35}\int n_e^2ds$
#
# with
# * $\tau_{FFA}$ = The optical depth
# * $\nu$ = The signal frequency
# * $T_e$ = The stellar wind temperature
# * $n_e$ = The number density
# * $s$ = The line of sight distance
#
# ## Flux density
# The flux density of the pulsar signal is decribed as
# # $S_{\nu} = S_{psr,\nu}e^{-\tau} = \nu^{-p}e^{-\tau}$
# with
# * $S_{psr,\nu}$ = The intrinsic flux of the pulsar
# * $\nu$ = The signal frequency
# * $p$ = The power law index
# * $\tau$ = The optical depth
# When the flux density of the signal is plotted against frequency, it results in the pulsar's spectrum, which changes along eccentric orbits.
#
# ## Be Disc
# Be stars such as SS 2883 have a circumstellar disc due to the star's immense rotation rate. The disc introduces an additional desnity structure to the system, which is described as
# # $\rho(r_{disc}, z) = \rho_0(\frac{r_{disc}}{R_*})^{-\beta}e^{\frac{-z^2}{H(r_{disc})^2}}$
# with
# * $\rho_0$ = The disc desnity at stellar surface
# * $r_{disc}$ = radial distance in the disc plane
# * $R_*$ = Stellar radius
# * $\beta$ = Disc power law exponent
# * $z$ = Height above the disc plane
# * $H(r)$ = Scale height
#
# The scale height is described as
# # $H(r_{disc}) = c_s\sqrt{\frac{r_{disc}}{GM_*}}r_{disc}$
# with
# * $c_s$ = Speed of sound
# * $G$ = Gravitational constant
# * $M_*$ = Stellar mass
#
# And the speed of sound is described as
# # $c_s = \sqrt{\frac{kT}{\mu_em_p}}$
# with
# * $k$ = Boltzmann constant
# * $T$ = Disc temperature
#
# Using the disc desnity profile the number density through the disc becomes
# # $n_{e,disc} = \frac{\rho(r_{disc},z)}{\mu_em_p}$
#
# From which the DM and optical depth can be calculated
#
# Placing the disc at the xy plane along with the pulsar orbit, the pulsar position is $ r_s = \begin{pmatrix} rcos(\phi) \\ rsin(\phi) \\ 0  \end{pmatrix}$. The line of sight unit vector is $\hat{n} = (sin(i)cos(\Omega), sin(i)sin(\Omega), cos(i))$.
#
# The pulsar position rotation onto the disc plane is described as
#
# # $r_{rot} = R_{z}(\Omega)R_{x}(i)R_{z}(\omega)r_s$
#
# Where
#
# # $ R_{z}(\Omega) = \begin{pmatrix} cos(\Omega) & -sin(\Omega) & 0 \\ sin(\Omega) & cos(\Omega) & 0 \\ 0 & 0 & 1  \end{pmatrix}$
#
# # $ R_{x}(i) = \begin{pmatrix} 1 & 0 & 0 \\ 0 & cos(i) & -sin(i) \\ 0 & sin(i) & cos(i)  \end{pmatrix}$
#
# # $ R_{z}(\omega) = \begin{pmatrix} cos(\omega) & -sin(\omega) & 0 \\ sin(\omega) & cos(\omega) & 0 \\ 0 & 0 & 1  \end{pmatrix}$
#
# Resulting in
#
# ### $ r_{rot} = \begin{pmatrix} r[(cos(\Omega)cos(\omega) - sin(\Omega)cos(i)sin(\omega)cos(\phi) + (-cos(\Omega)sin(\omega) - sin(\Omega)cos(i)cos(\omega))sin(\phi))] \\ r[(sin(\Omega)cos(\omega) + cos(\Omega)cos(i)sin(\omega))cos(\phi) + (-sin(\Omega)sin(\omega) + cos(\Omega)cos(i)cos(\omega))sin(\phi)] \\ rsin(i)sin(\phi + \omega)  \end{pmatrix}$
#
# The radial distance of the signal from the star along the path of the line of sight is computed by separating the x and y components of $r_{rot} + s\hat{n}$, where $s\ge0$, is the distance along the line of sight, and comuting $r_{disc} = \sqrt{x_{s}^2 + y_{s}^2}$.
#
# The disc height above its plane is described as $z = r(s)\cdot{\hat{n}_{disc}} = r_s\hat{n}_{disc} + s(\hat{n}\cdot{\hat{n}_{disc}})$. Where the line of sight unit vector is $\hat{n} = (sin(i)cos(\Omega), sin(i)sin(\Omega), cos(i))$, and the disc normal is $\hat{n}_{disc} = (0, sin(i_{disc}), cos(i_{disc}))$, such that the disc rotates on the x-axis.
#
# ## Combined Stellar Wind and Be Disc
# Since the stellar wind and Be disc do not depend on each-other, combining their number densities is straight forward
# # $n_{e,total} = n_{e,wind} + n_{e,disc}$
# With this total number density we can calculate the dispersion measure, optical depth, transmission factor and spectrum of the entire system.

# %%
#Packages
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import astropy.units as u
import astropy.constants as con
import ipywidgets as widgets
from IPython.display import display
from scipy.optimize import curve_fit
from scipy.optimize import minimize
import emcee
import corner
from IPython.display import display, Math

# %%
#Constants in cgs units
R_sun_cgs = con.R_sun.cgs.value   #Radius of sun in cgs
M_sun_cgs = con.M_sun.cgs.value   #Mass of the sun in cgs
yr_to_sec = u.yr.to(u.s)          #Year to seconds
kms_cgs = (u.km/u.s).to(u.cm/u.s) #Kms in cgs
m_p_cgs = con.m_p.cgs.value       #Mass of proton in cgs
G_cgs = con.G.cgs.value           #Gravitational constant in cgs   
k_B_cgs = con.k_B.cgs.value       #Boltzmann constant in cgs
AU_cgs = (con.au.cgs.value)       #AU in cgs
pc_to_cm = u.pc.to(u.cm)          #PC to cm

# %%
#Number density function
def num_density(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, s, e, omega, Omega, beta, mu_e=1.2):
    '''This function calculates the number density at a specific point along an elliptical orbit within a spherically cymmetric wind 
    with accelerating velocity.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    mu_e             [float] -> Mean molecular weight per free electron
    e                [float] -> Eccentricity (0 < e < 1)
    s                [float] -> Distance along line of sight from signal (AU)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent 
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the number density [array] -> (cm^-3)'''
    a = a_Rsun * R_sun_cgs                                                                                            #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                                                                                   #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec)                                                             #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                                                                                           #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                                                                                       #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                                                                                 #Calculates the k constant (cm^-1)
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                              #Calculates the orbital separation along the orbit
    x = r*(np.cos(Omega)*np.cos(phi) - np.sin(Omega)*np.cos(i)*np.sin(phi)) + s*(np.sin(i)*np.cos(Omega))             #Rotated x axis
    y = r*(np.sin(Omega)*np.cos(phi) + np.cos(Omega)*np.cos(i)*np.sin(phi)) + s*(np.sin(i)*np.sin(Omega))             #Rotated y axis
    z = r*np.sin(i)*np.sin(phi) + s*np.cos(i)                                                                         #Rotated z axis
    r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                 #Calculates the radial distance from the pulsar along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                    #Calculates the velocity of the wind 

    n_e = k/(r_s**2 * v_r_s)                                                                                          #Calculates the number density
    n_e[r_s <= R_star] = 0                                                                                            #Eclipse condition
     
    return n_e

# %%
#DM function
def dm_beta_wind(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, mu_e=1.2, s_array_cm=None):
    '''This function calculates the dispersion measure along a line of sight, given orbital phase and inclination, 
    assuming a spherically symmetric wind with an accelerating velocity.
    --------------------------------------------------------------------------------------------------------------
    Parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent 
    mu_e             [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the dispersion measure [array] -> (pc cm^-3).'''
    a = a_Rsun * R_sun_cgs                                #Converts the semi-major axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    DM_array = []

    for value in phi:
        r = a * (1 - e**2) / (1 + e * np.cos(value))                                                                             #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/r_s)**beta                                                                     #Calculates the velocity of the wind 
        n_e = k / (r_s**2 * v_r_s)                                                                                               #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition

        DM_cgs = np.trapz(n_e, s)                                                                                                #Integrating the DM in cm^-2
        DM = (DM_cgs / pc_to_cm)                                                                                                 #Converting DM to pc cm^3
        DM_array.append(DM)

    return np.array(DM_array)

# %%
#Free-free absorption function
def ffa(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, nu, T, mu_e=1.2, s_array_cm=None):
    '''This function calculates the free-free absorption along a line of sight, given orbital phase and inclination, 
    assuming a spherically symmetric wind with an accelerating velocity.
    --------------------------------------------------------------------------------------------------------------
    Parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    nu               [float] -> Signal frequency (GHz)
    T                [float] -> Stellar wind temperature (K)
    mu_e             [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array].'''
    a = a_Rsun * R_sun_cgs                                #Converts the semi-major axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    tau_array = []

    for value in phi:
        r = a * (1 - e**2) / (1 + e * np.cos(value))                                                                             #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/r_s)**beta                                                                     #Calculates the velocity of the wind 
        n_e = k / (r_s**2 * v_r_s)                                                                                               #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition

        tau = 8.24e-2*nu**-2.1*T**-1.35*np.trapz(n_e**2, s / pc_to_cm)                                                           #Integrating the optical depth
        tau_array.append(tau)

    return np.array(tau_array)

# %%
#Flux density function
def spectrum(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, nu, T, p, mu_e=1.2, s_array_cm=None):
    '''This function calculates the spectrum of the pulsar for a given inclination and frequency along the orbit.
    -------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    nu               [float] -> Signal frequency (GHz)
    T                [float] -> Stellar wind temperature (K)
    p                [float] -> Power law exponent
    mu_e             [float] -> Mean molecular weight per free electron
    
    -------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the pulsar spectrum [array] (Jy)'''
    a = a_Rsun * R_sun_cgs                                #Converts the semi-major axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a flux density array
    S_nu_array = []

    for value in phi:
        for freq in nu:
            r = a * (1 - e**2) / (1 + e * np.cos(value))                                                                             #Calculates the orbital separation along the orbit
            x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
            y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
            z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
            r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
            v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/r_s)**beta                                                                     #Calculates the velocity of the wind 
            n_e = k / (r_s**2 * v_r_s)                                                                                               #Calculates the number density
            n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition

            tau = 8.24e-2*freq**-2.1*T**-1.35*np.trapz(n_e**2, s / pc_to_cm) #Integrating the optical depth
            S_nu = freq**(-p)*np.exp(-tau)                                   #Calculating the flux density
            S_nu_array.append(S_nu)
    S_nu_2D = np.array(S_nu_array).reshape(len(phi), len(nu))                #Reshaping to a 2D array
    return S_nu_2D

# %%
#Disc number density function
def disc_ne(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, s, mu_e=1.2):
    '''This function calculates the number density along the line of sight from the
    pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Argument of periastron (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    s          [array] -> Array of line of sight points (cm)
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the number desnity [array] (cm^-3)'''
    a = a_Rsun * R_sun_cgs               #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs      #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs      #Converts the stellar mass from solar mass to g
    r = a*(1 - e**2)/(1 + e*np.cos(phi)) #Calculates the orbital separation along the orbit

    # x and y rotation coordinates of the disc
    x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.cos(Omega))
    y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.sin(Omega))
        
    r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                          #Projected radius through disc plane        
    c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                  #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                      #Calculates the scale height
    z = r*np.sin(phi)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
    rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                      #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                            #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                                                                   #Constraining the inner disc radius

    return ne_disc

# %%
#Disc dispersion measure function
def disc_DM(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, mu_e=1.2, s_array_cm=None):
    '''This function calculates dispersion measure along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the dispersion measure [array] (pc cm^-3)'''
    a = a_Rsun * R_sun_cgs          #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs #Converts the stellar mass from solar mass to g

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    disc_DM_array = []

    for value in phi:
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                           #Calculates the orbital separation along the orbit
        
        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane           
        c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                    #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                        #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius


        disc_DM_cgs = np.trapz(ne_disc, s)                                                                               #Integrating the DM in cm^-2
        disc_DM = (disc_DM_cgs / pc_to_cm)                                                                               #Converting DM to pc cm^3
        disc_DM_array.append(disc_DM)

    return np.array(disc_DM_array)

# %%
#Disc free-free absorption function
def disc_ffa(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, nu, mu_e=1.2, s_array_cm=None):
    '''This function calculates optical depth along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    nu         [float] -> Signal frequency (GHz)
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array]'''
    a = a_Rsun * R_sun_cgs          #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs #Converts the stellar mass from solar mass to g

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    disc_tau_array = []
    
    for value in phi:
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                           #Calculates the orbital separation along the orbit
        
        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane          
        c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                    #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                        #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius


        disc_tau = 8.24e-2*nu**(-2.1)*T**(-1.35)*np.trapz(ne_disc**2, s / pc_to_cm)                                      #Integrating tau
        disc_tau_array.append(disc_tau)

    return np.array(disc_tau_array)

# %%
#Disc flux density function
def disc_spectrum(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, nu, p, mu_e=1.2, s_array_cm=None):
    '''This function calculates optical depth along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    nu         [float] -> Signal frequency (GHz)
    p          [float] -> Power law exponent
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array]'''
    a = a_Rsun * R_sun_cgs          #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs #Converts the stellar mass from solar mass to g
    
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    disc_S_nu_array = []
    
    for value in phi:
        for freq in nu:
            r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                           #Calculates the orbital separation along the orbit
            
            # x and y rotation coordinates of the disc
            x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
            y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
            r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane          
            c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                    #Calculates the disc speed of sound
            H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
            z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
            rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                        #Calculates the disc desnity profile
            ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
            ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius


            disc_tau = 8.24e-2*freq**(-2.1)*T**(-1.35)*np.trapz(ne_disc**2, s / pc_to_cm)                                    #Integrating tau
            disc_S_nu = freq**(-p)*np.exp(-disc_tau)                                                                         #Calculatinng the flux density
            disc_S_nu_array.append(disc_S_nu)
    disc_S_nu_2D = np.array(disc_S_nu_array).reshape(len(phi), len(nu))                                                      #Reshaping to a 2D array
    return np.array(disc_S_nu_2D)

# %%
#Total wind-disc number density function
def tot_num_density(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, s, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, mu_e=1.2):
    '''This function calculates the total number density at a specific point along an elliptical orbit within a spherically cymmetric wind 
    with accelerating velocity and an axisymmetric disc.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    s                [float] -> Distance along line of sight from signal (AU)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total number density [array] -> (cm^-3)'''
    #Stellar wind number density
    a = a_Rsun * R_sun_cgs                                                                                               #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                                                                                      #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec)                                                                #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                                                                                              #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                                                                                          #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                                                                                    #Calculates the k constant (cm^-1)
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                                 #Calculates the orbital separation along the orbit
    x = r*(np.cos(Omega)*np.cos(phi) - np.sin(Omega)*np.cos(i)*np.sin(phi)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
    y = r*(np.sin(Omega)*np.cos(phi) + np.cos(Omega)*np.cos(i)*np.sin(phi)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
    z = r*np.sin(i)*np.sin(phi) + s*np.cos(i)                                                                            #Rotated z axis
    r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                    #Calculates the radial distance from the pulsar along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                       #Calculates the velocity of the wind 
    n_e = k/(r_s**2 * v_r_s)                                                                                             #Calculates the number density
    n_e[r_s <= R_star] = 0                                                                                               #Eclipse condition
    
    #Disc number density
    M_star = M_star_sol * M_sun_cgs                                                                                      #Converts the stellar mass from solar mass to g
    
    # x and y rotation coordinates of the disc
    x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.cos(Omega))
    y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.sin(Omega))
        
    r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                          #Projected radius through disc plane        
    c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                             #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                      #Calculates the scale height
    z = r*np.sin(phi)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
    rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                 #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                            #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                                                                   #Constraining the inner disc radius

    #Total number density
    total_ne = n_e + ne_disc

    return total_ne

# %%
#Total wind-disc dispersion measure function
def tot_DM(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, mu_e=1.2, s_array_cm=None):
    '''This function calculates the dispersion measure along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total dispersion measure [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_DM_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                           #Calculates the velocity of the wind 
        n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
        #Disc number density

        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane        
        c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_DM_cgs = np.trapz(total_ne, s) #Integrating the DM in cm^-2
        total_DM = (total_DM_cgs / pc_to_cm) #Converting DM to pc cm^3
        tot_DM_array.append(total_DM)

    return np.array(tot_DM_array)

# %%
#Total wind-disc free-free absorption function
def tot_ffa(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_wind, T_disc, beta_disc, rho0, i_disc, nu, mu_e=1.2, s_array_cm=None):
    '''This function calculates the optical depth along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    T_wind           [float] -> Temperature of wind (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    nu               [float] -> Signal frequency (GHz)
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total optical depth [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_tau_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                           #Calculates the velocity of the wind 
        n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
        #Disc number density

        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane 
        c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_tau = 8.24e-2*nu**(-2.1)*((T_wind+T_disc)/2)**(-1.35)*np.trapz(total_ne**2, s / pc_to_cm) #Integrating the optical depth
        tot_tau_array.append(total_tau)

    return np.array(tot_tau_array)

# %%
#Total wind-disc flux density function
def tot_spectrum(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_wind, T_disc, beta_disc, rho0, i_disc, nu, p, mu_e=1.2, s_array_cm=None):
    '''This function calculates the flux density along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    T_wind           [float] -> Temperature of wind (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    nu               [float] -> Signal frequency (GHz)
    p                [float] -> Spectrum power law exponent
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total flux density [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_S_nu_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        for freq in nu:
            #Stellar wind number density
            r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
            x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
            y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
            z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
            r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
            v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                           #Calculates the velocity of the wind 
            n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
            n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
            #Disc number density
            
            # x and y rotation coordinates of the disc
            x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
            y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
            r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane        
            c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
            H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
            z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
            rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
            ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
            ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

            #Total number density
            total_ne = n_e + ne_disc

            total_tau = 8.24e-2*freq**(-2.1)*((T_wind+T_disc)/2)**(-1.35)*np.trapz(total_ne**2, s / pc_to_cm) #Integrating the DM in cm^-2
            total_S_nu = freq**(-p)*np.exp(-total_tau)                                                        #Calculatinng the flux density
            tot_S_nu_array.append(total_S_nu)
        
    tot_S_nu_2D = np.array(tot_S_nu_array).reshape(len(phi), len(nu))                                         #Reshaping to a 2D array
    return np.array(tot_S_nu_2D)

# %%
#Total wind-disc dispersion measure function
def tot_DM_mcmc(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, ISM_DM, mu_e=1.2, s_array_cm=None):
    '''This function calculates the dispersion measure along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    ISM_DM           [float] -> Interstellar medium dispersion measure (pc cm^-3)
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total dispersion measure [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_DM_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1 - R_star/r_s)**beta                                                                         #Calculates the velocity of the wind 
        n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
        #Disc number density

        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane 
        c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_DM_cgs = np.trapz(total_ne, s)          #Integrating the DM in cm^-2
        total_DM = (total_DM_cgs / pc_to_cm) + ISM_DM #Converting DM to pc cm^3
        tot_DM_array.append(total_DM)

    return np.array(tot_DM_array)

# %%
#Curve_fit DM function
def DM_curve_fit(phi, Mdot, v_inf_kms, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, ISM_DM):
    '''
    This function employs scipy's curve_fit by implementing the general tot_DM function.
    -------------------------------------------------------------------------------------
    Parameters:

    phi    [array] -> Orbital Phase (rad)
    i_orb  [float] -> Orbital Inclination (rad)
    Mdot   [float] -> Log stellar Mass Loss (solar mass per year)
    e      [float] -> Eccentricity
    omega  [float] -> Argument of Periastron (rad)
    Omega  [float] -> Longitude of Ascending Node (rad)
    rho0   [float] -> Log initial Disc Density (gcm^-3)
    i_disc [float] -> Disc Inclination (rad)
    --------------------------------------------------------------------------------------
    Returns:

    The dipersion measure curve fit.
    '''
    #Fixing the remaining parameters of the model
    i_orb_fixed = np.deg2rad(25)
    a_Rsun_fixed = 1345
    R_star_sol_fixed = 9.2
    M_star_sol_fixed = 20
    v_0_kms_fixed = 5
    e_fixed = 0.87

    return tot_DM_mcmc(phi, i_orb_fixed, a_Rsun_fixed, R_star_sol_fixed, M_star_sol_fixed, Mdot, v_0_kms_fixed, v_inf_kms, e_fixed, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, ISM_DM)

# %% [markdown]
# # MeerKAT 2024 Periastron Passage

# %%
#Generating the MeerKAT data 
meerkatdata = np.genfromtxt('DM_lit.txt')

# %%
#Seperating the 2024 periastron datapoints
meerkat2024 = meerkatdata[38:109,:]
meerkat2024.shape
# Out:
# (71, 3)

# %%
#Separating the days, DM, and error values
days2024 = meerkat2024[:, 0]
DM2024 = meerkat2024[:, 1]
error2024 = meerkat2024[:, 2]

# %%
#Plotting the data over the entire orbital phase
plt.errorbar(days2024, DM2024,yerr=error2024, fmt='o')
plt.axvline(x=-77, color='magenta', label='pre-periastron crossing')
plt.axvline(x=35, color='purple', label='post-periastron crossing')
plt.title('MeerKAT 2024 Periastron Passage')
plt.xlabel('Days')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.xlim(-618.5, 618.5)
plt.legend()

# %%
#Plotting the data over the data orbital phase
plt.errorbar(days2024, DM2024,yerr=error2024, fmt='o')
plt.axvline(x=-77, color='magenta', label='pre-periastron crossing')
plt.axvline(x=35, color='purple', label='post-periastron crossing')
plt.title('MeerKAT 2024 Periastron Passage')
plt.xlabel('Days')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %% [markdown]
# # Comparing our Model with Results of Past Periastron Passages of PSR B1259-63
# Since most available papers only report $\Delta DM$ - the difference in dispersion measure from periastron, with locations of the pulsar in terms of days from or to periastron, the orbital phases need to be translated as
# ## $\phi = 2\pi(\frac{\Delta t}{P}) = 2\pi(\frac{\Delta t}{1237 days})$

# %%
phi2024 = []

for i in days2024:
    if i < 0:
        phi_min = 2*np.pi*((i)/1237)
        phi2024.append(phi_min)
    if i > 0:
        phi_pl = 2*np.pi*((i)/1237)
        phi2024.append(phi_pl)

# %%
#Extra synthetic datapoint
DM2024 = np.append(DM2024, 145.8)
error2024 = np.append(error2024, 0.2)
phi2024.append(2.8)

plt.scatter(phi2024, DM2024)
plt.axvline(x=-0.391, color='magenta', label='pre-periastron crossing')
plt.axvline(x=0.177, color='purple', label='post-periastron crossing')
plt.title('MeerKAT 2024 Periastron Passage')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.minorticks_on()
plt.grid(True, which='major', linestyle='-', linewidth=0.7)
plt.grid(True, which='minor', linestyle='--', linewidth=0.4)
plt.xlim(-np.pi, np.pi)
plt.legend()

# %% [markdown]
# # Curvefit Fit

# %%
#Fitting the 2024 data
p0_2024 = [-10, 1000, np.deg2rad(5), np.deg2rad(180), 1, 12000, 3.5, -13, np.deg2rad(60), 146] #Parameter guess values

#Setting lower and upper parameter bounds
lower = [-15, 800, np.deg2rad(0), np.deg2rad(0), 0.5, 9000, 2, -13, np.deg2rad(0), 145]
upper = [-8, 3000, np.deg2rad(120), np.deg2rad(200), 3, 30000, 6, -10, np.deg2rad(90), 146]

#Fitting the model
params_opt, cov = curve_fit(DM_curve_fit, phi2024, DM2024, p0=p0_2024, sigma=error2024, bounds=(lower, upper), maxfev=200000)
print('Fitted Stellar Mass Loss: 1e' + str(params_opt[0]) + ' Solar Mass Per Year')
print('Fitted Wind Terminal Velocity: ' + str(params_opt[1]) + ' km/s')
print('Fitted Argument of Periastron:' + str(np.rad2deg(params_opt[2])) + ' Degrees = ' + str(params_opt[2]) + ' rad')
print('Fitted Longitude of Ascending Node:' + str(np.rad2deg(params_opt[3])) + ' Degrees = ' + str(params_opt[3]) + ' rad')
print('Fitted Wind beta: ' + str(params_opt[4]))
print('Fitted Disc Temperature: ' + str(params_opt[5]) + ' K')
print('Fitted Disc beta: ' + str(params_opt[6]))
print('Fitted Initial Disc Density: 1e' + str(params_opt[7]) + ' gcm^-3')
print('Fitted Disc Inclination:' + str(np.rad2deg(params_opt[8])) + ' Degrees = ' + str(params_opt[8]) + ' rad')
print('Fitted ISM dispersion measure: ' + str(params_opt[9]) + ' pc cm^-3')
# Out:
# Fitted Stellar Mass Loss: 1e-8.95778204509141 Solar Mass Per Year
# Fitted Wind Terminal Velocity: 890.687728815317 km/s
# Fitted Argument of Periastron:30.3061862663014 Degrees = 0.5289427340696464 rad
# Fitted Longitude of Ascending Node:194.65598149661582 Degrees = 3.3973877858171053 rad
# Fitted Wind beta: 0.5000274432720176
# Fitted Disc Temperature: 12706.548619053749 K
# Fitted Disc beta: 4.9065407712739315
# Fitted Initial Disc Density: 1e-10.874563482444866 gcm^-3
# Fitted Disc Inclination:79.58390345559255 Degrees = 1.3890011468893828 rad
# Fitted ISM dispersion measure: 145.57597517459905 pc cm^-3

# %%
phi_fit_2024 = np.linspace(min(phi2024), max(phi2024), 512)
DM_fit_2024 = DM_curve_fit(phi_fit_2024, *params_opt)

#Plotting the fit  
plt.plot(phi_fit_2024, DM_fit_2024, color='red', label='Fit')
plt.scatter(phi2024, DM2024, color='cyan', label='Data Points')
plt.title('Fitted Dispersion Measure 2024 Periastron Vs Orbital Phase')
plt.xlabel('Orbital phase (rad)')
plt.ylabel('DM (pc cm^-3)')
plt.legend()
plt.show()

# %% [markdown]
# # MCMC Fits
#
# The MCMC code is based on the example provided at https://emcee.readthedocs.io/en/stable/tutorials/line/

# %%
#Fixed parameter values
i = np.deg2rad(25)
a_Rsun = 1345
R_star_sol = 9.2
M_star_sol = 20
Mdot_Msun_per_yr = -8.92
v_0_kms = 6.73
v_inf_kms = 943
e = 0.87
omega = np.deg2rad(0)
Omega = np.deg2rad(180)
beta = 0.5
rho0 = -10.58
i_disc = np.deg2rad(86.2)
T_disc = 11405
beta_disc = 5.053
ISM_DM = 145.54

# %%
#Maximum likelihood function
def log_likelihood(theta, phi_data, DM_data, DM_err, i, a_Rsun, R_star_sol, M_star_sol, v_0_kms, e, beta):
    '''
    This function calculates the log maximum likelihood for the fitted parameters.
    ------------------------------------------------------------------------------
    parameters:

    theta            [array] -> Fitted parameters
    phi_data         [array] -> Orbital Phase from literature (rad)
    DM_data          [array] -> Dispersion meausre from literature (pccm^-3)
    DM_err           [array] -> Dispersion measure error values from literature (pccm^-3)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    ISM_DM           [float] -> Interstellar medium dispersion measure
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    --------------------------------------------------------------------------------
    Returns:

    The log maximum likelihood for the fitted parameters.
    '''
    
    Mdot_Msun_per_yr, v_inf_kms, omega, Omega, T_disc, beta_disc, rho0, i_disc, ISM_DM = theta         #Parameters to fit
    model = tot_DM_mcmc(phi_data, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, 
                   v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, ISM_DM) #Model DM values
    
    #Likelihood calculation
    sigma = DM_err**2
    return -0.5 * np.sum((DM_data - model)**2 / sigma + np.log(sigma))

# %%
#Prior function
def log_prior(theta):
    '''
    This function calculates the priors.
    -------------------------------------
    parameters:

    theta [array] -> Fitted parameters
    -------------------------------------
    Returns:

    The priors of the fitted parameters.
    '''
    Mdot_Msun_per_yr, v_inf_kms, omega, Omega, T_disc, beta_disc, rho0, i_disc, ISM_DM = theta
    if -15 < Mdot_Msun_per_yr < -8 and 0 < v_inf_kms < 9000 and np.deg2rad(0) < omega < np.deg2rad(90) and np.deg2rad(0) < Omega < np.deg2rad(360) and 9000 < T_disc < 30000 and 2 < beta_disc < 6 and -13 < rho0 < -10 and np.deg2rad(0) < i_disc < np.deg2rad(90) and 144 < ISM_DM < 148:
        return 0.0
    return -np.inf

# %%
#Probability function
def log_probability(theta, phi_data, DM_data, DM_err, i, a_Rsun, R_star_sol, M_star_sol, v_0_kms, e, beta):
    '''
    This function calcultes the log probability of the fitted parameters.
    ---------------------------------------------------------------------
    parameters:

    theta            [array] -> Fitted parameters
    phi_data         [array] -> Orbital Phase from literature (rad)
    DM_data          [array] -> Dispersion meausre from literature (pccm^-3)
    DM_err           [array] -> Dispersion measure error values from literature (pccm^-3)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    --------------------------------------------------------------------------
    Returns:

    The log probability of the fitted parameters.
    '''
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(theta, phi_data, DM_data, DM_err, i, a_Rsun, R_star_sol, M_star_sol, v_0_kms, e, beta)

# %%
#Computing the maximum likelihood estimates
np.random.seed(42)                                                          #Random seed
nll = lambda *args: -log_likelihood(*args)                                  #Negative log likelihood
initial_Mdot_Msun_per_yr = -9                                               #Guess for mass loss
initial_v_inf_kms = 1000                                                    #Guess for wind terminal velocity
initial_omega = np.deg2rad(5)                                               #Guess for omega
initial_Omega = np.deg2rad(180)                                             #Guess for longitude of ascending node
initial_T_disc = 1.2e4                                                      #Guess for disc temp
initial_beta_disc = 4                                                       #Guess for disc beta
initial_rho0 = -12.169                                                      #Guess for initial disc density
initial_i_disc = np.deg2rad(60)                                             #Guess for disc inclination
initial_ISM_DM = 145.5                                                      #Guess for ISM DM

initial = np.array([initial_Mdot_Msun_per_yr, initial_v_inf_kms, initial_omega, initial_Omega, initial_T_disc, initial_beta_disc, initial_rho0, initial_i_disc, initial_ISM_DM]) + 0.1 * np.random.randn(9) #Initial guess array
bounds = [(-15, -8), (0, 9000), (np.deg2rad(0), np.deg2rad(90)), (np.deg2rad(0), np.deg2rad(360)), (9000, 30000), (2, 6), (-13, -10), (np.deg2rad(0), np.deg2rad(90)), (144, 148)]                                 #Setting parameter bounds

soln_2024 = minimize(nll, initial, args=(phi2024, DM2024, error2024, i, a_Rsun, R_star_sol, M_star_sol, v_0_kms, e, beta), bounds=bounds)
Mdot_Msun_per_yr_ml_2024, v_inf_kms_ml_2024, omega_ml_2024, Omega_ml_2024, T_disc_ml_2024, beta_disc_ml_2024, rho0_ml_2024, i_disc_ml_2024, ISM_DM_ml_2024 = soln_2024.x

print("Maximum likelihood estimates 2024:")
print("Mass loss = {0:.3f}".format(Mdot_Msun_per_yr_ml_2024))
print("Wind terminal velocity = {0:.3f}".format(v_inf_kms_ml_2024))
print("omega = {0:.3f}".format(omega_ml_2024))
print("Omega = {0:.3f}".format(Omega_ml_2024))
print("Disc temp = {0:.3f}".format(T_disc_ml_2024))
print("Disc beta = {0:.3f}".format(beta_disc_ml_2024))
print("Initial Disc Density = {0:.3f}".format(rho0_ml_2024))
print("Disc i = {0:.3f}".format(i_disc_ml_2024))
print("ISM DM = {0:.3f}".format(ISM_DM_ml_2024))
# Out:
# Maximum likelihood estimates 2024:
# Mass loss = -8.907
# Wind terminal velocity = 1000.133
# omega = 0.529
# Omega = 3.687
# Disc temp = 11999.963
# Disc beta = 4.907
# Initial Disc Density = -10.875
# Disc i = 1.272
# ISM DM = 145.576

# %% [markdown]
# # 2024 Periastron Passage

# %% [markdown]
# ## MCMC for All Parameters

# %%
#Running the MCMC

pos_2024 = soln_2024.x + 5e-2 * np.random.randn(72, 9)
nwalkers, ndim = pos_2024.shape

sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(phi2024, DM2024, error2024, i, a_Rsun, R_star_sol, M_star_sol, v_0_kms, e, beta)
)
sampler.run_mcmc(pos_2024, 3000, progress=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████| 3000/3000 [31:18<00:00,  1.60it/s]
# State([[-9.06727023e+00  7.55671966e+02  6.97274953e-01  3.50442261e+00
#    1.36347994e+04  4.69090286e+00 -1.12458324e+01  1.34524430e+00
#    1.45651577e+02]
#  [-9.04108449e+00  7.68983183e+02  6.09097208e-01  3.69503945e+00
#    1.21379994e+04  4.98196738e+00 -1.07811959e+01  1.26936546e+00
#    1.45626091e+02]
#  [-8.86410848e+00  1.07638453e+03  6.29905025e-01  3.74343322e+00
#    1.20020391e+04  4.74584642e+00 -1.11241618e+01  1.25508134e+00
#    1.45546917e+02]
#  [-9.00708689e+00  8.57017527e+02  5.37998081e-01  3.23689097e+00
#    1.28556510e+04  4.78438491e+00 -1.10536533e+01  1.46230767e+00
#    1.45634050e+02]
#  [-8.94435159e+00  9.42060197e+02  4.96778402e-01  3.26170835e+00
#    1.27419675e+04  5.02708444e+00 -1.06875014e+01  1.44880350e+00
#    1.45607333e+02]
#  [-8.66328888e+00  1.48938336e+03  6.06344157e-01  3.46343016e+00
#    1.24796446e+04  4.93250440e+00 -1.08407388e+01  1.36404687e+00
#    1.45394756e+02]
#  [-8.84576963e+00  1.35391991e+03  5.84418932e-01  4.04722677e+00
#    1.13034559e+04  4.95051987e+00 -1.08266942e+01  1.16155207e+00
#    1.45732951e+02]
#  [-8.80455221e+00  1.28022814e+03  6.36094593e-01  4.07204113e+00
#    1.16334456e+04  4.83776851e+00 -1.10093605e+01  1.15669471e+00
#    1.45575840e+02]
#  [-8.71113569e+00  1.55518536e+03  5.78991971e-01  3.71167927e+00
#    1.18412389e+04  4.79269244e+00 -1.10426314e+01  1.26541513e+00
#    1.45562757e+02]
#  [-8.78592327e+00  1.22964245e+03  5.83061726e-01  3.89712496e+00
#    1.16843538e+04  4.87079644e+00 -1.09423603e+01  1.20343543e+00
#    1.45500961e+02]
#  [-9.07228800e+00  7.55917657e+02  5.89225606e-01  3.27218920e+00
#    1.30765813e+04  4.82010829e+00 -1.10089659e+01  1.44658848e+00
#    1.45669115e+02]
#  [-9.00506880e+00  7.31639586e+02  3.88115447e-01  3.40573427e+00
#    1.16792695e+04  4.96673793e+00 -1.07359424e+01  1.38665728e+00
#    1.45485721e+02]
#  [-8.99370380e+00  8.81094772e+02  6.16826755e-01  3.78312207e+00
#    1.16224729e+04  4.81656346e+00 -1.10074594e+01  1.24203448e+00
#    1.45640068e+02]
#  [-8.97048924e+00  9.61036499e+02  6.01363388e-01  3.26941961e+00
#    1.35780706e+04  4.88441233e+00 -1.09386184e+01  1.44536098e+00
#    1.45681525e+02]
#  [-8.85159301e+00  1.21007556e+03  4.74552612e-01  4.01403956e+00
#    1.05602489e+04  5.08530751e+00 -1.05797980e+01  1.17213611e+00
#    1.45642658e+02]
#  [-8.82473369e+00  1.19952048e+03  6.19419830e-01  3.85284190e+00
#    1.22553099e+04  4.89844459e+00 -1.09173418e+01  1.21537343e+00
#    1.45565944e+02]
#  [-9.04603935e+00  7.35197755e+02  5.79408348e-01  3.15478903e+00
#    1.37176978e+04  4.78110703e+00 -1.10843298e+01  1.49733169e+00
#    1.45574114e+02]
#  [-8.75001268e+00  1.47971820e+03  3.80754739e-01  3.89058579e+00
#    1.15186057e+04  4.93353706e+00 -1.08301652e+01  1.20070359e+00
#    1.45606134e+02]
#  [-8.96357761e+00  9.12696412e+02  3.92083844e-01  3.14708496e+00
#    1.30226862e+04  4.87554608e+00 -1.09057987e+01  1.50103830e+00
#    1.45607658e+02]
#  [-8.73870272e+00  1.44559099e+03  5.23613184e-01  3.90456296e+00
#    1.10016244e+04  4.90603193e+00 -1.08532294e+01  1.20268543e+00
#    1.45551250e+02]
#  [-8.87211753e+00  1.16865915e+03  4.59180287e-01  3.93289231e+00
#    1.09128829e+04  4.81529223e+00 -1.09839669e+01  1.19458543e+00
#    1.45634174e+02]
#  [-8.93023969e+00  9.48590071e+02  5.45457942e-01  4.02745404e+00
#    1.14369935e+04  4.86635421e+00 -1.09446765e+01  1.16732926e+00
#    1.45571558e+02]
#  [-8.68254527e+00  1.74742460e+03  4.53249309e-01  3.99134302e+00
#    9.97539924e+03  4.97427108e+00 -1.07057602e+01  1.18202476e+00
#    1.45610055e+02]
#  [-8.84753182e+00  1.28034010e+03  6.65604694e-01  4.02544279e+00
#    1.25484104e+04  4.79394073e+00 -1.11056382e+01  1.16480950e+00
#    1.45676957e+02]
#  [-9.02417565e+00  7.59550602e+02  4.70643818e-01  3.32974897e+00
#    1.26509826e+04  4.91438038e+00 -1.08532728e+01  1.41823793e+00
#    1.45570946e+02]
#  [-8.76161323e+00  1.37938895e+03  5.88154521e-01  3.68138926e+00
#    1.19742669e+04  4.93986336e+00 -1.08271003e+01  1.27693752e+00
#    1.45567222e+02]
#  [-8.83765210e+00  1.19809595e+03  5.97173437e-01  3.27384375e+00
#    1.36090935e+04  4.85154111e+00 -1.09852253e+01  1.44241908e+00
#    1.45595750e+02]
#  [-8.77799693e+00  1.25575120e+03  7.80123170e-01  3.76243099e+00
#    1.34458100e+04  4.76969358e+00 -1.11585807e+01  1.24617588e+00
#    1.45496064e+02]
#  [-8.78402827e+00  1.21746636e+03  4.50540067e-01  3.62658492e+00
#    1.17132471e+04  5.05021045e+00 -1.06420678e+01  1.29497257e+00
#    1.45490817e+02]
#  [-9.02609361e+00  7.59859096e+02  4.04955416e-01  3.60867933e+00
#    1.12717049e+04  4.94107214e+00 -1.07837106e+01  1.30319244e+00
#    1.45580647e+02]
#  [-8.94015453e+00  1.03637347e+03  4.43594768e-01  3.64045233e+00
#    1.21949106e+04  4.97157686e+00 -1.07752108e+01  1.28679443e+00
#    1.45683148e+02]
#  [-9.04584272e+00  7.02898281e+02  7.34240095e-01  3.87909997e+00
#    1.32037603e+04  4.87604341e+00 -1.10044466e+01  1.20611470e+00
#    1.45542032e+02]
#  [-8.83121591e+00  1.20542962e+03  5.19323780e-01  3.56892970e+00
#    1.27080705e+04  4.99152894e+00 -1.07648649e+01  1.31367316e+00
#    1.45588853e+02]
#  [-9.04387289e+00  7.36979516e+02  5.53873525e-01  4.10492845e+00
#    1.08581310e+04  4.96296554e+00 -1.07893039e+01  1.14899220e+00
#    1.45591111e+02]
#  [-8.85659618e+00  1.17966158e+03  6.18304653e-01  4.01532386e+00
#    1.15766640e+04  4.82975020e+00 -1.10179873e+01  1.16958758e+00
#    1.45626132e+02]
#  [-8.78725801e+00  1.26721990e+03  5.24065641e-01  3.99012966e+00
#    1.01517186e+04  4.88039293e+00 -1.08612719e+01  1.18302428e+00
#    1.45537126e+02]
#  [-8.91832950e+00  9.74943063e+02  4.64894788e-01  3.84984774e+00
#    1.12287341e+04  4.91028863e+00 -1.08456636e+01  1.21873151e+00
#    1.45569983e+02]
#  [-8.86310572e+00  1.13744986e+03  4.75057736e-01  3.42429981e+00
#    1.27787603e+04  4.93851312e+00 -1.08247492e+01  1.37612560e+00
#    1.45602013e+02]
#  [-8.85160662e+00  1.24456575e+03  6.74622905e-01  3.85960329e+00
#    1.20285685e+04  4.61105416e+00 -1.13449194e+01  1.21764105e+00
#    1.45650911e+02]
#  [-8.80431914e+00  1.33323586e+03  6.56491025e-01  3.72313032e+00
#    1.19517544e+04  4.85657479e+00 -1.09604957e+01  1.26280656e+00
#    1.45634589e+02]
#  [-8.83655580e+00  1.21992053e+03  3.60754740e-01  3.73108343e+00
#    1.21859935e+04  5.05044201e+00 -1.06722020e+01  1.24980101e+00
#    1.45616517e+02]
#  [-8.90086259e+00  1.03897902e+03  6.26143278e-01  3.54877215e+00
#    1.26849194e+04  4.87108374e+00 -1.09462784e+01  1.32678079e+00
#    1.45597631e+02]
#  [-8.87767755e+00  1.18212425e+03  6.00248343e-01  3.99269662e+00
#    1.13188323e+04  4.83059578e+00 -1.09962531e+01  1.17773792e+00
#    1.45670190e+02]
#  [-8.80833957e+00  1.38791868e+03  7.10660479e-01  3.55565078e+00
#    1.36455501e+04  4.78694569e+00 -1.11194369e+01  1.32088043e+00
#    1.45670533e+02]
#  [-8.73322386e+00  1.54627672e+03  5.09508658e-01  3.82870859e+00
#    1.24493049e+04  4.71311302e+00 -1.11847790e+01  1.22054358e+00
#    1.45592960e+02]
#  [-8.91340584e+00  9.56774653e+02  5.53867417e-01  3.73655838e+00
#    1.16137641e+04  4.82047162e+00 -1.09900046e+01  1.25731443e+00
#    1.45532397e+02]
#  [-8.94318544e+00  8.23554122e+02  6.42040859e-01  3.98927978e+00
#    1.15843661e+04  4.87006545e+00 -1.09494913e+01  1.17864826e+00
#    1.45448297e+02]
#  [-8.74156422e+00  1.58153670e+03  5.61920938e-01  4.10072427e+00
#    1.08617993e+04  4.95969215e+00 -1.07985298e+01  1.15041628e+00
#    1.45654118e+02]
#  [-8.75503017e+00  1.30743345e+03  3.75062109e-01  3.23848286e+00
#    1.23356126e+04  5.06234891e+00 -1.06136839e+01  1.46019953e+00
#    1.45491236e+02]
#  [-8.78730025e+00  1.33260811e+03  3.85502749e-01  4.02911949e+00
#    1.13558140e+04  4.97963482e+00 -1.07655982e+01  1.16236742e+00
#    1.45583060e+02]
#  [-8.88808823e+00  9.60407000e+02  5.65835720e-01  4.00109732e+00
#    1.16575861e+04  4.96422958e+00 -1.08208378e+01  1.17135151e+00
#    1.45488917e+02]
#  [-9.09790286e+00  6.35512084e+02  5.83903573e-01  3.59549282e+00
#    1.29252482e+04  4.96217547e+00 -1.08230100e+01  1.30362767e+00
#    1.45562664e+02]
#  [-8.77300723e+00  1.30342607e+03  7.80092105e-01  4.07554347e+00
#    1.33799580e+04  5.07095422e+00 -1.07603913e+01  1.14984231e+00
#    1.45550374e+02]
#  [-8.80091700e+00  1.08829355e+03  6.27743619e-01  4.04551900e+00
#    1.16338970e+04  4.95293842e+00 -1.08407504e+01  1.16225158e+00
#    1.45404336e+02]
#  [-9.01022196e+00  8.26538358e+02  6.35901877e-01  3.19377039e+00
#    1.32618108e+04  4.67011117e+00 -1.12353940e+01  1.48503461e+00
#    1.45606153e+02]
#  [-8.93572920e+00  9.76196127e+02  5.84474004e-01  3.57695414e+00
#    1.20257338e+04  4.74771302e+00 -1.11081708e+01  1.31698129e+00
#    1.45616052e+02]
#  [-8.88560880e+00  1.15600831e+03  5.16770483e-01  3.68962508e+00
#    1.21279950e+04  4.98470346e+00 -1.07650698e+01  1.26902897e+00
#    1.45670886e+02]
#  [-8.85210333e+00  1.14390515e+03  4.80086984e-01  4.02414093e+00
#    1.12968121e+04  5.01546279e+00 -1.07223768e+01  1.16443260e+00
#    1.45585810e+02]
#  [-8.87026849e+00  1.12409459e+03  6.00346415e-01  3.37861931e+00
#    1.38907313e+04  4.88249991e+00 -1.09527198e+01  1.39361420e+00
#    1.45609048e+02]
#  [-8.80697730e+00  1.28518224e+03  5.33871262e-01  3.86270448e+00
#    1.16211477e+04  4.85232490e+00 -1.09578249e+01  1.21311921e+00
#    1.45591036e+02]
#  [-8.96647259e+00  9.02818769e+02  5.55570745e-01  3.49659437e+00
#    1.21577540e+04  4.84275784e+00 -1.09540198e+01  1.34990853e+00
#    1.45608887e+02]
#  [-8.86258975e+00  1.16173021e+03  7.08915345e-01  3.98452405e+00
#    1.22361185e+04  4.85206466e+00 -1.10143315e+01  1.17885089e+00
#    1.45622626e+02]
#  [-8.74825829e+00  1.32693718e+03  3.09927730e-01  3.93493921e+00
#    9.97230590e+03  5.06974313e+00 -1.05618760e+01  1.19445390e+00
#    1.45490602e+02]
#  [-8.93024053e+00  1.05853070e+03  6.01197151e-01  4.09596022e+00
#    1.19191064e+04  4.89013659e+00 -1.09429835e+01  1.14773344e+00
#    1.45675348e+02]
#  [-9.02811291e+00  9.15913819e+02  3.14725857e-01  3.54147299e+00
#    1.17384248e+04  4.99800200e+00 -1.07018020e+01  1.32705769e+00
#    1.45743962e+02]
#  [-8.90367802e+00  9.98245801e+02  6.33056998e-01  3.21484758e+00
#    1.34809261e+04  4.89550802e+00 -1.09165694e+01  1.47229082e+00
#    1.45564642e+02]
#  [-8.80309727e+00  1.31946047e+03  4.75874618e-01  4.08655202e+00
#    1.06721458e+04  4.84058298e+00 -1.09530878e+01  1.15466549e+00
#    1.45605057e+02]
#  [-8.78600705e+00  1.19533073e+03  6.67335185e-01  3.25312657e+00
#    1.40600674e+04  4.88167220e+00 -1.09609577e+01  1.45319615e+00
#    1.45472044e+02]
#  [-8.80235524e+00  1.27303120e+03  5.83336811e-01  3.30544326e+00
#    1.23878202e+04  4.68860100e+00 -1.11799264e+01  1.43631953e+00
#    1.45560247e+02]
#  [-9.00078716e+00  7.57302048e+02  4.88724104e-01  3.30723995e+00
#    1.32011940e+04  4.82696043e+00 -1.10013871e+01  1.42684162e+00
#    1.45512717e+02]
#  [-8.95099108e+00  9.96523458e+02  6.67007211e-01  3.50572601e+00
#    1.30276610e+04  4.58101315e+00 -1.13835211e+01  1.34562714e+00
#    1.45654838e+02]
#  [-8.81445495e+00  1.23357702e+03  6.02456129e-01  3.51062112e+00
#    1.37626353e+04  4.87089179e+00 -1.09789617e+01  1.33658656e+00
#    1.45569871e+02]], log_prob=[-2711.56451733 -2708.99051536 -2707.81789196 -2711.30389258
#  -2707.32010661 -2712.83181793 -2710.18743134 -2709.33927158
#  -2706.96332575 -2707.08227479 -2708.08670491 -2710.3168673
#  -2708.49381531 -2709.34001483 -2711.12071954 -2707.72794996
#  -2710.10352875 -2709.72202624 -2710.09727339 -2707.58666972
#  -2710.28579109 -2707.85893935 -2714.4060988  -2709.54044945
#  -2706.47776139 -2709.28487372 -2707.00960533 -2711.91878097
#  -2708.07910777 -2708.73932471 -2707.92424592 -2709.91952259
#  -2707.14967534 -2708.24324151 -2708.61991514 -2710.04611911
#  -2708.56895758 -2707.86355208 -2713.93529801 -2711.87986558
#  -2710.66276174 -2707.07904631 -2707.97747376 -2710.94541769
#  -2713.85048949 -2709.06343964 -2710.93947395 -2708.11194217
#  -2709.82739602 -2710.31513214 -2710.99215378 -2707.81149323
#  -2717.86976198 -2710.22486208 -2709.96801653 -2709.58925852
#  -2707.58721603 -2707.57940481 -2708.65937828 -2706.30777199
#  -2707.9772057  -2710.19854809 -2710.76599092 -2707.92558748
#  -2712.21034131 -2707.45965494 -2707.62238428 -2708.88481529
#  -2711.75144453 -2710.97144607 -2712.17553744 -2708.1258146 ], blobs=None, random_state=('MT19937', array([2760911590, 1686882365, 1340808046, 1197878386, 1203948481,
#        3885150216, 2453072937, 2165849302, 3194113327, 2741567520,
#        1237136548, 1245871436, 1568540656, 3962589286,  629250496,
#        1209539441, 1406615989, 1973748411, 2376186065, 1616825673,
#        1445977188, 4242867757, 1546202885, 3784965119, 3473529069,
#         495541807, 2622213456, 4258386503, 3078212168, 2627325461,
#         373171783, 2210546321, 3424946137, 2847651017,  887037355,
#         553248861, 4095968203, 2180226357, 4133362963, 2272182459,
#        3473702754,  593420227, 2514149476,   58018094, 1556573393,
#        1023970610, 3688754988, 1078266499, 1352421306, 2493021874,
#         793354538, 3723187237, 3900702231, 4090756107, 3635629864,
#        4058146202, 1583634269, 1751831508, 2796276181, 1016684604,
#        1718012861,  256453134,  578147151, 1462775982, 3414576513,
#        3172112508,   78035836, 1867705183, 3800293722,  484783186,
#        2550023017,  346232769,  186180708, 3507452666,  166747714,
#        4193201034,  927479110, 3823265930, 1889808127, 3685416558,
#        1219415367, 4047917021, 4226362502, 1677988864, 1576846233,
#         354285216, 3205211580,  307484246, 3177968732, 3684986268,
#        3509307396, 2235281759,  827573868, 2184637045, 1624137305,
#        2843883558, 3873842947, 4189290940, 1474348697, 2121298998,
#        2739059902, 3026844750, 3978303809, 2358169525,  718421329,
#         468545182, 4122584538, 2030645259,  786871349, 2295475028,
#        1918702008,  308845967, 3176788023, 2870618152, 1984703899,
#        2911348016, 1489737444,  299229657, 2374201439, 3080688949,
#         972601877, 1185653704, 1884255277, 1949263956, 2125188627,
#         861428543, 1249141127,  563005844, 3074324300, 4112424563,
#          66406555,  636905472, 3700225419,  794775569, 3057142485,
#         419340633,  643629066,  798533155,  197187047, 4255997827,
#        3399473427, 1298527438, 3761200709, 1389106154, 3063689327,
#        1438449521, 1235775463, 3181621644,  829278914, 1441167052,
#        3803645696, 3570053124,  945783567, 1136377413, 2951835569,
#         979275011, 3393044843, 4193993498, 1203335595, 3167811613,
#        3221125030, 3583949656, 3164499235,  271513256,  541126383,
#        2209701903, 2866233826, 2016247617, 2850510580, 2912031604,
#        2830745465, 3653664398, 2552291097,  662526239,   35775393,
#         453582308, 2942205382, 1021019661, 2507506541, 2627554473,
#        1365495448,  769233435, 2238256881, 3550145827, 3922301698,
#        2795158942,   43750440,  308813882, 2192702480, 3040792175,
#        2284354916, 3615253208, 2379384751, 2576432393, 3849234564,
#        1701140682,  427307050, 3425403192, 1352940254,  287617451,
#         513896873, 2821209110, 3292289840,  520669113, 2872292297,
#        3177512385, 4014514598,  256682446, 3667338289, 2702682142,
#        3981932397, 1448816410,  475941990, 3580995368,  353113069,
#        1525153784, 1176872917,  653091889,   14653909,  428818242,
#        4193415610,  394969423, 3286222351,  173803188, 2184364417,
#        3976010185, 1660983696, 3038809362, 2778192319,  696442187,
#        3064009455, 1372991908,  663756435, 4263131912, 1073936073,
#        1351291867, 2671419450, 1955260165, 2188560970, 1081781292,
#        3396350072,   26535089,  168972720, 1802877524, 3131495122,
#        1795474417, 3763953223, 1561640391,  226445909,  633825114,
#        3756554711, 1724795138, 2873148407,  102806717, 2649267006,
#         357855658, 1919163930, 1505500476, 2746241101, 1296659681,
#        3556542551, 3919355182, 4092899776, 1396216358, 3397245874,
#         574898346, 1264517403, 1310186422, 3309614365,  630908663,
#         484723173, 1144135277, 3043589250,  447432195, 3810014131,
#        2900054487, 3074427450, 2309713374, 2770085272,  386545703,
#        1034546318, 2846987400,  967481696, 2081938687,  369020302,
#        2634852056, 3163384152,  115371607, 3856489504, 3859015400,
#        3059914452, 4253109611, 2254139467,  143001747, 2913261724,
#         667713492, 3306197570,  834660196,  804784475,  721751043,
#         291207661, 4120702875, 4292472400,  284135762, 4225732377,
#         103845064, 3364152320, 1865438672,  234498777, 1317737588,
#         562425992, 2472756394,  946575543, 1294814716, 2412890610,
#        1222424538, 1048040479,  106406898, 2074092955, 3271236119,
#         632542552, 1293639128, 2346623224, 2599235341, 2136018227,
#         865474037, 3605850517,  533621924, 1375624957, 2453216916,
#        4032804651,  749122489, 1450523432, 1409370801,  517143100,
#        4215847564, 1938356883, 3986670460, 1676416642,   91252765,
#        4079373168, 1816339861,  513121866, 3121793838, 1618336213,
#        3536557450,  488821461, 2527390102, 1408688069,  442466782,
#         654897155, 2658745731,  271544635, 2205439811, 1243411888,
#        4058367442,  104549658, 1379801853, 2338329979, 3201807346,
#         400038016,  458750991,  500800783, 1540677906, 1112299302,
#        2204212398, 1894725257, 2251551380, 4086242292,   64266405,
#        3387508819,  361736225,  327744014, 3682086601, 3745224049,
#         737866993, 3747028296, 2407913408, 1099933019, 2856685428,
#        1756375749, 2460324244, 1108259386, 3989774383, 2573522357,
#        1839543544, 4133916393, 2790453892, 3081547988,  391784537,
#          44348310,  434865853, 2826487079, 4092353582, 2956650990,
#        3048347990, 1820705651, 2792172056, 2165910489, 3183984318,
#         485010924,  778358077, 2393593378, 2450222507, 1537851005,
#        1223444260, 2661894871, 2179095207,  442665618,  554805986,
#        1417590323, 3994215035,  484576950, 3127217953, 1794200096,
#        3546371484, 2664654831,  882625267, 2388529295, 3872808148,
#        3540419864, 2779641654, 3891325578,  817836513, 3786673054,
#        3633407500, 3364687397,  103669403, 2803473717, 1469310367,
#        4274043170, 1892557336, 3766331950,  664101238,  137798156,
#        1057675121,  371498362, 2430286163,  284196698, 3183827488,
#        3228154778, 3450049013,  187793364, 2033885205, 1735438569,
#         786166922, 4093664303,  494416070, 2356527565, 1264396381,
#        2878335124, 1483146951, 2858805570, 1822542820, 1831988998,
#         291924770, 3499822297, 2541279341,  605108540, 2159952451,
#        3574100812,  874733125, 1964916948, 3625761485, 3926594177,
#        3224041481,   38981297, 2307085829,  187952838, 3190830704,
#         314546454,  280725161, 2921490363,  139456480, 3522913724,
#        1810716506, 2608430462, 2242354634,  959406395, 3137800094,
#        2666623012, 3508336881, 1625017544, 1683420897, 4092682266,
#        1020778878, 2361871990,  245913592, 1422630379, 3470194184,
#        3620769349, 1036187474, 1277370945, 1727064783, 2226167566,
#        2455699717, 2873148287, 4265263126, 2994984566, 3470978242,
#        4205113083, 2182640077, 3128468304, 2986178186,  471061674,
#         250671577, 1398494751,  141635165, 1934967057, 4067793237,
#        2375050219, 1098962068, 1721080665, 3223321838,  949357930,
#        3118291707, 2894238965, 1258001191, 4211043390, 2041292410,
#        3169399915, 2623793206, 3748093041, 1086518368, 3477148937,
#        2987324543,  909736217, 1358632356,  585660054, 2285836283,
#        3137638152,  153568580,  475455001, 3171867537, 4093359603,
#        3350175396, 2702383125,  696105690, 1888906036, 2844837260,
#        4126785258,  998307855, 3293382340, 3605183886, 3712875476,
#         545799385, 2633658073, 3929226472, 1832888889,  162835867,
#         635526221, 4105691835, 3697366974, 1748016155, 3781222308,
#         331649323, 1723105635,   63797307, 2697508286, 2941391597,
#        2199636545, 2484893103, 3575441466, 1890560818, 2544148547,
#        3295653977, 4070592446, 2329980448, 2049400869,  208013011,
#        3694753176, 2106947039, 1445327696, 4050114845,  499483679,
#        3413442677, 2594549154,  730690551,  679100597, 3099787098,
#         742572986, 1007925759,  547723219, 3447464582, 1790124749,
#        3404033058,  131277892,  733939733, 3179900892, 3641338319,
#        1744148098, 1025559159, 1926439757, 1018532287,  873521244,
#        4129241050, 4200947431,  576829483, 3514109154,  210635056,
#        3404926179, 3671657388, 1486834687, 3824241067, 2860575156,
#        1055673379, 1269104717,  571806021, 2637452189, 2072370249,
#        2095940074, 1094854353,  893259016,  107416220, 1041893216,
#        2915605577, 2514872851, 3726303635, 3117770787,  251369197,
#        1532030484,  454182006, 2399041528, 2127418880], dtype=uint32), 97, 1, -0.024125087110003277))

# %%
#Positions of each walker as a function of the number of steps in the chain
fig, axes = plt.subplots(9, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["Mdot", "v-inf", "om", "Om", "disc-T", "disc-beta", "rho0", "disc-i", "ISM-DM"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number")
# Out:
# Text(0.5, 0, 'step number')

# %%
#Flat samples
flat_samples = sampler.get_chain(discard=700, thin=15, flat=True)
print(flat_samples.shape)
# Out:
# (11016, 9)

# %%
#Plotting the corner plot
fig = corner.corner(
    flat_samples, labels=labels, truths=[-8.892, 1052.071, np.deg2rad(30.137), np.deg2rad(211.765), 12115.949, 4.921, -10.858, np.deg2rad(72.65), 145.582]
)
plt.savefig("MCMCEXTRADOT.png", dpi=300, bbox_inches="tight")

# %%
#Best fit results
for i in range(ndim):
    mcmc = np.percentile(flat_samples[:, i], [16, 50, 84])
    q = np.diff(mcmc)
    txt = "\mathrm{{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{{2:.3f}}}"
    txt = txt.format(mcmc[1], q[0], q[1], labels[i])
    display(Math(txt))
# Out:
# $\displaystyle \mathrm{Mdot} = -8.892_{-0.083}^{0.091}$
# $\displaystyle \mathrm{v-inf} = 1055.737_{-185.441}^{228.464}$
# $\displaystyle \mathrm{om} = 0.528_{-0.097}^{0.085}$
# $\displaystyle \mathrm{Om} = 3.732_{-0.302}^{0.222}$
# $\displaystyle \mathrm{disc-T} = 12002.577_{-827.397}^{851.429}$
# $\displaystyle \mathrm{disc-beta} = 4.914_{-0.105}^{0.102}$
# $\displaystyle \mathrm{rho0} = -10.867_{-0.159}^{0.156}$
# $\displaystyle \mathrm{disc-i} = 1.256_{-0.070}^{0.118}$
# $\displaystyle \mathrm{ISM-DM} = 145.587_{-0.073}^{0.069}$

# %% [markdown]
# # -------------------------------------------------------------------------------------------

# %%
#DM plot with the fitted values

phi = np.linspace(-np.pi, np.pi, 512)
DM_2024 = tot_DM_mcmc(phi=phi, i=np.deg2rad(25), a_Rsun=1345, R_star_sol=9.2, M_star_sol=20, Mdot_Msun_per_yr=-8.92, v_0_kms=5, v_inf_kms=943, e=0.87, omega=np.deg2rad(0), Omega=np.deg2rad(180), beta=0.5, T_disc=11386, beta_disc=5, rho0=-10.661, i_disc=np.deg2rad(86.344), ISM_DM=145.54)

plt.plot(phi, DM_2024, label='MCMC plot')
plt.scatter(phi2024, DM2024, color='r', label='2024 datapoints')
plt.title('MCMC Best Fit Plot Vs 2024 Data Points')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (rad)')
plt.legend()

# %% [markdown]
# # -------------------------------------------------------------------------------------------
