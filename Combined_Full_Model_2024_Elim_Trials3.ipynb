# %% [markdown]
# ## This model features a high mass Be star accelerating wind and circumstellar disc, with an elliptical orbit, a 3D coordinate system, and a 'pseudo-signal' from a pulsar on the orbit.
# ## The main goal of this model is to see the number density, dispersion measure, optical depth, spectrum, and rotation measure along a line of sight from a point on the orbit given an orbital phase, orbital and disc inclination, eccentricity, argument of periastron and longitude of ascending node.
# ## Stellar parameters are modelled after the star SS 2883 of the HMXB system PSR B1259-63/SS 2883. Wind terminal velocity is taken from the paper - https://arxiv.org/pdf/0806.4868, while the remaining formulas are taken from https://ui.adsabs.harvard.edu/abs/2011ApJ...732L..11N/abstract, https://arxiv.org/abs/1307.7083 and https://arxiv.org/pdf/1804.08402.
# ## Formulas of the disc of SS 2883 are taken from the paper https://arxiv.org/abs/2204.08124

# %% [markdown]
# # Equations and Geometry
# ## Electron number density
# # $n_{e}(r) = \frac{\rho}{\mu_{e}m_{p}} = \frac{\dot{M}}{4\pi\mu_{e}m_{p}r^2v(r)} = \frac{k}{r^2v(r)}$
# Where
# # $\rho = \frac{\dot{M}}{4\pi r^2v(r)}$
#
# And
#
# # $k = \frac{\dot{M}}{4\pi\mu_{e}m_{p}}$
# With
#
# * $\rho$ =      Density
# * $\mu_{e}$ =   Mean molecular weight per free electron (typically set at a value of 1.2)
# * $m_{p}$ =     Proton mass
# * $\dot{M}$ =   Wind mass loss
# * $v(r)$ =     Radial wind velocity
# * $r$ =         radial distance from the center of the star
#
# ## Accelerating Wind ($\beta$ law)
# The wind velocity at a certain distance away from the star is
# # $v(r) = v_0 + (v_{\infty} - v_0)(1-\frac{R_{*}}{r})^\beta$
# with
# * $v_0$ =        The wind velocity at stellar surface
# * $v_{\infty}$ = Wind terminal velocity
# * $R_{*}$ =      Stellar radius
# * $\beta$ =      Wind acceleration exponent
#
# By placing the star and orbit at the xy plane origin, we can consider an elliptical orbit in cartesian coordinates
# # $\frac{x^2}{a^2} + \frac{y^2}{b^2} = 1$
# with
# * $a$ = Semi-major axis
# * $b$ = Semi-minor axis
# The semi-minor axis can be defined as $a\sqrt{1 - e^2}$, where $e^2$ is the eccentricity.
# In polar coordinates, the ellipse is offset along the x-axis by the focus - $f = ae$.
#
# The orbital separation in polar coordinates becomes
# # $r = \frac{a(1-e^2)}{1+ecos(\phi)}$
# Where $\phi$ is the orbital phase.
#
# The pulsar position vector along the orbit is described as
#
# # $ r_s = \begin{pmatrix} rcos(\phi) \\ rsin(\phi) \\ 0  \end{pmatrix}$
#
# The observer unit vector (direction of signal to observer) is situated on the y-z axis, and is defined as
#
# # $ \hat{n} = \begin{pmatrix} 0 \\ sin(i) \\ cos(i)  \end{pmatrix}$
#
# Where $i$ is the inclination.
#
# The 2D orbit is then rotated into 3D space by computing
#
# # $ r_{rot} = R_{z}(\Omega)R_{x}(i)r_s$
#
# Where $\Omega$ is the longitude of ascending node, and
#
# # $ R_{z}(\Omega) = \begin{pmatrix} cos(\Omega) & -sin(\Omega) & 0 \\ sin(\Omega) & cos(\Omega) & 0 \\ 0 & 0 & 1  \end{pmatrix}$
#
# # $ R_{x}(i) = \begin{pmatrix} 1 & 0 & 0 \\ 0 & cos(i) & -sin(i) \\ 0 & sin(i) & cos(i)  \end{pmatrix}$
#
# Resulting in
#
# # $ r_{rot} = \begin{pmatrix} r[cos(\Omega)cos(\phi) -sin(\Omega)cos(i)sin(\phi)] \\ r[sin(\Omega)cos(\phi) + cos(\Omega)cos(i)sin(\phi)] \\ rsin(i)sin(\phi)  \end{pmatrix}$
#
# The radial distance of the signal from the star along the path of the line of sight is computed by separating the x, y, and z components of $r_{rot} + s\hat{n}$, where $s\ge0$, is the distance along the line of sight, and comuting $r(s) = \sqrt{x_{s}^2 + y_{s}^2 + z_{s}^2}$.
#
# The number density at a specific point along the line of sight distance from the orbit can then be described as
# # $n_e(r(s)) = \frac{k}{r(s)^2v(r(s))}$
#
# From the definition of $r(s)$,
#
# ## $r(s)^2 = (r_s + s\hat{n})^2 = r^2 + 2rs [cos(\phi) sin (i)cos(\Omega) + sin(\phi)sin(i)sin(\Omega)] + s^2$
#
# ## Dispersion Measure
# # $DM(\phi,i) = \int_{0}^{\infty}n_e(r(s))ds = k\int_{0}^{\infty}\frac{ds}{v(r(s))r(s)^2}$
#
# ## Semi-major axis of PSR B1259-63
# Given that the orbital period of PSR B1259-63 is approximately 1237 days, its mass is $1.4 M_\odot$ and that the mass of SS 2883 is approximately $22.5 M_\odot$, using Kepler's 3rd law, the semi-major axis is
# # $a^3 = \frac{P^2G(M + m)}{4\pi^2}, a \sim 1396R_\odot$
# With
# * $P$ = Orbital period
# * $G$ = Gravitational constant
# * $M$ = Mass of SS 2883
# * $m$ = Mass of PSR B1259-63
#
# ## Free-free Absorption
# Free-free absorption causes signals to be absorbed by the stellar wind depending on its optical depth.
# # $\tau_{FFA} \approx 8.24x10^{-2}\nu^{-2.1}T_e^{-1.35}\int n_e^2ds$
#
# with
# * $\tau_{FFA}$ = The optical depth
# * $\nu$ = The signal frequency
# * $T_e$ = The stellar wind temperature
# * $n_e$ = The number density
# * $s$ = The line of sight distance
#
# ## Flux density
# The flux density of the pulsar signal is decribed as
# # $S_{\nu} = S_{psr,\nu}e^{-\tau} = \nu^{-p}e^{-\tau}$
# with
# * $S_{psr,\nu}$ = The intrinsic flux of the pulsar
# * $\nu$ = The signal frequency
# * $p$ = The power law index
# * $\tau$ = The optical depth
# When the flux density of the signal is plotted against frequency, it results in the pulsar's spectrum, which changes along eccentric orbits.
#
# ## Be Disc
# Be stars such as SS 2883 have a circumstellar disc due to the star's immense rotation rate. The disc introduces an additional desnity structure to the system, which is described as
# # $\rho(r_{disc}, z) = \rho_0(\frac{r_{disc}}{R_*})^{-\beta}e^{\frac{-z^2}{H(r_{disc})^2}}$
# with
# * $\rho_0$ = The disc desnity at stellar surface
# * $r_{disc}$ = radial distance in the disc plane
# * $R_*$ = Stellar radius
# * $\beta$ = Disc power law exponent
# * $z$ = Height above the disc plane
# * $H(r)$ = Scale height
#
# The scale height is described as
# # $H(r_{disc}) = c_s\sqrt{\frac{r_{disc}}{GM_*}}r_{disc}$
# with
# * $c_s$ = Speed of sound
# * $G$ = Gravitational constant
# * $M_*$ = Stellar mass
#
# And the speed of sound is described as
# # $c_s = \sqrt{\frac{kT}{\mu_em_p}}$
# with
# * $k$ = Boltzmann constant
# * $T$ = Disc temperature
#
# Using the disc desnity profile the number density through the disc becomes
# # $n_{e,disc} = \frac{\rho(r_{disc},z)}{\mu_em_p}$
#
# From which the DM and optical depth can be calculated
#
# Placing the disc at the xy plane along with the pulsar orbit, the pulsar position is $ r_s = \begin{pmatrix} rcos(\phi) \\ rsin(\phi) \\ 0  \end{pmatrix}$. The line of sight unit vector is $\hat{n} = (sin(i)cos(\Omega), sin(i)sin(\Omega), cos(i))$.
#
# The pulsar position rotation onto the disc plane is described as
#
# # $r_{rot} = R_{z}(\Omega)R_{x}(i)R_{z}(\omega)r_s$
#
# Where
#
# # $ R_{z}(\Omega) = \begin{pmatrix} cos(\Omega) & -sin(\Omega) & 0 \\ sin(\Omega) & cos(\Omega) & 0 \\ 0 & 0 & 1  \end{pmatrix}$
#
# # $ R_{x}(i) = \begin{pmatrix} 1 & 0 & 0 \\ 0 & cos(i) & -sin(i) \\ 0 & sin(i) & cos(i)  \end{pmatrix}$
#
# # $ R_{z}(\omega) = \begin{pmatrix} cos(\omega) & -sin(\omega) & 0 \\ sin(\omega) & cos(\omega) & 0 \\ 0 & 0 & 1  \end{pmatrix}$
#
# Resulting in
#
# ### $ r_{rot} = \begin{pmatrix} r[(cos(\Omega)cos(\omega) - sin(\Omega)cos(i)sin(\omega)cos(\phi) + (-cos(\Omega)sin(\omega) - sin(\Omega)cos(i)cos(\omega))sin(\phi))] \\ r[(sin(\Omega)cos(\omega) + cos(\Omega)cos(i)sin(\omega))cos(\phi) + (-sin(\Omega)sin(\omega) + cos(\Omega)cos(i)cos(\omega))sin(\phi)] \\ rsin(i)sin(\phi + \omega)  \end{pmatrix}$
#
# The radial distance of the signal from the star along the path of the line of sight is computed by separating the x and y components of $r_{rot} + s\hat{n}$, where $s\ge0$, is the distance along the line of sight, and comuting $r_{disc} = \sqrt{x_{s}^2 + y_{s}^2}$.
#
# The disc height above its plane is described as $z = r(s)\cdot{\hat{n}_{disc}} = r_s\hat{n}_{disc} + s(\hat{n}\cdot{\hat{n}_{disc}})$. Where the line of sight unit vector is $\hat{n} = (sin(i)cos(\Omega), sin(i)sin(\Omega), cos(i))$, and the disc normal is $\hat{n}_{disc} = (0, sin(i_{disc}), cos(i_{disc}))$, such that the disc rotates on the x-axis.
#
# ## Combined Stellar Wind and Be Disc
# Since the stellar wind and Be disc do not depend on each-other, combining their number densities is straight forward
# # $n_{e,total} = n_{e,wind} + n_{e,disc}$
# With this total number density we can calculate the dispersion measure, optical depth, transmission factor and spectrum of the entire system.
#
# ## Rotation Measure
# The rotation measure shows how much the plane of polarisation of the signal has rotated as a result of traveling through magnetised plasma such as the stellar wind and circumstellar disc. It depends on the number desnity and magnetic field strength along the line of sight. Higher rotation measure occurs when the polarisation rotates more at longer wavelengths, also known as Faraday rotation.
#
# The magnetic field of the star is described as
# # $B = B_0(\frac{R_*}{r(s)})$
#
# With $B_0$, the magnetic field at the stelllar surface assumed to be $0.8 G$ (Johnston et al., 1996 https://ui.adsabs.harvard.edu/abs/1996MNRAS.279.1026J/abstract).
#
# The magnetic field parallel to the line of sight is described as
# # $B_{\parallel} = B(\hat{r}\cdot\hat{n})$
#
# Where $\hat{r} = (cos(\phi), sin(\phi), 0)$ is the radial unit vector from the star to the signal source, and $\hat{n} = (sin(i)cos(\Omega), sin(i)sin(\Omega), cos(i))$ is the line of sight unit vector from the signal to the observer.
#
# The rotation measure is described as
# # $\Delta RM = 8.1x10^5 \int_{LOS} n_eB_{\parallel}ds$
# (Melatos et al., 1995, https://academic.oup.com/mnras/article/275/2/381/2896129?login=false)

# %%
#Packages
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import astropy.units as u
import astropy.constants as con
import ipywidgets as widgets
from IPython.display import display
from scipy.optimize import curve_fit
from scipy.optimize import minimize
import emcee
import corner
from IPython.display import display, Math

# %%
#Constants in cgs units
R_sun_cgs = con.R_sun.cgs.value   #Radius of sun in cgs
M_sun_cgs = con.M_sun.cgs.value   #Mass of the sun in cgs
yr_to_sec = u.yr.to(u.s)          #Year to seconds
kms_cgs = (u.km/u.s).to(u.cm/u.s) #Kms in cgs
m_p_cgs = con.m_p.cgs.value       #Mass of proton in cgs
G_cgs = con.G.cgs.value           #Gravitational constant in cgs   
k_B_cgs = con.k_B.cgs.value       #Boltzmann constant in cgs
AU_cgs = (con.au.cgs.value)       #AU in cgs
pc_to_cm = u.pc.to(u.cm)          #PC to cm

# %%
#Number density function
def num_density(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, s, e, omega, Omega, beta, mu_e=1):
    '''This function calculates the number density at a specific point along an elliptical orbit within a spherically cymmetric wind 
    with accelerating velocity.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    mu_e             [float] -> Mean molecular weight per free electron
    e                [float] -> Eccentricity (0 < e < 1)
    s                [float] -> Distance along line of sight from signal (AU)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent 
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the number density [array] -> (cm^-3)'''
    a = a_Rsun * R_sun_cgs                                                                                            #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                                                                                   #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec)                                                             #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                                                                                           #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                                                                                       #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                                                                                 #Calculates the k constant (cm^-1)
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                              #Calculates the orbital separation along the orbit
    x = r*(np.cos(Omega)*np.cos(phi) - np.sin(Omega)*np.cos(i)*np.sin(phi))                                           #Rotated x axis
    y = r*(np.sin(Omega)*np.cos(phi) + np.cos(Omega)*np.cos(i)*np.sin(phi)) + s*(np.sin(i))                           #Rotated y axis
    z = r*np.sin(i)*np.sin(phi) + s*np.cos(i)                                                                         #Rotated z axis
    r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                 #Calculates the radial distance from the pulsar along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                    #Calculates the velocity of the wind 

    n_e = k/(r_s**2 * v_r_s)                                                                                          #Calculates the number density
    n_e[r_s <= R_star] = 0                                                                                            #Eclipse condition
     
    return n_e

# %%
#DM function
def dm_beta_wind(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, Omega, beta, mu_e=1, s_array_cm=None):
    '''This function calculates the dispersion measure along a line of sight, given orbital phase and inclination, 
    assuming a spherically symmetric wind with an accelerating velocity.
    --------------------------------------------------------------------------------------------------------------
    Parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent 
    mu_e             [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the dispersion measure [array] -> (pc cm^-3).'''
    a = a_Rsun * R_sun_cgs                                #Converts the semi-major axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    DM_array = []

    for value in phi:
        r = a * (1 - e**2) / (1 + e * np.cos(value))                                                               #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value))                                #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i))                #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                          #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/r_s)**beta                                                       #Calculates the velocity of the wind 
        n_e = k / (r_s**2 * v_r_s)                                                                                 #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                     #Eclipse condition

        DM_cgs = np.trapz(n_e, s)                                                                                  #Integrating the DM in cm^-2
        DM = (DM_cgs / pc_to_cm)                                                                                   #Converting DM to pc cm^3
        DM_array.append(DM)

    return np.array(DM_array)

# %%
#Free-free absorption function
def ffa(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, nu, T, mu_e=1, s_array_cm=None):
    '''This function calculates the free-free absorption along a line of sight, given orbital phase and inclination, 
    assuming a spherically symmetric wind with an accelerating velocity.
    --------------------------------------------------------------------------------------------------------------
    Parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    nu               [float] -> Signal frequency (GHz)
    T                [float] -> Stellar wind temperature (K)
    mu_e             [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array].'''
    a = a_Rsun * R_sun_cgs                                #Converts the semi-major axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    tau_array = []

    for value in phi:
        r = a * (1 - e**2) / (1 + e * np.cos(value))                                                                             #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value))                 #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i))                #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/r_s)**beta                                                                     #Calculates the velocity of the wind 
        n_e = k / (r_s**2 * v_r_s)                                                                                               #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition

        tau = 8.24e-2*nu**-2.1*T**-1.35*np.trapz(n_e**2, s / pc_to_cm)                                                           #Integrating the optical depth
        tau_array.append(tau)

    return np.array(tau_array)

# %%
#Flux density function
def spectrum(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, nu, T, p, mu_e=1, s_array_cm=None):
    '''This function calculates the spectrum of the pulsar for a given inclination and frequency along the orbit.
    -------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    nu               [float] -> Signal frequency (GHz)
    T                [float] -> Stellar wind temperature (K)
    p                [float] -> Power law exponent
    mu_e             [float] -> Mean molecular weight per free electron
    
    -------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the pulsar spectrum [array] (Jy)'''
    a = a_Rsun * R_sun_cgs                                #Converts the semi-major axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a flux density array
    S_nu_array = []

    for value in phi:
        for freq in nu:
            r = a * (1 - e**2) / (1 + e * np.cos(value))                                                                             #Calculates the orbital separation along the orbit
            x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value))                                              #Rotated x axis
            y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i))                              #Rotated y axis
            z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
            r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
            v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/r_s)**beta                                                                     #Calculates the velocity of the wind 
            n_e = k / (r_s**2 * v_r_s)                                                                                               #Calculates the number density
            n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition

            tau = 8.24e-2*freq**-2.1*T**-1.35*np.trapz(n_e**2, s / pc_to_cm) #Integrating the optical depth
            S_nu = freq**(-p)*np.exp(-tau)                                   #Calculating the flux density
            S_nu_array.append(S_nu)
    S_nu_2D = np.array(S_nu_array).reshape(len(phi), len(nu))                #Reshaping to a 2D array
    return S_nu_2D

# %%
#Disc number density function
def disc_ne(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, s, mu_e=1):
    '''This function calculates the number density along the line of sight from the
    pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Argument of periastron (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    s          [array] -> Array of line of sight points (cm)
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the number desnity [array] (cm^-3)'''
    a = a_Rsun * R_sun_cgs               #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs      #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs      #Converts the stellar mass from solar mass to g
    r = a*(1 - e**2)/(1 + e*np.cos(phi)) #Calculates the orbital separation along the orbit

    # x and y rotation coordinates of the disc
    x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.cos(Omega))
    y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.sin(Omega))
        
    r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                          #Projected radius through disc plane        
    c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                  #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                      #Calculates the scale height
    z = r*np.sin(phi)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
    rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                      #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                            #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                                                                   #Constraining the inner disc radius

    return ne_disc

# %%
#Disc dispersion measure function
def disc_DM(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, mu_e=1, s_array_cm=None):
    '''This function calculates dispersion measure along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the dispersion measure [array] (pc cm^-3)'''
    a = a_Rsun * R_sun_cgs          #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs #Converts the stellar mass from solar mass to g

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    disc_DM_array = []

    for value in phi:
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                           #Calculates the orbital separation along the orbit
        
        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega)) 
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane           
        c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                    #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                        #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius


        disc_DM_cgs = np.trapz(ne_disc, s)                                                                               #Integrating the DM in cm^-2
        disc_DM = (disc_DM_cgs / pc_to_cm)                                                                               #Converting DM to pc cm^3
        disc_DM_array.append(disc_DM)

    return np.array(disc_DM_array)

# %%
#Disc free-free absorption function
def disc_ffa(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, nu, mu_e=1, s_array_cm=None):
    '''This function calculates optical depth along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    nu         [float] -> Signal frequency (GHz)
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array]'''
    a = a_Rsun * R_sun_cgs          #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs #Converts the stellar mass from solar mass to g

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    disc_tau_array = []
    
    for value in phi:
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                           #Calculates the orbital separation along the orbit
        
        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane          
        c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                    #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                        #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius


        disc_tau = 8.24e-2*nu**(-2.1)*T**(-1.35)*np.trapz(ne_disc**2, s / pc_to_cm)                                      #Integrating tau
        disc_tau_array.append(disc_tau)

    return np.array(disc_tau_array)

# %%
#Disc flux density function
def disc_spectrum(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, nu, p, mu_e=1, s_array_cm=None):
    '''This function calculates optical depth along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    nu         [float] -> Signal frequency (GHz)
    p          [float] -> Power law exponent
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array]'''
    a = a_Rsun * R_sun_cgs          #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs #Converts the stellar mass from solar mass to g
    
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    disc_S_nu_array = []
    
    for value in phi:
        for freq in nu:
            r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                           #Calculates the orbital separation along the orbit
            
            # x and y rotation coordinates of the disc
            x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
            y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
            r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane          
            c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                    #Calculates the disc speed of sound
            H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
            z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
            rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                        #Calculates the disc desnity profile
            ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
            ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius


            disc_tau = 8.24e-2*freq**(-2.1)*T**(-1.35)*np.trapz(ne_disc**2, s / pc_to_cm)                                    #Integrating tau
            disc_S_nu = freq**(-p)*np.exp(-disc_tau)                                                                         #Calculatinng the flux density
            disc_S_nu_array.append(disc_S_nu)
    disc_S_nu_2D = np.array(disc_S_nu_array).reshape(len(phi), len(nu))                                                      #Reshaping to a 2D array
    return np.array(disc_S_nu_2D)

# %%
#Total wind-disc number density function
def tot_num_density(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, s, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, mu_e=1):
    '''This function calculates the total number density at a specific point along an elliptical orbit within a spherically cymmetric wind 
    with accelerating velocity and an axisymmetric disc.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    s                [float] -> Distance along line of sight from signal (AU)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total number density [array] -> (cm^-3)'''
    #Stellar wind number density
    a = a_Rsun * R_sun_cgs                                                                                               #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                                                                                      #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec)                                                                #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                                                                                              #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                                                                                          #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                                                                                    #Calculates the k constant (cm^-1)
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                                 #Calculates the orbital separation along the orbit
    x = r*(np.cos(Omega)*np.cos(phi) - np.sin(Omega)*np.cos(i)*np.sin(phi))                                              #Rotated x axis
    y = r*(np.sin(Omega)*np.cos(phi) + np.cos(Omega)*np.cos(i)*np.sin(phi)) + s*(np.sin(i))                              #Rotated y axis
    z = r*np.sin(i)*np.sin(phi) + s*np.cos(i)                                                                            #Rotated z axis
    r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                    #Calculates the radial distance from the pulsar along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                       #Calculates the velocity of the wind 
    n_e = k/(r_s**2 * v_r_s)                                                                                             #Calculates the number density
    n_e[r_s <= R_star] = 0                                                                                               #Eclipse condition
    
    #Disc number density
    M_star = M_star_sol * M_sun_cgs                                                                                      #Converts the stellar mass from solar mass to g
    
    # x and y rotation coordinates of the disc
    x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.cos(Omega))
    y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.sin(Omega))
        
    r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                          #Projected radius through disc plane        
    c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                             #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                      #Calculates the scale height
    z = r*np.sin(phi)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
    rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                 #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                            #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                                                                   #Constraining the inner disc radius

    #Total number density
    total_ne = n_e + ne_disc

    return total_ne

# %%
#Total wind-disc dispersion measure function
def tot_DM(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, mu_e=1, s_array_cm=None):
    '''This function calculates the dispersion measure along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total dispersion measure [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_DM_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value))                                              #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i))                              #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                           #Calculates the velocity of the wind 
        n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
        #Disc number density

        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane        
        c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_DM_cgs = np.trapz(total_ne, s) #Integrating the DM in cm^-2
        total_DM = (total_DM_cgs / pc_to_cm) #Converting DM to pc cm^3
        tot_DM_array.append(total_DM)

    return np.array(tot_DM_array)

# %%
#Total wind-disc free-free absorption function
def tot_ffa(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_wind, T_disc, beta_disc, rho0, i_disc, nu, mu_e=1, s_array_cm=None):
    '''This function calculates the optical depth along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    T_wind           [float] -> Temperature of wind (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    nu               [float] -> Signal frequency (GHz)
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total optical depth [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_tau_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value))                                              #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i))                              #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                           #Calculates the velocity of the wind 
        n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
        #Disc number density

        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane 
        c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_tau = 8.24e-2*nu**(-2.1)*((T_wind+T_disc)/2)**(-1.35)*np.trapz(total_ne**2, s / pc_to_cm) #Integrating the optical depth
        tot_tau_array.append(total_tau)

    return np.array(tot_tau_array)

# %%
#Total wind-disc flux density function
def tot_spectrum(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_wind, T_disc, beta_disc, rho0, i_disc, nu, p, mu_e=1, s_array_cm=None):
    '''This function calculates the flux density along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    T_wind           [float] -> Temperature of wind (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    nu               [float] -> Signal frequency (GHz)
    p                [float] -> Spectrum power law exponent
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total flux density [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_S_nu_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        for freq in nu:
            #Stellar wind number density
            r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
            x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value))                                              #Rotated x axis
            y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i))                              #Rotated y axis
            z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
            r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
            v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                           #Calculates the velocity of the wind 
            n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
            n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
            #Disc number density
            
            # x and y rotation coordinates of the disc
            x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
            y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
            r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane        
            c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
            H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
            z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
            rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
            ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
            ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

            #Total number density
            total_ne = n_e + ne_disc

            total_tau = 8.24e-2*freq**(-2.1)*((T_wind+T_disc)/2)**(-1.35)*np.trapz(total_ne**2, s / pc_to_cm) #Integrating the DM in cm^-2
            total_S_nu = freq**(-p)*np.exp(-total_tau)                                                        #Calculatinng the flux density
            tot_S_nu_array.append(total_S_nu)
        
    tot_S_nu_2D = np.array(tot_S_nu_array).reshape(len(phi), len(nu))                                         #Reshaping to a 2D array
    return np.array(tot_S_nu_2D)

# %%
#Total wind-disc dispersion measure function
def tot_DM_mcmc(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, ISM_DM, mu_e=1, s_array_cm=None):
    '''This function calculates the dispersion measure along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    ISM_DM           [float] -> Interstellar medium dispersion measure (pc cm^-3)
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total dispersion measure [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_DM_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value))                                              #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i))                              #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1 - R_star/r_s)**beta                                                                         #Calculates the velocity of the wind 
        n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
        #Disc number density

        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane 
        c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_DM_cgs = np.trapz(total_ne, s)          #Integrating the DM in cm^-2
        total_DM = (total_DM_cgs / pc_to_cm) + ISM_DM #Converting DM to pc cm^3
        tot_DM_array.append(total_DM)

    return np.array(tot_DM_array)

# %%
#Curve_fit DM function
def DM_curve_fit(phi, R_star_sol, Mdot, v_0_kms, v_inf_kms, omega, Omega, T_disc, beta_disc, rho0, i_disc, ISM_DM):
    '''
    This function employs scipy's curve_fit by implementing the general tot_DM function.
    -------------------------------------------------------------------------------------
    Parameters:

    phi    [array] -> Orbital Phase (rad)
    i_orb  [float] -> Orbital Inclination (rad)
    Mdot   [float] -> Log stellar Mass Loss (solar mass per year)
    e      [float] -> Eccentricity
    omega  [float] -> Argument of Periastron (rad)
    Omega  [float] -> Longitude of Ascending Node (rad)
    rho0   [float] -> Log initial Disc Density (gcm^-3)
    i_disc [float] -> Disc Inclination (rad)
    --------------------------------------------------------------------------------------
    Returns:

    The dipersion measure curve fit.
    '''
    #Fixing the remaining parameters of the model
    i_orb_fixed = np.deg2rad(25)
    a_Rsun_fixed = 1396
    M_star_sol_fixed = 22.5
    beta_fixed = 0.8
    e_fixed = 0.87

    return tot_DM_mcmc(phi, i_orb_fixed, a_Rsun_fixed, R_star_sol, M_star_sol_fixed, Mdot, v_0_kms, v_inf_kms, e_fixed, omega, Omega, beta_fixed, T_disc, beta_disc, rho0, i_disc, ISM_DM)

# %%
#Total rotation measure
def tot_RM(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, mu_e=1, s_array_cm=None):
    '''
    This function calculates the rotation measure of the signal through the stellar wind and circumstellar disc.
    ------------------------------------------------------------------------------------------------------------
    Parameters:

    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total rotation measure of the signal [array] -> (rad m^-2).
    '''
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an RM array
    tot_RM_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = (M_star_sol * M_sun_cgs)                     #Converts the stellar mass from solar mass to g
    B0 = 0.8                                              #Magnetic field at the stellar surface in G

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                     #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value))                                #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i))                #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                          #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                             #Calculates the velocity of the wind 
        n_e = k/(r_s**2 * v_r_s)                                                                                   #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                     #Eclipse condition
    
        #Disc number density

        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane        
        c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        #Wind magnetic field
        B = B0 * (R_star/r_s)                                                                            #Total magnetic field
        B_parallel = B * (np.sin(i)*np.cos(Omega)*np.cos(value) + np.sin(i)*np.sin(Omega)*np.sin(value)) #Magnetic field parallel to line of sight
        RM_integrand = total_ne*B_parallel

        total_RM_cgs = 8.1e5 * np.trapz(RM_integrand, s / pc_to_cm)  #Integrating the RM in rad m^-2
        tot_RM_array.append(total_RM_cgs)

    return np.array(tot_RM_array)

# %% [markdown]
# # MeerKAT 2024 Periastron Passage

# %%
#Generating the MeerKAT data 
meerkatdata = np.genfromtxt('B1259_63_DM_vs_MJD.txt')

# %%
#Seperating the 2024 periastron datapoints
meerkat2024 = meerkatdata[:,0:3]
meerkat2024.shape
# Out:
# (75, 3)

# %%
#Separating the days, DM, and error values
days2024 = meerkat2024[1:, 0]
DM2024 = meerkat2024[1:, 1]
error2024 = meerkat2024[1:, 2]

meerkatdays = days2024[[0, 1, 2, 4, 6, 7, 24, 30, 43, 56]]
meerkatDM = DM2024[[0, 1, 2, 4, 6, 7, 24, 30, 43, 56]]
meerkaterror = error2024[[0, 1, 2, 4, 6, 7, 24, 30, 43, 56]]

# %%
plt.errorbar(days2024, DM2024,yerr=error2024, fmt='o', label='Parkes Data')
plt.errorbar(meerkatdays, meerkatDM, yerr=meerkaterror, fmt='o', label='MeerKAT Data')
plt.title('Full MeerKAT/Parkes 2024 Periastron Passage')
plt.xlabel('Days')
plt.ylabel('Dispersion Measure (pc cm$^-3$)')
plt.legend()
#plt.savefig("Full Data Section MeerKAT Parkes Data.png", dpi=300, bbox_inches="tight")

# %%
#Separating the days, DM, and error values
duplidays = days2024[[18, 19]]
dupliDM = DM2024[[18, 19]]
duplierror = error2024[[18, 19]]

abdays = days2024[[14, 21, 73]]
abDM = DM2024[[14, 21, 73]]
aberror = error2024[[14, 21, 73]]

plt.errorbar(days2024, DM2024,yerr=error2024, fmt='o', label='Parkes Data')
plt.errorbar(meerkatdays, meerkatDM, yerr=meerkaterror, fmt='o', label='MeerKAT Data')
plt.errorbar(duplidays, dupliDM, yerr=duplierror, fmt='o', label='Redundant Points')
plt.errorbar(abdays, abDM, yerr=aberror, fmt='o', label='Over Density Points')
plt.title('Full MeerKAT/Parkes 2024 Periastron Passage')
plt.xlabel('Days')
plt.ylabel('Dispersion Measure (pc cm$^-3$)')
plt.legend()
#plt.savefig("Full MeerKAT Parkes Data.png", dpi=300, bbox_inches="tight")

# %%
days2024 = np.delete(days2024, [14, 18, 19, 21, 73])
DM2024 = np.delete(DM2024, [14, 18, 19, 21, 73])
error2024 = np.delete(error2024, [14, 18, 19, 21, 73])

# %%
#Plotting the data over the entire orbital phase
plt.errorbar(days2024, DM2024,yerr=error2024, fmt='o')
plt.title('MeerKAT 2024 Periastron Passage')
plt.xlabel('Days')
plt.ylabel('Dispersion Measure (pc cm$^-3$)')
plt.xlim(-618.5, 618.5)
# Out:
# (-618.5, 618.5)

# %%
#Plotting the MeerKAT and Parkes data
plt.errorbar(days2024, DM2024,yerr=error2024, fmt='o', label='Parkes Data')
plt.errorbar(meerkatdays, meerkatDM, yerr=meerkaterror, fmt='o', label='MeerKAT Data')
plt.title('Cleaned MeerKAT/Parkes 2024 Periastron Passage')
plt.xlabel('Days')
plt.ylabel('Dispersion Measure (pc cm$^-3$)')
plt.legend()
#plt.savefig("Cleaned MeerKAT Parkes Data.png", dpi=300, bbox_inches="tight")

# %%
#Plotting the MeerKAT and Parkes data
plt.errorbar(days2024, DM2024,yerr=error2024, fmt='o', label='Parkes Data')
plt.errorbar(meerkatdays, meerkatDM, yerr=meerkaterror, fmt='o', label='MeerKAT Data')
plt.title('MeerKAT/Parkes 2024 Preperiastron')
plt.xlabel('Days')
plt.ylabel('Dispersion Measure $(pc cm^-3)$')
plt.xlim(None, 0)
plt.legend()

# %%
#Plotting the MeerKAT and Parkes data
plt.errorbar(days2024, DM2024,yerr=error2024, fmt='o', label='Parkes Data')
plt.errorbar(meerkatdays, meerkatDM, yerr=meerkaterror, fmt='o', label='MeerKAT Data')
plt.title('MeerKAT/Parkes 2024 Postperiastron')
plt.xlabel('Days')
plt.ylabel('Dispersion Measure $(pc cm^-3)$')
plt.xlim(0, None)
plt.legend()

# %%
#Plotting the data over the data orbital phase
plt.errorbar(days2024, DM2024,yerr=error2024, fmt='o')
plt.axvline(x=-63, color='magenta', label='pre-periastron crossing')
plt.axvline(x=26, color='purple', label='post-periastron crossing')
plt.title('MeerKAT 2024 Periastron Passage')
plt.xlabel('Days')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %% [markdown]
# # Comparing our Model with Results of Past Periastron Passages of PSR B1259-63
# Since most available papers only report $\Delta DM$ - the difference in dispersion measure from periastron, with locations of the pulsar in terms of days from or to periastron, the orbital phases need to be translated as
# ## $\phi = 2\pi(\frac{\Delta t}{P}) = 2\pi(\frac{\Delta t}{1237 days})$

# %%
phi2024 = []

for i in days2024:
    if i < 0:
        phi_min = 2*np.pi*((i)/1237)
        phi2024.append(phi_min)
    if i > 0:
        phi_pl = 2*np.pi*((i)/1237)
        phi2024.append(phi_pl)

# %%
plt.scatter(phi2024, DM2024)
plt.axvline(x=-0.32, color='magenta', label='pre-periastron crossing')
plt.axvline(x=0.132, color='purple', label='post-periastron crossing')
plt.title('MeerKAT 2024 Periastron Passage')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.minorticks_on()
plt.grid(True, which='major', linestyle='-', linewidth=0.7)
plt.grid(True, which='minor', linestyle='--', linewidth=0.4)
plt.xlim(-np.pi, np.pi)
plt.legend()

# %% [markdown]
# # Curvefit Fit

# %%
#Fitting the 2024 data
p0_2024 = [9, -9, 10, 1000, np.deg2rad(30), np.deg2rad(220), 1.35e4, 3, -12, np.deg2rad(60), 145.8] #Parameter guess values

#Setting lower and upper parameter bounds
lower = [8, -13, 5, 800, np.deg2rad(0), np.deg2rad(0), 9000, 0, -15, np.deg2rad(0), 144]
upper = [15, -7, 20, 3000, np.deg2rad(90), np.deg2rad(360), 1.4e4, 5, -8, np.deg2rad(90), 148]

#Fitting the model
params_opt, cov = curve_fit(DM_curve_fit, phi2024, DM2024, p0=p0_2024, sigma=error2024, bounds=(lower, upper), maxfev=200000)
print('Fitted Stellar Radius:' + str(params_opt[0]) + ' Solar Radii')
print('Fitted Stellar Mass Loss: 1e' + str(params_opt[1]) + ' Solar Mass Per Year')
print('Fitted Wind Initial Velocity: ' + str(params_opt[2]) + ' km/s')
print('Fitted Wind Terminal Velocity: ' + str(params_opt[3]) + ' km/s')
print('Fitted Argument of Periastron:' + str(np.rad2deg(params_opt[4])) + ' Degrees = ' + str(params_opt[4]) + ' rad')
print('Fitted Longitude of Ascending Node:' + str(np.rad2deg(params_opt[5])) + ' Degrees = ' + str(params_opt[5]) + ' rad')
print('Fitted Disc Temp: ' + str(params_opt[6]) + ' K')
print('Fitted Disc beta: ' + str(params_opt[7]))
print('Fitted Initial Disc Density: 1e' + str(params_opt[8]) + ' gcm^-3')
print('Fitted Disc Inclination:' + str(np.rad2deg(params_opt[9])) + ' Degrees = ' + str(params_opt[9]) + ' rad')
print('Fitted ISM DM:' + str(params_opt[10]) + ' pc cm^-3')
# Out:
# Fitted Stellar Radius:8.958151853549799 Solar Radii
# Fitted Stellar Mass Loss: 1e-12.649473067781589 Solar Mass Per Year
# Fitted Wind Initial Velocity: 9.435379061029357 km/s
# Fitted Wind Terminal Velocity: 1071.9745206797802 km/s
# Fitted Argument of Periastron:36.23053806561158 Degrees = 0.6323421790140594 rad
# Fitted Longitude of Ascending Node:220.16642706287988 Degrees = 3.8426290545992026 rad
# Fitted Disc Temp: 12745.467924634904 K
# Fitted Disc beta: 3.979712408500522
# Fitted Initial Disc Density: 1e-12.193506560509432 gcm^-3
# Fitted Disc Inclination:70.76062621052648 Degrees = 1.2350059081466853 rad
# Fitted ISM DM:146.72656977246203 pc cm^-3

# %%
phi_fit_2024 = np.linspace(min(phi2024), max(phi2024), 512)
DM_fit_2024 = DM_curve_fit(phi_fit_2024, *params_opt)

#Plotting the fit  
plt.plot(phi_fit_2024, DM_fit_2024, color='red', label='Fit')
plt.scatter(phi2024, DM2024, color='cyan', label='Data Points')
plt.title('Fitted Dispersion Measure 2024 Periastron Vs Orbital Phase')
plt.xlabel('Orbital phase (rad)')
plt.ylabel('DM (pc cm^-3)')
plt.legend()
plt.show()

# %% [markdown]
# # MCMC Fits
#
# The MCMC code is based on the example provided at https://emcee.readthedocs.io/en/stable/tutorials/line/

# %%
#Fixed parameter values
i = np.deg2rad(25)
a_Rsun = 1396
R_star_sol = 8.958
M_star_sol = 22.5
v_0_kms = 9.435
v_inf_kms = 1071.974
e = 0.87
Omega = np.deg2rad(220.166)
beta = 0.8
#ISM_DM = 145.8

# %%
#Maximum likelihood function
def log_likelihood(theta, phi_data, DM_data, DM_err, i, a_Rsun, R_star_sol, M_star_sol, v_0_kms, v_inf_kms, e, Omega, beta):
    '''
    This function calculates the log maximum likelihood for the fitted parameters.
    ------------------------------------------------------------------------------
    parameters:

    theta            [array] -> Fitted parameters
    phi_data         [array] -> Orbital Phase from literature (rad)
    DM_data          [array] -> Dispersion meausre from literature (pccm^-3)
    DM_err           [array] -> Dispersion measure error values from literature (pccm^-3)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    ISM_DM           [float] -> Interstellar medium dispersion measure
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    --------------------------------------------------------------------------------
    Returns:

    The log maximum likelihood for the fitted parameters.
    '''
    
    Mdot_Msun_per_yr, omega, T_disc, beta_disc, rho0, i_disc, ISM_DM = theta                           #Parameters to fit
    model = tot_DM_mcmc(phi_data, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, 
                   v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, ISM_DM) #Model DM values
    
    #Likelihood calculation
    sigma = DM_err**2
    return -0.5 * np.sum((DM_data - model)**2 / sigma + np.log(sigma))

# %%
#Prior function
def log_prior(theta):
    '''
    This function calculates the priors.
    -------------------------------------
    parameters:

    theta [array] -> Fitted parameters
    -------------------------------------
    Returns:

    The priors of the fitted parameters.
    '''
    Mdot_Msun_per_yr, omega, T_disc, beta_disc, rho0, i_disc, ISM_DM = theta
    if -15 < Mdot_Msun_per_yr < -7 and np.deg2rad(0) < omega < np.deg2rad(90) and 9000 < T_disc < 30000 and 2 < beta_disc < 5.5 and -13 < rho0 < -9 and np.deg2rad(0) < i_disc < np.deg2rad(90) and 144 < ISM_DM < 148:
        return 0.0
    return -np.inf

# %%
#Probability function
def log_probability(theta, phi_data, DM_data, DM_err, i, a_Rsun, R_star_sol, M_star_sol, v_0_kms, v_inf_kms, e, Omega, beta):
    '''
    This function calcultes the log probability of the fitted parameters.
    ---------------------------------------------------------------------
    parameters:

    theta            [array] -> Fitted parameters
    phi_data         [array] -> Orbital Phase from literature (rad)
    DM_data          [array] -> Dispersion meausre from literature (pccm^-3)
    DM_err           [array] -> Dispersion measure error values from literature (pccm^-3)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    --------------------------------------------------------------------------
    Returns:

    The log probability of the fitted parameters.
    '''
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(theta, phi_data, DM_data, DM_err, i, a_Rsun, R_star_sol, M_star_sol, v_0_kms, v_inf_kms, e, Omega, beta)

# %%
#Computing the maximum likelihood estimates
np.random.seed(42)                                                      #Random seed
nll = lambda *args: -log_likelihood(*args)                              #Negative log likelihood                                             
initial_Mdot_Msun_per_yr = -9                                           #Guess for mass loss
initial_omega = np.deg2rad(30)                                          #Guess for argument of periastron            
initial_T_disc = 1.5e4                                                  #Guess for disc temperature
initial_beta_disc = 3                                                   #Guess for disc beta
initial_rho0 = -12                                                      #Guess for initial disc density
initial_i_disc = np.deg2rad(60)                                         #Guess for disc inclination
initial_ISM_DM = 146

initial = np.array([initial_Mdot_Msun_per_yr, initial_omega, initial_T_disc, initial_beta_disc, initial_rho0, initial_i_disc, initial_ISM_DM]) + 0.1 * np.random.randn(7) #Initial guess array
bounds = [(-15, -7), (np.deg2rad(0), np.deg2rad(90)), (9000, 30000), (2, 5.5), (-13, -9), (np.deg2rad(0), np.deg2rad(90)), (144, 148)]                                #Setting parameter bounds

soln_2024 = minimize(nll, initial, args=(phi2024, DM2024, error2024, i, a_Rsun, R_star_sol, M_star_sol, v_0_kms, v_inf_kms, e, Omega, beta), bounds=bounds)
Mdot_Msun_per_yr_ml_2024, omega_ml_2024, T_disc_ml_2024, beta_disc_ml_2024, rho0_ml_2024, i_disc_ml_2024, ISM_DM_ml_2024 = soln_2024.x

print("Maximum likelihood estimates 2024:")
print("Mass loss = {0:.3f}".format(Mdot_Msun_per_yr_ml_2024))
print("omega = {0:.3f}".format(omega_ml_2024))
print("Disc T = {0:.3f}".format(T_disc_ml_2024))
print("Disc beta = {0:.3f}".format(beta_disc_ml_2024))
print("Initial Disc Density = {0:.3f}".format(rho0_ml_2024))
print("Disc i = {0:.3f}".format(i_disc_ml_2024))
print("ISM DM = {0:.3f}".format(ISM_DM_ml_2024))
# Out:
# Maximum likelihood estimates 2024:
# Mass loss = -12.919
# omega = 0.760
# Disc T = 14430.539
# Disc beta = 3.959
# Initial Disc Density = -12.284
# Disc i = 1.233
# ISM DM = 146.727

# %% [markdown]
# # 2024 Periastron Passage

# %% [markdown]
# ## MCMC for All Parameters

# %%
#Running the MCMC

pos_2024 = soln_2024.x + 2e-3 * np.random.randn(140, 7)
nwalkers, ndim = pos_2024.shape

sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(phi2024, DM2024, error2024, i, a_Rsun, R_star_sol, M_star_sol, v_0_kms, v_inf_kms, e, Omega, beta)
)
sampler.run_mcmc(pos_2024, 1500, progress=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1500/1500 [29:57<00:00,  1.20s/it]
# State([[-1.22474911e+01  5.09536158e-01  1.32539498e+04  4.07175126e+00
#   -1.20557436e+01  1.23087461e+00  1.46734564e+02]
#  [-1.16443927e+01  6.83694158e-01  1.38330787e+04  3.95962755e+00
#   -1.22596672e+01  1.23359299e+00  1.46721887e+02]
#  [-1.47393972e+01  4.75502199e-01  1.07838181e+04  3.95794252e+00
#   -1.21527528e+01  1.23880303e+00  1.46720021e+02]
#  [-1.33470109e+01  7.30428803e-01  1.32564053e+04  3.91603578e+00
#   -1.23126965e+01  1.23667178e+00  1.46726302e+02]
#  [-1.48472339e+01  5.72388930e-01  1.23238217e+04  4.05485385e+00
#   -1.20646221e+01  1.23485285e+00  1.46734455e+02]
#  [-1.45714727e+01  5.75968192e-01  1.24614200e+04  3.98804846e+00
#   -1.21715090e+01  1.23482339e+00  1.46727445e+02]
#  [-1.49075790e+01  6.04936719e-01  1.27784815e+04  3.94610621e+00
#   -1.22429141e+01  1.23465707e+00  1.46720819e+02]
#  [-1.38952532e+01  6.95437530e-01  1.29968471e+04  3.97746662e+00
#   -1.22085704e+01  1.23471426e+00  1.46734075e+02]
#  [-1.18701377e+01  6.58009341e-01  1.23469524e+04  3.99609427e+00
#   -1.21587192e+01  1.23659415e+00  1.46718899e+02]
#  [-1.12294235e+01  6.88488353e-01  1.30353018e+04  3.99256290e+00
#   -1.21874626e+01  1.23495673e+00  1.46716107e+02]
#  [-1.48684571e+01  5.84422407e-01  1.31151665e+04  4.02439975e+00
#   -1.21296436e+01  1.23227005e+00  1.46731754e+02]
#  [-1.43977417e+01  7.05560957e-01  1.38584223e+04  3.95376569e+00
#   -1.22737379e+01  1.23353014e+00  1.46721915e+02]
#  [-1.10629195e+01  6.39510952e-01  1.23404431e+04  3.87949221e+00
#   -1.23413980e+01  1.23720093e+00  1.46705734e+02]
#  [-1.46970281e+01  7.22461857e-01  1.34084036e+04  3.93298756e+00
#   -1.22914537e+01  1.23512219e+00  1.46719267e+02]
#  [-1.20258504e+01  5.70450735e-01  1.16918542e+04  4.08054190e+00
#   -1.19979603e+01  1.23686197e+00  1.46729859e+02]
#  [-1.41024667e+01  6.59312142e-01  1.42391026e+04  3.99655186e+00
#   -1.22096002e+01  1.23182439e+00  1.46723181e+02]
#  [-1.42299464e+01  6.32524711e-01  1.21484187e+04  3.85875096e+00
#   -1.23672009e+01  1.23746397e+00  1.46708234e+02]
#  [-1.45824820e+01  7.49469581e-01  1.32377730e+04  3.88722592e+00
#   -1.23611520e+01  1.23625713e+00  1.46727397e+02]
#  [-1.12562775e+01  6.07240960e-01  1.31788607e+04  4.00629856e+00
#   -1.21638707e+01  1.23330268e+00  1.46720767e+02]
#  [-1.30366746e+01  6.34481437e-01  1.29391569e+04  3.87019577e+00
#   -1.23666340e+01  1.23526863e+00  1.46714934e+02]
#  [-1.30761626e+01  5.79912841e-01  1.28546749e+04  4.03948695e+00
#   -1.20993528e+01  1.23416991e+00  1.46723858e+02]
#  [-1.32007713e+01  6.58436018e-01  1.25926795e+04  3.98133539e+00
#   -1.21843514e+01  1.23600757e+00  1.46722671e+02]
#  [-1.46494866e+01  5.90288630e-01  1.23500898e+04  3.95336992e+00
#   -1.22178033e+01  1.23516376e+00  1.46726541e+02]
#  [-1.28521886e+01  6.00290934e-01  1.19135942e+04  3.98013966e+00
#   -1.21613824e+01  1.23729168e+00  1.46726134e+02]
#  [-1.43886681e+01  6.66957833e-01  1.23045740e+04  3.92760129e+00
#   -1.22603060e+01  1.23724652e+00  1.46720479e+02]
#  [-1.14313911e+01  5.19416804e-01  1.25429150e+04  4.06756724e+00
#   -1.20426988e+01  1.23360475e+00  1.46722496e+02]
#  [-1.38750502e+01  6.96248741e-01  1.23778621e+04  3.98838055e+00
#   -1.21744953e+01  1.23761293e+00  1.46728812e+02]
#  [-1.20117546e+01  6.42558683e-01  1.28826993e+04  4.01003405e+00
#   -1.21494329e+01  1.23471177e+00  1.46727135e+02]
#  [-1.17397051e+01  5.14365539e-01  1.30022528e+04  4.07526118e+00
#   -1.20412724e+01  1.23211538e+00  1.46714883e+02]
#  [-1.43673675e+01  6.38647291e-01  1.36944819e+04  4.00858484e+00
#   -1.21797661e+01  1.23181162e+00  1.46727503e+02]
#  [-1.34786084e+01  6.12053468e-01  1.26020503e+04  3.91458170e+00
#   -1.22839552e+01  1.23516198e+00  1.46707439e+02]
#  [-1.31505299e+01  6.67123650e-01  1.26435685e+04  3.88836370e+00
#   -1.23318889e+01  1.23613084e+00  1.46709499e+02]
#  [-1.25054273e+01  6.83067051e-01  1.34281651e+04  3.94015153e+00
#   -1.22787326e+01  1.23399183e+00  1.46726154e+02]
#  [-1.21808245e+01  5.15409666e-01  1.14458167e+04  3.87160783e+00
#   -1.23099292e+01  1.23801956e+00  1.46705351e+02]
#  [-1.43379250e+01  7.20405686e-01  1.31997617e+04  3.98203233e+00
#   -1.22154127e+01  1.23468712e+00  1.46740594e+02]
#  [-1.28039711e+01  4.79429245e-01  1.16029678e+04  3.99183223e+00
#   -1.21297741e+01  1.23610457e+00  1.46726967e+02]
#  [-1.42791921e+01  6.20610371e-01  1.31246835e+04  4.07630156e+00
#   -1.20577122e+01  1.23224869e+00  1.46742381e+02]
#  [-1.27509659e+01  6.75679966e-01  1.35877942e+04  4.00009861e+00
#   -1.21943993e+01  1.23288118e+00  1.46732685e+02]
#  [-1.23198424e+01  6.41121096e-01  1.30649493e+04  3.95563768e+00
#   -1.22422402e+01  1.23406203e+00  1.46732880e+02]
#  [-1.18221061e+01  6.49772065e-01  1.23596492e+04  3.95525538e+00
#   -1.22216897e+01  1.23685576e+00  1.46729505e+02]
#  [-1.16463973e+01  6.18307704e-01  1.23033443e+04  3.90275596e+00
#   -1.22989566e+01  1.23698062e+00  1.46722203e+02]
#  [-1.19947847e+01  5.31860543e-01  1.21652113e+04  4.01921710e+00
#   -1.21085581e+01  1.23520302e+00  1.46729267e+02]
#  [-1.35197159e+01  5.65612382e-01  1.25708288e+04  3.98989735e+00
#   -1.21678998e+01  1.23436612e+00  1.46715971e+02]
#  [-1.19804461e+01  6.37176156e-01  1.25669813e+04  4.00110957e+00
#   -1.21501957e+01  1.23598185e+00  1.46715972e+02]
#  [-1.21000799e+01  6.01616978e-01  1.29146613e+04  4.00954104e+00
#   -1.21544666e+01  1.23426472e+00  1.46725273e+02]
#  [-1.33048986e+01  7.14906287e-01  1.41396324e+04  4.00695233e+00
#   -1.21948840e+01  1.23237007e+00  1.46733787e+02]
#  [-1.48027544e+01  5.69619877e-01  1.21467924e+04  3.99047183e+00
#   -1.21551835e+01  1.23579350e+00  1.46729047e+02]
#  [-1.30773688e+01  5.54792615e-01  1.32081137e+04  4.05081039e+00
#   -1.20929849e+01  1.23184835e+00  1.46730834e+02]
#  [-1.44416587e+01  4.93255124e-01  1.17283705e+04  3.89347557e+00
#   -1.22823397e+01  1.23617133e+00  1.46703556e+02]
#  [-1.29147488e+01  6.91204922e-01  1.30661400e+04  3.93832177e+00
#   -1.22702682e+01  1.23519192e+00  1.46719767e+02]
#  [-1.34280740e+01  6.19900038e-01  1.29463140e+04  3.95840107e+00
#   -1.22328723e+01  1.23432379e+00  1.46723954e+02]
#  [-1.47652351e+01  7.02083495e-01  1.34203677e+04  3.95233435e+00
#   -1.22653932e+01  1.23461192e+00  1.46729148e+02]
#  [-1.45794693e+01  6.08724331e-01  1.29042665e+04  3.88940535e+00
#   -1.23342685e+01  1.23464070e+00  1.46710523e+02]
#  [-1.32357010e+01  6.47362324e-01  1.28447710e+04  3.88827772e+00
#   -1.23405324e+01  1.23548710e+00  1.46718128e+02]
#  [-1.39482334e+01  6.45491709e-01  1.28326271e+04  4.02458069e+00
#   -1.21276419e+01  1.23494399e+00  1.46731453e+02]
#  [-1.33381450e+01  5.79305940e-01  1.16197914e+04  3.94980279e+00
#   -1.22022636e+01  1.23754001e+00  1.46722450e+02]
#  [-1.48470868e+01  5.90426951e-01  1.29952735e+04  4.01727707e+00
#   -1.21419314e+01  1.23343953e+00  1.46738077e+02]
#  [-1.34165532e+01  7.84197661e-01  1.47987488e+04  4.08426688e+00
#   -1.21090742e+01  1.23153792e+00  1.46745409e+02]
#  [-1.08026586e+01  5.39643115e-01  1.30181367e+04  4.07830847e+00
#   -1.20416423e+01  1.23187291e+00  1.46703318e+02]
#  [-1.38561408e+01  6.43269122e-01  1.23077537e+04  3.86300162e+00
#   -1.23652525e+01  1.23690304e+00  1.46714739e+02]
#  [-1.40482459e+01  6.30590658e-01  1.21594704e+04  3.97982571e+00
#   -1.21716259e+01  1.23656748e+00  1.46720676e+02]
#  [-1.24823699e+01  6.40580673e-01  1.23007372e+04  4.03012320e+00
#   -1.21031195e+01  1.23584970e+00  1.46727486e+02]
#  [-1.30576834e+01  6.56952657e-01  1.33470343e+04  4.01144850e+00
#   -1.21628260e+01  1.23335843e+00  1.46731442e+02]
#  [-1.43438409e+01  6.25987620e-01  1.34602721e+04  4.02565092e+00
#   -1.21417207e+01  1.23221231e+00  1.46731222e+02]
#  [-1.20607645e+01  6.57049510e-01  1.29121361e+04  3.99429110e+00
#   -1.21826120e+01  1.23483541e+00  1.46726046e+02]
#  [-1.26950506e+01  5.75014597e-01  1.26709029e+04  3.99217212e+00
#   -1.21673189e+01  1.23448372e+00  1.46725615e+02]
#  [-1.13807438e+01  6.33025674e-01  1.28654796e+04  3.99769693e+00
#   -1.21706751e+01  1.23442806e+00  1.46727625e+02]
#  [-1.29802479e+01  7.50576602e-01  1.41187313e+04  3.98282815e+00
#   -1.22393613e+01  1.23384140e+00  1.46727979e+02]
#  [-1.16408365e+01  5.82000348e-01  1.43217134e+04  4.04684458e+00
#   -1.21326707e+01  1.22853830e+00  1.46728746e+02]
#  [-1.19922689e+01  6.60255215e-01  1.27035886e+04  4.00198941e+00
#   -1.21608696e+01  1.23528674e+00  1.46730279e+02]
#  [-1.08424470e+01  6.26813067e-01  1.20986498e+04  3.88728442e+00
#   -1.23195706e+01  1.23773149e+00  1.46695175e+02]
#  [-1.44880457e+01  5.32193843e-01  1.24675248e+04  4.01639488e+00
#   -1.21208927e+01  1.23404381e+00  1.46723142e+02]
#  [-1.38314706e+01  6.17823330e-01  1.29873173e+04  3.97015477e+00
#   -1.22162490e+01  1.23391762e+00  1.46723420e+02]
#  [-1.19300018e+01  6.03137508e-01  1.24612623e+04  3.95751755e+00
#   -1.22169582e+01  1.23566182e+00  1.46730955e+02]
#  [-1.49685305e+01  5.98559460e-01  1.33128884e+04  4.02736094e+00
#   -1.21314207e+01  1.23240959e+00  1.46730175e+02]
#  [-1.45539268e+01  6.50745271e-01  1.33692705e+04  4.00388087e+00
#   -1.21749367e+01  1.23286004e+00  1.46723571e+02]
#  [-1.38990618e+01  6.86099242e-01  1.32800780e+04  4.04561554e+00
#   -1.21122245e+01  1.23420004e+00  1.46733441e+02]
#  [-1.47378189e+01  6.76300851e-01  1.25414673e+04  3.80607465e+00
#   -1.24574735e+01  1.23751727e+00  1.46710524e+02]
#  [-1.34311103e+01  6.73039293e-01  1.19822460e+04  3.88970910e+00
#   -1.23109312e+01  1.23821456e+00  1.46712056e+02]
#  [-1.23034545e+01  7.00374167e-01  1.33024263e+04  4.04973228e+00
#   -1.21098212e+01  1.23409114e+00  1.46738592e+02]
#  [-1.42586517e+01  7.51338589e-01  1.36529389e+04  3.94198487e+00
#   -1.22906182e+01  1.23460306e+00  1.46725458e+02]
#  [-1.19864546e+01  7.41775330e-01  1.33575860e+04  3.98233149e+00
#   -1.22152903e+01  1.23540560e+00  1.46735813e+02]
#  [-1.23007098e+01  4.90025846e-01  1.21047119e+04  3.97151779e+00
#   -1.21791253e+01  1.23483533e+00  1.46715282e+02]
#  [-1.18034737e+01  6.60641902e-01  1.34467701e+04  3.96598706e+00
#   -1.22373212e+01  1.23363091e+00  1.46721451e+02]
#  [-1.25098352e+01  5.54481725e-01  1.20482988e+04  3.96835797e+00
#   -1.21831916e+01  1.23573936e+00  1.46717838e+02]
#  [-1.42119732e+01  6.09924536e-01  1.28678568e+04  3.84839189e+00
#   -1.23976984e+01  1.23452784e+00  1.46715698e+02]
#  [-1.36913144e+01  6.60742012e-01  1.32930681e+04  3.96198390e+00
#   -1.22354169e+01  1.23431678e+00  1.46720605e+02]
#  [-1.47497064e+01  7.38912183e-01  1.32864234e+04  3.94374330e+00
#   -1.22697932e+01  1.23593560e+00  1.46719997e+02]
#  [-1.39537797e+01  5.76004254e-01  1.26792037e+04  4.02774273e+00
#   -1.21148437e+01  1.23351097e+00  1.46734329e+02]
#  [-1.40733322e+01  7.33963681e-01  1.43066720e+04  3.94051907e+00
#   -1.23068943e+01  1.23292611e+00  1.46723349e+02]
#  [-1.25532969e+01  5.66145848e-01  1.24542181e+04  3.98227755e+00
#   -1.21767893e+01  1.23508221e+00  1.46730932e+02]
#  [-1.48823271e+01  5.64331845e-01  1.24765964e+04  3.99290980e+00
#   -1.21601808e+01  1.23486849e+00  1.46731072e+02]
#  [-1.40297969e+01  5.42455463e-01  1.21312593e+04  4.00292304e+00
#   -1.21348969e+01  1.23498990e+00  1.46728043e+02]
#  [-1.20819228e+01  6.64804796e-01  1.35040241e+04  4.10908205e+00
#   -1.20220025e+01  1.23284238e+00  1.46741129e+02]
#  [-1.15218435e+01  6.42000714e-01  1.27695106e+04  3.92743409e+00
#   -1.22758825e+01  1.23573975e+00  1.46720903e+02]
#  [-1.49479569e+01  6.40064993e-01  1.24975118e+04  4.01952209e+00
#   -1.21302043e+01  1.23565844e+00  1.46729151e+02]
#  [-1.33406830e+01  6.05642693e-01  1.18499755e+04  3.95618159e+00
#   -1.22018820e+01  1.23786693e+00  1.46729199e+02]
#  [-1.21094517e+01  5.65751901e-01  1.25549962e+04  3.98430424e+00
#   -1.21766525e+01  1.23454229e+00  1.46727829e+02]
#  [-1.32425873e+01  6.23393592e-01  1.23169415e+04  4.02135906e+00
#   -1.21180328e+01  1.23558788e+00  1.46740656e+02]
#  [-1.35525421e+01  7.06340253e-01  1.31960136e+04  3.96505820e+00
#   -1.22322009e+01  1.23530846e+00  1.46720715e+02]
#  [-1.29528845e+01  5.43737623e-01  1.18692186e+04  3.98336906e+00
#   -1.21543992e+01  1.23700972e+00  1.46719782e+02]
#  [-1.26892978e+01  5.25018565e-01  1.24889405e+04  4.07152149e+00
#   -1.20357079e+01  1.23392395e+00  1.46734535e+02]
#  [-1.30009353e+01  4.77836560e-01  1.16371630e+04  3.99826324e+00
#   -1.21173980e+01  1.23624189e+00  1.46722828e+02]
#  [-1.34588615e+01  6.59290773e-01  1.26591695e+04  4.03134633e+00
#   -1.21146273e+01  1.23520253e+00  1.46737823e+02]
#  [-1.32676455e+01  6.01796190e-01  1.28604384e+04  4.05310433e+00
#   -1.20794357e+01  1.23318001e+00  1.46726001e+02]
#  [-1.48058275e+01  6.41499906e-01  1.35182574e+04  4.00955189e+00
#   -1.21718439e+01  1.23305391e+00  1.46723546e+02]
#  [-1.44698625e+01  5.82224976e-01  1.25285740e+04  4.04397683e+00
#   -1.20902012e+01  1.23452036e+00  1.46739538e+02]
#  [-1.32369248e+01  5.67474600e-01  1.27295540e+04  4.00283302e+00
#   -1.21495641e+01  1.23438570e+00  1.46723107e+02]
#  [-1.18071907e+01  6.06011516e-01  1.23986943e+04  3.88861646e+00
#   -1.23224681e+01  1.23553145e+00  1.46714154e+02]
#  [-1.36834475e+01  6.14217523e-01  1.23949348e+04  4.08426810e+00
#   -1.20207623e+01  1.23564667e+00  1.46736850e+02]
#  [-1.28387221e+01  7.86703553e-01  1.35755413e+04  3.87892202e+00
#   -1.23848680e+01  1.23647905e+00  1.46719974e+02]
#  [-1.20275592e+01  5.87165258e-01  1.30802861e+04  3.98601895e+00
#   -1.21955862e+01  1.23315909e+00  1.46729174e+02]
#  [-1.46802815e+01  5.84494343e-01  1.28194096e+04  4.08002761e+00
#   -1.20388021e+01  1.23305049e+00  1.46741970e+02]
#  [-1.45477835e+01  6.02788087e-01  1.35887683e+04  4.08816964e+00
#   -1.20493142e+01  1.23220876e+00  1.46726897e+02]
#  [-1.13528165e+01  6.94479664e-01  1.30903559e+04  4.00231134e+00
#   -1.21773252e+01  1.23536482e+00  1.46726619e+02]
#  [-1.18147913e+01  5.83398885e-01  1.27061434e+04  4.00443621e+00
#   -1.21501096e+01  1.23443792e+00  1.46720149e+02]
#  [-1.23879495e+01  5.88207830e-01  1.26831295e+04  4.04974233e+00
#   -1.20793254e+01  1.23437177e+00  1.46730526e+02]
#  [-1.45663945e+01  6.39024905e-01  1.24364706e+04  3.90557966e+00
#   -1.22999639e+01  1.23655645e+00  1.46714767e+02]
#  [-1.20396275e+01  5.67148028e-01  1.26043176e+04  4.03516267e+00
#   -1.20975117e+01  1.23448019e+00  1.46719462e+02]
#  [-1.17256763e+01  6.68987055e-01  1.29090609e+04  3.91593689e+00
#   -1.23016544e+01  1.23570643e+00  1.46722499e+02]
#  [-1.25845967e+01  7.71684768e-01  1.45281202e+04  3.87875682e+00
#   -1.24124633e+01  1.23366202e+00  1.46721706e+02]
#  [-1.36017557e+01  5.52327273e-01  1.26208610e+04  4.03847983e+00
#   -1.20967785e+01  1.23384812e+00  1.46732571e+02]
#  [-1.31931929e+01  6.91934026e-01  1.36117568e+04  3.93113405e+00
#   -1.22998893e+01  1.23316501e+00  1.46722417e+02]
#  [-1.42743223e+01  7.20585668e-01  1.46701900e+04  3.87006188e+00
#   -1.24187147e+01  1.23204916e+00  1.46703613e+02]
#  [-1.26506486e+01  7.80225829e-01  1.40349546e+04  3.94617003e+00
#   -1.22913401e+01  1.23403416e+00  1.46726135e+02]
#  [-1.14627924e+01  5.61635711e-01  1.30411226e+04  4.05236557e+00
#   -1.20881278e+01  1.23245007e+00  1.46727575e+02]
#  [-1.23867439e+01  6.89320638e-01  1.29397877e+04  3.82023440e+00
#   -1.24494626e+01  1.23608789e+00  1.46706436e+02]
#  [-1.32095269e+01  5.68370830e-01  1.25580799e+04  4.05069131e+00
#   -1.20725245e+01  1.23392172e+00  1.46730280e+02]
#  [-1.24380871e+01  6.19058023e-01  1.29210985e+04  3.95017796e+00
#   -1.22425452e+01  1.23390183e+00  1.46728854e+02]
#  [-1.28411897e+01  6.57192884e-01  1.35416180e+04  4.11119173e+00
#   -1.20208860e+01  1.23294557e+00  1.46747423e+02]
#  [-1.43349425e+01  6.55361444e-01  1.29366314e+04  3.98157146e+00
#   -1.21995226e+01  1.23444562e+00  1.46731667e+02]
#  [-1.23627484e+01  6.43622243e-01  1.28635304e+04  3.97028801e+00
#   -1.22110019e+01  1.23476341e+00  1.46726259e+02]
#  [-1.35296916e+01  5.61020497e-01  1.24929544e+04  3.98413332e+00
#   -1.21754103e+01  1.23446932e+00  1.46723485e+02]
#  [-1.35781836e+01  5.84236619e-01  1.26185196e+04  3.96085761e+00
#   -1.22187463e+01  1.23497189e+00  1.46724004e+02]
#  [-1.41061855e+01  6.22768407e-01  1.33118834e+04  3.98195924e+00
#   -1.22030631e+01  1.23318416e+00  1.46722899e+02]
#  [-1.47002099e+01  4.40052082e-01  1.09606807e+04  4.06395594e+00
#   -1.19968273e+01  1.23729555e+00  1.46738600e+02]
#  [-1.19747557e+01  5.71738517e-01  1.26676688e+04  4.04763966e+00
#   -1.20855675e+01  1.23399819e+00  1.46735931e+02]
#  [-1.22465100e+01  6.25540305e-01  1.29308412e+04  3.97676427e+00
#   -1.21964945e+01  1.23442708e+00  1.46725043e+02]
#  [-1.26879291e+01  6.24933213e-01  1.29544255e+04  3.98531192e+00
#   -1.21863900e+01  1.23440461e+00  1.46728004e+02]
#  [-1.37642051e+01  5.69963393e-01  1.26464905e+04  4.04822445e+00
#   -1.20793506e+01  1.23391162e+00  1.46732669e+02]], log_prob=[-2553.94473356 -2550.97286506 -2552.66893681 -2555.59978185
#  -2549.82193726 -2548.98883712 -2548.22138268 -2551.04817108
#  -2552.3636016  -2550.91011659 -2551.4384802  -2550.40827382
#  -2554.6931416  -2548.69756833 -2552.62578823 -2552.15945622
#  -2555.72834199 -2550.12976386 -2549.07346266 -2551.04114322
#  -2550.44445645 -2549.45432229 -2549.64050409 -2550.44458336
#  -2549.25879817 -2550.21844227 -2551.44796217 -2548.3896198
#  -2554.56623563 -2551.12265993 -2551.32468019 -2550.21761233
#  -2548.52902561 -2553.89731542 -2551.62690741 -2549.76817141
#  -2552.65201016 -2550.39301956 -2550.06460905 -2549.83624875
#  -2552.71191606 -2548.78280239 -2550.55871409 -2552.30100976
#  -2551.20157466 -2551.32844129 -2548.06806681 -2549.80601721
#  -2554.33703626 -2548.35199651 -2548.25406681 -2549.89035
#  -2550.22725162 -2549.61901265 -2548.22166603 -2549.69197399
#  -2550.03973321 -2554.86443654 -2555.20474679 -2551.87465593
#  -2550.00913832 -2551.29938367 -2548.51136842 -2549.46179492
#  -2550.96645945 -2548.28158329 -2548.44420292 -2550.69702892
#  -2556.36735843 -2548.32118425 -2555.98751037 -2548.81827488
#  -2548.84547423 -2550.7258829  -2549.75877373 -2550.4886811
#  -2549.29786496 -2553.83366555 -2551.41406401 -2549.78547678
#  -2550.2377794  -2551.22524711 -2551.60437578 -2548.44442191
#  -2549.1174859  -2554.41529186 -2548.91762359 -2550.30196477
#  -2549.34278147 -2549.98532655 -2549.70721309 -2549.12752794
#  -2549.06726737 -2551.10877051 -2549.75753031 -2552.07421621
#  -2551.41629185 -2548.64552864 -2549.54124237 -2549.24896968
#  -2551.8589563  -2549.83895067 -2550.51944272 -2548.99059808
#  -2551.96019245 -2549.8328842  -2550.48842729 -2549.73443235
#  -2551.10536595 -2550.91785939 -2550.51886965 -2551.42638193
#  -2549.96739822 -2553.62869592 -2550.49772593 -2548.76293805
#  -2548.65187942 -2549.32348857 -2550.44931975 -2549.35829777
#  -2552.86869384 -2549.09200472 -2551.57612562 -2554.79574858
#  -2551.51047193 -2550.20698537 -2551.67646794 -2548.83633495
#  -2550.66205729 -2553.02648868 -2548.4019111  -2547.93891392
#  -2548.61478309 -2549.81428553 -2548.75652496 -2552.62366772
#  -2549.19108129 -2552.56064171 -2550.1838979  -2548.43884301], blobs=None, random_state=('MT19937', array([ 198443501, 2773903204, 3687029016, 3779876238, 1855667620,
#        2016834896, 1635553750, 1049097545, 1925214743,  536571032,
#        3388684975, 3224826854, 1094316014, 3659794825, 4140519787,
#         692135470, 3727360003, 1929749797, 2034744759,  957722540,
#         665577794, 1295793229,  304248726, 1009354086, 2867406731,
#        1333560207, 3198544497, 2164101762,  577784028, 3377146559,
#        2504745580,  944291303, 4138240526, 1214517499,  974709286,
#        1478319427, 3910223952, 4205638084, 3342006626,  682907111,
#        3895405736, 1695796413,  604162970, 3655886544, 3260384520,
#        1873585113, 2864845706, 3858777235, 1898219357, 2772884145,
#        1562677881, 2135922187, 3007723886, 3376119931, 3349706798,
#        2245618954, 1690033659,  315726411,  943807973,  815874462,
#        1301144522, 2539096756, 2107888031, 3266047509, 2884253731,
#        1388056349, 2622176507, 2148547507, 2267505897, 4278885359,
#        3413334512, 3560256590, 2699948835, 2856729905, 1848822044,
#        2238718563, 1840991877, 3047171656, 3405147780, 3420542163,
#         884622778, 3017028298,  926127374, 2134675368,  691317587,
#        3577613271, 2781546971,  327200408, 4193955493, 3007498604,
#        1734715739, 1528999544, 2610833011, 2551447596, 4196303470,
#        3665643677,  603373788,  911502036, 3871021656, 2897120166,
#          74528963,  172837479, 1024324780, 4249492045, 1800091290,
#         337322540, 4042152477, 3743873950, 2956064052, 3722505116,
#        1870387989, 4054421897,  925835825, 3213011827, 2436132994,
#        2119662227,  155770422, 2903013442, 1595013826, 1852146495,
#        3438397312, 2961343786, 1560492231, 1323083550, 2329745314,
#        1277049354, 1039936070, 3179228282, 3271712352,  773693466,
#         899980649, 1888487365, 2789963917, 2248269024, 2955570688,
#        2360193416, 3010622414,  260594050, 1460764127, 4163745968,
#        4081479783, 1087638457, 1418032713, 1039579507, 4041263326,
#        1711181878, 1456826252, 2869879166,  943036406, 3231922805,
#        4127797589, 1665079517, 1112375430,  815149883, 2562757468,
#        3807868713, 2582690453, 3131782719, 3256975386, 3940549218,
#        2617965664,  953612779, 1350710291, 2196768341, 1004394574,
#        3677813058, 2749470312, 3192219761,  900028472, 1102070703,
#        3371151612, 1427452191,  300400320, 1299045311, 3596448552,
#        2459543577, 3331669257,  365066679, 1784168456,  469496400,
#        4060671097, 1060393766, 1350304603, 1766123189, 1646756387,
#        4242380789,  287539684, 1838521808, 1673237469, 1305152049,
#        1320489968,  306673537, 2213760342, 1485905431, 1367680957,
#        2181489805, 1734438790, 1186598558, 3925936471, 3118360589,
#        2295806877, 4052263170, 1215260292, 3262673628, 2270336810,
#        3988239224, 2888930814,   95421949, 2832758632,   46542312,
#          97043003,  986586744,  218140855, 1600988996, 3020676798,
#         662863302, 3932728292, 1735830453,  293878366, 3186582270,
#        3177890522, 3989889801,  276504422, 3182189178, 3286115545,
#        1099708268, 2395688312,  902430846,  931391787, 1970600177,
#        4267600801, 3030646351, 4019918217, 2044480316, 1984800990,
#        1641388529, 2074174525, 2837870352,  111647973, 1698828461,
#        2545018312, 3859431787,   34183070, 3960008818,  470429294,
#        1396320042,  972884911, 1939000705, 1289384725, 2906991981,
#        1592360640, 3975287723,  929284481,  713873848, 2213910995,
#        1929883995,  728169690,  158187580, 2072168308, 1064036261,
#        2088965487, 2763630805, 2157347639, 3259050544,  164137054,
#        2161860621, 2117425125, 2867371600,  964505288,   96831190,
#        2087037529, 3212528693,  938896978, 2492828806, 1018552125,
#         696424034,  141354193, 3948135205, 4129505722, 1974095060,
#        4070862730, 1306619355, 3996396739,  537315381, 2104106213,
#         628831877,  766068463, 2629615313, 2852128930, 2711848490,
#        1847169085, 3892090840,  342873394, 2812555368, 3827234347,
#        3852923231, 1182319258, 1316088898, 2262264056, 2922108141,
#        2728046028, 3109299768, 4191214718,  916358178, 2057800157,
#        2078120552,  268019654, 3282272122, 1609757749,  956872997,
#        2619459841, 2522063879, 2041662803, 3629500228, 3759004441,
#        1439884695, 1739828138, 2998756480,  930251819, 3611531638,
#        1415300739,  351302238, 1522079656, 2157786475, 4292306647,
#        1063567270, 3486406147, 2046784101,  987119432, 2148542491,
#        1742748853, 3046767690, 1014996738, 3292083008,  532763788,
#        1233912257, 3466897444,  799021629, 1167267975, 1429420895,
#        4151971617, 3360230515,  207531902, 1257876901,  826080392,
#          86022320, 1107832204, 3560105763,  201789186, 1277501604,
#        2693988535, 3447022339, 2329084043, 3155373064, 4014322483,
#        3346605263, 1155734880, 2757994095, 1165243607, 1969313359,
#        1480559978,  407445677, 2086633497,  794859350, 3122603786,
#        2921311022,   86901420, 3783172526, 1679291319, 4255078449,
#         686373030, 2501276507,   67173921, 3205771512, 3074141400,
#         571038404, 1454110872, 2779821434, 4209600664, 1654019063,
#        3254140228, 3512319572, 2535460977, 1312126898, 2355604872,
#        2062853856,   13924792, 1923933735, 4285291419, 2129568184,
#         161444695, 1935707882, 3850182716,  183911957, 3247610030,
#        3453488221, 3329346937, 3459911553, 2702034563,  417075044,
#        2215107277, 1073891500, 3046930852, 1128886179, 3325437170,
#        2806650722,  339684250, 1650415243, 1805434572, 2156066365,
#         337489271, 2297950504, 2306253031, 1499152384, 3283899114,
#        1886955173, 1387285005, 3846103026, 2642221462, 2449606755,
#         563465595,  936505614, 2657466949, 2947390650,  241490751,
#        1391838696, 4070133095, 3592967119, 1133448750,  737271591,
#        3444818703, 2373925759, 2495006382,  935645003,  228373242,
#        2968262161, 1049421861, 2037096324, 4104746814,  643491127,
#         126173637,  481618080,  695690861, 1741878416, 1690010652,
#         929166299, 1338811433,  249356169, 2596013298, 3392386235,
#        1080661550,  135795967, 1729068044, 2662651403, 2086882319,
#         444894529, 4024089037,  120671408,   23890702, 1718023510,
#        4048792827, 4135880943, 3750979796, 1557113768, 3306481368,
#         315908060, 2581282399, 1082040907, 3724845270, 4125758110,
#        1653219189, 1614183671,  321388073, 1083573798, 1145901958,
#         744753140,  486157532, 2665127216, 3736508282, 1265826265,
#        1803220694, 1414027949,  463959796, 2980642363, 1106135977,
#        2907607494, 4110485363, 1253524366,  826678097,  698699618,
#        1655176919, 3988310800,  498246288, 3100884083, 1939712982,
#         642671053,   64842646, 1880975903, 1345103505, 2879751640,
#        1461431555, 2826230419, 2176544776,   64644105,  873072297,
#         931617089,  491743524, 2422631042, 3210083482, 2583493450,
#         978172509, 2828800336, 1903635538,  200803737, 1606067257,
#        1186108404, 4208414265, 3903009033, 1986146046, 2145064290,
#        2172706428, 4211586847, 4095578949, 2771013141, 3809444677,
#        2956489331,  258945171, 3810894635, 3770887856,  810736277,
#        3361574559, 3982133266, 1465664602, 1504564981,  907119442,
#        2724460327, 3600102880, 2846625062, 3945132750,  342105306,
#        3320970780, 3129418467, 3505924967,  755241198, 2643922171,
#         297678096, 1759805264, 3142248363, 2288799568, 3056628946,
#        1065976664,  885696180, 3265980867, 2774697559, 4222807654,
#        3870624306, 1374975765, 1991273120, 2929466352, 3027410896,
#         843127858, 3303101870, 3290841269, 4087728782, 2226351598,
#        3567950526, 1357974713, 3034171597, 1177022158, 1782579907,
#         113371701, 3280755947, 3080973398,  679508602, 4124975916,
#        2442675119,  918561132, 4243863616,   98754677, 2729979009,
#        2635453293, 1759929776, 3629447442, 3409472925,  346359614,
#        1618617296, 1022441632, 2853999854,  400948045, 1956446722,
#        2079013113, 1620452111,  123309579, 2084199346,  689320272,
#         742919574, 1195539219, 3172872481, 1974496690,  386981529,
#        3245060528, 2421238633, 1513684013, 3652587081, 1672018754,
#        2609545417, 2551030070, 1872584585,  858022373,  316868712,
#        2576030139, 2636614470, 3517750309, 3771856611, 3511642353,
#        1709820508, 3862872981, 1138286167,  151867807,  311592710,
#        2596024156, 2638063828, 1859331595, 1519615312], dtype=uint32), 156, 1, 0.8773622905756714))

# %%
#Positions of each walker as a function of the number of steps in the chain
fig, axes = plt.subplots(7, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = [r"$log(\dot{M})$", r"$\omega$", r"$T_{disc}$", r"$\beta_{disc}$", r"$log(\rho_0)$", r"$i_{disc}$", "ISM DM"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number")
# Out:
# Text(0.5, 0, 'step number')

# %%
#Flat samples
flat_samples = sampler.get_chain(discard=500, thin=15, flat=True)
print(flat_samples.shape)
# Out:
# (9240, 7)

# %%
#Plotting the corner plot
fig = corner.corner(
    flat_samples, labels=labels, truths=[-9.081, 0.663, 16552.900, 4.815, -11.079, 1.215, 146.7]
)
#plt.savefig("MCMC_6params.png", dpi=300, bbox_inches="tight")

# %%
#Best fit results
for i in range(ndim):
    mcmc = np.percentile(flat_samples[:, i], [16, 50, 84])
    q = np.diff(mcmc)
    txt = "\mathrm{{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{{2:.3f}}}"
    txt = txt.format(mcmc[1], q[0], q[1], labels[i])
    display(Math(txt))
# Out:
# $\displaystyle \mathrm{$log(\dot{M})$} = -13.164_{-1.222}^{1.278}$
# $\displaystyle \mathrm{$\omega$} = 0.633_{-0.082}^{0.077}$
# $\displaystyle \mathrm{$T_{disc}$} = 12798.311_{-666.587}^{769.446}$
# $\displaystyle \mathrm{$\beta_{disc}$} = 3.983_{-0.063}^{0.062}$
# $\displaystyle \mathrm{$log(\rho_0)$} = -12.190_{-0.107}^{0.102}$
# $\displaystyle \mathrm{$i_{disc}$} = 1.235_{-0.002}^{0.002}$
# $\displaystyle \mathrm{ISM DM} = 146.726_{-0.009}^{0.008}$

# %% [markdown]
# # DM Vs Orbital Phase as Observed by MeerKAT

# %%
fig, axes = plt.subplots(7, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = [r"$log(\dot{M})$", r"$\omega$", r"$T_{disc}$", r"$\beta_{disc}$", r"$log(\rho_0)$", r"$i_{disc}$", "ISM DM"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[0:1500, 20:25, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number")
# Out:
# Text(0.5, 0, 'step number')

# %%
num = [100, 200, 300, 400, 500]

for i in range(ndim):
    for j in num:
        mcmc = np.percentile(flat_samples[j, i], [16, 50, 84])
        q = np.diff(mcmc)
        txt = "\mathrm{{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{{2:.3f}}}"
        txt = txt.format(mcmc[1], q[0], q[1], labels[i])
        display(Math(txt))
# Out:
# $\displaystyle \mathrm{$log(\dot{M})$} = -13.853_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$log(\dot{M})$} = -14.799_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$log(\dot{M})$} = -11.580_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$log(\dot{M})$} = -13.181_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$log(\dot{M})$} = -12.881_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$\omega$} = 0.688_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$\omega$} = 0.716_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$\omega$} = 0.850_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$\omega$} = 0.596_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$\omega$} = 0.572_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$T_{disc}$} = 13807.385_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$T_{disc}$} = 13291.460_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$T_{disc}$} = 15151.932_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$T_{disc}$} = 12425.825_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$T_{disc}$} = 12964.906_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$\beta_{disc}$} = 4.041_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$\beta_{disc}$} = 4.037_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$\beta_{disc}$} = 3.972_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$\beta_{disc}$} = 3.969_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$\beta_{disc}$} = 3.943_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$log(\rho_0)$} = -12.133_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$log(\rho_0)$} = -12.135_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$log(\rho_0)$} = -12.292_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$log(\rho_0)$} = -12.198_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$log(\rho_0)$} = -12.252_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$i_{disc}$} = 1.232_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$i_{disc}$} = 1.235_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$i_{disc}$} = 1.233_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$i_{disc}$} = 1.235_{-0.000}^{0.000}$
# $\displaystyle \mathrm{$i_{disc}$} = 1.234_{-0.000}^{0.000}$
# $\displaystyle \mathrm{ISM DM} = 146.735_{-0.000}^{0.000}$
# $\displaystyle \mathrm{ISM DM} = 146.740_{-0.000}^{0.000}$
# $\displaystyle \mathrm{ISM DM} = 146.727_{-0.000}^{0.000}$
# $\displaystyle \mathrm{ISM DM} = 146.726_{-0.000}^{0.000}$
# $\displaystyle \mathrm{ISM DM} = 146.716_{-0.000}^{0.000}$

# %%
#DM plot with the fitted values

phi = np.linspace(-np.pi, np.pi, 512)
DM1_2024 = tot_DM_mcmc(phi=phi, i=np.deg2rad(25), a_Rsun=1396, R_star_sol=8.958, M_star_sol=22.5, Mdot_Msun_per_yr=-13.853, v_0_kms=9.435, v_inf_kms=1071.974, e=0.87, omega=0.688, Omega=np.deg2rad(220.166), beta=0.8, T_disc=13807.385, beta_disc=4.041, rho0=-12.133, i_disc=1.232, ISM_DM=146.735)
DM2_2024 = tot_DM_mcmc(phi=phi, i=np.deg2rad(25), a_Rsun=1396, R_star_sol=8.958, M_star_sol=22.5, Mdot_Msun_per_yr=-14.799, v_0_kms=9.435, v_inf_kms=1071.974, e=0.87, omega=0.716, Omega=np.deg2rad(220.166), beta=0.8, T_disc=13291.460, beta_disc=4.037, rho0=-12.135, i_disc=1.235, ISM_DM=146.740)
DM3_2024 = tot_DM_mcmc(phi=phi, i=np.deg2rad(25), a_Rsun=1396, R_star_sol=8.958, M_star_sol=22.5, Mdot_Msun_per_yr=-11.580, v_0_kms=9.435, v_inf_kms=1071.974, e=0.87, omega=0.850, Omega=np.deg2rad(220.166), beta=0.8, T_disc=15151.932, beta_disc=3.972, rho0=-12.292, i_disc=1.233, ISM_DM=146.727)
DM4_2024 = tot_DM_mcmc(phi=phi, i=np.deg2rad(25), a_Rsun=1396, R_star_sol=8.958, M_star_sol=22.5, Mdot_Msun_per_yr=-13.181, v_0_kms=9.435, v_inf_kms=1071.974, e=0.87, omega=0.596, Omega=np.deg2rad(220.166), beta=0.8, T_disc=12425.825, beta_disc=3.969, rho0=-12.198, i_disc=1.235, ISM_DM=146.726)
DM5_2024 = tot_DM_mcmc(phi=phi, i=np.deg2rad(25), a_Rsun=1396, R_star_sol=8.958, M_star_sol=22.5, Mdot_Msun_per_yr=-12.881, v_0_kms=9.435, v_inf_kms=1071.974, e=0.87, omega=0.572, Omega=np.deg2rad(220.166), beta=0.8, T_disc=12964.906, beta_disc=3.943, rho0=-12.252, i_disc=1.234, ISM_DM=146.716)


plt.plot(phi, DM1_2024, alpha=0.5, label='MCMC plot 1')
plt.plot(phi, DM2_2024, alpha=0.5, label='MCMC plot 2')
plt.plot(phi, DM3_2024, alpha=0.5, label='MCMC plot 3')
plt.plot(phi, DM4_2024, alpha=0.5, label='MCMC plot 4')
plt.plot(phi, DM5_2024, alpha=0.5, label='MCMC plot 5')
plt.title('MCMC Best Fit Plots')
plt.ylabel('Dispersion Measure (pc $cm^-3$)')
plt.xlabel('Orbital Phase (rad)')
plt.legend()

# %%
#DM plot with the fitted values

phi = np.linspace(-np.pi, np.pi, 512)
DM1_2024 = tot_DM_mcmc(phi=phi, i=np.deg2rad(25), a_Rsun=1396, R_star_sol=8.958, M_star_sol=22.5, Mdot_Msun_per_yr=-13.853, v_0_kms=9.435, v_inf_kms=1071.974, e=0.87, omega=0.688, Omega=np.deg2rad(220.166), beta=0.8, T_disc=13807.385, beta_disc=4.041, rho0=-12.133, i_disc=1.232, ISM_DM=146.735)
DM2_2024 = tot_DM_mcmc(phi=phi, i=np.deg2rad(25), a_Rsun=1396, R_star_sol=8.958, M_star_sol=22.5, Mdot_Msun_per_yr=-14.799, v_0_kms=9.435, v_inf_kms=1071.974, e=0.87, omega=0.716, Omega=np.deg2rad(220.166), beta=0.8, T_disc=13291.460, beta_disc=4.037, rho0=-12.135, i_disc=1.235, ISM_DM=146.740)
DM3_2024 = tot_DM_mcmc(phi=phi, i=np.deg2rad(25), a_Rsun=1396, R_star_sol=8.958, M_star_sol=22.5, Mdot_Msun_per_yr=-11.580, v_0_kms=9.435, v_inf_kms=1071.974, e=0.87, omega=0.850, Omega=np.deg2rad(220.166), beta=0.8, T_disc=15151.932, beta_disc=3.972, rho0=-12.292, i_disc=1.233, ISM_DM=146.727)
DM4_2024 = tot_DM_mcmc(phi=phi, i=np.deg2rad(25), a_Rsun=1396, R_star_sol=8.958, M_star_sol=22.5, Mdot_Msun_per_yr=-13.181, v_0_kms=9.435, v_inf_kms=1071.974, e=0.87, omega=0.596, Omega=np.deg2rad(220.166), beta=0.8, T_disc=12425.825, beta_disc=3.969, rho0=-12.198, i_disc=1.235, ISM_DM=146.726)
DM5_2024 = tot_DM_mcmc(phi=phi, i=np.deg2rad(25), a_Rsun=1396, R_star_sol=8.958, M_star_sol=22.5, Mdot_Msun_per_yr=-12.881, v_0_kms=9.435, v_inf_kms=1071.974, e=0.87, omega=0.572, Omega=np.deg2rad(220.166), beta=0.8, T_disc=12964.906, beta_disc=3.943, rho0=-12.252, i_disc=1.234, ISM_DM=146.716)


plt.plot(phi, DM1_2024, alpha=0.5, label='MCMC plot 1')
plt.plot(phi, DM2_2024, alpha=0.5, label='MCMC plot 2')
plt.plot(phi, DM3_2024, alpha=0.5, label='MCMC plot 3')
plt.plot(phi, DM4_2024, alpha=0.5, label='MCMC plot 4')
plt.plot(phi, DM5_2024, alpha=0.5, label='MCMC plot 5')
plt.scatter(phi2024, DM2024, color='r', label='2024 datapoints')
plt.title('MCMC Best Fit Plots & Data')
plt.ylabel('Dispersion Measure (pc $cm^-3$)')
plt.xlabel('Orbital Phase (rad)')
plt.legend()

# %%
#DM plot with the fitted values

phi = np.linspace(-np.pi, np.pi, 512)
DM_2024 = tot_DM_mcmc(phi=phi, i=np.deg2rad(25), a_Rsun=1396, R_star_sol=8.958, M_star_sol=22.5, Mdot_Msun_per_yr=-9.081, v_0_kms=9.435, v_inf_kms=1071.974, e=0.87, omega=0.663, Omega=np.deg2rad(220.166), beta=0.8, T_disc=16552.900, beta_disc=4.815, rho0=-11.079, i_disc=1.215, ISM_DM=145.8)

plt.plot(phi, DM_2024, label='MCMC plot')
plt.scatter(phi2024, DM2024, color='r', label='2024 datapoints')
plt.title('MCMC Best Fit Plot Vs 2024 Data Points')
plt.ylabel('Dispersion Measure (pc $cm^-3$)')
plt.xlabel('Orbital Phase (rad)')
plt.xlim(-1.3, 0.8)
plt.legend()
