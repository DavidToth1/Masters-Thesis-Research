# %% [markdown]
# ## This model features a high mass Be star accelerating wind and circumstellar disc, with an elliptical orbit, a 3D coordinate system, and eclipses of a 'pseudo-signal' from a pulsar on the orbit.
# ## The main goal of this model is to see the number density, dispersion measure, optical depth and spectrum along a line of sight from a point on the orbit given an orbital phase, orbital and disc inclination, eccentricity, argument of periastron and longitude of ascending node.
# ## Stellar parameters are modelled after the star SS 2883 of the HMXB system PSR B1259-63/SS 2883. Wind terminal velocity is taken from the paper - https://arxiv.org/pdf/0806.4868, while the remaining stellar properties are taken from https://ui.adsabs.harvard.edu/abs/2011ApJ...732L..11N/abstract, https://arxiv.org/abs/1307.7083 and https://arxiv.org/pdf/1804.08402.
# ## Parameter values of the disc of SS 2883 are taken from the paper https://arxiv.org/abs/2204.08124

# %% [markdown]
# # Equations and Geometry
# ## Electron number density
# # $n_{e}(r) = \frac{\rho}{\mu_{e}m_{p}} = \frac{\dot{M}}{4\pi\mu_{e}m_{p}r^2v(r)} = \frac{k}{r^2v(r)}$
# Where
# # $\rho = \frac{\dot{M}}{4\pi r^2v(r)}$
#
# And
#
# # $k = \frac{\dot{M}}{4\pi\mu_{e}m_{p}}$
# With
#
# * $\rho$ =      Density
# * $\mu_{e}$ =   Mean molecular weight per free electron (typically set at a value of 1.2)
# * $m_{p}$ =     Proton mass
# * $\dot{M}$ =   Wind mass loss
# * $v(r)$ =     Radial wind velocity
# * $r$ =         radial distance from the center of the star
#
# ## Accelerating Wind ($\beta$ law)
# The wind velocity at a certain distance away from the star is
# # $v(r) = v_0 + (v_{\infty} - v_0)(1-\frac{R_{*}}{r})^\beta$
# with
# * $v_0$ =        The wind velocity at stellar surface
# * $v_{\infty}$ = Wind terminal velocity
# * $R_{*}$ =      Stellar radius
# * $\beta$ =      Wind acceleration exponent
#
# By placing the star and orbit at the xy plane origin, we can consider an elliptical orbit in cartesian coordinates
# # $\frac{x^2}{a^2} + \frac{y^2}{b^2} = 1$
# with
# * $a$ = Semi-major axis
# * $b$ = Semi-minor axis
# The semi-minor axis can be defined as $a\sqrt{1 - e^2}$, where $e^2$ is the eccentricity.
# In polar coordinates, since the ellipse is offset by along the x-axis by the focus - $f = ae$, the coordinates relative to the star are
# ## $x = rcos(\phi) - ae$, $y = bsin(\phi)$, and $r = \sqrt{x^2 + y^2}$
# The orbital separation in polar coordinates becomes
# # $r = \frac{a(1-e^2)}{1+ecos(\phi)}$
# Where $\phi$ is the true anomaly.
# The signal position in polar coordinates is defined as $r_s = r(cos(\phi + \omega),sin(\phi + \omega),0)$, where $\omega$ is the argument of periastron. The observer unit vector (direction of signal to observer) is then defined as $\hat{n} = (sin(i)cos(\Omega), sin(i)sin(\Omega), cos(i))$, where $i$ is the inclination and $\Omega$ is the longitude of ascending node. The radial distance of the signal from the star along the path of the line of sight becomes $r(s) = r_s + s\hat{n}$, where $s\ge0$, is the distance along the line of sight.
#
# The number density at a specific point along the line of sight distance from the orbit can then be described as
# # $n_e(r(s)) = \frac{k}{r(s)^2v(r(s))}$
#
# From the definition of $r(s)$,
#
# ## $r(s)^2 = (r_s + s\hat{n})^2 = r^2 + 2rs [cos(\phi + \omega) sin (i)cos(\Omega) + sin(\phi + \omega)sin(i)sin(\Omega)] + s^2$
#
# ## Dispersion Measure
# # $DM(\phi,i) = \int_{0}^{\infty}n_e(r(s))ds = k\int_{0}^{\infty}\frac{ds}{v(r(s))r(s)^2}$
#
# ## Semi-major axis of PSR B1259-63
# Given that the orbital period of PSR B1259-63 is approximately 1237 days, its mass is $1.4 M_\odot$ and that the mass of SS 2883 is approximately $20 M_\odot$, using Kepler's 3rd law, the semi-major axis is
# # $a^3 = \frac{P^2G(M + m)}{4\pi^2}, a \sim 1345R_\odot$
# With
# * $P$ = Orbital period
# * $G$ = Gravitational constant
# * $M$ = Mass of SS 2883
# * $m$ = Mass of PSR B1259-63
#
# ## Free-free Absorption
# Free-free absorption causes signals to be absorbed by the stellar wind depending on its optical depth.
# # $\tau_{FFA} \approx 8.24x10^{-2}\nu^{-2.1}T_e^{-1.35}\int n_e^2ds$
#
# with
# * $\tau_{FFA}$ = The optical depth
# * $\nu$ = The signal frequency
# * $T_e$ = The stellar wind temperature
# * $n_e$ = The number density
# * $s$ = The line of sight distance
#
# ## Flux density
# The flux density of the pulsar signal is decribed as
# # $S_{\nu} = S_{psr,\nu}e^{-\tau} = \nu^{-p}e^{-\tau}$
# with
# * $S_{psr,\nu}$ = The intrinsic flux of the pulsar
# * $\nu$ = The signal frequency
# * $p$ = The power law index
# * $\tau$ = The optical depth
# When the flux density of the signal is plotted against frequency, it results in the pulsar's spectrum, which changes along eccentric orbits.
#
# ## Be Disc
# Be stars such as SS 2883 have a circumstellar disc due to the star's immense rotation rate. The disc introduces an additional desnity structure to the system, which is described as
# # $\rho(r_{disc}, z) = \rho_0(\frac{r_{disc}}{R_*})^{-\beta}e^{\frac{-z^2}{H(r_{disc})^2}}$
# with
# * $\rho_0$ = The disc desnity at stellar surface
# * $r_{disc}$ = radial distance in the disc plane
# * $R_*$ = Stellar radius
# * $\beta$ = Disc power law exponent
# * $z$ = Height above the disc plane
# * $H(r)$ = Scale height
#
# The scale height is described as
# # $H(r_{disc}) = c_s\sqrt{\frac{r_{disc}}{GM_*}}r_{disc}$
# with
# * $c_s$ = Speed of sound
# * $G$ = Gravitational constant
# * $M_*$ = Stellar mass
#
# And the speed of sound is described as
# # $c_s = \sqrt{\frac{kT}{\mu_em_p}}$
# with
# * $k$ = Boltzmann constant
# * $T$ = Disc temperature
#
# Using the disc desnity profile the number density through the disc becomes
# # $n_{e,disc} = \frac{\rho(r_{disc},z)}{\mu_em_p}$
#
# From which the DM and optical depth can be calculated
#
# Placing the disc at the xy plane along with the pulsar orbit allows the radial distance from the pulsar to the observer $r(s)$ serve as the radial distance from the pulsar that passes through the wind to the observer $r(s) = r_{disc}$.
#
# The height of the pulsar orbit above the disc plane can be decribed as $z = r(s)\cdot\hat{n} = rsin(\phi+\omega)sin(i_{disc}) + scos(i)cos(i_{disc})$.
#
# ## Combined Stellar Wind and Be Disc
# Since the stellar wind and Be disc do not depend on each-other, combining their number densities is straight forward
# # $n_{e,total} = n_{e,wind} + n_{e,disc}$
# With this total number density we can calculate the dispersion measure, optical depth, transmission factor and spectrum of the entire system.

# %%
#Packages
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import astropy.units as u
import astropy.constants as con
import ipywidgets as widgets
from IPython.display import display
from scipy.optimize import curve_fit

# %%
#Number density function
def num_density(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, s, e, omega, Omega, beta, mu_e=1.2):
    '''This function calculates the number density at a specific point along an elliptical orbit within a spherically cymmetric wind 
    with accelerating velocity.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> True anomaly (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    mu_e             [float] -> Mean molecular weight per free electron
    e                [float] -> Eccentricity (0 < e < 1)
    s                [float] -> Distance along line of sight from signal (AU)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent 
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the number density [array] -> (cm^-3)'''
    a = (a_Rsun * con.R_sun).cgs.value                                                                                   #Converts the semi-mmajor axis from solar radii to cm
    R_star = (R_star_sol * con.R_sun).cgs.value                                                                          #Converts the stellar radius from solar radii to cm
    Mdot = (Mdot_Msun_per_yr * con.M_sun / (1 * u.yr)).cgs.value                                                         #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = (v_0_kms * u.km / u.s).cgs.value                                                                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = (v_inf_kms * u.km / u.s).cgs.value                                                                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*con.m_p.cgs.value)                                                                          #Calculates the k constant (cm^-1)
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                                 #Calculates the orbital separation along the orbit
    r_s_sqrd = r**2 + 2*r*s*(np.cos(phi+omega)*np.sin(i)*np.cos(Omega)+np.sin(phi+omega)*np.sin(i)*np.sin(Omega)) + s**2 #Calculates the squared radial distance from the star along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                         #Calculates the velocity of the wind 

    n_e = k/(r_s_sqrd*v_r_s)                                                                                             #Calculates the number density
    n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                                                                 #Eclipse condition
     
    return n_e

# %%
#DM function
def dm_beta_wind(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, mu_e=1.2, s_array_cm=None):
    '''This function calculates the dispersion measure along a line of sight, given orbital phase and inclination, 
    assuming a spherically symmetric wind with an accelerating velocity.
    --------------------------------------------------------------------------------------------------------------
    Parameters:
    
    phi              [float] -> True anomaly (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent 
    mu_e             [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the dispersion measure [array] -> (pc cm^-3).'''
    a = (a_Rsun * con.R_sun).cgs.value                           #Converts the semi-major axis from solar radii to cm
    R_star = (R_star_sol * con.R_sun).cgs.value                  #Converts the stellar radius from solar radii to cm
    Mdot = (Mdot_Msun_per_yr * con.M_sun / (1 * u.yr)).cgs.value #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = (v_0_kms * u.km / u.s).cgs.value                       #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = (v_inf_kms * u.km / u.s).cgs.value                   #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*con.m_p.cgs.value)                  #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10((200 * con.au.cgs).value), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    DM_array = []

    for value in phi:
        r = a * (1 - e**2) / (1 + e * np.cos(value))                                 #Calculates the orbital separation along the orbit
        r_s_sqrd = r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega) +       #Calculates the squared radial distance from the star along the line of sight
                                 np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2
        v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/np.sqrt(r_s_sqrd))**beta           #Calculates the velocity of the wind 
        n_e = k / (r_s_sqrd * v_r_s)                                                 #Calculates the number density
        n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                         #Eclipse condition

        DM_cgs = np.trapz(n_e, s)                                                    #Integrating the DM in cm^-2
        DM = (DM_cgs / u.pc.to(u.cm))                                                #Converting DM to pc cm^3
        DM_array.append(DM)

    return np.array(DM_array)

# %%
#Free-free absorption function
def ffa(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, nu, T, mu_e=1.2, s_array_cm=None):
    '''This function calculates the free-free absorption along a line of sight, given orbital phase and inclination, 
    assuming a spherically symmetric wind with an accelerating velocity.
    --------------------------------------------------------------------------------------------------------------
    Parameters:
    
    phi              [float] -> True anomaly (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    nu               [float] -> Signal frequency (GHz)
    T                [float] -> Stellar wind temperature (K)
    mu_e             [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array].'''
    a = (a_Rsun * con.R_sun).cgs.value                           #Converts the semi-major axis from solar radii to cm
    R_star = (R_star_sol * con.R_sun).cgs.value                  #Converts the stellar radius from solar radii to cm
    Mdot = (Mdot_Msun_per_yr * con.M_sun / (1 * u.yr)).cgs.value #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = (v_0_kms * u.km / u.s).cgs.value                       #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = (v_inf_kms * u.km / u.s).cgs.value                   #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*con.m_p.cgs.value)                  #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10((200 * con.au.cgs).value), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    tau_array = []

    for value in phi:
        r = a * (1 - e**2) / (1 + e * np.cos(value))                                 #Calculates the orbital separation along the orbit
        r_s_sqrd = r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega) +       #Calculates the squared radial distance from the star along the line of sight
                                 np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2
        v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/np.sqrt(r_s_sqrd))**beta           #Calculates the velocity of the wind 
        n_e = k / (r_s_sqrd * v_r_s)                                                 #Calculates the number density
        n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                         #Eclipse condition

        tau = 8.24e-2*nu**-2.1*T**-1.35*np.trapz(n_e**2, s / u.pc.to(u.cm))          #Integrating the optical depth
        tau_array.append(tau)

    return np.array(tau_array)

# %%
#Flux density function
def spectrum(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, nu, T, p, mu_e=1.2, s_array_cm=None):
    '''This function calculates the spectrum of the pulsar for a given inclination and frequency along the orbit.
    -------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> True anomaly (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    nu               [float] -> Signal frequency (GHz)
    T                [float] -> Stellar wind temperature (K)
    p                [float] -> Power law exponent
    mu_e             [float] -> Mean molecular weight per free electron
    
    -------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the pulsar spectrum [array] (Jy)'''
    a = (a_Rsun * con.R_sun).cgs.value                           #Converts the semi-major axis from solar radii to cm
    R_star = (R_star_sol * con.R_sun).cgs.value                  #Converts the stellar radius from solar radii to cm
    Mdot = (Mdot_Msun_per_yr * con.M_sun / (1 * u.yr)).cgs.value #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = (v_0_kms * u.km / u.s).cgs.value                       #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = (v_inf_kms * u.km / u.s).cgs.value                   #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*con.m_p.cgs.value)                  #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10((200 * con.au.cgs).value), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a flux density array
    S_nu_array = []

    for value in phi:
        for freq in nu:
            r = a * (1 - e**2) / (1 + e * np.cos(value))                                 #Calculates the orbital separation along the orbit
            r_s_sqrd = r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega) +       #Calculates the squared radial distance from the star along the line of sight
                                     np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2
            v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/np.sqrt(r_s_sqrd))**beta           #Calculates the velocity of the wind 
            n_e = k / (r_s_sqrd * v_r_s)                                                 #Calculates the number density
            n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                         #Eclipse condition

            tau = 8.24e-2*freq**-2.1*T**-1.35*np.trapz(n_e**2, s / u.pc.to(u.cm))        #Integrating the optical depth
            S_nu = freq**(-p)*np.exp(-tau)                                               #Calculating the flux density
            S_nu_array.append(S_nu)
    S_nu_2D = np.array(S_nu_array).reshape(len(phi), len(nu))                            #Reshaping to a 2D array
    return S_nu_2D

# %%
#Disc number density function
def disc_ne(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, s, mu_e=1.2):
    '''This function calculates the number density along the line of sight from the
    pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> True anomaly (rad)
    omega      [float] -> Argument of periastron (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    s          [array] -> Array of line of sight points (cm)
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the number desnity [array] (cm^-3)'''
    a = (a_Rsun * con.R_sun).cgs.value          #Converts the orbital radius from solar radii to cm
    R_star = (R_star_sol * con.R_sun).cgs.value #Converts the stellar radius from solar radii to cm
    M_star = (M_star_sol * con.M_sun).cgs.value #Converts the stellar mass from solar mass to g
    r = a*(1 - e**2)/(1 + e*np.cos(phi))        #Calculates the orbital separation along the orbit

    r_disc = np.sqrt(r**2 + 2*r*s*(np.cos(phi+omega)*np.sin(i)*np.cos(Omega)+np.sin(phi+omega)*np.sin(i)*np.sin(Omega)) + s**2) #Projected radius through disc plane   
    c_s = np.sqrt((con.k_B * T)/(mu_e * con.m_p)).cgs.value                                                                     #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(con.G * M_star).cgs.value) * r_disc                                                         #Calculates the scale height
    z = (r*np.sin(phi+omega)*np.sin(i_disc) + s*np.cos(i)*np.cos(i_disc))                                                       #Calculates the height above the disc plane
    rho_disc = rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                                       #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * con.m_p).cgs.value                                                                               #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                                                                                #Constraining the inner disc radius

    return ne_disc

# %%
#Disc dispersion measure function
def disc_DM(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, mu_e=1.2, s_array_cm=None):
    '''This function calculates dispersion measure along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> True anomaly (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the dispersion measure [array] (pc cm^-3)'''
    a = (a_Rsun * con.R_sun).cgs.value          #Converts the orbital radius from solar radii to cm
    R_star = (R_star_sol * con.R_sun).cgs.value #Converts the stellar radius from solar radii to cm
    M_star = (M_star_sol * con.M_sun).cgs.value #Converts the stellar mass from solar mass to g

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10((3 * con.au.cgs).value), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    disc_DM_array = []

    for value in phi:
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                          #Calculates the orbital separation along the orbit
        r_disc = np.sqrt(r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega)+np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2) #Projected radius through disc plane        
        c_s = np.sqrt((con.k_B * T)/(mu_e * con.m_p)).cgs.value                                                                         #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(con.G * M_star).cgs.value) * r_disc                                                             #Calculates the scale height
        z = (r*np.sin(value+omega)*np.sin(i_disc) + s*np.cos(i)*np.cos(i_disc))                                                         #Calculates the height above the disc plane
        rho_disc = rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                                           #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * con.m_p).cgs.value                                                                                   #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                                    #Constraining the inner disc radius


        disc_DM_cgs = np.trapz(ne_disc, s)                                                                                              #Integrating the DM in cm^-2
        disc_DM = (disc_DM_cgs / u.pc.to(u.cm))                                                                                         #Converting DM to pc cm^3
        disc_DM_array.append(disc_DM)

    return np.array(disc_DM_array)

# %%
#Disc free-free absorption function
def disc_ffa(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, nu, mu_e=1.2, s_array_cm=None):
    '''This function calculates optical depth along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> True anomaly (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    nu         [float] -> Signal frequency (GHz)
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array]'''
    a = (a_Rsun * con.R_sun).cgs.value          #Converts the orbital radius from solar radii to cm
    R_star = (R_star_sol * con.R_sun).cgs.value #Converts the stellar radius from solar radii to cm
    M_star = (M_star_sol * con.M_sun).cgs.value #Converts the stellar mass from solar mass to g

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10((3 * con.au.cgs).value), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    disc_tau_array = []
    
    for value in phi:
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                          #Calculates the orbital separation along the orbit
        r_disc = np.sqrt(r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega)+np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2) #Projected radius through disc plane         
        c_s = np.sqrt((con.k_B * T)/(mu_e * con.m_p)).cgs.value                                                                         #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(con.G * M_star).cgs.value) * r_disc                                                             #Calculates the scale height
        z = (r*np.sin(value+omega)*np.sin(i_disc) + s*np.cos(i)*np.cos(i_disc))                                                         #Calculates the height above the disc plane
        rho_disc = rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                                           #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * con.m_p).cgs.value                                                                                   #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                                    #Constraining the inner disc radius


        disc_tau = 8.24e-2*nu**(-2.1)*T**(-1.35)*np.trapz(ne_disc**2, s / u.pc.to(u.cm))                                                #Integrating tau
        disc_tau_array.append(disc_tau)

    return np.array(disc_tau_array)

# %%
#Disc flux density function
def disc_spectrum(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, nu, p, mu_e=1.2, s_array_cm=None):
    '''This function calculates optical depth along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> True anomaly (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    nu         [float] -> Signal frequency (GHz)
    p          [float] -> Power law exponent
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array]'''
    a = (a_Rsun * con.R_sun).cgs.value          #Converts the orbital radius from solar radii to cm
    R_star = (R_star_sol * con.R_sun).cgs.value #Converts the stellar radius from solar radii to cm
    M_star = (M_star_sol * con.M_sun).cgs.value #Converts the stellar mass from solar mass to g
    
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10((3 * con.au.cgs).value), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    disc_S_nu_array = []
    
    for value in phi:
        for freq in nu:
            r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                          #Calculates the orbital separation along the orbit
            r_disc = np.sqrt(r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega)+np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2) #Projected radius through disc plane             
            c_s = np.sqrt((con.k_B * T)/(mu_e * con.m_p)).cgs.value                                                                         #Calculates the disc speed of sound
            H_rdisc = c_s * np.sqrt(r_disc/(con.G * M_star).cgs.value) * r_disc                                                             #Calculates the scale height
            z = (r*np.sin(value+omega)*np.sin(i_disc) + s*np.cos(i)*np.cos(i_disc))                                                         #Calculates the height above the disc plane
            rho_disc = rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                                           #Calculates the disc desnity profile
            ne_disc = rho_disc/(mu_e * con.m_p).cgs.value                                                                                   #Calculates the number density
            ne_disc[r_disc < R_star] = 0                                                                                                    #Constraining the inner disc radius


            disc_tau = 8.24e-2*freq**(-2.1)*T**(-1.35)*np.trapz(ne_disc**2, s / u.pc.to(u.cm))                                              #Integrating tau
            disc_S_nu = freq**(-p)*np.exp(-disc_tau)                                                                                        #Calculatinng the flux density
            disc_S_nu_array.append(disc_S_nu)
    disc_S_nu_2D = np.array(disc_S_nu_array).reshape(len(phi), len(nu))                                                                     #Reshaping to a 2D array
    return np.array(disc_S_nu_2D)

# %%
#Total wind-disc number density function
def tot_num_density(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, s, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, mu_e=1.2):
    '''This function calculates the total number density at a specific point along an elliptical orbit within a spherically cymmetric wind 
    with accelerating velocity and an axisymmetric disc.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> True anomaly (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    s                [float] -> Distance along line of sight from signal (AU)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total number density [array] -> (cm^-3)'''
    #Stellar wind number density
    a = (a_Rsun * con.R_sun).cgs.value                                                                                   #Converts the semi-mmajor axis from solar radii to cm
    R_star = (R_star_sol * con.R_sun).cgs.value                                                                          #Converts the stellar radius from solar radii to cm
    Mdot = (Mdot_Msun_per_yr * con.M_sun / (1 * u.yr)).cgs.value                                                         #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = (v_0_kms * u.km / u.s).cgs.value                                                                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = (v_inf_kms * u.km / u.s).cgs.value                                                                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*con.m_p.cgs.value)                                                                          #Calculates the k constant (cm^-1)
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                                 #Calculates the orbital separation along the orbit
    r_s_sqrd = r**2 + 2*r*s*(np.cos(phi+omega)*np.sin(i)*np.cos(Omega)+np.sin(phi+omega)*np.sin(i)*np.sin(Omega)) + s**2 #Calculates the squared radial distance from the star along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                         #Calculates the velocity of the wind 
    n_e = k/(r_s_sqrd*v_r_s)                                                                                             #Calculates the number density
    n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                                                                 #Eclipse condition
    
    #Disc number density
    M_star = (M_star_sol * con.M_sun).cgs.value                                #Converts the stellar mass from solar mass to g
    r_disc = np.sqrt(r_s_sqrd)                                                 #Projected radius through disc plane   
    c_s = np.sqrt((con.k_B * T_disc)/(mu_e * con.m_p)).cgs.value               #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(con.G * M_star).cgs.value) * r_disc        #Calculates the scale height
    z = (r*np.sin(phi+omega)*np.sin(i_disc) + s*np.cos(i)*np.cos(i_disc))      #Calculates the height above the disc plane
    rho_disc = rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2) #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * con.m_p).cgs.value                              #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                               #Constraining the inner disc radius

    #Total number density
    total_ne = n_e + ne_disc

    return total_ne

# %%
#Total wind-disc dispersion measure function
def tot_DM(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, mu_e=1.2, s_array_cm=None):
    '''This function calculates the dispersion measure along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> True anomaly (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total dispersion measure [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(1e14), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_DM_array = []
  
    a = (a_Rsun * con.R_sun).cgs.value                                                                                   #Converts the semi-mmajor axis from solar radii to cm
    R_star = (R_star_sol * con.R_sun).cgs.value                                                                          #Converts the stellar radius from solar radii to cm
    Mdot = (Mdot_Msun_per_yr * con.M_sun / (1 * u.yr)).cgs.value                                                         #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = (v_0_kms * u.km / u.s).cgs.value                                                                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = (v_inf_kms * u.km / u.s).cgs.value                                                                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*con.m_p.cgs.value)                                                                          #Calculates the k constant (cm^-1)
    M_star = (M_star_sol * con.M_sun).cgs.value                                                                          #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        r_s_sqrd = r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega)+np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2 #Calculates the squared radial distance from the star along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                             #Calculates the velocity of the wind 
        n_e = k/(r_s_sqrd*v_r_s)                                                                                                 #Calculates the number density
        n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                                                                     #Eclipse condition
    
        #Disc number density
        r_disc = np.sqrt(r_s_sqrd)                                                 #Projected radius through disc plane   
        c_s = np.sqrt((con.k_B * T_disc)/(mu_e * con.m_p)).cgs.value               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(con.G * M_star).cgs.value) * r_disc        #Calculates the scale height
        z = (r*np.sin(value+omega)*np.sin(i_disc) + s*np.cos(i)*np.cos(i_disc))    #Calculates the height above the disc plane
        rho_disc = rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2) #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * con.m_p).cgs.value                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                               #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_DM_cgs = np.trapz(total_ne, s)                                       #Integrating the DM in cm^-2
        total_DM = (total_DM_cgs / u.pc.to(u.cm))                                  #Converting DM to pc cm^3
        tot_DM_array.append(total_DM)

    return np.array(tot_DM_array)

# %%
#Total wind-disc free-free absorption function
def tot_ffa(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_wind, T_disc, beta_disc, rho0, i_disc, nu, mu_e=1.2, s_array_cm=None):
    '''This function calculates the optical depth along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> True anomaly (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    T_wind           [float] -> Temperature of wind (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    nu               [float] -> Signal frequency (GHz)
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total optical depth [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(1e14), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_tau_array = []
  
    a = (a_Rsun * con.R_sun).cgs.value                                                                                   #Converts the semi-mmajor axis from solar radii to cm
    R_star = (R_star_sol * con.R_sun).cgs.value                                                                          #Converts the stellar radius from solar radii to cm
    Mdot = (Mdot_Msun_per_yr * con.M_sun / (1 * u.yr)).cgs.value                                                         #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = (v_0_kms * u.km / u.s).cgs.value                                                                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = (v_inf_kms * u.km / u.s).cgs.value                                                                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*con.m_p.cgs.value)                                                                          #Calculates the k constant (cm^-1)
    M_star = (M_star_sol * con.M_sun).cgs.value                                                                          #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        r_s_sqrd = r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega)+np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2 #Calculates the squared radial distance from the star along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                             #Calculates the velocity of the wind 
        n_e = k/(r_s_sqrd*v_r_s)                                                                                                 #Calculates the number density
        n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                                                                     #Eclipse condition
    
        #Disc number density
        r_disc = np.sqrt(r_s_sqrd)                                                 #Projected radius through disc plane   
        c_s = np.sqrt((con.k_B * T_disc)/(mu_e * con.m_p)).cgs.value               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(con.G * M_star).cgs.value) * r_disc        #Calculates the scale height
        z = (r*np.sin(value+omega)*np.sin(i_disc) + s*np.cos(i)*np.cos(i_disc))    #Calculates the height above the disc plane
        rho_disc = rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2) #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * con.m_p).cgs.value                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                               #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_tau = 8.24e-2*nu**(-2.1)*((T_wind+T_disc)/2)**(-1.35)*np.trapz(total_ne**2, s / u.pc.to(u.cm)) #Integrating the optical depth
        tot_tau_array.append(total_tau)

    return np.array(tot_tau_array)

# %%
#Total wind-disc flux density function
def tot_spectrum(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_wind, T_disc, beta_disc, rho0, i_disc, nu, p, mu_e=1.2, s_array_cm=None):
    '''This function calculates the flux density along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> True anomaly (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    T_wind           [float] -> Temperature of wind (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    nu               [float] -> Signal frequency (GHz)
    p                [float] -> Spectrum power law exponent
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total flux density [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(1e14), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_S_nu_array = []
  
    a = (a_Rsun * con.R_sun).cgs.value                                                                                   #Converts the semi-mmajor axis from solar radii to cm
    R_star = (R_star_sol * con.R_sun).cgs.value                                                                          #Converts the stellar radius from solar radii to cm
    Mdot = (Mdot_Msun_per_yr * con.M_sun / (1 * u.yr)).cgs.value                                                         #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = (v_0_kms * u.km / u.s).cgs.value                                                                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = (v_inf_kms * u.km / u.s).cgs.value                                                                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*con.m_p.cgs.value)                                                                          #Calculates the k constant (cm^-1)
    M_star = (M_star_sol * con.M_sun).cgs.value                                                                          #Converts the stellar mass from solar mass to g

    for value in phi:
        for freq in nu:
            #Stellar wind number density
            r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
            r_s_sqrd = r**2 + 2*r*s*(np.cos(value+omega)*np.sin(i)*np.cos(Omega)+np.sin(value+omega)*np.sin(i)*np.sin(Omega)) + s**2 #Calculates the squared radial distance from the star along the line of sight
            v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                             #Calculates the velocity of the wind 
            n_e = k/(r_s_sqrd*v_r_s)                                                                                                 #Calculates the number density
            n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                                                                     #Eclipse condition
    
            #Disc number density
            r_disc = np.sqrt(r_s_sqrd)                                                 #Projected radius through disc plane   
            c_s = np.sqrt((con.k_B * T_disc)/(mu_e * con.m_p)).cgs.value               #Calculates the disc speed of sound
            H_rdisc = c_s * np.sqrt(r_disc/(con.G * M_star).cgs.value) * r_disc        #Calculates the scale height
            z = (r*np.sin(value+omega)*np.sin(i_disc) + s*np.cos(i)*np.cos(i_disc))    #Calculates the height above the disc plane
            rho_disc = rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2) #Calculates the disc desnity profile
            ne_disc = rho_disc/(mu_e * con.m_p).cgs.value                              #Calculates the number density
            ne_disc[r_disc < R_star] = 0                                               #Constraining the inner disc radius

            #Total number density
            total_ne = n_e + ne_disc

            total_tau = 8.24e-2*freq**(-2.1)*((T_wind+T_disc)/2)**(-1.35)*np.trapz(total_ne**2, s / u.pc.to(u.cm)) #Integrating the DM in cm^-2
            total_S_nu = freq**(-p)*np.exp(-total_tau)                                                             #Calculatinng the flux density
            tot_S_nu_array.append(total_S_nu)
        
    tot_S_nu_2D = np.array(tot_S_nu_array).reshape(len(phi), len(nu))                                              #Reshaping to a 2D array
    return np.array(tot_S_nu_2D)

# %%
#Curve_fit DM function
def DM_curve_fit(phi, i_orb, Mdot, e, omega, Omega, rho0, i_disc):
    '''
    This function employs scipy's curve_fit by implementing the general tot_DM function.
    -------------------------------------------------------------------------------------
    Parameters:

    phi    [array] -> True Anomaly (rad)
    i_orb  [float] -> Orbital Inclination (rad)
    Mdot   [float] -> Stellar Mass Loss (solar mass per year)
    e      [float] -> Eccentricity
    omega  [float] -> Argument of Periastron (rad)
    Omega  [float] -> Longitude of Ascending Node (rad)
    rho0   [float] -> Initial Disc Density (gcm^-3)
    i_disc [float] -> Disc Inclination (rad)
    --------------------------------------------------------------------------------------
    Returns:

    The dipersion measure curve fit.
    '''
    #Fixing the remaining parameters of the model
    a_Rsun_fixed = 1091
    R_star_sol_fixed = 6
    M_star_sol_fixed = 10
    v_0_kms_fixed = 10
    v_inf_kms_fixed = 1e3
    beta_fixed = 2
    T_disc_fixed = 5e3
    beta_disc_fixed = 1.6

    return tot_DM(phi, i_orb, a_Rsun_fixed, R_star_sol_fixed, M_star_sol_fixed, Mdot, v_0_kms_fixed, v_inf_kms_fixed, e, omega, Omega, beta_fixed, T_disc_fixed, beta_disc_fixed, rho0, i_disc)

# %%
#Wind only curve_fit DM function
def wind_only_DM_fit(phi, i_orb, Mdot, e, omega, Omega):
    '''
    This function employs scipy's curve_fit by implementing the general dm_beta_wind function.
    -------------------------------------------------------------------------------------
    Parameters:

    phi    [array] -> True Anomaly (rad)
    i_orb  [float] -> Orbital Inclination (rad)
    Mdot   [float] -> Stellar Mass Loss (solar mass per year)
    e      [float] -> Eccentricity
    omega  [float] -> Argument of Periastron (rad)
    Omega  [float] -> Longitude of Ascending Node (rad)
    --------------------------------------------------------------------------------------
    Returns:

    The dipersion measure curve fit from the wind model only.
    '''
    #Fixing the remaining parameters of the model
    a_Rsun_fixed = 1091
    R_star_sol_fixed = 6
    v_0_kms_fixed = 10
    v_inf_kms_fixed = 1e3
    beta_fixed = 2

    return dm_beta_wind(phi, i_orb, a_Rsun_fixed, R_star_sol_fixed, Mdot, v_0_kms_fixed, v_inf_kms_fixed, e, omega, Omega, beta_fixed)

# %% [markdown]
# # Number Density

# %%
#Calculating the number density along the line of sight
i_deg = [25, 45, 60, 90]                                                                  #Inclinations in degrees
i = np.deg2rad(i_deg)                                                                     #Converting the inclinations to rad
phi_deg = [50, 150, 200, 250]                                                             #Orbital phases in degrees
phi = np.deg2rad(phi_deg)                                                                 #Converting the orbital phases to rad
om = np.deg2rad(138)                                                                      #Argument of periastron deg->rad
Om = np.deg2rad(189)                                                                      #Longitude of ascending node deg->rad
s = np.logspace(np.log10(1e12), np.log10((200 * con.au.cgs).value), 512)                  #Line of sight distance array
n_e1 = num_density(phi[0], i[0], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=1e-7,
                   v_0_kms=10, v_inf_kms=1000, s=s, e=0.87, omega=om, Omega=Om, beta=1.5) #Number densities
n_e2 = num_density(phi[1], i[1], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=1e-7,
                   v_0_kms=10, v_inf_kms=1000, s=s, e=0.87, omega=om, Omega=Om, beta=1.5)
n_e3 = num_density(phi[2], i[2], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=1e-7,
                   v_0_kms=10, v_inf_kms=1000, s=s, e=0.87, omega=om, Omega=Om, beta=1.5)
n_e4 = num_density(phi[3], i[3], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=1e-7,
                   v_0_kms=10, v_inf_kms=1000, s=s, e=0.87, omega=om, Omega=Om, beta=1.5)

# %% [markdown]
# When plotting the number density as a function of line of sight distance, it is important to revisit the squared radial distance from the star along the line of sight:
# ## $r(s)^2 = (r_s + s\hat{n})^2 = r^2 + 2rs [cos(\phi + \omega) sin (i)cos(\Omega) + sin(\phi + \omega)sin(i)sin(\Omega)] + s^2$
# As we can see, when
# ## $r >> s$, $r(s)^2 \approx r^2$
# so
# ## $n_e(r(s)) \approx \frac{k}{r^2} = const$
# Therefore, we can only start seeing a power law relation when
# ## $r \sim s$

# %%
#Plotting the number density as a function of line of sight distance
plt.plot(s, n_e1, label = 'i = ' + str(i_deg[0]) + ', phi = ' + str(phi_deg[0]) + ' (deg)')
plt.plot(s, n_e2, label = 'i = ' + str(i_deg[1]) + ', phi = ' + str(phi_deg[1]) + ' (deg)')
plt.plot(s, n_e3, label = 'i = ' + str(i_deg[2]) + ', phi = ' + str(phi_deg[2]) + ' (deg)')
plt.plot(s, n_e4, label = 'i = ' + str(i_deg[3]) + ', phi = ' + str(phi_deg[3]) + ' (deg)')
plt.title('Number Density Vs Line of Sight Distance')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %% [markdown]
# # Number Density Vs Line of Sight Distance GIF

# %%
phi_deg_array = np.linspace(0, 360, 180)   #Orbital phases in deg
phi_array = np.deg2rad(phi_deg_array)      #Orbital phases in rad
i_gif_deg = 25                             #Inclination in deg
i_gif = np.deg2rad(i_gif_deg)              #Inclination in rad

#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1e12, (200 * con.au.cgs).value)
ax.set_ylim(1e2, 1e8) 
ax.set_xlabel('Line of Sight Distance (cm)')
ax.set_ylabel('Number Density (cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    phi = phi_array[frame]
    n_e = num_density(phi, i_gif, a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=1e-7,
                      v_0_kms=10, v_inf_kms=1000, s=s, e=0.87, omega=om, Omega=Om, beta=1.5)
    line.set_data(s, n_e)
    title.set_text('Number Density Vs LoS Distance, i = ' + str(int(i_gif_deg)) + ' (deg) \nphi = ' + str(int(phi_deg_array[frame])) + ' deg')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(phi_array), blit=False, interval=100)
#Saving GIF
ani.save("num_density_evolution.gif", writer="pillow", fps=10)
plt.show()

# %% [markdown]
# # Interactive Number Density Vs Line of Sight Distance Widget

# %%
#Orbital phase slider
phi_slider = widgets.IntSlider(
    value=0,
    min=0,
    max=360,
    step=1,
    description='Phi (deg)',
    continuous_update=True,
    layout=widgets.Layout(width='80%')
)

#Interactive plotting function
def plot_n_e(phi_deg):
    phi_rad = np.deg2rad(phi_deg)
    n_e_plot = num_density(phi_rad, i_gif, a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=1e-7,
                           v_0_kms=10, v_inf_kms=1000, s=s, e=0.87, omega=om, Omega=Om, beta=1.5) #Number density
    
    plt.plot(s, n_e_plot)
    plt.title('Number Density Vs Line of Sight Distance, i = ' + str(int(i_gif_deg)) + ' (deg)\nat Orbital Phase = ' + str(int(phi_deg))+ ' deg')
    plt.xlabel('Line of Sight Distance (cm)')
    plt.ylabel('Number Density (cm^-3)')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(1e12, (200 * con.au.cgs).value)
    plt.show()

#Linking slider to plot function
widgets.interact(plot_n_e, phi_deg=phi_slider)
# Out:
# interactive(children=(IntSlider(value=0, description='Phi (deg)', layout=Layout(width='80%'), max=360), Output…
# <function __main__.plot_n_e(phi_deg)>

# %% [markdown]
# # Eclipsing Cases of Orbital Phases
#
# For the orbital phase $\phi = 231^\circ$, the line of sight intersects the stellar radius at an edge-on inclination ($i = 90^\circ$), resulting in an eclipsed signal.

# %%
i_deg_ec_sig = 90                       #Eclipsing inclination in deg
i_ec_sig = np.deg2rad(i_deg_ec_sig)     #Eclipsing inclination in rad
phi_deg_ec_sig = 231                    #Eclipsing orbital phase in deg
phi_ec_sig = np.deg2rad(phi_deg_ec_sig) #Eclipsing orbital phase in rad

n_e_ec_sig = num_density(phi_ec_sig, i_ec_sig, a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=1e-7,
                   v_0_kms=10, v_inf_kms=1000, s=s, e=0.87, omega=om, Omega=Om, beta=1.5)        #Number density

#Plotting
plt.plot(s, n_e_ec_sig, label = 'i = ' + str(i_deg_ec_sig) + ', phi = ' + str(phi_deg_ec_sig) + ' (deg)')
plt.title('Number Density Vs Line of Sight Distance')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.xscale('log')
plt.yscale('log')
plt.xlim(4e13, 8e13)
plt.legend()
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_25092\1711043343.py:34: RuntimeWarning: invalid value encountered in power
#   v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                         #Calculates the velocity of the wind

# %% [markdown]
# # Dispersion Measure

# %%
#Calculating the DM
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                                  #Orbital phase array in rad (redundancy removed)
DM1 = dm_beta_wind(phi, i[0], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=1e-7,
                  v_0_kms=10, v_inf_kms=1000, e=0.87, omega=om, Omega=Om, beta=1.5) #Dispersion measure
DM2 = dm_beta_wind(phi, i[1], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=1e-7,
                  v_0_kms=10, v_inf_kms=1000, e=0.87, omega=om, Omega=Om, beta=1.5)
DM3 = dm_beta_wind(phi, i[2], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=1e-7,
                  v_0_kms=10, v_inf_kms=1000, e=0.87, omega=om, Omega=Om, beta=1.5)

# %%
#Plotting the DM as a function of the orbital phase
plt.plot(phi, DM1, label = 'i = ' + str(i_deg[0]) + ' (deg)')
plt.plot(phi, DM2, label = 'i = ' + str(i_deg[1]) + ' (deg)')
plt.plot(phi, DM3, label = 'i = ' + str(i_deg[2]) + ' (deg)')
plt.title('Dispersion Measure Vs True Anomaly')
plt.xlabel('True Anomaly (Rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %% [markdown]
# # Consistency Check
# For parameter values relevant to 1994 papers, Simon Johnston et al. find the dispersion measure of PSR B1259-63 to be in the range of 146 - 158 $pc cm^{-3}$ around periastron. https://academic.oup.com/mnras/article/279/3/1026/967531

# %%
#Calculating the DM
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                                  #Orbital phase array in rad (redundancy removed)
DM_1994 = dm_beta_wind(phi, i=np.deg2rad(35), a_Rsun=1091, R_star_sol=6, Mdot_Msun_per_yr=1e-7,
                  v_0_kms=10, v_inf_kms=1000, e=0.9, omega=om, Omega=Om, beta=4.2)  #Dispersion measure

# %%
#Plotting the DM as a function of the orbital phase
plt.plot(phi, DM_1994, label = 'i = 35 (deg)')
plt.title('Dispersion Measure Vs True Anomaly 1994')
plt.xlabel('True Anomaly (Rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %% [markdown]
# # Free-free Absorption

# %%
#Calculating the optical depth
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                                                   #Orbital phase array in rad (redundancy removed)
nu = [1.5, 1.75, 2]                                                                                  #Signal frequency in GHz
tau1 = ffa(phi, i[0], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=1e-7,
                  v_0_kms=10, v_inf_kms=1000, e=0.87, omega=om, Omega=Om, beta=1.5, nu=nu[0], T=1e4) #Optical depth
tau2 = ffa(phi, i[1], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=1e-7,
                  v_0_kms=10, v_inf_kms=1000, e=0.87, omega=om, Omega=Om, beta=1.5, nu=nu[1], T=1e4)
tau3 = ffa(phi, i[2], a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=1e-7,
                  v_0_kms=10, v_inf_kms=1000, e=0.87, omega=om, Omega=Om, beta=1.5, nu=nu[2], T=1e4)

# %%
#Plotting the optical depth as a function of the orbital phase
plt.plot(phi, tau1, label = 'i = ' + str(i_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, tau2, label = 'i = ' + str(i_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, tau3, label = 'i = ' + str(i_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('FFA Optical Depth Vs True Anomaly')
plt.xlabel('True Anomaly (Rad)')
plt.ylabel('Optical Depth')
plt.legend()

# %% [markdown]
# # Transmission factor $e^{-\tau}$ Vs $\phi$
#
# The transmission factor $e^{-\tau}$ shows how much the flux at a given frequency is actually suppressed. It is the fraction of radiation that survives after passing though the stellar wind material with a certain optical depth.

# %%
#Plotting e^(-tau) as a function of the orbital phase
plt.plot(phi, np.exp(-tau1), label = 'i = ' + str(i_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, np.exp(-tau2), label = 'i = ' + str(i_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, np.exp(-tau3), label = 'i = ' + str(i_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('Transmission Factor e^(-tau) Vs True Anomaly')
plt.xlabel('True Anomaly (Rad)')
plt.ylabel('e^(-tau)')
plt.ylim(1e-3, None)
plt.yscale('log')
plt.legend()

# %% [markdown]
# # Pulsar Spectrum Evolution Along the Orbit GIF

# %%
phi_deg_array = np.linspace(0, 360, 180)   #Orbital phases in deg
phi_array = np.deg2rad(phi_deg_array)      #Orbital phases in rad
i_gif = np.deg2rad(i_gif_deg)              #Inclination in rad
nu_array = np.linspace(1, 8.4, 512)        #Frequency array

#Computing the spectra for all orbital phases
S_nu = spectrum(phi=phi_array, i=i_gif, a_Rsun=1345, R_star_sol=9, Mdot_Msun_per_yr=1e-7,
                v_0_kms=10, v_inf_kms=1000, e=0.87, omega=om, Omega=Om, beta=1.5, nu=nu_array, T=1e4, p=1.3)         

#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1, 8.4)
ax.set_ylim(1e-5, 1)
ax.set_xlabel('Frequency (GHz)')
ax.set_ylabel('Flux density (Jy)')
title = ax.set_title('')

#Frame update function
def update(frame):
    line.set_data(nu_array, S_nu[frame, :])
    title.set_text('Spectrum Evolution at Inclination i = ' + str(int(i_gif_deg)) + '(deg)\n at Orbital Phase = ' + str(int(phi_deg_array[frame])) + ' deg')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(phi_array), blit=False, interval=100)
#Saving GIF
ani.save("spectrum_evolution.gif", writer="pillow", fps=10)
plt.show()

# %% [markdown]
# # Be Disc

# %% [markdown]
# ## Be Disc Mass
# As a preliminary step of analysing the Be disc it is important to check its total mass.
#
# Using the definition of density
# ## $\rho = \frac{dM}{dV} \to dM = \rho dV \to M = \int \rho dV$
#
# With
# * $M$ = Disc mass
# * $V$ = Disc volume
#
# For discs, $dV = rdrd\phi dz$
# With
# * $dr$ = Radial change
# * $d\phi$ = Angular change
# * $dz$ = Vertical change
#
# Since $\int_0^{2\pi} rd\phi = 2\pi r$, we end up with
#
# ## $M = 2\pi \int_{R_*}^{R_{out}} \int_{-\infty}^{\infty} \rho_0 (\frac{r}{R_*})^{-\beta} e^{\frac{-z^2}{H_{r}^2}} dzdr$
# With
# * $R_*$ = Stellar radius
# * $R_{out}$ = Outer radius of disc
#
# Using the gaussian integral $\int_{-\infty}^{\infty} e^{-ax^2} = \sqrt{\frac{\pi}{a}}$, the integral of the vertical change becomes
#
# ## $\int_{-\infty}^{\infty} e^{\frac{-z^2}{H_{r}^2}}dz = \sqrt{\pi}H_{r}$
# The final expression of the disc mass is
#
# ## $M = 2\pi^{1.5} \rho_0 \int_{R_*}^{R_out} (\frac{r}{R_*})^{-\beta} H_r r dr$

# %%
#Disc parameters
rho0 = 5e-12                        #Disc density at stellar surface (g cm^-3)
R_star = (9*con.R_sun).cgs.value    #Stellar radius converted from stellar radii (cm)
R_out = (100*con.R_sun).cgs.value   #Disc outer radius converted from stellar radii (cm)
M_star = (20*con.M_sun).cgs.value   #Stellar mass converted from kg (g)
r = np.linspace(R_star, R_out, 512) #Radial integration grid of disc (cm)
T_disc = 0.7e4                      #Disc temperature (K)
mu_e = 1.2                          #Mean molecular weight per free electron
beta = 3                            #Disc density power-law exponent

c_s = np.sqrt((con.k_B*T_disc)/(mu_e*con.m_p)).cgs.value #Speed of sound through disc (cm/s)

H_r = c_s*np.sqrt(r/(con.G.cgs.value*M_star))*r          #Disc scale height (cm)  

integrand = (r/R_star)**(-beta)*H_r*r                    #Disc mass integrand

M_disc_cgs = 2*np.pi**1.5*rho0*np.trapz(integrand, r)    #Integrating the disc mass (g)

M_disc = M_disc_cgs/con.M_sun.cgs.value                  #Disc mass in solar mass

print('The mass of the disc is ' + "{:.3e}".format(M_disc) + ' solar masses')
# Out:
# The mass of the disc is 3.419e-10 solar masses

# %% [markdown]
# ## Number Density

# %% [markdown]
# # Looking at the Paper by Chen et al. (2019)
# https://arxiv.org/abs/1904.07527v2
#
# Parameter Values:
# * Orbit Inclination - $26^\circ$
# * Eccentricity - 0.87
# * Stellar Mass - $20 M_{\odot}$
# * Stellar Radius - $9.2 R_{\odot}$
# * Argument of Periastron - $138^\circ$
# * Disc Inclination - $45^\circ$
# * Initial disc density - $10^{-12} g cm^{-3}$
# * Disc Temperature - $1.45e4 K$
# * Orbital phase - $90^\circ$
#
# Chen et al. Claim that PSR B1259-63 passes through the disk at distances of $1.8e13 cm - 2.4e13 cm$

# %%
s = np.logspace(np.log10(1e8), np.log10((3 * con.au.cgs).value), 10000)  #Line of sight distance array
i_disc_deg = [35, 40, 45, 50]                                            #Disc inclination in degrees                                                   
i_disc_rad = np.deg2rad(i_disc_deg)                                      #Disc inclination in rad
i_orb_deg = 26                                                           #Orbital inclination in deg
i_orb_rad = np.deg2rad(i_orb_deg)                                        #Orbital inclination in rad
phi_orb_deg = 90                                                         #Orbital phase in degree
phi_orb_rad = np.deg2rad(phi_orb_deg)                                    #Orbital phase in rad
om_deg = 138
om = np.deg2rad(om_deg)
Om_deg = 0
Om = np.deg2rad(Om_deg)

disc_num_den1 = disc_ne(a_Rsun=1345, T=1.45e4, M_star_sol=20, R_star_sol=9.2, #Number density
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[0], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s)
disc_num_den2 = disc_ne(a_Rsun=1345, T=1.45e4, M_star_sol=20, R_star_sol=9.2,        
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[1], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s)
disc_num_den3 = disc_ne(a_Rsun=1345, T=1.45e4, M_star_sol=20, R_star_sol=9.2,       
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[2], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s)
disc_num_den4 = disc_ne(a_Rsun=1345, T=1.45e4, M_star_sol=20, R_star_sol=9.2,        
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[3], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s)
#Plotting
plt.plot(s, disc_num_den1, label='i disc = ' + str(int(i_disc_deg[0])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den2, label='i disc = ' + str(int(i_disc_deg[1])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den3, label='i disc = ' + str(int(i_disc_deg[2])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den4, label='i disc = ' + str(int(i_disc_deg[3])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.title('Disc Number Density Vs Line of Sight Distance at Periastron (Chen et al., 2019)')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.legend()

# %%
s = np.logspace(np.log10(1e8), np.log10((20000 * con.au.cgs).value), 10000)  #Line of sight distance array
i_disc_deg = [60, 65, 70, 75]                                                #Disc inclination in degrees                                                   
i_disc_rad = np.deg2rad(i_disc_deg)                                          #Disc inclination in rad
i_orb_deg = 25                                                               #Orbital inclination in deg
i_orb_rad = np.deg2rad(i_orb_deg)                                            #Orbital inclination in rad
phi_orb_deg = 60                                                             #Orbital phase in degree
phi_orb_rad = np.deg2rad(phi_orb_deg)                                        #Orbital phase in rad
om_deg = 138
om = np.deg2rad(om_deg)
Om_deg = 30
Om = np.deg2rad(Om_deg)

disc_num_den1 = disc_ne(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,     #Number density
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[0], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s)
disc_num_den2 = disc_ne(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,        
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[1], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s)
disc_num_den3 = disc_ne(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,       
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[2], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s)
disc_num_den4 = disc_ne(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,        
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[3], phi=phi_orb_rad, omega=om, Omega=Om, e=0.87, i=i_orb_rad, s=s)
#Plotting
plt.plot(s, disc_num_den1, label='i disc = ' + str(int(i_disc_deg[0])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den2, label='i disc = ' + str(int(i_disc_deg[1])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den3, label='i disc = ' + str(int(i_disc_deg[2])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.plot(s, disc_num_den4, label='i disc = ' + str(int(i_disc_deg[3])) + ' deg' + ' i = ' + str(int(i_orb_deg)) + ' deg')
plt.title('Disc Number Density Vs Line of Sight Distance')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %% [markdown]
# # Disc Number Density Vs Line of Sight Distance GIF

# %%
phi_deg_array = np.linspace(0, 360, 360)   #Orbital phases in deg
phi_array = np.deg2rad(phi_deg_array)      #Orbital phases in rad
disc_i_gif_deg = 60                        #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)    #Inclination in rad

#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(1e2, (3 * con.au.cgs).value)
ax.set_ylim(0, 2e7)
ax.set_xlabel('Line of Sight Distance (cm)')
ax.set_ylabel('Number Density (cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    s = np.logspace(np.log10(1e2), np.log10((3 * con.au.cgs).value), 10000) #Line of sight distance array
    orb_i_deg = 25
    i_rad = np.deg2rad(orb_i_deg)
    Om_deg = 0
    Om = np.deg2rad(Om_deg)
    om_deg = 90
    om = np.deg2rad(om_deg)
    phi = phi_array[frame]
    disc_n_e = disc_ne(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,  
                       beta=3, rho0=1e-12, i_disc=disc_i_gif, phi=phi, omega=om, Omega=Om, e=0.87, i=i_rad, s=s)
    line.set_data(s, disc_n_e)
    title.set_text('Number Density Vs LoS Distance,disc i = ' + str(int(disc_i_gif_deg)) + ' (deg) \nphi = ' + str(int(phi_deg_array[frame])) + ' deg')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(phi_array), blit=False, interval=100)
#Saving GIF
ani.save("disc_num_density_evolution.gif", writer="pillow", fps=10)
plt.show()

# %% [markdown]
# # Dispersion Measure

# %%
#Calculating the DM
om_deg = 90                                                           #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                                               #Orbital argument of periastron in rad
Om_deg = 0                                                            #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                                               #Longitude of ascending note in rad
i_orb_deg = 0                                                         #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                                     #Orbital inclination is rad
i_disc_deg = [70, 80, 90]                                             #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                                   #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                    #Orbital phase array in rad (redundancy removed)

disc_DM1 = disc_DM(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,   #Number density
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[0], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad)
disc_DM2 = disc_DM(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,        
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[1], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad)
disc_DM3 = disc_DM(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,       
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[2], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad)
#Plotting
plt.plot(phi, disc_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' deg')
plt.plot(phi, disc_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' deg')
plt.plot(phi, disc_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' deg')
plt.title('Disc Dispersion Measure Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %%
#Calculating the DM
om_deg = 60                                                           #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                                               #Orbital argument of periastron in rad
Om_deg = 0                                                            #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                                               #Longitude of ascending note in rad
i_orb_deg = 0                                                         #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                                     #Orbital inclination is rad
i_disc_deg = [70, 80, 90]                                             #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                                   #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                    #Orbital phase array in rad (redundancy removed)

disc_DM1 = disc_DM(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,   #Number density
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[0], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad)
disc_DM2 = disc_DM(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,        
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[1], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad)
disc_DM3 = disc_DM(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,       
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[2], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad)
#Plotting
plt.plot(phi, disc_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' deg')
plt.plot(phi, disc_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' deg')
plt.plot(phi, disc_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' deg')
plt.title('Disc Dispersion Measure Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %%
#Calculating the DM
om_deg = 90                                                           #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                                               #Orbital argument of periastron in rad
Om_deg = 0                                                            #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                                               #Longitude of ascending note in rad
i_orb_deg = 0                                                         #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                                     #Orbital inclination is rad
i_disc_deg = [70, 80, 90]                                             #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                                   #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                    #Orbital phase array in rad (redundancy removed)

disc_DM1 = disc_DM(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,   #Number density
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[0], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad)
disc_DM2 = disc_DM(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,        
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[1], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad)
disc_DM3 = disc_DM(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,       
                       beta=3, rho0=1e-12, i_disc=i_disc_rad[2], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad)
#Plotting
plt.plot(phi, disc_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' deg')
plt.plot(phi, disc_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' deg')
plt.plot(phi, disc_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' deg')
plt.title('Disc Dispersion Measure Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.yscale('log')
plt.ylim(None, 1e2)
plt.legend()

# %% [markdown]
# # Dispersion Measure Vs True Anomaly GIF

# %%
#Takes long to run
'''
#Varying disc inclination GIF
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad
disc_i_gif_deg = np.linspace(0, 90, 90)            #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad
orb_i_deg = 0                                      #Orbital inclination in degrees
i_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad
Om_deg = 0                                         #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad
om_deg = 90                                        #Argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Argumnet of periastron in rad


#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(None, 0.6e2)
ax.set_xlabel('True Anomaly (rad)')
ax.set_ylabel('Dispersion Measure (pc cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    disc_i = disc_i_gif[frame]
    disc_DM_gif = disc_DM(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,   
                       beta=3, rho0=1e-12, i_disc=disc_i, phi=phi, omega=om, Omega=Om, e=0.87, i=i_rad)
    line.set_data(phi, disc_DM_gif)
    title.set_text('Disc Dispersion Measure Vs True Anomaly \ndisc i = ' + str(int(disc_i_gif_deg[frame])) + ' (deg)')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(disc_i_gif), blit=False, interval=100)
#Saving GIF
ani.save("disc_DM_evolution_varying_disc_i.gif", writer="pillow", fps=10)
plt.show()
'''
# Out:
# '\n#Varying disc inclination GIF\nphi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad\ndisc_i_gif_deg = np.linspace(0, 90, 90)            #Inclination in deg\ndisc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad\norb_i_deg = 0                                      #Orbital inclination in degrees\ni_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad\nOm_deg = 0                                         #Longitude of ascending node in degrees\nOm = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad\nom_deg = 90                                        #Argument of periastron in degrees\nom = np.deg2rad(om_deg)                            #Argumnet of periastron in rad\n\n\n#Setting up the figure\nfig, ax = plt.subplots()\nline, = ax.plot([], [], lw=2)\nax.set_xlim(0, 2*np.pi)\nax.set_ylim(None, 0.6e2)\nax.set_xlabel(\'True Anomaly (rad)\')\nax.set_ylabel(\'Dispersion Measure (pc cm^-3)\')\ntitle 
# ...

# %%
#Takes long to run
'''
#Varying orbital inclination GIF
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad
disc_i_gif_deg = 0                                 #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad
orb_i_deg = np.linspace(0, 90, 90)                 #Orbital inclination in degrees
i_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad
Om_deg = 0                                         #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad
om_deg = 90                                        #Argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Argumnet of periastron in rad


#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(None, 1e2)
ax.set_xlabel('True Anomaly (rad)')
ax.set_ylabel('Dispersion Measure (pc cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    orb_i_gif = i_rad[frame]
    disc_DM_gif = disc_DM(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,   
                       beta=3, rho0=1e-12, i_disc=disc_i_gif, phi=phi, omega=om, Omega=Om, e=0.87, i=orb_i_gif)
    line.set_data(phi, disc_DM_gif)
    title.set_text('Disc Dispersion Measure Vs True Anomaly \norbital i = ' + str(int(orb_i_deg[frame])) + ' (deg)')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(i_rad), blit=False, interval=100)
#Saving GIF
ani.save("disc_DM_evolution_varying_orb_i.gif", writer="pillow", fps=10)
plt.show()
'''
# Out:
# '\n#Varying orbital inclination GIF\nphi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad\ndisc_i_gif_deg = 0                                 #Inclination in deg\ndisc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad\norb_i_deg = np.linspace(0, 90, 90)                 #Orbital inclination in degrees\ni_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad\nOm_deg = 0                                         #Longitude of ascending node in degrees\nOm = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad\nom_deg = 90                                        #Argument of periastron in degrees\nom = np.deg2rad(om_deg)                            #Argumnet of periastron in rad\n\n\n#Setting up the figure\nfig, ax = plt.subplots()\nline, = ax.plot([], [], lw=2)\nax.set_xlim(0, 2*np.pi)\nax.set_ylim(None, 1e2)\nax.set_xlabel(\'True Anomaly (rad)\')\nax.set_ylabel(\'Dispersion Measure (pc cm^-3)\')\ntitle
# ...

# %%
#Takes long to run
'''
#Varying argument of periastron GIF
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad
disc_i_gif_deg = 90                                #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad
orb_i_deg = 0                                      #Orbital inclination in degrees
i_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad
Om_deg = 0                                         #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad
om_gif_deg = np.linspace(0, 360, 180)              #Argument of periastron in degrees
om_gif_rad = np.deg2rad(om_gif_deg)                #Argumnet of periastron in rad


#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(None, 1e2)
ax.set_xlabel('True Anomaly (rad)')
ax.set_ylabel('Dispersion Measure (pc cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    om = om_gif_rad[frame]
    disc_DM_gif = disc_DM(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9,   
                       beta=3, rho0=1e-12, i_disc=disc_i_gif, phi=phi, omega=om, Omega=Om, e=0.87, i=i_rad)
    line.set_data(phi, disc_DM_gif)
    title.set_text('Disc Dispersion Measure Vs True Anomaly \nomega = ' + str(int(om_gif_deg[frame])) + ' (deg)')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(om_gif_rad), blit=False, interval=100)
#Saving GIF
ani.save("disc_DM_evolution_varying_omega.gif", writer="pillow", fps=10)
plt.show()
'''
# Out:
# '\n#Varying argument of periastron GIF\nphi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad\ndisc_i_gif_deg = 90                                #Inclination in deg\ndisc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad\norb_i_deg = 0                                      #Orbital inclination in degrees\ni_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad\nOm_deg = 0                                         #Longitude of ascending node in degrees\nOm = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad\nom_gif_deg = np.linspace(0, 360, 180)              #Argument of periastron in degrees\nom_gif_rad = np.deg2rad(om_gif_deg)                #Argumnet of periastron in rad\n\n\n#Setting up the figure\nfig, ax = plt.subplots()\nline, = ax.plot([], [], lw=2)\nax.set_xlim(0, 2*np.pi)\nax.set_ylim(None, 1e2)\nax.set_xlabel(\'True Anomaly (rad)\')\nax.set_ylabel(\'Dispersion Measure (pc cm^-3)\')\nti
# ...

# %% [markdown]
# # Optical Depth

# %%
#Calculating the optical depth
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)                            #Orbital phase array in rad (redundancy removed)
nu = [1.5, 1.75, 2]                                                           #Signal frequency in GHz
disc_tau1 = disc_ffa(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9, beta=3, #Optical depth
                  rho0=1e-12, i_disc=i_disc_rad[0], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad, nu=nu[0]) 
disc_tau2 = disc_ffa(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9, beta=3,
                  rho0=1e-12, i_disc=i_disc_rad[1], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad, nu=nu[1])
disc_tau3 = disc_ffa(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9, beta=3,
                  rho0=1e-12, i_disc=i_disc_rad[2], phi=phi, omega=om, Omega=Om, e=0.87, i=i_orb_rad, nu=nu[2])

# %%
#Plotting the optical depth as a function of the orbital phase
plt.plot(phi, disc_tau1, label = 'i disc = ' + str(i_disc_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, disc_tau2, label = 'i disc = ' + str(i_disc_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, disc_tau3, label = 'i disc = ' + str(i_disc_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('FFA Optical Depth Vs True Anomaly')
plt.xlabel('True Anomaly (Rad)')
plt.ylabel('Optical Depth')
plt.legend()

# %%
#Plotting the optical depth as a function of the orbital phase
plt.plot(phi, disc_tau1, label = 'i disc = ' + str(i_disc_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, disc_tau2, label = 'i disc = ' + str(i_disc_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, disc_tau3, label = 'i disc = ' + str(i_disc_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('FFA Optical Depth Vs True Anomaly')
plt.xlabel('True Anomaly (Rad)')
plt.ylabel('Optical Depth')
plt.yscale('log')
plt.ylim(1e-4, 1e2)
plt.legend()

# %% [markdown]
# # Transmission Factor $e^{-\tau}$ Vs $\phi$

# %%
#Plotting e^(-tau) as a function of the orbital phase
plt.plot(phi, np.exp(-disc_tau1), label = 'i disc = ' + str(i_disc_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, np.exp(-disc_tau2), label = 'i disc = ' + str(i_disc_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, np.exp(-disc_tau3), label = 'i disc = ' + str(i_disc_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('Disc Transmission Factor e^(-tau) Vs True Anomaly')
plt.xlabel('True Anomaly (Rad)')
plt.ylabel('e^(-tau)')
plt.ylim(0.5, None)
plt.legend()

# %%
#Plotting e^(-tau) as a function of the orbital phase
plt.plot(phi, np.exp(-disc_tau1), label = 'i disc = ' + str(i_disc_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, np.exp(-disc_tau2), label = 'i disc = ' + str(i_disc_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, np.exp(-disc_tau3), label = 'i disc = ' + str(i_disc_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('Disc Transmission Factor e^(-tau) Vs True Anomaly')
plt.xlabel('True Anomaly (Rad)')
plt.ylabel('e^(-tau)')
plt.yscale('log')
plt.ylim(1e-2, 1.1)
plt.legend()

# %% [markdown]
# # Pulsar spectrum evolution through the disc along the orbit GIF

# %%
#Takes long to run
'''
phi_deg_array = np.linspace(0, 360, 180)   #Orbital phases in deg
phi_array = np.deg2rad(phi_deg_array)      #Orbital phases in rad
disc_i_gif_deg = 60                        #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)    #Inclination in rad
nu_array = np.linspace(1, 8.4, 512)        #Frequency array

#Computing the spectra for all orbital phases
disc_S_nu = disc_spectrum(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9, beta=3, 
                  rho0=1e-12, i_disc=disc_i_gif, phi=phi_array, omega=om, Omega=Om, e=0.87, i=i_orb_rad, nu=nu_array, p=1.3)         

#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1, 8.4)
ax.set_ylim(1e-5, 1)
ax.set_xlabel('Frequency (GHz)')
ax.set_ylabel('Flux density (Jy)')
title = ax.set_title('')

#Frame update function
def update(frame):
    line.set_data(nu_array, disc_S_nu[frame, :])
    title.set_text('Spectrum Evolution at Inclination i = ' + str(int(disc_i_gif_deg)) + '(deg)\n at Orbital Phase = ' + str(int(phi_deg_array[frame])) + ' deg')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(phi_array), blit=False, interval=100)
#Saving GIF
ani.save("disc_spectrum_evolution.gif", writer="pillow", fps=10)
plt.show()
'''
# Out:
# '\nphi_deg_array = np.linspace(0, 360, 180)   #Orbital phases in deg\nphi_array = np.deg2rad(phi_deg_array)      #Orbital phases in rad\ndisc_i_gif_deg = 60                        #Inclination in deg\ndisc_i_gif = np.deg2rad(disc_i_gif_deg)    #Inclination in rad\nnu_array = np.linspace(1, 8.4, 512)        #Frequency array\n\n#Computing the spectra for all orbital phases\ndisc_S_nu = disc_spectrum(a_Rsun=1345, T=7e3, M_star_sol=20, R_star_sol=9, beta=3, \n                  rho0=1e-12, i_disc=disc_i_gif, phi=phi_array, omega=om, Omega=Om, e=0.87, i=i_orb_rad, nu=nu_array, p=1.3)         \n\n#Setting up the figure\nfig, ax = plt.subplots()\nline, = ax.plot([], [], lw=2)\nax.set_xscale(\'log\')\nax.set_yscale(\'log\')\nax.set_xlim(1, 8.4)\nax.set_ylim(1e-5, 1)\nax.set_xlabel(\'Frequency (GHz)\')\nax.set_ylabel(\'Flux density (Jy)\')\ntitle = ax.set_title(\'\')\n\n#Frame update function\ndef update(frame):\n    line.set_data(nu_array, disc_S_nu[frame, :])\n    title.set_text(\'Spectrum E
# ...

# %% [markdown]
# ## Combined Stellar Wind and Disk

# %% [markdown]
# ## Number Density Vs Line of Sight Distance

# %%
s = np.logspace(np.log10(1e8), np.log10((3 * con.au.cgs).value), 10000)      #Line of sight distance array
i_disc_deg = [60, 65, 70, 75]                                                #Disc inclination in degrees                                                   
i_disc_rad = np.deg2rad(i_disc_deg)                                          #Disc inclination in rad
i_orb_deg = 25                                                               #Orbital inclination in deg
i_orb_rad = np.deg2rad(i_orb_deg)                                            #Orbital inclination in rad
phi_orb_deg = 60                                                             #Orbital phase in degree
phi_orb_rad = np.deg2rad(phi_orb_deg)                                        #Orbital phase in rad
om_deg = 138
om = np.deg2rad(om_deg)
Om_deg = 30
Om = np.deg2rad(Om_deg)

tot_ne1 = tot_num_density(phi=phi_orb_rad, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          s=s, e=0.87, omega=om, Omega=Om, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=i_disc_rad[0])
tot_ne2 = tot_num_density(phi=phi_orb_rad, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          s=s, e=0.87, omega=om, Omega=Om, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=i_disc_rad[1])
tot_ne3 = tot_num_density(phi=phi_orb_rad, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          s=s, e=0.87, omega=om, Omega=Om, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=i_disc_rad[2])
tot_ne4 = tot_num_density(phi=phi_orb_rad, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          s=s, e=0.87, omega=om, Omega=Om, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=i_disc_rad[3])

#Plotting
plt.plot(s, tot_ne1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg)')
plt.plot(s, tot_ne2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg)')
plt.plot(s, tot_ne3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg)')
plt.plot(s, tot_ne4, label='i disc = ' + str(int(i_disc_deg[3])) + ' (deg)')
plt.title('Total Number Density Vs Line of Sight Distance')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.legend()

# %%
#Plotting
plt.plot(s, tot_ne1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg)')
plt.plot(s, tot_ne2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg)')
plt.plot(s, tot_ne3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg)')
plt.plot(s, tot_ne4, label='i disc = ' + str(int(i_disc_deg[3])) + ' (deg)')
plt.title('Total Number Density Vs Line of Sight Distance')
plt.xlabel('Line of Sight Distance (cm)')
plt.ylabel('Number Density (cm^-3)')
plt.xscale('log')
plt.yscale('log')
plt.xlim(1e11, None)
plt.legend()

# %% [markdown]
# ## Total Number Density Vs Line of Sight Distance GIF

# %%
phi_deg_array = np.linspace(0, 360, 360)   #Orbital phases in deg
phi_array = np.deg2rad(phi_deg_array)      #Orbital phases in rad
disc_i_gif_deg = 60                        #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)    #Inclination in rad

#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(1e2, (3 * con.au.cgs).value)
ax.set_ylim(0, 1e9)
ax.set_xlabel('Line of Sight Distance (cm)')
ax.set_ylabel('Number Density (cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    s = np.logspace(np.log10(1e2), np.log10((3 * con.au.cgs).value), 10000) #Line of sight distance array
    orb_i_deg = 25
    i_rad = np.deg2rad(orb_i_deg)
    Om_deg = 0
    Om = np.deg2rad(Om_deg)
    om_deg = 90
    om = np.deg2rad(om_deg)
    phi = phi_array[frame]
    tot_ne = tot_num_density(phi=phi, i=i_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          s=s, e=0.87, omega=om, Omega=Om, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=disc_i_gif)
    line.set_data(s, tot_ne)
    title.set_text('Total Number Density Vs LoS Distance,disc i = ' + str(int(disc_i_gif_deg)) + ' (deg) \nphi = ' + str(int(phi_deg_array[frame])) + ' deg')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(phi_array), blit=False, interval=100)
#Saving GIF
ani.save("total_num_density_evolution.gif", writer="pillow", fps=10)
plt.show()

# %% [markdown]
# ## Dispersion Measure Vs True Anomaly

# %%
#Calculating the DM
om_deg = 90                                        #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Orbital argument of periastron in rad
Om_deg = 0                                         #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending note in rad
i_orb_deg = 0                                      #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                  #Orbital inclination is rad
i_disc_deg = [60, 65, 70]                          #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)

tot_DM1 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=i_disc_rad[0])
tot_DM2 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=i_disc_rad[1])
tot_DM3 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=i_disc_rad[2])

#Plotting
plt.plot(phi, tot_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg)')
plt.plot(phi, tot_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg)')
plt.plot(phi, tot_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg)')
plt.title('Total Dispersion Measure Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %%
#Plotting
plt.plot(phi, tot_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg)')
plt.plot(phi, tot_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg)')
plt.plot(phi, tot_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg)')
plt.title('Total Dispersion Measure Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.yscale('log')
plt.legend()

# %%
#Calculating the DM
om_deg = 60                                        #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Orbital argument of periastron in rad
Om_deg = 0                                         #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending note in rad
i_orb_deg = 0                                      #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                  #Orbital inclination is rad
i_disc_deg = [60, 65, 70]                          #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)

tot_DM1 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=i_disc_rad[0])
tot_DM2 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=i_disc_rad[1])
tot_DM3 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=i_disc_rad[2])

#Plotting
plt.plot(phi, tot_DM1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg)')
plt.plot(phi, tot_DM2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg)')
plt.plot(phi, tot_DM3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg)')
plt.title('Total Dispersion Measure Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.legend()

# %% [markdown]
# ## Total Dispersion Measure Vs True Anomaly GIF

# %%
'''
#Varying disc inclination GIF
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad
disc_i_gif_deg = np.linspace(0, 90, 90)            #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad
orb_i_deg = 0                                      #Orbital inclination in degrees
i_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad
Om_deg = 0                                         #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad
om_deg = 90                                        #Argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Argumnet of periastron in rad


#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(None, 5e2)
ax.set_xlabel('True Anomaly (rad)')
ax.set_ylabel('Dispersion Measure (pc cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    disc_i = disc_i_gif[frame]
    tot_DM_disc_i = tot_DM(phi=phi, i=i_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=disc_i)
    line.set_data(phi, tot_DM_disc_i)
    title.set_text('Total Dispersion Measure Vs True Anomaly \ndisc i = ' + str(int(disc_i_gif_deg[frame])) + ' (deg)')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(disc_i_gif), blit=False, interval=100)
#Saving GIF
ani.save("total_DM_evolution_varying_disc_i.gif", writer="pillow", fps=10)
plt.show()
'''
# Out:
# '\n#Varying disc inclination GIF\nphi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad\ndisc_i_gif_deg = np.linspace(0, 90, 90)            #Inclination in deg\ndisc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad\norb_i_deg = 0                                      #Orbital inclination in degrees\ni_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad\nOm_deg = 0                                         #Longitude of ascending node in degrees\nOm = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad\nom_deg = 90                                        #Argument of periastron in degrees\nom = np.deg2rad(om_deg)                            #Argumnet of periastron in rad\n\n\n#Setting up the figure\nfig, ax = plt.subplots()\nline, = ax.plot([], [], lw=2)\nax.set_xlim(0, 2*np.pi)\nax.set_ylim(None, 5e2)\nax.set_xlabel(\'True Anomaly (rad)\')\nax.set_ylabel(\'Dispersion Measure (pc cm^-3)\')\ntitle = 
# ...

# %%
'''
#Varying orbital inclination GIF
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad
disc_i_gif_deg = 0                                 #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad
orb_i_deg = np.linspace(0, 90, 90)                 #Orbital inclination in degrees
i_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad
Om_deg = 0                                         #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad
om_deg = 90                                        #Argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Argumnet of periastron in rad


#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(None, 5e2)
ax.set_xlabel('True Anomaly (rad)')
ax.set_ylabel('Dispersion Measure (pc cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    orb_i_gif = i_rad[frame]
    tot_DM_orb_i = tot_DM(phi=phi, i=orb_i_gif, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=disc_i_gif)
    line.set_data(phi, tot_DM_orb_i)
    title.set_text('Total Dispersion Measure Vs True Anomaly \norbital i = ' + str(int(orb_i_deg[frame])) + ' (deg)')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(i_rad), blit=False, interval=100)
#Saving GIF
ani.save("total_DM_evolution_varying_orb_i.gif", writer="pillow", fps=10)
plt.show()
'''
# Out:
# '\n#Varying orbital inclination GIF\nphi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad\ndisc_i_gif_deg = 0                                 #Inclination in deg\ndisc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad\norb_i_deg = np.linspace(0, 90, 90)                 #Orbital inclination in degrees\ni_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad\nOm_deg = 0                                         #Longitude of ascending node in degrees\nOm = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad\nom_deg = 90                                        #Argument of periastron in degrees\nom = np.deg2rad(om_deg)                            #Argumnet of periastron in rad\n\n\n#Setting up the figure\nfig, ax = plt.subplots()\nline, = ax.plot([], [], lw=2)\nax.set_xlim(0, 2*np.pi)\nax.set_ylim(None, 5e2)\nax.set_xlabel(\'True Anomaly (rad)\')\nax.set_ylabel(\'Dispersion Measure (pc cm^-3)\')\ntitle
# ...

# %%
'''
#Varying argument of periastron GIF
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad
disc_i_gif_deg = 90                                #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad
orb_i_deg = 0                                      #Orbital inclination in degrees
i_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad
Om_deg = 0                                         #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad
om_gif_deg = np.linspace(0, 360, 180)              #Argument of periastron in degrees
om_gif_rad = np.deg2rad(om_gif_deg)                #Argumnet of periastron in rad


#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(0, 2*np.pi)
ax.set_ylim(None, 5e2)
ax.set_xlabel('True Anomaly (rad)')
ax.set_ylabel('Dispersion Measure (pc cm^-3)')
title = ax.set_title('')

#Frame update function
def update(frame):
    om = om_gif_rad[frame]
    tot_DM_om = tot_DM(phi=phi, i=i_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=disc_i_gif)
    line.set_data(phi, tot_DM_om)
    title.set_text('Total Dispersion Measure Vs True Anomaly \nomega = ' + str(int(om_gif_deg[frame])) + ' (deg)')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(om_gif_rad), blit=False, interval=100)
#Saving GIF
ani.save("total_DM_evolution_varying_omega.gif", writer="pillow", fps=10)
plt.show()
'''
# Out:
# '\n#Varying argument of periastron GIF\nphi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phases in rad\ndisc_i_gif_deg = 90                                #Inclination in deg\ndisc_i_gif = np.deg2rad(disc_i_gif_deg)            #Inclination in rad\norb_i_deg = 0                                      #Orbital inclination in degrees\ni_rad = np.deg2rad(orb_i_deg)                      #Orbital inclination in rad\nOm_deg = 0                                         #Longitude of ascending node in degrees\nOm = np.deg2rad(Om_deg)                            #Longitude of ascending node on rad\nom_gif_deg = np.linspace(0, 360, 180)              #Argument of periastron in degrees\nom_gif_rad = np.deg2rad(om_gif_deg)                #Argumnet of periastron in rad\n\n\n#Setting up the figure\nfig, ax = plt.subplots()\nline, = ax.plot([], [], lw=2)\nax.set_xlim(0, 2*np.pi)\nax.set_ylim(None, 5e2)\nax.set_xlabel(\'True Anomaly (rad)\')\nax.set_ylabel(\'Dispersion Measure (pc cm^-3)\')\nti
# ...

# %% [markdown]
# ## Optical Depth Vs True Anomaly

# %%
#Calculating the optical depth
om_deg = 90                                        #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Orbital argument of periastron in rad
Om_deg = 0                                         #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending note in rad
i_orb_deg = 0                                      #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                  #Orbital inclination is rad
i_disc_deg = [60, 65, 70]                          #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                #Disc inclinations in rad
nu = [1.5, 1.75, 2]                                #Signal frequency in GHz
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)

tot_tau1 = tot_ffa(phi=phi, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1.5, T_wind=1e4, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=i_disc_rad[0], nu=nu[0])
tot_tau2 = tot_ffa(phi=phi, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1.5, T_wind=1e4, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=i_disc_rad[1], nu=nu[1])
tot_tau3 = tot_ffa(phi=phi, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1.5, T_wind=1e4, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, i_disc=i_disc_rad[2], nu=nu[2])

#Plotting
plt.plot(phi, tot_tau1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg), freq = ' + str(int(nu[0])) + ' (GHz)')
plt.plot(phi, tot_tau2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg), freq = ' + str(int(nu[1])) + ' (GHz)')
plt.plot(phi, tot_tau3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg), freq = ' + str(int(nu[2])) + ' (GHz)')
plt.title('FFA Optical Depth Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Optical Depth')
plt.legend()

# %%
#Plotting
plt.plot(phi, tot_tau1, label='i disc = ' + str(int(i_disc_deg[0])) + ' (deg), freq = ' + str(int(nu[0])) + ' (GHz)')
plt.plot(phi, tot_tau2, label='i disc = ' + str(int(i_disc_deg[1])) + ' (deg), freq = ' + str(int(nu[1])) + ' (GHz)')
plt.plot(phi, tot_tau3, label='i disc = ' + str(int(i_disc_deg[2])) + ' (deg), freq = ' + str(int(nu[2])) + ' (GHz)')
plt.title('FFA Optical Depth Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Optical Depth')
plt.yscale('log')
plt.legend()

# %% [markdown]
# ## Transmission Factor $e^{-\tau}$ Vs True Anomaly

# %%
#Plotting e^(-tau) as a function of the orbital phase
plt.plot(phi, np.exp(-tot_tau1), label = 'i disc = ' + str(i_disc_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, np.exp(-tot_tau2), label = 'i disc = ' + str(i_disc_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, np.exp(-tot_tau3), label = 'i disc = ' + str(i_disc_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('Total Transmission Factor e^(-tau) Vs True Anomaly')
plt.xlabel('True Anomaly (Rad)')
plt.ylabel('e^(-tau)')
plt.ylim(0, 0.00001)
plt.legend()

# %%
#Plotting e^(-tau) as a function of the orbital phase
plt.plot(phi, np.exp(-tot_tau1), label = 'i disc = ' + str(i_disc_deg[0]) + ' (deg), freq = ' + str(nu[0]) + ' (GHz)')
plt.plot(phi, np.exp(-tot_tau2), label = 'i disc = ' + str(i_disc_deg[1]) + ' (deg), freq = ' + str(nu[1]) + ' (GHz)')
plt.plot(phi, np.exp(-tot_tau3), label = 'i disc = ' + str(i_disc_deg[2]) + ' (deg), freq = ' + str(nu[2]) + ' (GHz)')
plt.title('Total Transmission Factor e^(-tau) Vs True Anomaly')
plt.xlabel('True Anomaly (Rad)')
plt.ylabel('e^(-tau)')
plt.ylim(0.5, None)
plt.yscale('log')
plt.legend()

# %% [markdown]
# ## Total Pulsar Spectrum Through the Disk and Stellar Wind GIF

# %%
'''
i_orb_deg = 0                              #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)          #Orbital inclination in rad
phi_deg_array = np.linspace(0, 360, 180)   #Orbital phases in deg
phi_array = np.deg2rad(phi_deg_array)      #Orbital phases in rad
disc_i_gif_deg = 60                        #Inclination in deg
disc_i_gif = np.deg2rad(disc_i_gif_deg)    #Inclination in rad
om_deg = 90                                #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                    #Orbital argument of periastron in rad
Om_deg = 0                                 #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                    #Longitude of ascending note in rad
nu_array = np.linspace(1, 8.4, 512)        #Frequency array

#Computing the spectra for all orbital phases
total_S_nu = tot_spectrum(phi=phi_array, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1.5, T_wind=1e4, T_disc=7e3, beta_disc=3, rho0=5e-14, i_disc=disc_i_gif, nu=nu_array, p=1.3) 
                      

#Setting up the figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1, 8.4)
ax.set_ylim(1e-5, 1)
ax.set_xlabel('Frequency (GHz)')
ax.set_ylabel('Flux density (Jy)')
title = ax.set_title('')

#Frame update function
def update(frame):
    line.set_data(nu_array, total_S_nu[frame, :])
    title.set_text('Total Spectrum Evolution at Inclination i = ' + str(int(disc_i_gif_deg)) + '(deg)\n at Orbital Phase = ' + str(int(phi_deg_array[frame])) + ' deg')
    return line, title

#Animating
ani = animation.FuncAnimation(fig, update, frames=len(phi_array), blit=False, interval=100)
#Saving GIF
ani.save("total_spectrum_evolution.gif", writer="pillow", fps=10)
plt.show()
'''
# Out:
# '\ni_orb_deg = 0                              #Orbital inclination in degrees\ni_orb_rad = np.deg2rad(i_orb_deg)          #Orbital inclination in rad\nphi_deg_array = np.linspace(0, 360, 180)   #Orbital phases in deg\nphi_array = np.deg2rad(phi_deg_array)      #Orbital phases in rad\ndisc_i_gif_deg = 60                        #Inclination in deg\ndisc_i_gif = np.deg2rad(disc_i_gif_deg)    #Inclination in rad\nom_deg = 90                                #Orbital argument of periastron in degrees\nom = np.deg2rad(om_deg)                    #Orbital argument of periastron in rad\nOm_deg = 0                                 #Longitude of ascending node in degrees\nOm = np.deg2rad(Om_deg)                    #Longitude of ascending note in rad\nnu_array = np.linspace(1, 8.4, 512)        #Frequency array\n\n#Computing the spectra for all orbital phases\ntotal_S_nu = tot_spectrum(phi=phi_array, i=i_orb_rad, a_Rsun=1345, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, v_inf_kms=
# ...

# %% [markdown]
# # Parameter Studies

# %%
#DM function for parameter studies
def tot_DM_map(phi, i, i_disc, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, mu_e=1.2, s_array_cm=None):
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10((1 * con.au.cgs).value), 512)  
    s = np.asarray(s_array_cm, dtype=float)
    
    M_star = (M_star_sol * con.M_sun).cgs.value                                                                          #Converts the stellar mass from solar mass to g
    P = 1.068e8                                                                                                          #Orbital period in seconds (1237 days)
    a = ((P**2*con.G*(M_star_sol+1.4)*con.M_sun).cgs.value/(4*np.pi**2))**(1/3)                                          #Semi-mmajor axis (cm)
    R_star = (R_star_sol * con.R_sun).cgs.value                                                                          #Converts the stellar radius from solar radii to cm
    Mdot = (Mdot_Msun_per_yr * con.M_sun / (1 * u.yr)).cgs.value                                                         #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = (v_0_kms * u.km / u.s).cgs.value                                                                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = (v_inf_kms * u.km / u.s).cgs.value                                                                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*con.m_p.cgs.value)                                                                          #Calculates the k constant (cm^-1)

    #Stellar wind number density
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                                 #Calculates the orbital separation along the orbit
    r_s_sqrd = r**2 + 2*r*s*(np.cos(phi+omega)*np.sin(i)*np.cos(Omega)+np.sin(phi+omega)*np.sin(i)*np.sin(Omega)) + s**2 #Calculates the squared radial distance from the star along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                         #Calculates the velocity of the wind 
    n_e = k/(r_s_sqrd*v_r_s)                                                                                             #Calculates the number density
    n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                                                                 #Eclipse condition
    
    #Disc number density
    r_disc = np.sqrt(r_s_sqrd)                                                 #Projected radius through disc plane   
    c_s = np.sqrt((con.k_B * T_disc)/(mu_e * con.m_p)).cgs.value               #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(con.G * M_star).cgs.value) * r_disc        #Calculates the scale height
    z = (r*np.sin(phi+omega)*np.sin(i_disc) + s*np.cos(i)*np.cos(i_disc))      #Calculates the height above the disc plane
    rho_disc = rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2) #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * con.m_p).cgs.value                              #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                               #Constraining the inner disc radius

    #Total number density
    total_ne = n_e + ne_disc
    
    total_DM = np.trapz(total_ne, s) / u.pc.to(u.cm)                           #Integrating the DM 

    return total_DM

# %%
#Free-free absorption function for parameter studies
def tot_ffa_map(phi, i, i_disc, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_wind, T_disc, beta_disc, rho0, nu, mu_e=1.2, s_array_cm=None):
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10((1 * con.au.cgs).value), 512)  
    s = np.asarray(s_array_cm, dtype=float)
  
    M_star = (M_star_sol * con.M_sun).cgs.value                                 #Converts the stellar mass from solar mass to g
    P = 1.068e8                                                                 #Orbital period in seconds (1237 days)
    a = ((P**2*con.G*(M_star_sol+1.4)*con.M_sun).cgs.value/(4*np.pi**2))**(1/3) #Semi-mmajor axis (cm)
    R_star = (R_star_sol * con.R_sun).cgs.value                                 #Converts the stellar radius from solar radii to cm
    Mdot = (Mdot_Msun_per_yr * con.M_sun / (1 * u.yr)).cgs.value                #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = (v_0_kms * u.km / u.s).cgs.value                                      #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = (v_inf_kms * u.km / u.s).cgs.value                                  #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*con.m_p.cgs.value)                                 #Calculates the k constant (cm^-1)

    #Stellar wind number density
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                                 #Calculates the orbital separation along the orbit
    r_s_sqrd = r**2 + 2*r*s*(np.cos(phi+omega)*np.sin(i)*np.cos(Omega)+np.sin(phi+omega)*np.sin(i)*np.sin(Omega)) + s**2 #Calculates the squared radial distance from the star along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/np.sqrt(r_s_sqrd))**beta                                                         #Calculates the velocity of the wind 
    n_e = k/(r_s_sqrd*v_r_s)                                                                                             #Calculates the number density
    n_e[np.sqrt(r_s_sqrd) <= R_star] = 0                                                                                 #Eclipse condition
    
    #Disc number density
    r_disc = np.sqrt(r_s_sqrd)                                                 #Projected radius through disc plane   
    c_s = np.sqrt((con.k_B * T_disc)/(mu_e * con.m_p)).cgs.value               #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(con.G * M_star).cgs.value) * r_disc        #Calculates the scale height
    z = (r*np.sin(phi+omega)*np.sin(i_disc) + s*np.cos(i)*np.cos(i_disc))      #Calculates the height above the disc plane
    rho_disc = rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2) #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * con.m_p).cgs.value                              #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                               #Constraining the inner disc radius

    #Total number density
    total_ne = n_e + ne_disc

    total_tau = 8.24e-2*nu**(-2.1)*((T_wind+T_disc)/2)**(-1.35)*np.trapz(total_ne**2, s / u.pc.to(u.cm)) #Integrating the DM in cm^-2

    return total_tau

# %%
#DM Vs i disc and orb phase
i_disc_array_deg = np.linspace(0, 90, 50)       #Disc inclinations in degrees
i_disc_array_rad = np.deg2rad(i_disc_array_deg) #Disc inclinations in rad
phi_array_deg = np.linspace(0, 360, 50)         #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg)       #Orbital degrees in rad
i_orb_deg = 0                                   #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)               #Orbital inclination in rad
om_deg = 90                                     #Argument of periastron in degrees
om_rad = np.deg2rad(om_deg)                     #Argument of periastron in rad
Om_deg = 0                                      #Longitude of ascending node in degrees
Om_rad = np.deg2rad(Om_deg)                     #Longitude of ascending node in rad

#Initialising a DM 2D array
DM_map = np.zeros((len(i_disc_array_rad), len(phi_array_rad)))

#Filling the DM map 
for i_idx, i_disc in enumerate(i_disc_array_rad):
    for phi_idx, phi in enumerate(phi_array_rad):
        DM_map[i_idx, phi_idx] = tot_DM_map(phi=phi, i=i_orb_rad, i_disc=i_disc, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, 
                                               v_inf_kms=1e3, e=0.87, omega=om_rad, Omega=Om_rad, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(DM_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], i_disc_array_deg[0], i_disc_array_deg[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Disc Inclination (deg)')
plt.title('Dispersion Measure Vs Orbital Phase and Disc Inclination')
plt.show()

# %%
#DM Vs M_star_sol and orb phase
i_disc_deg = 40                           #Disc inclination in degrees
i_disc_rad = np.deg2rad(i_disc_deg)       #Disc inclination in rad
phi_array_deg = np.linspace(0, 360, 50)   #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg) #Orbital degrees in rad
M_star_array = np.linspace(10, 30, 50)    #Stellar mass array

#Initialising a DM 2D array
DM_map = np.zeros((len(M_star_array), len(phi_array_rad)))

#Filling the DM map 
for m_idx, m_star in enumerate(M_star_array):
    for phi_idx, phi in enumerate(phi_array_rad):
        DM_map[m_idx, phi_idx] = tot_DM_map(phi=phi, i=i_orb_rad, i_disc=i_disc_rad, R_star_sol=9, M_star_sol=m_star, Mdot_Msun_per_yr=1e-7, v_0_kms=10, 
                                               v_inf_kms=1e3, e=0.87, omega=om_rad, Omega=Om_rad, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(DM_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], M_star_array[0], M_star_array[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Stellar Mass (solar mass)')
plt.title('Dispersion Measure Vs Orbital Phase and Stellar Mass')
plt.show()

# %%
#DM Vs v_0 and orb phase
phi_array_deg = np.linspace(0, 360, 50)   #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg) #Orbital degrees in rad
v_0_array = np.linspace(5, 15, 50)        #Initial stellar wind velocity array

#Initialising a DM 2D array
DM_map = np.zeros((len(v_0_array), len(phi_array_rad)))

#Filling the DM map 
for v_idx, v_wind in enumerate(v_0_array):
    for phi_idx, phi in enumerate(phi_array_rad):
        DM_map[v_idx, phi_idx] = tot_DM_map(phi=phi, i=i_orb_rad, i_disc=i_disc_rad, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=v_wind, 
                                               v_inf_kms=1e3, e=0.87, omega=om_rad, Omega=Om_rad, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(DM_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], v_0_array[0], v_0_array[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Initial Stellar Wind Velocity (km/s)')
plt.title('Dispersion Measure Vs Orbital Phase and Initial Stellar Wind Velocity')
plt.show()

# %%
#DM Vs v_inf and orb phase
phi_array_deg = np.linspace(0, 360, 50)   #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg) #Orbital degrees in rad
v_inf_array = np.linspace(1e3, 1.5e3, 50) #Stellar wind terminal velocity array

#Initialising a DM 2D array
DM_map = np.zeros((len(v_inf_array), len(phi_array_rad)))

#Filling the DM map 
for v_idx, v_wind in enumerate(v_inf_array):
    for phi_idx, phi in enumerate(phi_array_rad):
        DM_map[v_idx, phi_idx] = tot_DM_map(phi=phi, i=i_orb_rad, i_disc=i_disc_rad, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, 
                                               v_inf_kms=v_wind, e=0.87, omega=om_rad, Omega=Om_rad, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(DM_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], v_inf_array[0], v_inf_array[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Stellar Wind Terminal Velocity (km/s)')
plt.title('Dispersion Measure Vs Orbital Phase and Stellar Wind Terminal Velocity')
plt.show()

# %%
#DM Vs T_disc and orb phase
phi_array_deg = np.linspace(0, 360, 50)    #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg)  #Orbital degrees in rad
T_disc_array = np.linspace(0.5e4, 2e4, 50) #Disc Temperature array

#Initialising a DM 2D array
DM_map = np.zeros((len(T_disc_array), len(phi_array_rad)))

#Filling the DM map 
for T_idx, T_disc in enumerate(T_disc_array):
    for phi_idx, phi in enumerate(phi_array_rad):
        DM_map[T_idx, phi_idx] = tot_DM_map(phi=phi, i=i_orb_rad, i_disc=i_disc_rad, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, 
                                               v_inf_kms=1e3, e=0.87, omega=om_rad, Omega=Om_rad, beta=1.5, T_disc=T_disc, beta_disc=1.6, rho0=5e-14)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(DM_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], T_disc_array[0], T_disc_array[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Disc Temperature (K)')
plt.title('Dispersion Measure Vs Orbital Phase and Disc Temperature')
plt.show()

# %%
#DM Vs rho0 and orb phase
phi_array_deg = np.linspace(0, 360, 50)    #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg)  #Orbital degrees in rad
rho0_array = np.linspace(1e-16, 1e-10, 50) #Disc density at stellar surface array

#Initialising a DM 2D array
DM_map = np.zeros((len(rho0_array), len(phi_array_rad)))

#Filling the DM map 
for rho0_idx, rho0 in enumerate(rho0_array):
    for phi_idx, phi in enumerate(phi_array_rad):
        DM_map[rho0_idx, phi_idx] = tot_DM_map(phi=phi, i=i_orb_rad, i_disc=i_disc_rad, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, 
                                               v_inf_kms=1e3, e=0.87, omega=om_rad, Omega=Om_rad, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=rho0)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(DM_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], rho0_array[0], rho0_array[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Disc Intrinsic Density (gcm^-3)')
plt.title('Dispersion Measure Vs Orbital Phase and Disc Intrinsic Density')
plt.show()

# %%
#DM Vs mass loss and orb phase
phi_array_deg = np.linspace(0, 360, 50)        #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg)      #Orbital degrees in rad
Mdot_Msun_array = np.linspace(1e-10, 1e-6, 50) #Stellar mass loss per year array

#Initialising a DM 2D array
DM_map = np.zeros((len(rho0_array), len(phi_array_rad)))

#Filling the DM map 
for Mdot_idx, Mdot in enumerate(Mdot_Msun_array):
    for phi_idx, phi in enumerate(phi_array_rad):
        DM_map[Mdot_idx, phi_idx] = tot_DM_map(phi=phi, i=i_orb_rad, i_disc=i_disc_rad, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=Mdot, v_0_kms=10, 
                                               v_inf_kms=1e3, e=0.87, omega=om_rad, Omega=Om_rad, beta=1.5, T_disc=0.7e4, beta_disc=1.6, rho0=1e-12)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(DM_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], Mdot_Msun_array[0], Mdot_Msun_array[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Dispersion Measure (pc cm^-3)')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Stellar Mass Loss (solar mass/ yr)')
plt.title('Dispersion Measure Vs Orbital Phase and Stellar Mass Loss')
plt.show()

# %%
#Optical depth Vs wind temperature and orbital phase
phi_array_deg = np.linspace(0, 360, 50)   #Orbital phases in degrees
phi_array_rad = np.deg2rad(phi_array_deg) #Orbital degrees in rad
T_wind_array = np.linspace(1e4, 4e4, 50)  #Wind temperature array
nu = 1.5                                  #Signal frequency (GHz)

#Initialising an optical depth 2D array
tau_map = np.zeros((len(T_wind_array), len(phi_array_rad)))

#Filling the optical depth map 
for T_idx, T_wind in enumerate(T_wind_array):
    for phi_idx, phi in enumerate(phi_array_rad):
        tau_map[T_idx, phi_idx] = tot_ffa_map(phi=phi, i=i_orb_rad, i_disc=i_disc_rad, R_star_sol=9, M_star_sol=20, Mdot_Msun_per_yr=1e-7, v_0_kms=10, 
                                               v_inf_kms=1e3, e=0.87, omega=om_rad, Omega=Om_rad, beta=1.5, T_wind=T_wind, T_disc=0.7e4, beta_disc=1.6, rho0=5e-14, nu=nu)

#Plotting
plt.figure(figsize=(8,6))
plt.imshow(tau_map, origin='lower', extent=[phi_array_deg[0], phi_array_deg[-1], T_wind_array[0], T_wind_array[-1]], aspect='auto', cmap='viridis')
plt.colorbar(label='Optical Depth')
plt.xlabel('Orbital Phase (deg)')
plt.ylabel('Wind Temperature (K)')
plt.title('Optical Depth Vs Orbital Phase and Wind Temperature, nu = ' + str(nu) + ' (GHz)')
plt.show()

# %% [markdown]
# # Comparing our Model with Results of Past Periastron Passages of PSR B1259-63
# Since most available papers only report $\Delta DM$ - the difference in dispersion measure from periastron, with locations of the pulsar in terms of days from or to periastron, the orbital phases need to be translated as
# ## $\phi = 360^\circ (\frac{\Delta t}{P}) = 360^\circ (\frac{\Delta t}{1237 days})$

# %% [markdown]
# # 1994 Periastron Passage - Johnston et al. (1995)
# https://ui.adsabs.harvard.edu/abs/1996MNRAS.279.1026J/abstract

# %% [markdown]
# Parameter Values:
# * Orbit Inclination - $35^\circ$ (fixed)
# * Eccentricity - 0.9 (fixed)
# * Stellar Mass - $10 M_{\odot}$ (fixed)
# * Stellar Radius - $6 R_{\odot}$ (fixed)
# * Argument of Periastron - $0^\circ$ (free)
# * Disc Inclination - $10^\circ$ (free)
# * Stellar Mass Loss - $1x10^{-10} M_{\odot}yr^{-1}$ (free)
# * Wind Terminal Velocity - $3x10^3 kms^{-1}$ (free)
# * Disc Temperature - $4x10^3 K$ (free)
# * Wind $\beta$ - 2 (free)
# * Initial Disc Density - $5x10^{-16} gcm^{-3}$
# * Longitude of Ascending Node - $150^\circ$ (free)
#
# | 1994 Model - | Δt (days) | φ (°) | φ (rad) | ΔDM (pc cm⁻³) | Our Model - | ΔDM (pc cm⁻³) |
# |---------------|------------|--------|---------|----------------|---------------|----------------|
# |               | **-75** | **338** | **5.90** | **0.0** |               | **-** |
# |               | **-53** | **334** | **6.01** | **0.4** |               | **-** |
# |               | **-30** | **351** | **6.13** | **1.5** |               | **-** |
# |               | **-28** | **352** | **6.14** | **3.7** |               | **-** |
# |               | **-20** | **354** | **6.18** | **11.3** |               | **-** |
# |               | **24**  | **7**   | **0.12** | **0.2** |               | **-** |
# |               | **52**  | **15**  | **0.26** | **0.0** |               | **-** |

# %%
'''
#Calculating the DM
om_deg = 138                                            #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                                 #Orbital argument of periastron in rad
Om_deg = 150                                            #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                                 #Longitude of ascending note in rad
i_orb_deg = 35                                          #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                       #Orbital inclination is rad
i_disc_deg = 10                                         #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                     #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)      #Orbital phase array in rad (redundancy removed)

#Plotting the datapoints from the paper
paper_phi_1994 = [5.90, 6.01, 6.13, 6.14, 6.18, 0.12, 0.26]
paper_DM_1994 = [146.7, 147.1, 148.2, 150.4, 158, 146.9, 146.7]

tot_DM_1994 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=9.5e-8, v_0_kms=10, v_inf_kms=1e3,
                          e=0.9, omega=om, Omega=Om, beta=2.5, T_disc=1.2e4, beta_disc=1.6, rho0=0.2e-13, i_disc=i_disc_rad)

#Plotting
plt.plot(phi, tot_DM_1994, label='i disc = ' + str(int(i_disc_deg)) + ' deg')
plt.scatter(paper_phi_1994, paper_DM_1994, color='red', label='Paper Datapoints 1994')
plt.title('Dispersion Measure 1994 Periastron Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
#plt.xlim(0, 0.3)
#plt.ylim(146, 150)
plt.legend()
'''
# Out:
# "\n#Calculating the DM\nom_deg = 138                                            #Orbital argument of periastron in degrees\nom = np.deg2rad(om_deg)                                 #Orbital argument of periastron in rad\nOm_deg = 150                                            #Longitude of ascending node in degrees\nOm = np.deg2rad(Om_deg)                                 #Longitude of ascending note in rad\ni_orb_deg = 35                                          #Orbital inclination in degrees\ni_orb_rad = np.deg2rad(i_orb_deg)                       #Orbital inclination is rad\ni_disc_deg = 10                                         #Disc inclinations in degrees\ni_disc_rad = np.deg2rad(i_disc_deg)                     #Disc inclinations in rad\nphi = np.linspace(0, 2*np.pi, 512, endpoint=False)      #Orbital phase array in rad (redundancy removed)\n\n#Plotting the datapoints from the paper\npaper_phi_1994 = [5.90, 6.01, 6.13, 6.14, 6.18, 0.12, 0.26]\npaper_DM_1994 = [146.7, 147.1, 148
# ...

# %%
#Calculating the DM
om_deg = 0                                              #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                                 #Orbital argument of periastron in rad
Om_deg = 150                                            #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                                 #Longitude of ascending note in rad
i_orb_deg = 35                                          #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                       #Orbital inclination is rad
i_disc_deg = 90                                         #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                     #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False)      #Orbital phase array in rad (redundancy removed)

#Plotting the datapoints from the paper
paper_phi_1994 = [5.90, 6.01, 6.13, 6.14, 6.18, 0.12, 0.26]
paper_DM_1994 = [0.0, 0.4, 1.5, 3.7, 11.3, 0.2, 0.0]

tot_DM_1994 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=1e-10, v_0_kms=10, v_inf_kms=3e3,
                          e=0.9, omega=om, Omega=Om, beta=2, T_disc=4e3, beta_disc=1.6, rho0=5e-16, i_disc=i_disc_rad)

#Plotting
plt.plot(phi, tot_DM_1994, label='i disc = ' + str(int(i_disc_deg)) + ' deg')
plt.scatter(paper_phi_1994, paper_DM_1994, color='red', label='Paper Datapoints 1994')
plt.title('Dispersion Measure 1994 Periastron Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
#plt.xlim(0, 0.3)
#plt.ylim(146, 150)
plt.legend()

# %% [markdown]
# # 1997 Periastron Passage - Johnston et al. (2001)
# https://arxiv.org/abs/astro-ph/0008256

# %% [markdown]
# Parameter Values:
# * Orbit Inclination - $36^\circ$ (fixed)
# * Eccentricity - 0.87 (fixed)
# * Stellar Mass - $10 M_{\odot}$ (fixed)
# * Stellar Radius - $6 R_{\odot}$ (fixed)
# * Argument of Periastron - $3^\circ$ (free)
# * Disc Inclination - $72^\circ$ (free)
# * Stellar Mass Loss - $10^{-10} M_{\odot}yr^{-1}$ (free)
# * Wind Terminal Velocity - $10^3 kms^{-1}$ (free)
# * Disc Temperature - $9x10^3 K$ (free)
# * Wind $\beta$ - 1.8 (free)
# * Initial Disc Density - $10^{-15}$ $gcm^{-3}$ (free)
# * Longitude of Ascending Node - $189^\circ$ (free)
#
# | 1997 Model - | Δt (days) | φ (°) | φ (rad) | ΔDM (pc cm⁻³) | Our Model - | ΔDM (pc cm⁻³) |
# |---------------|------------|--------|---------|----------------|---------------|----------------|
# |               | **-25.5** | **352.60** | **6.15** | **5**   |               | **-** |
# |               | **-24.5** | **352.87** | **6.16** | **5.5** |               | **-** |
# |               | **-23.5** | **353.16** | **6.16** | **3.5** |               | **-** |
# |               | **-21.5** | **353.74** | **6.17** | **4**   |               | **-** |
# |               | **-20.5** | **354.03** | **6.18** | **4.5** |               | **-** |
# |               | **-19.5** | **354.32** | **6.18** | **3**   |               | **-** |
# |               | **-17.5** | **354.90** | **6.19** | **4**   |               | **-** |

# %%
'''
#Calculating the DM
om_deg = 138                                       #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Orbital argument of periastron in rad
Om_deg = 120                                       #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending note in rad
i_orb_deg = 36                                     #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                  #Orbital inclination is rad
i_disc_deg = 11                                    #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)

#Plotting the datapoints from the paper
paper_phi_1997 = [6.15, 6.16, 6.16, 6.17, 6.18, 6.18, 6.19]
paper_DM_1997 = [151.7, 152.2, 150.2, 150.7, 151.2, 149.7, 150.7]

tot_DM_1997 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=4e-8, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1.8, T_disc=9e3, beta_disc=1.6, rho0=1.4e-13, i_disc=i_disc_rad)

#Plotting
plt.plot(phi, tot_DM_1997, label='i disc = ' + str(int(i_disc_deg)) + ' deg')
plt.scatter(paper_phi_1997, paper_DM_1997, color='red', label='Paper Datapoints 1997')
plt.title('Dispersion Measure 1997 Periastron Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
plt.xlim(6.14, 6.20)
plt.ylim(140, 160)
plt.legend()
'''
# Out:
# "\n#Calculating the DM\nom_deg = 138                                       #Orbital argument of periastron in degrees\nom = np.deg2rad(om_deg)                            #Orbital argument of periastron in rad\nOm_deg = 120                                       #Longitude of ascending node in degrees\nOm = np.deg2rad(Om_deg)                            #Longitude of ascending note in rad\ni_orb_deg = 36                                     #Orbital inclination in degrees\ni_orb_rad = np.deg2rad(i_orb_deg)                  #Orbital inclination is rad\ni_disc_deg = 11                                    #Disc inclinations in degrees\ni_disc_rad = np.deg2rad(i_disc_deg)                #Disc inclinations in rad\nphi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)\n\n#Plotting the datapoints from the paper\npaper_phi_1997 = [6.15, 6.16, 6.16, 6.17, 6.18, 6.18, 6.19]\npaper_DM_1997 = [151.7, 152.2, 150.2, 150.7, 151.2, 149.7, 150.7]\n\ntot_DM_199
# ...

# %%
#Calculating the DM
om_deg = 3                                         #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Orbital argument of periastron in rad
Om_deg = 189                                       #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending note in rad
i_orb_deg = 36                                     #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                  #Orbital inclination is rad
i_disc_deg = 72                                    #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)

#Plotting the datapoints from the paper
paper_phi_1997 = [6.15, 6.16, 6.16, 6.17, 6.18, 6.18, 6.19]
paper_DM_1997 = [5, 5.5, 3.5, 4, 4.5, 3, 4]

tot_DM_1997 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=1e-10, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1.8, T_disc=9e3, beta_disc=1.6, rho0=1e-15, i_disc=i_disc_rad)

#Plotting
plt.plot(phi, tot_DM_1997, label='i disc = ' + str(int(i_disc_deg)) + ' deg')
plt.scatter(paper_phi_1997, paper_DM_1997, color='red', label='Paper Datapoints 1997')
plt.title('Dispersion Measure 1997 Periastron Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
#plt.xlim(6.14, 6.20)
#plt.ylim(140, 160)
plt.legend()

# %% [markdown]
# # 2000 Periastron Passage - Connors et al. (2002)
# https://academic.oup.com/mnras/article/336/4/1201/981706?login=false

# %% [markdown]
# Parameter Values:
# * Orbit Inclination - $36^\circ$ (fixed)
# * Eccentricity - 0.87 (fixed)
# * Stellar Mass - $10 M_{\odot}$ (fixed)
# * Stellar Radius - $6 R_{\odot}$ (fixed)
# * Argument of Periastron - $160^\circ$ (free)
# * Disc Inclination - $70^\circ$ (free)
# * Stellar Mass Loss - $10^{-10} M_{\odot}yr^{-1}$ (free)
# * Wind Terminal Velocity - $10^3 kms^{-1}$ (free)
# * Disc Temperature - $5x10^{3} K$ (free)
# * Wind $\beta$ - 3 (free)
# * Initial Disc Density - $7x10^{-16}$ $gcm^{-3}$ (free)
# * Longitude of Ascending Node - $150^\circ$ (free)
#
#
# | 2000 Model - | Δt (days) | φ (°) | φ (rad) | ΔDM (pc cm⁻³) | Our Model - | ΔDM (pc cm⁻³) |
# |---------------|------------|--------|---------|----------------|---------------|----------------|
# |               | **-46.4** | **346.49** | **6.04** | **2** |               | **-** |
# |               | **29.5**  | **8.58**   | **0.15** | **2.2** |               | **-** |
# |               | **40.3**  | **11.72**  | **0.20** | **2.3** |               | **-** |
# |               | **55.3**  | **16.09**  | **0.28** | **1.7** |               | **-** |
# |               | **63.4**  | **18.45**  | **0.32** | **0.2** |               | **-** |
# |               | **83.1**  | **24.18**  | **0.42** | **0.9** |               | **-** |
# |               | **113.3** | **32.97**  | **0.57** | **1.6** |               | **-** |

# %%
'''
#Calculating the DM
om_deg = 138                                       #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Orbital argument of periastron in rad
Om_deg = 150                                       #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending node in rad
i_orb_deg = 36                                     #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                  #Orbital inclination is rad
i_disc_deg = 60                                    #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)

tot_DM_2000 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=1e-10, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=3, T_disc=1e4, beta_disc=1.6, rho0=0.8e-13, i_disc=i_disc_rad)

#Plotting the datapoints from the paper
paper_phi_2000 = [6.04, 0.15, 0.20, 0.28, 0.32, 0.42, 0.57]
paper_DM_2000 = [148.7, 148.9, 144.4, 148.4, 146.9, 147.6, 145.1]

#Plotting
plt.plot(phi, tot_DM_2000, label='i disc = ' + str(int(i_disc_deg)) + ' deg')
plt.scatter(paper_phi_2000, paper_DM_2000, color='red', label='Paper Datapoints 2000')
plt.title('Dispersion Measure 2000 Periastron Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
#plt.xlim(0.10, 0.60)
#plt.ylim(142, 155)
plt.legend()
'''
# Out:
# "\n#Calculating the DM\nom_deg = 138                                       #Orbital argument of periastron in degrees\nom = np.deg2rad(om_deg)                            #Orbital argument of periastron in rad\nOm_deg = 150                                       #Longitude of ascending node in degrees\nOm = np.deg2rad(Om_deg)                            #Longitude of ascending node in rad\ni_orb_deg = 36                                     #Orbital inclination in degrees\ni_orb_rad = np.deg2rad(i_orb_deg)                  #Orbital inclination is rad\ni_disc_deg = 60                                    #Disc inclinations in degrees\ni_disc_rad = np.deg2rad(i_disc_deg)                #Disc inclinations in rad\nphi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)\n\ntot_DM_2000 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=1e-10, v_0_kms=10, v_inf_kms=1e3,\n                          e=0.87, omega=om, 
# ...

# %%
#Calculating the DM
om_deg = 160                                       #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Orbital argument of periastron in rad
Om_deg = 150                                       #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending node in rad
i_orb_deg = 36                                     #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                  #Orbital inclination is rad
i_disc_deg = 70                                    #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)

tot_DM_2000 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=1e-10, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=3, T_disc=5e3, beta_disc=1.6, rho0=7e-16, i_disc=i_disc_rad)

#Plotting the datapoints from the paper
paper_phi_2000 = [6.04, 0.15, 0.20, 0.28, 0.32, 0.42, 0.57]
paper_DM_2000 = [2, 2.2, 2.3, 1.7, 0.2, 0.9, 1.6]

#Plotting
plt.plot(phi, tot_DM_2000, label='i disc = ' + str(int(i_disc_deg)) + ' deg')
plt.scatter(paper_phi_2000, paper_DM_2000, color='red', label='Paper Datapoints 2000')
plt.title('Dispersion Measure 2000 Periastron Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
#plt.xlim(0.10, 0.60)
#plt.ylim(142, 155)
plt.legend()

# %% [markdown]
# # 2004 Periastron Passage - Johnston et al. (2005)
# https://arxiv.org/abs/astro-ph/0501660

# %% [markdown]
# Parameter Values:
# * Orbit Inclination - $36^\circ$ (fixed)
# * Eccentricity - 0.87 (fixed)
# * Stellar Mass - $10 M_{\odot}$ (fixed)
# * Stellar Radius - $6 R_{\odot}$ (fixed)
# * Argument of Periastron - $0^\circ$ (free)
# * Disc Inclination - $90^\circ$ (free)
# * Stellar Mass Loss - $10^{-11} M_{\odot}yr^{-1}$ (O.O.M fixed)
# * Wind Terminal Velocity - $10^3 kms^{-1}$ (free)
# * Disc Temperature - $4x10^3 K$ (free)
# * Longitude of Ascending Node - $150^\circ$ (free)
#
# | 2004 Model - | Δt (days) | φ (°) | φ (rad) | ΔDM (pc cm⁻³) | Our Model - | ΔDM (pc cm⁻³) |
# |---------------|------------|--------|---------|----------------|---------------|----------------|
# |               | **-39.8** | **348.41** | **6.08** | **3.0**   |               | **-** |
# |               | **-33.7** | **350.19** | **6.11** | **5.6**   |               | **-** |
# |               | **-27.7** | **351.93** | **6.14** | **5.9**   |               | **-** |
# |               | **-17.8** | **354.82** | **6.19** | **19.5**  |               | **-**  |
# |               | **16.1**  | **4.68**   | **0.08** | **3.2**   |               | **-**  |
# |               | **26.2**  | **7.62**   | **0.13** | **0.7**   |               | **-**  |
# |               | **46.1**  | **13.41**  | **0.23** | **0.2**   |               | **-**  |

# %%
'''
#Calculating the DM
om_deg = 138                                       #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Orbital argument of periastron in rad
Om_deg = 150                                       #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending note in rad
i_orb_deg = 36                                     #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                  #Orbital inclination is rad
i_disc_deg = 10                                    #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)

tot_DM_2004 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=0.14e-6, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=4, T_disc=6e3, beta_disc=1.6, rho0=2e-15, i_disc=i_disc_rad)

#Plotting the datapoints from the paper
paper_phi_2004 = [6.08, 6.11, 6.14, 6.19, 0.08, 0.13, 0.23]
paper_DM_2004 = [149.7, 152.3, 152.6, 166.2, 149.9, 147.4, 146.9]

#Plotting
plt.plot(phi, tot_DM_2004, label='i disc = ' + str(int(i_disc_deg)) + ' deg')
plt.scatter(paper_phi_2004, paper_DM_2004, color='red', label='Paper Datapoints 2004')
plt.title('Dispersion Measure 2004 Periastron Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
#plt.xlim(0.07, 0.24)
#plt.ylim(146, 151)
plt.legend()
'''
# Out:
# "\n#Calculating the DM\nom_deg = 138                                       #Orbital argument of periastron in degrees\nom = np.deg2rad(om_deg)                            #Orbital argument of periastron in rad\nOm_deg = 150                                       #Longitude of ascending node in degrees\nOm = np.deg2rad(Om_deg)                            #Longitude of ascending note in rad\ni_orb_deg = 36                                     #Orbital inclination in degrees\ni_orb_rad = np.deg2rad(i_orb_deg)                  #Orbital inclination is rad\ni_disc_deg = 10                                    #Disc inclinations in degrees\ni_disc_rad = np.deg2rad(i_disc_deg)                #Disc inclinations in rad\nphi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)\n\ntot_DM_2004 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=0.14e-6, v_0_kms=10, v_inf_kms=1e3,\n                          e=0.87, omega=om
# ...

# %%
#Calculating the DM
om_deg = 0                                         #Orbital argument of periastron in degrees
om = np.deg2rad(om_deg)                            #Orbital argument of periastron in rad
Om_deg = 150                                       #Longitude of ascending node in degrees
Om = np.deg2rad(Om_deg)                            #Longitude of ascending note in rad
i_orb_deg = 36                                     #Orbital inclination in degrees
i_orb_rad = np.deg2rad(i_orb_deg)                  #Orbital inclination is rad
i_disc_deg = 90                                    #Disc inclinations in degrees
i_disc_rad = np.deg2rad(i_disc_deg)                #Disc inclinations in rad
phi = np.linspace(0, 2*np.pi, 512, endpoint=False) #Orbital phase array in rad (redundancy removed)

tot_DM_2004 = tot_DM(phi=phi, i=i_orb_rad, a_Rsun=1091, R_star_sol=6, M_star_sol=10, Mdot_Msun_per_yr=1e-11, v_0_kms=10, v_inf_kms=1e3,
                          e=0.87, omega=om, Omega=Om, beta=1, T_disc=4e3, beta_disc=1.6, rho0=8e-16, i_disc=i_disc_rad)

#Plotting the datapoints from the paper
paper_phi_2004 = [6.08, 6.11, 6.14, 6.19, 0.08, 0.13, 0.23]
paper_DM_2004 = [3.0, 5.6, 5.9, 19.5, 3.2, 0.7, 0.2]

#Plotting
plt.plot(phi, tot_DM_2004, label='i disc = ' + str(int(i_disc_deg)) + ' deg')
plt.scatter(paper_phi_2004, paper_DM_2004, color='red', label='Paper Datapoints 2004')
plt.title('Dispersion Measure 2004 Periastron Vs True Anomaly')
plt.xlabel('True Anomaly (rad)')
plt.ylabel('Dispersion Measure (pc cm^-3)')
#plt.xlim(0.07, 0.24)
#plt.ylim(146, 151)
plt.legend()

# %% [markdown]
# # Fitting the Data Points Using scipy curve_fit

# %% [markdown]
# ## Periastron 1994 Fit

# %%
#Orbital phase and DM values
paper_phi_1994 = [5.90, 6.01, 6.13, 6.14, 6.18, 0.12, 0.26]
paper_DM_1994 = [0.0, 0.4, 1.5, 3.7, 11.3, 0.2, 0.0]

p0_1994 = [np.deg2rad(35), 1e-10, 0.90, np.deg2rad(0), np.deg2rad(150), 5e-16, np.deg2rad(90)] #Parameter guess values

#Fitting the model
params_opt, cov = curve_fit(DM_curve_fit, paper_phi_1994, paper_DM_1994, p0=p0_1994)
print('Fitted Orbital Inclination:' + str(np.rad2deg(params_opt[0])))
print('Fitted Stellar Mass Loss:' + str(params_opt[1]))
print('Fitted Eccentricity:' + str(params_opt[2]))
print('Fitted Argument of Periastron:' + str(np.rad2deg(params_opt[3])))
print('Fitted Longitude of Ascending Node:' + str(np.rad2deg(params_opt[4])))
print('Fitted Initial Disc Density:' + str(params_opt[5]))
print('Fitted Disc Inclination:' + str(np.rad2deg(params_opt[6])))
# Out:
# Fitted Orbital Inclination:-484.1935738973827
# Fitted Stellar Mass Loss:-2.0529789327605557e-11
# Fitted Eccentricity:0.9862227286177936
# Fitted Argument of Periastron:7.913720878037783
# Fitted Longitude of Ascending Node:-1787.6868665897648
# Fitted Initial Disc Density:1.9552267101940307e-16
# Fitted Disc Inclination:87.72027048516763
# C:\Users\david\AppData\Local\Temp\ipykernel_25092\2067608423.py:8: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_opt, cov = curve_fit(DM_curve_fit, paper_phi_1994, paper_DM_1994, p0=p0_1994)

# %%
phi_fit_1994 = np.linspace(min(paper_phi_1994), max(paper_phi_1994), 512)
DM_fit_1994 = DM_curve_fit(phi_fit_1994, *params_opt)

#Plotting the fit
plt.scatter(phi_fit_1994, DM_fit_1994, label='Data Array')  
plt.plot(phi_fit_1994, DM_fit_1994, color='red', label='Fit')
plt.scatter(paper_phi_1994, paper_DM_1994, color='orange', label='Data Points')
plt.title('Fitted Dispersion Measure 1994 Periastron Vs True Anomaly')
plt.xlabel('Orbital phase (rad)')
plt.ylabel('DM (pc cm^-3)')
plt.legend()
plt.show()

# %% [markdown]
# ## Periastron 1997 Fit

# %%
#Orbital phase and DM values
paper_phi_1997 = [6.15, 6.16, 6.16, 6.17, 6.18, 6.18, 6.19]
paper_DM_1997 = [5, 5.5, 3.5, 4, 4.5, 3, 4]

p0_1997 = [np.deg2rad(36), 1e-10, 0.87, np.deg2rad(0), np.deg2rad(150), 5e-16, np.deg2rad(90)] #Parameter guess values

#Fitting the model
params_opt, cov = curve_fit(DM_curve_fit, paper_phi_1997, paper_DM_1997, p0=p0_1997)
print('Fitted Orbital Inclination:' + str(np.rad2deg(params_opt[0])))
print('Fitted Stellar Mass Loss:' + str(params_opt[1]))
print('Fitted Eccentricity:' + str(params_opt[2]))
print('Fitted Argument of Periastron:' + str(np.rad2deg(params_opt[3])))
print('Fitted Longitude of Ascending Node:' + str(np.rad2deg(params_opt[4])))
print('Fitted Initial Disc Density:' + str(params_opt[5]))
print('Fitted Disc Inclination:' + str(np.rad2deg(params_opt[6])))
# Out:
# Fitted Orbital Inclination:977.0596122970298
# Fitted Stellar Mass Loss:1.3948712444953131e-09
# Fitted Eccentricity:0.9764290331659592
# Fitted Argument of Periastron:5.490214278528346
# Fitted Longitude of Ascending Node:-3474.6419564316743
# Fitted Initial Disc Density:-1.2799792098211744e-16
# Fitted Disc Inclination:93.68261191835904
# C:\Users\david\AppData\Local\Temp\ipykernel_25092\1145594364.py:8: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_opt, cov = curve_fit(DM_curve_fit, paper_phi_1997, paper_DM_1997, p0=p0_1997)

# %%
phi_fit_1997 = np.linspace(min(paper_phi_1997), max(paper_phi_1997), 512)
DM_fit_1997 = DM_curve_fit(phi_fit_1997, *params_opt)

#Plotting the fit
plt.scatter(phi_fit_1997, DM_fit_1997, label='Data Array')  
plt.plot(phi_fit_1997, DM_fit_1997, color='red', label='Fit')
plt.scatter(paper_phi_1997, paper_DM_1997, color='orange', label='Data Points')
plt.title('Fitted Dispersion Measure 1997 Periastron Vs True Anomaly')
plt.xlabel('Orbital phase (rad)')
plt.ylabel('DM (pc cm^-3)')
plt.legend()
plt.show()

# %% [markdown]
# ## Periastron 2000 Fit

# %%
#Orbital phase and DM values
paper_phi_2000 = [6.04, 0.15, 0.20, 0.28, 0.32, 0.42, 0.57]
paper_DM_2000 = [2, 2.2, 2.3, 1.7, 0.2, 0.9, 1.6]

p0_2000 = [np.deg2rad(36), 1e-10, 0.87, np.deg2rad(160), np.deg2rad(150), 7e-16, np.deg2rad(70)] #Parameter guess values

#Fitting the model
params_opt, cov = curve_fit(DM_curve_fit, paper_phi_2000, paper_DM_2000, p0=p0_2000)
print('Fitted Orbital Inclination:' + str(np.rad2deg(params_opt[0])))
print('Fitted Stellar Mass Loss:' + str(params_opt[1]))
print('Fitted Eccentricity:' + str(params_opt[2]))
print('Fitted Argument of Periastron:' + str(np.rad2deg(params_opt[3])))
print('Fitted Longitude of Ascending Node:' + str(np.rad2deg(params_opt[4])))
print('Fitted Initial Disc Density:' + str(params_opt[5]))
print('Fitted Disc Inclination:' + str(np.rad2deg(params_opt[6])))
# Out:
# Fitted Orbital Inclination:86.5558730244341
# Fitted Stellar Mass Loss:1.373370638382524e-09
# Fitted Eccentricity:0.11969359833129457
# Fitted Argument of Periastron:147.9175015637933
# Fitted Longitude of Ascending Node:-753.8064417171981
# Fitted Initial Disc Density:1.4480714568702118e-16
# Fitted Disc Inclination:111.94759087265305
# C:\Users\david\AppData\Local\Temp\ipykernel_25092\1737410640.py:8: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_opt, cov = curve_fit(DM_curve_fit, paper_phi_2000, paper_DM_2000, p0=p0_2000)

# %%
phi_fit_2000 = np.linspace(min(paper_phi_2000), max(paper_phi_2000), 512)
DM_fit_2000 = DM_curve_fit(phi_fit_2000, *params_opt)

#Plotting the fit
plt.scatter(phi_fit_2000, DM_fit_2000, label='Data Array')  
plt.plot(phi_fit_2000, DM_fit_2000, color='red', label='Fit')
plt.scatter(paper_phi_2000, paper_DM_2000, color='orange', label='Data Points')
plt.title('Fitted Dispersion Measure 2000 Periastron Vs True Anomaly')
plt.xlabel('Orbital phase (rad)')
plt.ylabel('DM (pc cm^-3)')
plt.legend()
plt.show()

# %% [markdown]
# ## Periastron 2004 Fit

# %%
#Orbital phase and DM values
paper_phi_2004 = [6.08, 6.11, 6.14, 6.19, 0.08, 0.13, 0.23]
paper_DM_2004 = [3.0, 5.6, 5.9, 19.5, 3.2, 0.7, 0.2]

p0_2004 = [np.deg2rad(36), 1e-11, 0.87, np.deg2rad(0), np.deg2rad(150), 8e-16, np.deg2rad(90)] #Parameter guess values

#Fitting the model
params_opt, cov = curve_fit(DM_curve_fit, paper_phi_2004, paper_DM_2004, p0=p0_2004)
print('Fitted Orbital Inclination:' + str(np.rad2deg(params_opt[0])))
print('Fitted Stellar Mass Loss:' + str(params_opt[1]))
print('Fitted Eccentricity:' + str(params_opt[2]))
print('Fitted Argument of Periastron:' + str(np.rad2deg(params_opt[3])))
print('Fitted Longitude of Ascending Node:' + str(np.rad2deg(params_opt[4])))
print('Fitted Initial Disc Density:' + str(params_opt[5]))
print('Fitted Disc Inclination:' + str(np.rad2deg(params_opt[6])))
# Out:
# Fitted Orbital Inclination:-283.14717160687786
# Fitted Stellar Mass Loss:-6.650559819916604e-10
# Fitted Eccentricity:0.9142617439972269
# Fitted Argument of Periastron:3.943263776578319
# Fitted Longitude of Ascending Node:-533.0923420986478
# Fitted Initial Disc Density:2.0474627651568455e-15
# Fitted Disc Inclination:93.76840825896296
# C:\Users\david\AppData\Local\Temp\ipykernel_25092\3801601131.py:8: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_opt, cov = curve_fit(DM_curve_fit, paper_phi_2004, paper_DM_2004, p0=p0_2004)

# %%
phi_fit_2004 = np.linspace(min(paper_phi_2004), max(paper_phi_2004), 512)
DM_fit_2004 = DM_curve_fit(phi_fit_2004, *params_opt)

#Plotting the fit
plt.scatter(phi_fit_2004, DM_fit_2004, label='Data Array')  
plt.plot(phi_fit_2004, DM_fit_2004, color='red', label='Fit')
plt.scatter(paper_phi_2004, paper_DM_2004, color='orange', label='Data Points')
plt.title('Fitted Dispersion Measure 2004 Periastron Vs True Anomaly')
plt.xlabel('Orbital phase (rad)')
plt.ylabel('DM (pc cm^-3)')
plt.legend()
plt.show()

# %% [markdown]
# # Wind Model Only curve fit

# %% [markdown]
# ## Periastron 1994 Fit

# %%
#Orbital phase and DM values
paper_phi_1994 = [5.90, 6.01, 6.13, 6.14, 6.18, 0.12, 0.26]
paper_DM_1994 = [0.0, 0.4, 1.5, 3.7, 11.3, 0.2, 0.0]

p0_1994 = [np.deg2rad(35), 1e-10, 0.90, np.deg2rad(0), np.deg2rad(150)] #Parameter guess values

#Fitting the model
params_opt, cov = curve_fit(wind_only_DM_fit, paper_phi_1994, paper_DM_1994, p0=p0_1994)
print('Fitted Orbital Inclination:' + str(np.rad2deg(params_opt[0])))
print('Fitted Stellar Mass Loss:' + str(params_opt[1]))
print('Fitted Eccentricity:' + str(params_opt[2]))
print('Fitted Argument of Periastron:' + str(np.rad2deg(params_opt[3])))
print('Fitted Longitude of Ascending Node:' + str(np.rad2deg(params_opt[4])))
# Out:
# Fitted Orbital Inclination:85.37752638156019
# Fitted Stellar Mass Loss:6.0865084904318e-12
# Fitted Eccentricity:0.9326800771791381
# Fitted Argument of Periastron:-12.389348035806915
# Fitted Longitude of Ascending Node:162.38926041148025

# %%
phi_fit_1994 = np.linspace(min(paper_phi_1994), max(paper_phi_1994), 512)
DM_fit_1994 = wind_only_DM_fit(phi_fit_1994, *params_opt)

#Plotting the fit
plt.scatter(phi_fit_1994, DM_fit_1994, label='Data Array')  
plt.plot(phi_fit_1994, DM_fit_1994, color='red', label='Fit')
plt.scatter(paper_phi_1994, paper_DM_1994, color='orange', label='Data Points')
plt.title('Wind Only Fitted Dispersion Measure 1994 Periastron Vs True Anomaly')
plt.xlabel('Orbital phase (rad)')
plt.ylabel('DM (pc cm^-3)')
plt.legend()
plt.show()

# %% [markdown]
# ## Periastron 1997 Fit

# %%
#Orbital phase and DM values
paper_phi_1997 = [6.15, 6.16, 6.16, 6.17, 6.18, 6.18, 6.19]
paper_DM_1997 = [5, 5.5, 3.5, 4, 4.5, 3, 4]

p0_1997 = [np.deg2rad(36), 1e-10, 0.87, np.deg2rad(0), np.deg2rad(150)] #Parameter guess values

#Fitting the model
params_opt, cov = curve_fit(wind_only_DM_fit, paper_phi_1997, paper_DM_1997, p0=p0_1997)
print('Fitted Orbital Inclination:' + str(np.rad2deg(params_opt[0])))
print('Fitted Stellar Mass Loss:' + str(params_opt[1]))
print('Fitted Eccentricity:' + str(params_opt[2]))
print('Fitted Argument of Periastron:' + str(np.rad2deg(params_opt[3])))
print('Fitted Longitude of Ascending Node:' + str(np.rad2deg(params_opt[4])))
# Out:
# Fitted Orbital Inclination:1530.000104407161
# Fitted Stellar Mass Loss:1.637912839806231e-09
# Fitted Eccentricity:1.8887039412404822
# Fitted Argument of Periastron:3142.5208196542676
# Fitted Longitude of Ascending Node:-2992.4904367482786

# %%
phi_fit_1997 = np.linspace(min(paper_phi_1997), max(paper_phi_1997), 512)
DM_fit_1997 = wind_only_DM_fit(phi_fit_1997, *params_opt)

#Plotting the fit
plt.scatter(phi_fit_1997, DM_fit_1997, label='Data Array')  
plt.plot(phi_fit_1997, DM_fit_1997, color='red', label='Fit')
plt.scatter(paper_phi_1997, paper_DM_1997, color='orange', label='Data Points')
plt.title('Wind Only Fitted Dispersion Measure 1997 Periastron Vs True Anomaly')
plt.xlabel('Orbital phase (rad)')
plt.ylabel('DM (pc cm^-3)')
plt.legend()
plt.show()

# %% [markdown]
# ## Periastron 2000 Fit

# %%
#Orbital phase and DM values
paper_phi_2000 = [6.04, 0.15, 0.20, 0.28, 0.32, 0.42, 0.57]
paper_DM_2000 = [2, 2.2, 2.3, 1.7, 0.2, 0.9, 1.6]

p0_2000 = [np.deg2rad(36), 1e-10, 0.87, np.deg2rad(160), np.deg2rad(150)] #Parameter guess values

#Fitting the model
params_opt, cov = curve_fit(wind_only_DM_fit, paper_phi_2000, paper_DM_2000, p0=p0_2000)
print('Fitted Orbital Inclination:' + str(np.rad2deg(params_opt[0])))
print('Fitted Stellar Mass Loss:' + str(params_opt[1]))
print('Fitted Eccentricity:' + str(params_opt[2]))
print('Fitted Argument of Periastron:' + str(np.rad2deg(params_opt[3])))
print('Fitted Longitude of Ascending Node:' + str(np.rad2deg(params_opt[4])))
# Out:
# Fitted Orbital Inclination:-278.6721866911875
# Fitted Stellar Mass Loss:5.078365207850736e-10
# Fitted Eccentricity:1.3235912115282362
# Fitted Argument of Periastron:-1284.4888204002661
# Fitted Longitude of Ascending Node:1593.7883579151185

# %%
phi_fit_2000 = np.linspace(min(paper_phi_2000), max(paper_phi_2000), 512)
DM_fit_2000 = wind_only_DM_fit(phi_fit_2000, *params_opt)

#Plotting the fit
plt.scatter(phi_fit_2000, DM_fit_2000, label='Data Array')  
plt.plot(phi_fit_2000, DM_fit_2000, color='red', label='Fit')
plt.scatter(paper_phi_2000, paper_DM_2000, color='orange', label='Data Points')
plt.title('Wind Only Fitted Dispersion Measure 2000 Periastron Vs True Anomaly')
plt.xlabel('Orbital phase (rad)')
plt.ylabel('DM (pc cm^-3)')
plt.legend()
plt.show()

# %% [markdown]
# ## Periastron 2004 Fit

# %%
#Orbital phase and DM values
paper_phi_2004 = [6.08, 6.11, 6.14, 6.19, 0.08, 0.13, 0.23]
paper_DM_2004 = [3.0, 5.6, 5.9, 19.5, 3.2, 0.7, 0.2]

p0_2004 = [np.deg2rad(36), 1e-10, 0.87, np.deg2rad(0), np.deg2rad(150)] #Parameter guess values

#Fitting the model
params_opt, cov = curve_fit(wind_only_DM_fit, paper_phi_2004, paper_DM_2004, p0=p0_2004)
print('Fitted Orbital Inclination:' + str(np.rad2deg(params_opt[0])))
print('Fitted Stellar Mass Loss:' + str(params_opt[1]))
print('Fitted Eccentricity:' + str(params_opt[2]))
print('Fitted Argument of Periastron:' + str(np.rad2deg(params_opt[3])))
print('Fitted Longitude of Ascending Node:' + str(np.rad2deg(params_opt[4])))
# Out:
# Fitted Orbital Inclination:455.37499518765264
# Fitted Stellar Mass Loss:4.2588849115216766e-11
# Fitted Eccentricity:1.0675573383276507
# Fitted Argument of Periastron:-826.1115848409164
# Fitted Longitude of Ascending Node:970.2397684995587

# %%
phi_fit_2004 = np.linspace(min(paper_phi_2004), max(paper_phi_2004), 512)
DM_fit_2004 = wind_only_DM_fit(phi_fit_2004, *params_opt)

#Plotting the fit
plt.scatter(phi_fit_2004, DM_fit_2004, label='Data Array')  
plt.plot(phi_fit_2004, DM_fit_2004, color='red', label='Fit')
plt.scatter(paper_phi_2004, paper_DM_2004, color='orange', label='Data Points')
plt.title('Wind Only Fitted Dispersion Measure 2004 Periastron Vs True Anomaly')
plt.xlabel('Orbital phase (rad)')
plt.ylabel('DM (pc cm^-3)')
plt.legend()
plt.show()
