# %% [markdown]
# ## Fitting RM data for repeating FRBs

# %% [markdown]
# # Equations and Geometry
# ## Electron number density
# # $n_{e}(r) = \frac{\rho}{\mu_{e}m_{p}} = \frac{\dot{M}}{4\pi\mu_{e}m_{p}r^2v(r)} = \frac{k}{r^2v(r)}$
# Where
# # $\rho = \frac{\dot{M}}{4\pi r^2v(r)}$
#
# And
#
# # $k = \frac{\dot{M}}{4\pi\mu_{e}m_{p}}$
# With
#
# * $\rho$ =      Density
# * $\mu_{e}$ =   Mean molecular weight per free electron (typically set at a value of 1.2)
# * $m_{p}$ =     Proton mass
# * $\dot{M}$ =   Wind mass loss
# * $v(r)$ =     Radial wind velocity
# * $r$ =         radial distance from the center of the star
#
# ## Accelerating Wind ($\beta$ law)
# The wind velocity at a certain distance away from the star is
# # $v(r) = v_0 + (v_{\infty} - v_0)(1-\frac{R_{*}}{r})^\beta$
# with
# * $v_0$ =        The wind velocity at stellar surface
# * $v_{\infty}$ = Wind terminal velocity
# * $R_{*}$ =      Stellar radius
# * $\beta$ =      Wind acceleration exponent
#
# By placing the star and orbit at the xy plane origin, we can consider an elliptical orbit in cartesian coordinates
# # $\frac{x^2}{a^2} + \frac{y^2}{b^2} = 1$
# with
# * $a$ = Semi-major axis
# * $b$ = Semi-minor axis
# The semi-minor axis can be defined as $a\sqrt{1 - e^2}$, where $e^2$ is the eccentricity.
# In polar coordinates, the ellipse is offset along the x-axis by the focus - $f = ae$.
#
# The orbital separation in polar coordinates becomes
# # $r = \frac{a(1-e^2)}{1+ecos(\phi)}$
# Where $\phi$ is the orbital phase.
#
# The pulsar position vector along the orbit is described as
#
# # $ r_s = \begin{pmatrix} rcos(\phi) \\ rsin(\phi) \\ 0  \end{pmatrix}$
#
# Where $\omega$ is the argument of periastron. The observer unit vector (direction of signal to observer) is then defined as
#
# # $ \hat{n} = \begin{pmatrix} sin(i)cos(\Omega) \\ sin(i)sin(\Omega) \\ cos(i)  \end{pmatrix}$
#
# Where $i$ is the inclination and $\Omega$ is the longitude of ascending node.
#
# The 2D orbit is then rotated into 3D space by computing
#
# # $ r_{rot} = R_{z}(\Omega)R_{x}(i)r_s$
#
# Where
#
# # $ R_{z}(\Omega) = \begin{pmatrix} cos(\Omega) & -sin(\Omega) & 0 \\ sin(\Omega) & cos(\Omega) & 0 \\ 0 & 0 & 1  \end{pmatrix}$
#
# # $ R_{x}(i) = \begin{pmatrix} 1 & 0 & 0 \\ 0 & cos(i) & -sin(i) \\ 0 & sin(i) & cos(i)  \end{pmatrix}$
#
# Resulting in
#
# # $ r_{rot} = \begin{pmatrix} r[cos(\Omega)cos(\phi) -sin(\Omega)cos(i)sin(\phi)] \\ r[sin(\Omega)cos(\phi) + cos(\Omega)cos(i)sin(\phi)] \\ rsin(i)sin(\phi)  \end{pmatrix}$
#
# The radial distance of the signal from the star along the path of the line of sight is computed by separating the x, y, and z components of $r_{rot} + s\hat{n}$, where $s\ge0$, is the distance along the line of sight, and comuting $r(s) = \sqrt{x_{s}^2 + y_{s}^2 + z_{s}^2}$.
#
# The number density at a specific point along the line of sight distance from the orbit can then be described as
# # $n_e(r(s)) = \frac{k}{r(s)^2v(r(s))}$
#
# From the definition of $r(s)$,
#
# ## $r(s)^2 = (r_s + s\hat{n})^2 = r^2 + 2rs [cos(\phi) sin (i)cos(\Omega) + sin(\phi)sin(i)sin(\Omega)] + s^2$
#
# ## Dispersion Measure
# # $DM(\phi,i) = \int_{0}^{\infty}n_e(r(s))ds = k\int_{0}^{\infty}\frac{ds}{v(r(s))r(s)^2}$
#
# ## Semi-major axis of FRB 20190520B
# Given that the orbital period is approximately 600 days, the neutron star mass is $1.4 M_\odot$ and the mass of the star is approximately $30 M_\odot$, using Kepler's 3rd law, the semi-major axis is
# # $a^3 = \frac{P^2G(M + m)}{4\pi^2}, a \sim 944R_\odot$
# With
# * $P$ = Orbital period
# * $G$ = Gravitational constant
# * $M$ = Mass of star
# * $m$ = Mass of neutron star
#
# ## Free-free Absorption
# Free-free absorption causes signals to be absorbed by the stellar wind depending on its optical depth.
# # $\tau_{FFA} \approx 8.24x10^{-2}\nu^{-2.1}T_e^{-1.35}\int n_e^2ds$
#
# with
# * $\tau_{FFA}$ = The optical depth
# * $\nu$ = The signal frequency
# * $T_e$ = The stellar wind temperature
# * $n_e$ = The number density
# * $s$ = The line of sight distance
#
# ## Flux density
# The flux density of the pulsar signal is decribed as
# # $S_{\nu} = S_{psr,\nu}e^{-\tau} = \nu^{-p}e^{-\tau}$
# with
# * $S_{psr,\nu}$ = The intrinsic flux of the pulsar
# * $\nu$ = The signal frequency
# * $p$ = The power law index
# * $\tau$ = The optical depth
# When the flux density of the signal is plotted against frequency, it results in the pulsar's spectrum, which changes along eccentric orbits.
#
# ## Be Disc
# Be stars such as SS 2883 have a circumstellar disc due to the star's immense rotation rate. The disc introduces an additional desnity structure to the system, which is described as
# # $\rho(r_{disc}, z) = \rho_0(\frac{r_{disc}}{R_*})^{-\beta}e^{\frac{-z^2}{H(r_{disc})^2}}$
# with
# * $\rho_0$ = The disc desnity at stellar surface
# * $r_{disc}$ = radial distance in the disc plane
# * $R_*$ = Stellar radius
# * $\beta$ = Disc power law exponent
# * $z$ = Height above the disc plane
# * $H(r)$ = Scale height
#
# The scale height is described as
# # $H(r_{disc}) = c_s\sqrt{\frac{r_{disc}}{GM_*}}r_{disc}$
# with
# * $c_s$ = Speed of sound
# * $G$ = Gravitational constant
# * $M_*$ = Stellar mass
#
# And the speed of sound is described as
# # $c_s = \sqrt{\frac{kT}{\mu_em_p}}$
# with
# * $k$ = Boltzmann constant
# * $T$ = Disc temperature
#
# Using the disc desnity profile the number density through the disc becomes
# # $n_{e,disc} = \frac{\rho(r_{disc},z)}{\mu_em_p}$
#
# From which the DM and optical depth can be calculated
#
# Placing the disc at the xy plane along with the pulsar orbit, the pulsar position is $ r_s = \begin{pmatrix} rcos(\phi) \\ rsin(\phi) \\ 0  \end{pmatrix}$. The line of sight unit vector is $\hat{n} = (sin(i)cos(\Omega), sin(i)sin(\Omega), cos(i))$.
#
# The pulsar position rotation onto the disc plane is described as
#
# # $r_{rot} = R_{z}(\Omega)R_{x}(i)R_{z}(\omega)r_s$
#
# Where
#
# # $ R_{z}(\Omega) = \begin{pmatrix} cos(\Omega) & -sin(\Omega) & 0 \\ sin(\Omega) & cos(\Omega) & 0 \\ 0 & 0 & 1  \end{pmatrix}$
#
# # $ R_{x}(i) = \begin{pmatrix} 1 & 0 & 0 \\ 0 & cos(i) & -sin(i) \\ 0 & sin(i) & cos(i)  \end{pmatrix}$
#
# # $ R_{z}(\omega) = \begin{pmatrix} cos(\omega) & -sin(\omega) & 0 \\ sin(\omega) & cos(\omega) & 0 \\ 0 & 0 & 1  \end{pmatrix}$
#
# Resulting in
#
# ### $ r_{rot} = \begin{pmatrix} r[(cos(\Omega)cos(\omega) - sin(\Omega)cos(i)sin(\omega)cos(\phi) + (-cos(\Omega)sin(\omega) - sin(\Omega)cos(i)cos(\omega))sin(\phi))] \\ r[(sin(\Omega)cos(\omega) + cos(\Omega)cos(i)sin(\omega))cos(\phi) + (-sin(\Omega)sin(\omega) + cos(\Omega)cos(i)cos(\omega))sin(\phi)] \\ rsin(i)sin(\phi + \omega)  \end{pmatrix}$
#
# The radial distance of the signal from the star along the path of the line of sight is computed by separating the x and y components of $r_{rot} + s\hat{n}$, where $s\ge0$, is the distance along the line of sight, and comuting $r_{disc} = \sqrt{x_{s}^2 + y_{s}^2}$.
#
# The disc height above its plane is described as $z = r(s)\cdot{\hat{n}_{disc}} = r_s\hat{n}_{disc} + s(\hat{n}\cdot{\hat{n}_{disc}})$. Where the line of sight unit vector is $\hat{n} = (sin(i)cos(\Omega), sin(i)sin(\Omega), cos(i))$, and the disc normal is $\hat{n}_{disc} = (0, sin(i_{disc}), cos(i_{disc}))$, such that the disc rotates on the x-axis.
#
# ## Combined Stellar Wind and Be Disc
# Since the stellar wind and Be disc do not depend on each-other, combining their number densities is straight forward
# # $n_{e,total} = n_{e,wind} + n_{e,disc}$
# With this total number density we can calculate the dispersion measure, optical depth, transmission factor and spectrum of the entire system.
#
# ## Rotation Measure
# The rotation measure shows how much the plane of polarisation of the signal has rotated as a result of traveling through magnetised plasma such as the stellar wind and circumstellar disc. It depends on the number desnity and magnetic field strength along the line of sight. Higher rotation measure occurs when the polarisation rotates more at longer wavelengths, also known as Faraday rotation.
#
# The magnetic field of the star is described as
# # $B = B_0(\frac{R_*}{r(s)})$
#
# With $B_0$, the magnetic field at the stelllar surface assumed to be $0.8 G$ (Johnston et al., 1996 https://ui.adsabs.harvard.edu/abs/1996MNRAS.279.1026J/abstract).
#
# The magnetic field parallel to the line of sight is described as
# # $B_{\parallel} = B(\hat{r}\cdot\hat{n})$
#
# Where $\hat{r} = (cos(\phi), sin(\phi), 0)$ is the radial unit vector from the star to the signal source, and $\hat{n} = (sin(i)cos(\Omega), sin(i)sin(\Omega), cos(i))$ is the line of sight unit vector from the signal to the observer.
#
# The rotation measure is described as
# # $\Delta RM = 8.1x10^5 \int_{LOS} n_eB_{\parallel}ds$
# (Melatos et al., 1995, https://academic.oup.com/mnras/article/275/2/381/2896129?login=false)

# %%
#Packages
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import astropy.units as u
import astropy.constants as con
import ipywidgets as widgets
from IPython.display import display
from scipy.optimize import curve_fit
from scipy.optimize import minimize
import emcee
import corner
from IPython.display import display, Math

# %%
#Constants in cgs units
R_sun_cgs = con.R_sun.cgs.value   #Radius of sun in cgs
M_sun_cgs = con.M_sun.cgs.value   #Mass of the sun in cgs
yr_to_sec = u.yr.to(u.s)          #Year to seconds
kms_cgs = (u.km/u.s).to(u.cm/u.s) #Kms in cgs
m_p_cgs = con.m_p.cgs.value       #Mass of proton in cgs
G_cgs = con.G.cgs.value           #Gravitational constant in cgs   
k_B_cgs = con.k_B.cgs.value       #Boltzmann constant in cgs
AU_cgs = (con.au.cgs.value)       #AU in cgs
pc_to_cm = u.pc.to(u.cm)          #PC to cm

# %%
#Number density function
def num_density(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, s, e, omega, Omega, beta, mu_e=1.2):
    '''This function calculates the number density at a specific point along an elliptical orbit within a spherically cymmetric wind 
    with accelerating velocity.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    mu_e             [float] -> Mean molecular weight per free electron
    e                [float] -> Eccentricity (0 < e < 1)
    s                [float] -> Distance along line of sight from signal (AU)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent 
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the number density [array] -> (cm^-3)'''
    a = a_Rsun * R_sun_cgs                                                                                            #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                                                                                   #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec)                                                             #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                                                                                           #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                                                                                       #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                                                                                 #Calculates the k constant (cm^-1)
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                              #Calculates the orbital separation along the orbit
    x = r*(np.cos(Omega)*np.cos(phi) - np.sin(Omega)*np.cos(i)*np.sin(phi)) + s*(np.sin(i)*np.cos(Omega))             #Rotated x axis
    y = r*(np.sin(Omega)*np.cos(phi) + np.cos(Omega)*np.cos(i)*np.sin(phi)) + s*(np.sin(i)*np.sin(Omega))             #Rotated y axis
    z = r*np.sin(i)*np.sin(phi) + s*np.cos(i)                                                                         #Rotated z axis
    r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                 #Calculates the radial distance from the pulsar along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                    #Calculates the velocity of the wind 

    n_e = k/(r_s**2 * v_r_s)                                                                                          #Calculates the number density
    n_e[r_s <= R_star] = 0                                                                                            #Eclipse condition
     
    return n_e

# %%
#DM function
def dm_beta_wind(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, mu_e=1.2, s_array_cm=None):
    '''This function calculates the dispersion measure along a line of sight, given orbital phase and inclination, 
    assuming a spherically symmetric wind with an accelerating velocity.
    --------------------------------------------------------------------------------------------------------------
    Parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent 
    mu_e             [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the dispersion measure [array] -> (pc cm^-3).'''
    a = a_Rsun * R_sun_cgs                                #Converts the semi-major axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    DM_array = []

    for value in phi:
        r = a * (1 - e**2) / (1 + e * np.cos(value))                                                                             #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/r_s)**beta                                                                     #Calculates the velocity of the wind 
        n_e = k / (r_s**2 * v_r_s)                                                                                               #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition

        DM_cgs = np.trapz(n_e, s)                                                                                                #Integrating the DM in cm^-2
        DM = (DM_cgs / pc_to_cm)                                                                                                 #Converting DM to pc cm^3
        DM_array.append(DM)

    return np.array(DM_array)

# %%
#Free-free absorption function
def ffa(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, nu, T, mu_e=1.2, s_array_cm=None):
    '''This function calculates the free-free absorption along a line of sight, given orbital phase and inclination, 
    assuming a spherically symmetric wind with an accelerating velocity.
    --------------------------------------------------------------------------------------------------------------
    Parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    nu               [float] -> Signal frequency (GHz)
    T                [float] -> Stellar wind temperature (K)
    mu_e             [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array].'''
    a = a_Rsun * R_sun_cgs                                #Converts the semi-major axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    tau_array = []

    for value in phi:
        r = a * (1 - e**2) / (1 + e * np.cos(value))                                                                             #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/r_s)**beta                                                                     #Calculates the velocity of the wind 
        n_e = k / (r_s**2 * v_r_s)                                                                                               #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition

        tau = 8.24e-2*nu**-2.1*T**-1.35*np.trapz(n_e**2, s / pc_to_cm)                                                           #Integrating the optical depth
        tau_array.append(tau)

    return np.array(tau_array)

# %%
#Flux density function
def spectrum(phi, i, a_Rsun, R_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, nu, T, p, mu_e=1.2, s_array_cm=None):
    '''This function calculates the spectrum of the pulsar for a given inclination and frequency along the orbit.
    -------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    nu               [float] -> Signal frequency (GHz)
    T                [float] -> Stellar wind temperature (K)
    p                [float] -> Power law exponent
    mu_e             [float] -> Mean molecular weight per free electron
    
    -------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the pulsar spectrum [array] (Jy)'''
    a = a_Rsun * R_sun_cgs                                #Converts the semi-major axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a flux density array
    S_nu_array = []

    for value in phi:
        for freq in nu:
            r = a * (1 - e**2) / (1 + e * np.cos(value))                                                                             #Calculates the orbital separation along the orbit
            x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
            y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
            z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
            r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
            v_r_s = v_0 + (v_inf - v_0) * (1 - R_star/r_s)**beta                                                                     #Calculates the velocity of the wind 
            n_e = k / (r_s**2 * v_r_s)                                                                                               #Calculates the number density
            n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition

            tau = 8.24e-2*freq**-2.1*T**-1.35*np.trapz(n_e**2, s / pc_to_cm) #Integrating the optical depth
            S_nu = freq**(-p)*np.exp(-tau)                                   #Calculating the flux density
            S_nu_array.append(S_nu)
    S_nu_2D = np.array(S_nu_array).reshape(len(phi), len(nu))                #Reshaping to a 2D array
    return S_nu_2D

# %%
#Disc number density function
def disc_ne(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, s, mu_e=1.2):
    '''This function calculates the number density along the line of sight from the
    pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Argument of periastron (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    s          [array] -> Array of line of sight points (cm)
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the number desnity [array] (cm^-3)'''
    a = a_Rsun * R_sun_cgs               #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs      #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs      #Converts the stellar mass from solar mass to g
    r = a*(1 - e**2)/(1 + e*np.cos(phi)) #Calculates the orbital separation along the orbit

    # x and y rotation coordinates of the disc
    x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.cos(Omega))
    y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.sin(Omega))
        
    r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                          #Projected radius through disc plane        
    c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                  #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                      #Calculates the scale height
    z = r*np.sin(phi)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
    rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                      #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                            #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                                                                   #Constraining the inner disc radius

    return ne_disc

# %%
#Disc dispersion measure function
def disc_DM(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, mu_e=1.2, s_array_cm=None):
    '''This function calculates dispersion measure along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the dispersion measure [array] (pc cm^-3)'''
    a = a_Rsun * R_sun_cgs          #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs #Converts the stellar mass from solar mass to g

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    disc_DM_array = []

    for value in phi:
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                           #Calculates the orbital separation along the orbit
        
        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane           
        c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                    #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                        #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius


        disc_DM_cgs = np.trapz(ne_disc, s)                                                                               #Integrating the DM in cm^-2
        disc_DM = (disc_DM_cgs / pc_to_cm)                                                                               #Converting DM to pc cm^3
        disc_DM_array.append(disc_DM)

    return np.array(disc_DM_array)

# %%
#Disc free-free absorption function
def disc_ffa(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, nu, mu_e=1.2, s_array_cm=None):
    '''This function calculates optical depth along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    nu         [float] -> Signal frequency (GHz)
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array]'''
    a = a_Rsun * R_sun_cgs          #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs #Converts the stellar mass from solar mass to g

    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    disc_tau_array = []
    
    for value in phi:
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                           #Calculates the orbital separation along the orbit
        
        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane          
        c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                    #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                        #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius


        disc_tau = 8.24e-2*nu**(-2.1)*T**(-1.35)*np.trapz(ne_disc**2, s / pc_to_cm)                                      #Integrating tau
        disc_tau_array.append(disc_tau)

    return np.array(disc_tau_array)

# %%
#Disc flux density function
def disc_spectrum(a_Rsun, T, M_star_sol, R_star_sol, beta, rho0, i_disc, phi, omega, Omega, e, i, nu, p, mu_e=1.2, s_array_cm=None):
    '''This function calculates optical depth along 
    the line of sight from the pulsar through the disc for a given inclination and an eccentric orbit.
    -------------------------------------------------------------------------------
    parameters:
    
    a_Rsun     [float] -> Orbital radius (solar radii)
    T          [float] -> Be disc temperature (K)
    M_star_sol [float] -> Stellar mass (solar masses)
    R_star_sol [float] -> Stellar radius (solar radii)
    beta       [float] -> Disc power law exponent
    rho0       [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc     [float] -> Inclination of disc plane (rad)
    phi        [float] -> Orbital Phase (rad)
    omega      [float] -> Orbit phase angle (rad)
    Omega      [float] -> Longitude of ascending node (rad)
    e          [float] -> Eccentricity of orbit
    i          [float] -> Orbital Inclination
    nu         [float] -> Signal frequency (GHz)
    p          [float] -> Power law exponent
    mu_e       [float] -> Mean molecular weight per free electron
    
    --------------------------------------------------------------------------------
    Returns:
    
    The function returns the optical depth [array]'''
    a = a_Rsun * R_sun_cgs          #Converts the orbital radius from solar radii to cm
    R_star = R_star_sol * R_sun_cgs #Converts the stellar radius from solar radii to cm
    M_star = M_star_sol * M_sun_cgs #Converts the stellar mass from solar mass to g
    
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an optical depth array
    disc_S_nu_array = []
    
    for value in phi:
        for freq in nu:
            r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                           #Calculates the orbital separation along the orbit
            
            # x and y rotation coordinates of the disc
            x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
            y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
            r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane          
            c_s = np.sqrt((k_B_cgs * T)/(mu_e * m_p_cgs))                                                                    #Calculates the disc speed of sound
            H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
            z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
            rho_disc = 10**rho0 * (r_disc/R_star)**(-beta) * np.exp(-z**2/H_rdisc**2)                                        #Calculates the disc desnity profile
            ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
            ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius


            disc_tau = 8.24e-2*freq**(-2.1)*T**(-1.35)*np.trapz(ne_disc**2, s / pc_to_cm)                                    #Integrating tau
            disc_S_nu = freq**(-p)*np.exp(-disc_tau)                                                                         #Calculatinng the flux density
            disc_S_nu_array.append(disc_S_nu)
    disc_S_nu_2D = np.array(disc_S_nu_array).reshape(len(phi), len(nu))                                                      #Reshaping to a 2D array
    return np.array(disc_S_nu_2D)

# %%
#Total wind-disc number density function
def tot_num_density(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, s, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, mu_e=1.2):
    '''This function calculates the total number density at a specific point along an elliptical orbit within a spherically cymmetric wind 
    with accelerating velocity and an axisymmetric disc.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    s                [float] -> Distance along line of sight from signal (AU)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total number density [array] -> (cm^-3)'''
    #Stellar wind number density
    a = a_Rsun * R_sun_cgs                                                                                               #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                                                                                      #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec)                                                                #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                                                                                              #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                                                                                          #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                                                                                    #Calculates the k constant (cm^-1)
    r = a*(1 - e**2)/(1 + e*np.cos(phi))                                                                                 #Calculates the orbital separation along the orbit
    x = r*(np.cos(Omega)*np.cos(phi) - np.sin(Omega)*np.cos(i)*np.sin(phi)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
    y = r*(np.sin(Omega)*np.cos(phi) + np.cos(Omega)*np.cos(i)*np.sin(phi)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
    z = r*np.sin(i)*np.sin(phi) + s*np.cos(i)                                                                            #Rotated z axis
    r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                    #Calculates the radial distance from the pulsar along the line of sight
    v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                       #Calculates the velocity of the wind 
    n_e = k/(r_s**2 * v_r_s)                                                                                             #Calculates the number density
    n_e[r_s <= R_star] = 0                                                                                               #Eclipse condition
    
    #Disc number density
    M_star = M_star_sol * M_sun_cgs                                                                                      #Converts the stellar mass from solar mass to g
    
    # x and y rotation coordinates of the disc
    x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.cos(Omega))
    y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(phi) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(phi)) + s*(np.sin(i)*np.sin(Omega))
        
    r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                          #Projected radius through disc plane        
    c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                             #Calculates the disc speed of sound
    H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                      #Calculates the scale height
    z = r*np.sin(phi)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
    rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                 #Calculates the disc desnity profile
    ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                            #Calculates the number density
    ne_disc[r_disc < R_star] = 0                                                                                   #Constraining the inner disc radius

    #Total number density
    total_ne = n_e + ne_disc

    return total_ne

# %%
#Total wind-disc dispersion measure function
def tot_DM(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, mu_e=1.2, s_array_cm=None):
    '''This function calculates the dispersion measure along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total dispersion measure [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_DM_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                           #Calculates the velocity of the wind 
        n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
        #Disc number density

        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane        
        c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_DM_cgs = np.trapz(total_ne, s) #Integrating the DM in cm^-2
        total_DM = (total_DM_cgs / pc_to_cm) #Converting DM to pc cm^3
        tot_DM_array.append(total_DM)

    return np.array(tot_DM_array)

# %%
#Total wind-disc free-free absorption function
def tot_ffa(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_wind, T_disc, beta_disc, rho0, i_disc, nu, mu_e=1.2, s_array_cm=None):
    '''This function calculates the optical depth along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    T_wind           [float] -> Temperature of wind (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    nu               [float] -> Signal frequency (GHz)
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total optical depth [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_tau_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                           #Calculates the velocity of the wind 
        n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
        #Disc number density

        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane 
        c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_tau = 8.24e-2*nu**(-2.1)*((T_wind+T_disc)/2)**(-1.35)*np.trapz(total_ne**2, s / pc_to_cm) #Integrating the optical depth
        tot_tau_array.append(total_tau)

    return np.array(tot_tau_array)

# %%
#Total wind-disc flux density function
def tot_spectrum(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_wind, T_disc, beta_disc, rho0, i_disc, nu, p, mu_e=1.2, s_array_cm=None):
    '''This function calculates the flux density along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    T_wind           [float] -> Temperature of wind (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    nu               [float] -> Signal frequency (GHz)
    p                [float] -> Spectrum power law exponent
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total flux density [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_S_nu_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        for freq in nu:
            #Stellar wind number density
            r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
            x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
            y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
            z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
            r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
            v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                                           #Calculates the velocity of the wind 
            n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
            n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
            #Disc number density
            
            # x and y rotation coordinates of the disc
            x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
            y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
            r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane        
            c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
            H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
            z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
            rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
            ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
            ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

            #Total number density
            total_ne = n_e + ne_disc

            total_tau = 8.24e-2*freq**(-2.1)*((T_wind+T_disc)/2)**(-1.35)*np.trapz(total_ne**2, s / pc_to_cm) #Integrating the DM in cm^-2
            total_S_nu = freq**(-p)*np.exp(-total_tau)                                                        #Calculatinng the flux density
            tot_S_nu_array.append(total_S_nu)
        
    tot_S_nu_2D = np.array(tot_S_nu_array).reshape(len(phi), len(nu))                                         #Reshaping to a 2D array
    return np.array(tot_S_nu_2D)

# %%
#Total wind-disc dispersion measure function
def tot_DM_mcmc(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, ISM_DM, mu_e=1.2, s_array_cm=None):
    '''This function calculates the dispersion measure along 
    the line of sight from the pulsar through the disc and stellar wind for a given inclination and an eccentric orbit.
    -----------------------------------------------------------------------------------------------------------------------------
    parameters:
    
    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    ISM_DM           [float] -> Interstellar medium dispersion measure (pc cm^-3)
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total dispersion measure [array] -> (cm^-3)'''
    #Instantiating a line of sight array
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising a DM array
    tot_DM_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = M_star_sol * M_sun_cgs                       #Converts the stellar mass from solar mass to g

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                                   #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))                #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))                #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                              #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                                        #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1 - R_star/r_s)**beta                                                                         #Calculates the velocity of the wind 
        n_e = k/(r_s**2 * v_r_s)                                                                                                 #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                                   #Eclipse condition
    
        #Disc number density

        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane 
        c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        total_DM_cgs = np.trapz(total_ne, s)          #Integrating the DM in cm^-2
        total_DM = (total_DM_cgs / pc_to_cm) + ISM_DM #Converting DM to pc cm^3
        tot_DM_array.append(total_DM)

    return np.array(tot_DM_array)

# %%
#Curve_fit DM function
def DM_curve_fit(phi, Mdot, v_0_kms, v_inf_kms, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, ISM_DM):
    '''
    This function employs scipy's curve_fit by implementing the general tot_DM function.
    -------------------------------------------------------------------------------------
    Parameters:

    phi    [array] -> Orbital Phase (rad)
    i_orb  [float] -> Orbital Inclination (rad)
    Mdot   [float] -> Log stellar Mass Loss (solar mass per year)
    e      [float] -> Eccentricity
    omega  [float] -> Argument of Periastron (rad)
    Omega  [float] -> Longitude of Ascending Node (rad)
    rho0   [float] -> Log initial Disc Density (gcm^-3)
    i_disc [float] -> Disc Inclination (rad)
    --------------------------------------------------------------------------------------
    Returns:

    The dipersion measure curve fit.
    '''
    #Fixing the remaining parameters of the model
    i_orb_fixed = np.deg2rad(24.9)
    a_Rsun_fixed = 1396
    R_star_sol_fixed = 10.4
    M_star_sol_fixed = 22.5
    e_fixed = 0.87

    return tot_DM_mcmc(phi, i_orb_fixed, a_Rsun_fixed, R_star_sol_fixed, M_star_sol_fixed, Mdot, v_0_kms, v_inf_kms, e_fixed, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, ISM_DM)

# %%
#Total rotation measure
def tot_RM(phi, i, a_Rsun, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, mu_e=1.2, s_array_cm=None):
    '''
    This function calculates the rotation measure of the signal through the stellar wind and circumstellar disc.
    ------------------------------------------------------------------------------------------------------------
    Parameters:

    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    a_Rsun           [float] -> Orbital radius (solar radii)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total rotation measure of the signal [array] -> (rad m^-2).
    '''
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an RM array
    tot_RM_array = []
  
    a = a_Rsun * R_sun_cgs                                #Converts the semi-mmajor axis from solar radii to cm
    R_star = R_star_sol * R_sun_cgs                       #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec) #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                               #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                           #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                     #Calculates the k constant (cm^-1)
    M_star = (M_star_sol * M_sun_cgs)                     #Converts the stellar mass from solar mass to g
    B0 = 100                                              #Magnetic field at the stellar surface in G

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                     #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))  #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))  #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                          #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                             #Calculates the velocity of the wind 
        n_e = k/(r_s**2 * v_r_s)                                                                                   #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                     #Eclipse condition
    
        #Disc number density

        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane        
        c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        #Wind magnetic field
        B = B0 * (R_star/r_s)                                                                            #Total magnetic field
        B_parallel = B * (np.sin(i)*np.cos(Omega)*np.cos(value) + np.sin(i)*np.sin(Omega)*np.sin(value)) #Magnetic field parallel to line of sight
        RM_integrand = total_ne*B_parallel

        total_RM_cgs = 8.1e5 * np.trapz(RM_integrand, s / pc_to_cm)  #Integrating the RM in rad m^-2
        tot_RM_array.append(total_RM_cgs)

    return np.array(tot_RM_array)

# %%
#Total rotation measure
def tot_RM_mcmc(phi, i, P, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, B0, mu_e=1, s_array_cm=None):
    '''
    This function calculates the rotation measure of the signal through the stellar wind and circumstellar disc.
    ------------------------------------------------------------------------------------------------------------
    Parameters:

    phi              [float] -> Orbital Phase (rad)
    i                [float] -> Inclination (rad)
    P                [float] -> Orbital period (sec)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    B0               [float] -> Magnetic field (G)
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    
    -----------------------------------------------------------------------------------------------------------------------------
    Returns:
    
    The function returns the total rotation measure of the signal [array] -> (rad m^-2).
    '''
    if s_array_cm is None:
        s_array_cm = np.logspace(np.log10(1e5), np.log10(12 * AU_cgs), 512)  
    s = np.asarray(s_array_cm, dtype=float)

    #Initialising an RM array
    tot_RM_array = []
  
    R_star = R_star_sol * R_sun_cgs                           #Converts the stellar radius from solar radii to cm
    Mdot = 10**Mdot_Msun_per_yr * (M_sun_cgs / yr_to_sec)     #Converts the stellar mass loss from solar mass per year to g/s
    v_0 = v_0_kms * kms_cgs                                   #Converts the stellar surface wind velocity ftom km/s to cm/s
    v_inf = v_inf_kms * kms_cgs                               #Converts the terminal wind velocity from km/s to cm/s
    k = Mdot / (4*np.pi*mu_e*m_p_cgs)                         #Calculates the k constant (cm^-1)
    M_star = (M_star_sol * M_sun_cgs)                         #Converts the stellar mass from solar mass to g
    M_p = 1.4 * M_sun_cgs                                     #Pulsar mass
    a = (((P**2 * G_cgs)*(M_star+M_p))/(4 * np.pi**2))**(1/3) #Converts the semi-mmajor axis from solar radii to cm

    for value in phi:
        #Stellar wind number density
        r = a*(1 - e**2)/(1 + e*np.cos(value))                                                                     #Calculates the orbital separation along the orbit
        x = r*(np.cos(Omega)*np.cos(value) - np.sin(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))  #Rotated x axis
        y = r*(np.sin(Omega)*np.cos(value) + np.cos(Omega)*np.cos(i)*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))  #Rotated y axis
        z = r*np.sin(i)*np.sin(value) + s*np.cos(i)                                                                #Rotated z axis
        r_s = np.sqrt(x**2 + y**2 + z**2)                                                                          #Calculates the radial distance from the pulsar along the line of sight
        v_r_s = v_0 + (v_inf-v_0)*(1-R_star/r_s)**beta                                                             #Calculates the velocity of the wind 
        n_e = k/(r_s**2 * v_r_s)                                                                                   #Calculates the number density
        n_e[r_s <= R_star] = 0                                                                                     #Eclipse condition
    
        #Disc number density

        # x and y rotation coordinates of the disc
        x_rot = r*((np.cos(Omega)*np.cos(omega) - np.sin(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.cos(Omega)*np.sin(omega) - np.sin(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.cos(Omega))
        y_rot = r*((np.sin(Omega)*np.cos(omega) + np.cos(Omega)*np.cos(i)*np.sin(omega))*np.cos(value) + (-np.sin(Omega)*np.sin(omega) + np.cos(Omega)*np.cos(i)*np.cos(omega))*np.sin(value)) + s*(np.sin(i)*np.sin(Omega))
        
        r_disc = np.sqrt(x_rot**2 + y_rot**2)                                                                            #Projected radius through disc plane        
        c_s = np.sqrt((k_B_cgs * T_disc)/(mu_e * m_p_cgs))                                                               #Calculates the disc speed of sound
        H_rdisc = c_s * np.sqrt(r_disc/(G_cgs * M_star)) * r_disc                                                        #Calculates the scale height
        z = r*np.sin(value)*np.sin(i_disc) + s*(np.sin(i)*np.sin(Omega)*np.sin(i_disc) + np.cos(i)*np.cos(i_disc))       #Calculates the height above the disc plane
        rho_disc = 10**rho0 * (r_disc/R_star)**(-beta_disc) * np.exp(-z**2/H_rdisc**2)                                   #Calculates the disc desnity profile
        ne_disc = rho_disc/(mu_e * m_p_cgs)                                                                              #Calculates the number density
        ne_disc[r_disc < R_star] = 0                                                                                     #Constraining the inner disc radius

        #Total number density
        total_ne = n_e + ne_disc

        #Wind magnetic field
        B = B0 * (R_star/r_s)                                                                            #Total magnetic field
        B_parallel = B * (np.sin(i)*np.cos(Omega)*np.cos(value) + np.sin(i)*np.sin(Omega)*np.sin(value)) #Magnetic field parallel to line of sight
        RM_integrand = total_ne*B_parallel

        total_RM_cgs = 8.1e5 * np.trapz(RM_integrand, s / pc_to_cm)  #Integrating the RM in rad m^-2
        tot_RM_array.append(total_RM_cgs)

    return np.array(tot_RM_array)

# %%
#Curve_fit DM function
def RM_curve_fit(phi, i_orb, M_star_sol, Mdot, v_0_kms, v_inf_kms, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, B0):
    '''
    This function employs scipy's curve_fit by implementing the general tot_RM function.
    -------------------------------------------------------------------------------------
    Parameters:

    phi    [array] -> Orbital Phase (rad)
    i_orb  [float] -> Orbital Inclination (rad)
    Mdot   [float] -> Log stellar Mass Loss (solar mass per year)
    e      [float] -> Eccentricity
    omega  [float] -> Argument of Periastron (rad)
    Omega  [float] -> Longitude of Ascending Node (rad)
    rho0   [float] -> Log initial Disc Density (gcm^-3)
    i_disc [float] -> Disc Inclination (rad)
    --------------------------------------------------------------------------------------
    Returns:

    The dipersion measure curve fit.
    '''
    #Fixing the remaining parameters of the model
    P_fixed = 600*24*60*60
    R_star_sol_fixed = 10
    e_fixed = 0.75

    return tot_RM_mcmc(phi, i_orb, P_fixed, R_star_sol_fixed, M_star_sol, Mdot, v_0_kms, v_inf_kms, e_fixed, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, B0)

# %% [markdown]
# # FRB 20190520

# %%
#RM data

RM = [-10318, 5698.30, 3234.17, 19953.29, 19337.26, 18105.19, 12403.81, 15608.72, 14961.89, -36977.34, -36191.90, -23898.98, -25192.64]

MJD = [59106.79, 59292.45, 59300.47, 59373.61, 59373.61, 59373.65, 59384.63, 59400.43, 59400.48, 59522.71, 59522.69, 59588.83, 59588.91] #First entry later shifted by 2pi

Days = [184.08, -230.26, -222.24, -149.1, -149.1, -149.06, -138.08, -122.28, -122.23, 0, -0.02, 66.12, 66.2] #59522.71 is the artificial periastron passage aka T0

error = [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10]

# %%
#Plotting the data over the entire orbital phase
plt.errorbar(Days, RM, yerr=error, fmt='o')
plt.title('FRB 20190520M RM')
plt.xlabel('Days')
plt.ylabel('RM $(rad m^-2)$')
plt.xlim(-300, 300)
# Out:
# (-300.0, 300.0)

# %% [markdown]
# # Comparing our Model with Results of Past Periastron Passages of PSR B1259-63
# Since most available papers only report $\Delta DM$ - the difference in dispersion measure from periastron, with locations of the pulsar in terms of days from or to periastron, the orbital phases need to be translated as
# ## $\phi = 2\pi(\frac{\Delta t}{P}) = 2\pi(\frac{\Delta t}{1237 days})$

# %%
#Days to orbital phase

phi_data = []

for i in Days:
    if i < 0 or i == 0:
        op_minus = 2*np.pi*(i/600)
        phi_data.append(op_minus)

    if i > 0:
        op_plus = 2*np.pi*(i/600)
        phi_data.append(op_plus)

print(phi_data)
# Out:
# [1.9276812522426972, -2.4112770813852857, -2.3272918377793186, -1.561371548834127, -1.561371548834127, -1.5609526698136487, -1.4459703786922622, -1.2805131656031998, -1.2799895668276016, 0.0, -0.00020943951023931956, 0.6924070208511904, 0.6932447788921478]

# %%
#Plotting the data over the entire orbital phase
plt.errorbar(phi_data, RM, yerr=error, fmt='o')
plt.title('FRB 20190520M RM')
plt.xlabel('Orbital Phase')
plt.ylabel('RM $(rad m^-2)$')
plt.xlim(-np.pi, np.pi)
# Out:
# (-3.141592653589793, 3.141592653589793)

# %% [markdown]
# # Curvefit Fit

# %%
#Fitting the data
p0 = [np.deg2rad(25), 30, -14, 5, 1000, np.deg2rad(30), np.deg2rad(180), 1, 12000, 4, -13, np.deg2rad(60), 100] #Parameter guess values

#Setting lower and upper parameter bounds
lower = [np.deg2rad(0), 10, -15, 0, 100, np.deg2rad(0), np.deg2rad(0), 0.8, 9000, 2, -20, np.deg2rad(0), 50]
upper = [np.deg2rad(90), 40, -12, 100, 9000, np.deg2rad(360), np.deg2rad(360), 3, 30000, 6, -13, np.deg2rad(90), 200]

#Fitting the model
params_opt, cov = curve_fit(RM_curve_fit, phi_data, RM, p0=p0, sigma=error, bounds=(lower, upper), maxfev=200000)
print('Fitted Orbital Inclination:' + str(np.rad2deg(params_opt[0])) + ' Degrees = ' + str(params_opt[0]) + ' rad')
print('Fitted Stellar Mass:' + str(params_opt[1]) + ' solar masses')
print('Fitted Stellar Mass Loss: 1e' + str(params_opt[2]) + ' Solar Mass Per Year')
print('Fitted Wind Initial Velocity: ' + str(params_opt[3]) + ' km/s')
print('Fitted Wind Terminal Velocity: ' + str(params_opt[4]) + ' km/s')
print('Fitted Argument of Periastron:' + str(np.rad2deg(params_opt[5])) + ' Degrees = ' + str(params_opt[5]) + ' rad')
print('Fitted Longitude of Ascending Node:' + str(np.rad2deg(params_opt[6])) + ' Degrees = ' + str(params_opt[6]) + ' rad')
print('Fitted Wind beta: ' + str(params_opt[7]))
print('Fitted Disc Temperature: ' + str(params_opt[8]) + ' K')
print('Fitted Disc beta: ' + str(params_opt[9]))
print('Fitted Initial Disc Density: 1e' + str(params_opt[10]) + ' gcm^-3')
print('Fitted Disc Inclination:' + str(np.rad2deg(params_opt[11])) + ' Degrees = ' + str(params_opt[11]) + ' rad')
print('Fitted Magnetic Field:' + str(params_opt[12]) + ' Gauss')
# Out:
# Fitted Orbital Inclination:0.029103252190403425 Degrees = 0.0005079475737607914 rad
# Fitted Stellar Mass:10.000000040780657 solar masses
# Fitted Stellar Mass Loss: 1e-14.34684238996217 Solar Mass Per Year
# Fitted Wind Initial Velocity: 5.237437958192192 km/s
# Fitted Wind Terminal Velocity: 5602.036295493714 km/s
# Fitted Argument of Periastron:292.3659142423498 Degrees = 5.102747824132386 rad
# Fitted Longitude of Ascending Node:220.89319645095057 Degrees = 3.8553135733237403 rad
# Fitted Wind beta: 1.3789084086812886
# Fitted Disc Temperature: 23681.420528243285 K
# Fitted Disc beta: 2.2280426283562855
# Fitted Initial Disc Density: 1e-13.515085813344907 gcm^-3
# Fitted Disc Inclination:4.313446550934289 Degrees = 0.07528384442259664 rad
# Fitted Magnetic Field:131.66027276434295 Gauss
# C:\Users\david\AppData\Local\Temp\ipykernel_14376\3996196133.py:9: OptimizeWarning: Covariance of the parameters could not be estimated
#   params_opt, cov = curve_fit(RM_curve_fit, phi_data, RM, p0=p0, sigma=error, bounds=(lower, upper), maxfev=200000)

# %%
phi_fit = np.linspace(min(phi_data), max(phi_data), 512)
RM_fit = RM_curve_fit(phi_fit, *params_opt)

#Plotting the fit  
plt.plot(phi_fit, RM_fit, color='red', label='Fit')
plt.scatter(phi_data, RM, color='cyan', label='Data Points')
plt.title('Fitted Dispersion Measure 2024 Periastron Vs Orbital Phase')
plt.xlabel('Orbital phase (rad)')
plt.ylabel('RM $(rad m^-2)$')
plt.legend()
plt.show()

# %% [markdown]
# # MCMC Fits
#
# The MCMC code is based on the example provided at https://emcee.readthedocs.io/en/stable/tutorials/line/

# %%
#Fixed parameter values
i = np.deg2rad(26.32)
P = 600*24*60*60
R_star_sol = 10
M_star_sol = 28.6
Mdot_Msun_per_yr = -15
v_0_kms = 8.632
v_inf_kms = 1000
T_disc = 9000
e = 0.75
beta = 0.8

RM = np.array(RM)
phi = np.array(phi_data)
error = np.array(error)

# %%
#Maximum likelihood function
def log_likelihood(theta, phi_data, RM_data, RM_err, i, P, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, beta, T_disc):
    '''
    This function calculates the log maximum likelihood for the fitted parameters.
    ------------------------------------------------------------------------------
    parameters:

    theta            [array] -> Fitted parameters
    phi_data         [array] -> Orbital Phase from literature (rad)
    DM_data          [array] -> Dispersion meausre from literature (pccm^-3)
    DM_err           [array] -> Dispersion measure error values from literature (pccm^-3)
    i                [float] -> Inclination (rad)
    P                [float] -> Orbital period (sec)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    B0               [float] -> Magnetic field (G)
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    --------------------------------------------------------------------------------
    Returns:

    The log maximum likelihood for the fitted parameters.
    '''
    
    omega, Omega, beta_disc, rho0, i_disc, B0 = theta                                              #Parameters to fit
    model = tot_RM_mcmc(phi_data, i, P, R_star_sol, M_star_sol, Mdot_Msun_per_yr, 
                   v_0_kms, v_inf_kms, e, omega, Omega, beta, T_disc, beta_disc, rho0, i_disc, B0) #Model RM values
    
    #Likelihood calculation
    sigma = RM_err**2
    return -0.5 * np.sum((RM_data - model)**2 / sigma + np.log(sigma))

# %%
#Prior function
def log_prior(theta):
    '''
    This function calculates the priors.
    -------------------------------------
    parameters:

    theta [array] -> Fitted parameters
    -------------------------------------
    Returns:

    The priors of the fitted parameters.
    '''
    omega, Omega, beta_disc, rho0, i_disc, B0 = theta
    if np.deg2rad(0) < omega < np.deg2rad(360) and np.deg2rad(0) < Omega < np.deg2rad(360) and 0 < beta_disc < 6 and -20 < rho0 < -13 and np.deg2rad(0) < i_disc < np.deg2rad(60) and 50 < B0 < 200:
        return 0.0
    return -np.inf

# %%
#Probability function
def log_probability(theta, phi_data, RM_data, RM_err, i, P, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, beta, T_disc):
    '''
    This function calcultes the log probability of the fitted parameters.
    ---------------------------------------------------------------------
    parameters:

    theta            [array] -> Fitted parameters
    phi_data         [array] -> Orbital Phase from literature (rad)
    DM_data          [array] -> Dispersion meausre from literature (pccm^-3)
    DM_err           [array] -> Dispersion measure error values from literature (pccm^-3)
    i                [float] -> Inclination (rad)
    P                [float] -> Orbital period (sec)
    R_star_sol       [float] -> Stellar radius (solar radii)
    M_star_sol       [float] -> Stellar mass (solar masses)
    Mdot_Msun_per_yr [float] -> Log wind mass loss (solar masses per year)
    v_0_kms          [float] -> Wind velocity at stellar radius (km/s)
    v_inf_kms        [float] -> Terminal velocity of wind (km/s)
    e                [float] -> Eccentricity (0 < e < 1)
    omega            [float] -> Argument of periastron (rad)
    Omega            [float] -> Longitude of ascending node (rad)
    beta             [float] -> Wind acceleration exponent
    T_disc           [float] -> Temperature of disc (K)
    beta_disc        [floar] -> Disc power-law exponent
    rho0             [float] -> Log disc density at stellar surface (gcm^-3)
    i_disc           [float] -> Inclination of disc
    B0               [float] -> Magnetic field (G)
    mu_e             [float] -> Mean molecular weight per free electron
    s_array_cm       [array] -> Distance along line of sight from signal (AU)
    --------------------------------------------------------------------------
    Returns:

    The log probability of the fitted parameters.
    '''
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(theta, phi_data, RM_data, RM_err, i, P, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, beta, T_disc)

# %%
#Computing the maximum likelihood estimates
np.random.seed(42)                                                          #Random seed
nll = lambda *args: -log_likelihood(*args)                                  #Negative log likelihood
initial_omega = np.deg2rad(5)                                               #Guess for omega
initial_Omega = np.deg2rad(180)                                             #Guess for longitude of ascending node
initial_beta_disc = 4                                                       #Guess for disc beta
initial_rho0 = -15                                                          #Guess for initial disc density
initial_i_disc = np.deg2rad(60)                                             #Guess for disc inclination
initial_B0 = 100                                                            #Guess for magnetic field

initial = np.array([initial_omega, initial_Omega, initial_beta_disc, initial_rho0, initial_i_disc, initial_B0]) + 0.1 * np.random.randn(6)     #Initial guess array
bounds = [(np.deg2rad(0), np.deg2rad(360)), (np.deg2rad(0), np.deg2rad(360)), (0, 6), (-20, -13), (np.deg2rad(0), np.deg2rad(60)), (50, 200)]  #Setting parameter bounds

soln = minimize(nll, initial, args=(phi, RM, error, i, P, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, beta, T_disc), bounds=bounds)
omega_ml, Omega_ml, beta_disc_ml, rho0_ml, i_disc_ml, B0_ml = soln.x

print("Maximum likelihood estimates:")
print("omega = {0:.3f}".format(omega_ml))
print("Omega = {0:.3f}".format(Omega_ml))
print("Disc beta = {0:.3f}".format(beta_disc_ml))
print("Initial Disc Density = {0:.3f}".format(rho0_ml))
print("Disc i = {0:.3f}".format(i_disc_ml))
print("B0 = {0:.3f}".format(B0_ml))
# Out:
# Maximum likelihood estimates:
# omega = 1.349
# Omega = 3.893
# Disc beta = 2.264
# Initial Disc Density = -15.646
# Disc i = 0.028
# B0 = 93.937

# %% [markdown]
# ## MCMC for All Parameters

# %%
#Running the MCMC

pos = soln.x + 2e-6 * np.random.randn(140, 6)
nwalkers, ndim = pos.shape

sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(phi, RM, error, i, P, R_star_sol, M_star_sol, Mdot_Msun_per_yr, v_0_kms, v_inf_kms, e, beta, T_disc)
)
sampler.run_mcmc(pos, 5000, progress=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 5000/5000 [38:36<00:00,  2.16it/s]
# State([[ 1.35054705e+00  3.89291821e+00  2.26465011e+00 -1.57230840e+01
#    2.83600483e-02  1.12156028e+02]
#  [ 1.34046517e+00  3.89258814e+00  2.26403308e+00 -1.56907956e+01
#    2.83877726e-02  1.03914093e+02]
#  [ 1.34458707e+00  3.89238779e+00  2.26363277e+00 -1.56973361e+01
#    2.83712607e-02  1.05352419e+02]
#  [ 1.33444757e+00  3.89280674e+00  2.26712323e+00 -1.56388534e+01
#    2.84082621e-02  9.31197261e+01]
#  [ 1.35008618e+00  3.89296625e+00  2.26481394e+00 -1.55840634e+01
#    2.83557640e-02  8.14760445e+01]
#  [ 1.36113222e+00  3.89293744e+00  2.26373777e+00 -1.56780573e+01
#    2.83358985e-02  1.00812772e+02]
#  [ 1.35489390e+00  3.89284282e+00  2.26466399e+00 -1.56846622e+01
#    2.83605265e-02  1.02644815e+02]
#  [ 1.34702008e+00  3.89262910e+00  2.26345165e+00 -1.56937621e+01
#    2.83451727e-02  1.04441769e+02]
#  [ 1.35409578e+00  3.89244530e+00  2.26369173e+00 -1.55852032e+01
#    2.83428148e-02  8.13775818e+01]
#  [ 1.34602508e+00  3.89269411e+00  2.26517025e+00 -1.57343913e+01
#    2.83686825e-02  1.15306682e+02]
#  [ 1.33996770e+00  3.89290071e+00  2.26606980e+00 -1.55641959e+01
#    2.83895277e-02  7.81385429e+01]
#  [ 1.34810781e+00  3.89237291e+00  2.26295816e+00 -1.56264885e+01
#    2.83407804e-02  8.92999456e+01]
#  [ 1.34355027e+00  3.89277068e+00  2.26477824e+00 -1.56219412e+01
#    2.83708348e-02  8.88916703e+01]
#  [ 1.34551459e+00  3.89255133e+00  2.26391801e+00 -1.57083420e+01
#    2.83720415e-02  1.08178287e+02]
#  [ 1.35117561e+00  3.89259103e+00  2.26375803e+00 -1.56318979e+01
#    2.83664755e-02  9.06379718e+01]
#  [ 1.35032985e+00  3.89283931e+00  2.26487482e+00 -1.56869845e+01
#    2.83654447e-02  1.03279814e+02]
#  [ 1.34079096e+00  3.89250132e+00  2.26435626e+00 -1.56480594e+01
#    2.83661004e-02  9.42896825e+01]
#  [ 1.33871101e+00  3.89297940e+00  2.26600439e+00 -1.56375496e+01
#    2.83954074e-02  9.25087155e+01]
#  [ 1.34519289e+00  3.89245566e+00  2.26408897e+00 -1.56291757e+01
#    2.83875780e-02  9.01798227e+01]
#  [ 1.34952770e+00  3.89222959e+00  2.26291619e+00 -1.55809052e+01
#    2.83800361e-02  8.03891746e+01]
#  [ 1.33490161e+00  3.89292979e+00  2.26652867e+00 -1.56308283e+01
#    2.83995475e-02  9.12544894e+01]
#  [ 1.34314826e+00  3.89253665e+00  2.26440654e+00 -1.55788407e+01
#    2.83685878e-02  8.03903506e+01]
#  [ 1.34109582e+00  3.89291458e+00  2.26552034e+00 -1.55898651e+01
#    2.83799473e-02  8.27724820e+01]
#  [ 1.34801584e+00  3.89244545e+00  2.26417027e+00 -1.56000554e+01
#    2.83882910e-02  8.43485152e+01]
#  [ 1.34553674e+00  3.89246462e+00  2.26398039e+00 -1.56261343e+01
#    2.83541218e-02  8.95238101e+01]
#  [ 1.35349395e+00  3.89251261e+00  2.26281693e+00 -1.56940400e+01
#    2.83406622e-02  1.04267445e+02]
#  [ 1.33652985e+00  3.89266176e+00  2.26563318e+00 -1.56236232e+01
#    2.83929050e-02  8.94859433e+01]
#  [ 1.35207721e+00  3.89280914e+00  2.26447995e+00 -1.56477070e+01
#    2.83631873e-02  9.42514283e+01]
#  [ 1.34723430e+00  3.89298463e+00  2.26552954e+00 -1.55679482e+01
#    2.83652569e-02  7.86737127e+01]
#  [ 1.35934855e+00  3.89239007e+00  2.26257206e+00 -1.56520299e+01
#    2.83546324e-02  9.45601012e+01]
#  [ 1.35333216e+00  3.89251655e+00  2.26288239e+00 -1.56420121e+01
#    2.83501721e-02  9.25270004e+01]
#  [ 1.35525379e+00  3.89250795e+00  2.26327613e+00 -1.55986968e+01
#    2.83483823e-02  8.38608280e+01]
#  [ 1.34723976e+00  3.89256272e+00  2.26440003e+00 -1.56992995e+01
#    2.83702828e-02  1.06104602e+02]
#  [ 1.34090269e+00  3.89322682e+00  2.26705867e+00 -1.57151304e+01
#    2.84043783e-02  1.10993857e+02]
#  [ 1.35220557e+00  3.89239810e+00  2.26359008e+00 -1.56867012e+01
#    2.83544564e-02  1.02813125e+02]
#  [ 1.33811831e+00  3.89275880e+00  2.26598643e+00 -1.56662623e+01
#    2.83957691e-02  9.88620130e+01]
#  [ 1.34313669e+00  3.89286285e+00  2.26525219e+00 -1.56126605e+01
#    2.83592961e-02  8.71542674e+01]
#  [ 1.34847582e+00  3.89260190e+00  2.26386023e+00 -1.57256441e+01
#    2.83708092e-02  1.12513612e+02]
#  [ 1.34689037e+00  3.89262206e+00  2.26467312e+00 -1.55682340e+01
#    2.83973258e-02  7.85262094e+01]
#  [ 1.35676589e+00  3.89285430e+00  2.26343866e+00 -1.57286271e+01
#    2.83361248e-02  1.13149671e+02]
#  [ 1.34418199e+00  3.89263794e+00  2.26516595e+00 -1.56412789e+01
#    2.83791020e-02  9.30723313e+01]
#  [ 1.35558772e+00  3.89318284e+00  2.26447275e+00 -1.56128795e+01
#    2.83440540e-02  8.69634612e+01]
#  [ 1.35185963e+00  3.89320341e+00  2.26507455e+00 -1.55728236e+01
#    2.83440210e-02  7.94554756e+01]
#  [ 1.35706559e+00  3.89247468e+00  2.26367424e+00 -1.56460454e+01
#    2.83588042e-02  9.36074526e+01]
#  [ 1.35250722e+00  3.89264467e+00  2.26483071e+00 -1.56922928e+01
#    2.83731759e-02  1.04531854e+02]
#  [ 1.34864249e+00  3.89280804e+00  2.26442925e+00 -1.56633798e+01
#    2.83642250e-02  9.76744768e+01]
#  [ 1.34442992e+00  3.89261953e+00  2.26421002e+00 -1.56061122e+01
#    2.83594136e-02  8.55270172e+01]
#  [ 1.35464796e+00  3.89266963e+00  2.26359896e+00 -1.57110537e+01
#    2.83456089e-02  1.08719531e+02]
#  [ 1.35191665e+00  3.89262661e+00  2.26292299e+00 -1.56330486e+01
#    2.83401988e-02  9.06520778e+01]
#  [ 1.34871616e+00  3.89322727e+00  2.26529543e+00 -1.56038780e+01
#    2.83458454e-02  8.54072696e+01]
#  [ 1.35459603e+00  3.89267796e+00  2.26392862e+00 -1.56839822e+01
#    2.83514897e-02  1.02252223e+02]
#  [ 1.35955678e+00  3.89289215e+00  2.26322318e+00 -1.57049796e+01
#    2.83470730e-02  1.07069895e+02]
#  [ 1.35887321e+00  3.89237644e+00  2.26217721e+00 -1.56936735e+01
#    2.83385694e-02  1.03955556e+02]
#  [ 1.35521805e+00  3.89264529e+00  2.26418005e+00 -1.56372257e+01
#    2.83633916e-02  9.19029554e+01]
#  [ 1.35116140e+00  3.89255181e+00  2.26364898e+00 -1.56338633e+01
#    2.83446377e-02  9.10227583e+01]
#  [ 1.34835846e+00  3.89273304e+00  2.26456052e+00 -1.56116772e+01
#    2.83880083e-02  8.67643048e+01]
#  [ 1.34804712e+00  3.89284994e+00  2.26464811e+00 -1.56476296e+01
#    2.83566208e-02  9.42409967e+01]
#  [ 1.35971935e+00  3.89253028e+00  2.26271101e+00 -1.56530870e+01
#    2.83481252e-02  9.48566181e+01]
#  [ 1.35501459e+00  3.89303346e+00  2.26490597e+00 -1.56293004e+01
#    2.83120889e-02  9.04182301e+01]
#  [ 1.34562838e+00  3.89317793e+00  2.26651967e+00 -1.56290849e+01
#    2.83972512e-02  9.08790044e+01]
#  [ 1.34308259e+00  3.89301885e+00  2.26614241e+00 -1.56586259e+01
#    2.83742101e-02  9.71587662e+01]
#  [ 1.35060955e+00  3.89276102e+00  2.26444999e+00 -1.56805067e+01
#    2.83556935e-02  1.01589455e+02]
#  [ 1.35331803e+00  3.89256275e+00  2.26336535e+00 -1.56108237e+01
#    2.83397204e-02  8.62468542e+01]
#  [ 1.35792491e+00  3.89289359e+00  2.26426840e+00 -1.57178288e+01
#    2.83651470e-02  1.10693640e+02]
#  [ 1.35854578e+00  3.89237378e+00  2.26197692e+00 -1.56173122e+01
#    2.83494066e-02  8.71340293e+01]
#  [ 1.35710446e+00  3.89225432e+00  2.26205995e+00 -1.57296231e+01
#    2.83392555e-02  1.12910880e+02]
#  [ 1.33672269e+00  3.89292119e+00  2.26642619e+00 -1.56238178e+01
#    2.84047095e-02  8.97664456e+01]
#  [ 1.35708750e+00  3.89284237e+00  2.26456025e+00 -1.56622745e+01
#    2.83421611e-02  9.74543440e+01]
#  [ 1.35705547e+00  3.89273624e+00  2.26368603e+00 -1.56304449e+01
#    2.83430021e-02  9.03257242e+01]
#  [ 1.33845057e+00  3.89266266e+00  2.26591482e+00 -1.56124161e+01
#    2.83925143e-02  8.72773686e+01]
#  [ 1.35326611e+00  3.89291491e+00  2.26410059e+00 -1.56776091e+01
#    2.83528326e-02  1.00838175e+02]
#  [ 1.34894259e+00  3.89234532e+00  2.26270991e+00 -1.55868446e+01
#    2.83535064e-02  8.14250213e+01]
#  [ 1.36603789e+00  3.89252280e+00  2.26260112e+00 -1.56771280e+01
#    2.83309851e-02  1.00204295e+02]
#  [ 1.34570402e+00  3.89267366e+00  2.26474375e+00 -1.56952894e+01
#    2.83802756e-02  1.05264140e+02]
#  [ 1.34783127e+00  3.89268446e+00  2.26381154e+00 -1.55911522e+01
#    2.83551338e-02  8.25459440e+01]
#  [ 1.34539246e+00  3.89277042e+00  2.26477646e+00 -1.56929379e+01
#    2.83827122e-02  1.04683087e+02]
#  [ 1.34760749e+00  3.89240437e+00  2.26397048e+00 -1.56064846e+01
#    2.83531630e-02  8.55531758e+01]
#  [ 1.34816346e+00  3.89247161e+00  2.26335389e+00 -1.56415226e+01
#    2.83570478e-02  9.25665935e+01]
#  [ 1.33375452e+00  3.89274725e+00  2.26543892e+00 -1.56014117e+01
#    2.84040161e-02  8.49605389e+01]
#  [ 1.35213365e+00  3.89242721e+00  2.26353724e+00 -1.56401456e+01
#    2.83645705e-02  9.23257228e+01]
#  [ 1.34984036e+00  3.89284612e+00  2.26558338e+00 -1.56726838e+01
#    2.83741512e-02  1.00157564e+02]
#  [ 1.35012160e+00  3.89246090e+00  2.26295796e+00 -1.56427946e+01
#    2.83283554e-02  9.26991433e+01]
#  [ 1.35052869e+00  3.89297021e+00  2.26550255e+00 -1.56891131e+01
#    2.83830521e-02  1.04010630e+02]
#  [ 1.34871174e+00  3.89266318e+00  2.26381255e+00 -1.55722384e+01
#    2.83646521e-02  7.90133711e+01]
#  [ 1.35805037e+00  3.89269038e+00  2.26370211e+00 -1.57262239e+01
#    2.83663299e-02  1.12604121e+02]
#  [ 1.35112185e+00  3.89314463e+00  2.26502399e+00 -1.56434236e+01
#    2.83570169e-02  9.34787714e+01]
#  [ 1.35171087e+00  3.89289937e+00  2.26493506e+00 -1.56575865e+01
#    2.83984127e-02  9.65500453e+01]
#  [ 1.36047199e+00  3.89285390e+00  2.26459738e+00 -1.56704641e+01
#    2.83440130e-02  9.93697750e+01]
#  [ 1.35444184e+00  3.89276582e+00  2.26332281e+00 -1.56261432e+01
#    2.83452071e-02  8.93342629e+01]
#  [ 1.35944620e+00  3.89284453e+00  2.26332970e+00 -1.56829353e+01
#    2.83366818e-02  1.01811501e+02]
#  [ 1.34683661e+00  3.89308421e+00  2.26647927e+00 -1.56276453e+01
#    2.83757684e-02  9.05688623e+01]
#  [ 1.34616012e+00  3.89276134e+00  2.26456205e+00 -1.56045720e+01
#    2.83503256e-02  8.53485513e+01]
#  [ 1.34734500e+00  3.89241351e+00  2.26376200e+00 -1.56606987e+01
#    2.83675247e-02  9.68724429e+01]
#  [ 1.36218072e+00  3.89241769e+00  2.26261176e+00 -1.57328090e+01
#    2.83484670e-02  1.13932199e+02]
#  [ 1.35694971e+00  3.89305235e+00  2.26485132e+00 -1.56096570e+01
#    2.83614347e-02  8.64246596e+01]
#  [ 1.34697788e+00  3.89273410e+00  2.26543630e+00 -1.57162812e+01
#    2.83744952e-02  1.10705911e+02]
#  [ 1.35344955e+00  3.89273267e+00  2.26282761e+00 -1.57141534e+01
#    2.83267993e-02  1.09205768e+02]
#  [ 1.33510734e+00  3.89248986e+00  2.26476242e+00 -1.57199267e+01
#    2.83776676e-02  1.11385298e+02]
#  [ 1.35195063e+00  3.89296625e+00  2.26530390e+00 -1.56570505e+01
#    2.83788986e-02  9.65499322e+01]
#  [ 1.33771111e+00  3.89235475e+00  2.26468862e+00 -1.56737587e+01
#    2.84207655e-02  1.00143449e+02]
#  [ 1.33543085e+00  3.89306743e+00  2.26754703e+00 -1.56976079e+01
#    2.84084134e-02  1.06787581e+02]
#  [ 1.35318991e+00  3.89246190e+00  2.26270263e+00 -1.56721457e+01
#    2.83516642e-02  9.91134171e+01]
#  [ 1.36029397e+00  3.89283163e+00  2.26332363e+00 -1.56844544e+01
#    2.83361150e-02  1.02164326e+02]
#  [ 1.35620323e+00  3.89294286e+00  2.26373621e+00 -1.57154784e+01
#    2.83488780e-02  1.09864836e+02]
#  [ 1.35220397e+00  3.89302089e+00  2.26411503e+00 -1.57025277e+01
#    2.83466908e-02  1.06765772e+02]
#  [ 1.34333964e+00  3.89277208e+00  2.26640430e+00 -1.56698736e+01
#    2.84253906e-02  9.98317979e+01]
#  [ 1.35027159e+00  3.89228358e+00  2.26247572e+00 -1.56422954e+01
#    2.83585378e-02  9.24487010e+01]
#  [ 1.33542986e+00  3.89223742e+00  2.26463789e+00 -1.56423209e+01
#    2.83909646e-02  9.31184117e+01]
#  [ 1.35740320e+00  3.89268627e+00  2.26392703e+00 -1.57405886e+01
#    2.83742310e-02  1.16469498e+02]
#  [ 1.34986374e+00  3.89277772e+00  2.26452701e+00 -1.57345338e+01
#    2.83779543e-02  1.15102056e+02]
#  [ 1.35062360e+00  3.89248536e+00  2.26390986e+00 -1.55839823e+01
#    2.83846821e-02  8.12303195e+01]
#  [ 1.35695468e+00  3.89274358e+00  2.26394246e+00 -1.55727572e+01
#    2.83483698e-02  7.91477351e+01]
#  [ 1.34650973e+00  3.89264505e+00  2.26438176e+00 -1.55819530e+01
#    2.83565084e-02  8.09443440e+01]
#  [ 1.34586431e+00  3.89228726e+00  2.26302010e+00 -1.56438505e+01
#    2.83601667e-02  9.29732000e+01]
#  [ 1.35182920e+00  3.89240417e+00  2.26382582e+00 -1.56718534e+01
#    2.83662738e-02  9.94027873e+01]
#  [ 1.35445348e+00  3.89265033e+00  2.26260074e+00 -1.56955508e+01
#    2.83157005e-02  1.04558774e+02]
#  [ 1.34642192e+00  3.89252383e+00  2.26383828e+00 -1.56761714e+01
#    2.83652945e-02  1.00403423e+02]
#  [ 1.35940731e+00  3.89273154e+00  2.26331557e+00 -1.56380338e+01
#    2.83497103e-02  9.17807145e+01]
#  [ 1.35755870e+00  3.89280245e+00  2.26449781e+00 -1.56865581e+01
#    2.83660026e-02  1.03026272e+02]
#  [ 1.34779414e+00  3.89263325e+00  2.26434978e+00 -1.56441825e+01
#    2.83729174e-02  9.34282977e+01]
#  [ 1.34487246e+00  3.89296519e+00  2.26591721e+00 -1.56580771e+01
#    2.83931442e-02  9.69888630e+01]
#  [ 1.35298950e+00  3.89295875e+00  2.26462968e+00 -1.55748911e+01
#    2.83542860e-02  7.97166064e+01]
#  [ 1.33699706e+00  3.89263677e+00  2.26421458e+00 -1.56449184e+01
#    2.83565763e-02  9.35492955e+01]
#  [ 1.34922655e+00  3.89326787e+00  2.26548593e+00 -1.56807594e+01
#    2.83823774e-02  1.02011897e+02]
#  [ 1.35207308e+00  3.89296700e+00  2.26408208e+00 -1.55903489e+01
#    2.83460470e-02  8.24744456e+01]
#  [ 1.35702147e+00  3.89287887e+00  2.26411058e+00 -1.56001148e+01
#    2.83438127e-02  8.43607219e+01]
#  [ 1.34271710e+00  3.89306116e+00  2.26663452e+00 -1.56351725e+01
#    2.83914458e-02  9.21942558e+01]
#  [ 1.35128919e+00  3.89284077e+00  2.26501199e+00 -1.56614264e+01
#    2.83525510e-02  9.74425386e+01]
#  [ 1.35037489e+00  3.89257943e+00  2.26380150e+00 -1.56508342e+01
#    2.83869416e-02  9.46835914e+01]
#  [ 1.35810418e+00  3.89262905e+00  2.26319649e+00 -1.56855912e+01
#    2.83444538e-02  1.02391304e+02]
#  [ 1.34538847e+00  3.89282014e+00  2.26591572e+00 -1.56782983e+01
#    2.83852089e-02  1.01610225e+02]
#  [ 1.34913842e+00  3.89243082e+00  2.26330205e+00 -1.56985805e+01
#    2.83551661e-02  1.05547333e+02]
#  [ 1.34541111e+00  3.89261839e+00  2.26482251e+00 -1.56497300e+01
#    2.83816579e-02  9.47963780e+01]
#  [ 1.34439121e+00  3.89291786e+00  2.26623489e+00 -1.55757736e+01
#    2.84121419e-02  8.02932731e+01]
#  [ 1.34485098e+00  3.89284237e+00  2.26419897e+00 -1.55895474e+01
#    2.83599981e-02  8.23468468e+01]
#  [ 1.33905850e+00  3.89288631e+00  2.26591636e+00 -1.57209318e+01
#    2.83849041e-02  1.12077940e+02]
#  [ 1.34944988e+00  3.89264856e+00  2.26354484e+00 -1.55901998e+01
#    2.83513121e-02  8.22971173e+01]
#  [ 1.35297582e+00  3.89264749e+00  2.26441636e+00 -1.56991525e+01
#    2.83435775e-02  1.06078210e+02]
#  [ 1.33767199e+00  3.89292059e+00  2.26640456e+00 -1.56750631e+01
#    2.83739113e-02  1.01004274e+02]
#  [ 1.35277315e+00  3.89276869e+00  2.26471504e+00 -1.57175161e+01
#    2.83524150e-02  1.10752060e+02]], log_prob=[-559588.93691063 -559592.61534603 -559590.18590452 -559593.50256177
#  -559589.00940421 -559590.91265956 -559590.56070858 -559591.3370437
#  -559591.88867364 -559589.35576971 -559591.46352766 -559591.22164941
#  -559588.91005622 -559590.54492367 -559589.37356097 -559588.85642974
#  -559590.76056902 -559591.45405294 -559590.25888324 -559592.13962907
#  -559591.04698354 -559589.34489488 -559589.53428359 -559590.74046717
#  -559589.86736488 -559589.83042035 -559590.1999504  -559589.51502042
#  -559591.21154205 -559592.45096985 -559589.67073654 -559590.35075817
#  -559589.09186094 -559592.96540804 -559592.36161745 -559591.17243538
#  -559589.5530025  -559589.72688657 -559590.41940015 -559590.08202419
#  -559589.38102965 -559591.71701475 -559591.68996351 -559591.96891432
#  -559590.81219846 -559588.72462586 -559591.63981885 -559589.05066455
#  -559590.56334445 -559592.2922482  -559589.03062491 -559590.95467228
#  -559591.04574878 -559589.7449567  -559589.40394295 -559589.83750907
#  -559591.25751171 -559590.09764027 -559598.72462367 -559592.18445614
#  -559589.86995912 -559590.52888089 -559589.43936078 -559591.7527606
#  -559591.8133578  -559592.48185368 -559590.8747335  -559591.87626608
#  -559589.25684363 -559590.82913139 -559589.83182151 -559591.38173897
#  -559592.96552672 -559590.30706804 -559589.03737783 -559589.17060681
#  -559590.53799661 -559589.60600607 -559594.65560984 -559589.61687919
#  -559590.93988777 -559591.76662445 -559590.06543627 -559590.1738245
#  -559590.77807088 -559590.5370265  -559592.37941249 -559595.63686405
#  -559589.5355237  -559590.08531655 -559591.08090805 -559589.24096626
#  -559589.50358135 -559591.74362068 -559590.86191248 -559589.67595824
#  -559591.79598574 -559591.83154046 -559590.00960584 -559595.17769027
#  -559592.38767845 -559589.99911506 -559590.14391092 -559590.62631571
#  -559591.41866868 -559596.49219664 -559591.58782464 -559593.05153334
#  -559592.05069252 -559589.24259518 -559590.38836324 -559589.55308099
#  -559591.23925094 -559592.05067481 -559590.35110619 -559592.36762755
#  -559589.13033126 -559591.65997816 -559593.17647436 -559588.64722323
#  -559590.84295443 -559589.46082933 -559593.54083841 -559593.908218
#  -559590.16194153 -559590.0667352  -559590.97146687 -559590.53621569
#  -559592.58721479 -559589.46131721 -559590.77846381 -559589.87792351
#  -559589.37391695 -559594.24022261 -559590.48598373 -559589.82205636
#  -559589.09683815 -559591.85742738 -559590.94955757 -559589.84219649], blobs=None, random_state=('MT19937', array([2384504078, 3551904933, 1206160640, 1431074197, 4229251586,
#         144972833,  285423190, 1867612057, 4100462262, 2067841439,
#         263725574, 4057169437, 3421798335, 3723074101, 4119224535,
#        2938722856, 3383239779, 1913392783, 3380277105, 3888651325,
#         222010160, 2966922391,  202532521,  991532291,  745203399,
#         628071206, 1689418514, 2295850521, 3427612665, 3274066368,
#        1910300476,  520829822, 1258820337, 2716779812, 1639468209,
#        1660071897, 1346202069, 2800787181,  176820325, 3880372529,
#          87357210, 1569961629, 1910757834, 2131850588,  100755203,
#        1537065434,  718499767,  544830457, 1650701941, 2681244047,
#        1221716071, 3225843402,  112769387,  929343264, 2793608938,
#        2968986270, 2310674015,  187004684, 1104289267, 1984182609,
#        1280962914, 3648108372, 2722709864, 2478076079, 1873979908,
#        2410466474, 3019008117,  837443058, 4166186598, 3176053571,
#        1320562780, 3475450290, 3435840214, 2319659200,  717286035,
#        3690340797, 3563115701, 2690240745, 3981128605, 2689624498,
#        3742826481,  376014391, 3157965289, 1981732601, 1519122464,
#        3025455433, 1982705699,  371709333, 2670574483, 3322150952,
#        3569456403, 4220033986, 3532674782, 2732091363, 3617628015,
#        3640835728, 1896035868, 2820002176, 2017383220, 3982642763,
#        2458645623, 2585238227, 2484608373,  260005497, 4225740868,
#         533938851, 3172779443, 1613424230, 3320119320,  757542644,
#        3744607023, 1643369069,  421588133, 3925237296, 4016641007,
#         637884536, 1740505887, 1198041256, 3700576144, 3701488620,
#        4149784548, 3368028033, 2495201008, 2630064289, 2784576595,
#         360562161, 1228594786,  384767893, 2674047389, 2682308118,
#        3449153022, 1064347399, 2344470996, 1719175010, 2647773367,
#        3466666341, 1773722924, 4064013116, 1069688694, 3909522656,
#        3521904959, 3720357760,  622353620, 1788051502,  266948710,
#         359544543, 1801083548, 3829202899, 2018787023,  383548606,
#        3399854063,  888661141,  630165161, 3657300475,  101593178,
#         280782265,  158239614, 1248668984, 1815226334, 4119006369,
#        2954787214, 1301936253, 1308598561, 1448520874, 2535193787,
#        1663074124, 1029607103, 2309407742, 2780398981, 3765281711,
#        3451629361, 3661013964,  649398683,  887014271, 2175166526,
#        2769044806, 1450880263, 1545454630, 1610361801, 2365032969,
#        3103063393,  995618469,  395810136, 1129317025, 1740942751,
#        3126915628, 3418366720,  542039694,  533779187, 1049816938,
#        1526134928, 3488326361,   35692035, 1118984970, 2762875725,
#         359973008, 1555361725,   87802758, 2268746564, 2551357374,
#        3728997695, 2986741774, 4076801331,  424760759,  858186866,
#        4006973733, 1230769801,  324439059, 3937158810,  723860978,
#        3959351051, 1619915569, 1117030818,  185235221, 3123528060,
#        1102809748, 3960697889, 1436883065, 1072408321, 2805639672,
#          75458129, 2986367771,  626785337, 2687787770, 3944225171,
#         280961544, 1929139167, 2229668264, 3381256327, 1481338580,
#        1926244505, 2715023792, 1456414536,  481549022, 1610408147,
#        1134616062, 1278883218, 1661192846,  284266501, 3282884704,
#        1454043463, 2769161968, 1356430141, 4029122235,  399442308,
#        2185212010, 2205000300,  564813650,  419430779, 3373836643,
#        4223731055, 2475988651, 3158877873, 1445036822, 1382864844,
#        1988965370, 1368174779, 2271810449, 1556263987, 3778775855,
#         744322793, 1304479348, 3611837009, 2220606614, 4255367731,
#        2883080097, 3458946029, 2483866385,  425723317, 3370282423,
#        1783680723, 1112389229, 1339845197, 4153383932, 1442078021,
#        3632527884,  462825413, 3286981817,   84467405, 2421618151,
#        4012387604, 3539256902, 3837658459, 1186671558, 3040680396,
#        2332850022, 2361095018, 1179260048, 2530265224, 3680539750,
#         880950292, 3561266617, 1428298393, 1937188322, 3862035704,
#         729806351, 2943040382,  215856431, 2291299009, 3631213222,
#        3370478783, 3261337830, 1278730259,  387010178, 4103776064,
#        2325205675, 1891923745,  910582627,  683715055, 4092618044,
#        4212994109, 1984752373, 2782192818, 2219888151,   92199111,
#        3319739539, 2018768101, 3705468533, 3354295377, 4150746963,
#        4024755158, 2012634039, 1524566227, 3236724707, 2834889976,
#        2177753226, 2005219368,  777746355, 1925903727, 1143592069,
#        3347046348,  347960285,  911636676, 1000196092, 2147772435,
#        3635824354, 1748485646, 2242487338, 3610919035, 2979381084,
#        4113718002, 3943252293,  553394353, 1473264378, 1304350870,
#         674144312,  318912521, 1581716865, 1068195675, 3602305667,
#        2578589120, 4170615980, 3397063768, 3776417643,  457892491,
#        3701636604,  259989818, 1366926179, 3588375763, 1076789540,
#        1119556715, 2145458919,  355231706, 1825009857,  523673901,
#        1502553499, 2626120070, 4180851803,  819916112, 2269588766,
#        4292330353, 3395217414, 3322704950, 3783443602, 3093784253,
#        2468838174, 4074721962,  532518314, 3997250126,   69506222,
#         816177707, 2356224162, 3352915953, 2856274801,  361687982,
#        3131739007,  356391483, 4264477008, 4208044257,  800508723,
#        3346107822, 4178823887, 2102845292,  436120046, 2465976209,
#         533269381,   49153300, 3995780227, 3733133975, 1871698445,
#         857320968, 3478020536, 3272650356,  157926690, 3009489541,
#        1613959248, 3896882551, 3766355000, 1642489278,  983454477,
#        3048495696, 3929838618, 2265187522, 1227055552, 1911666576,
#        2869272225, 1750705751, 2816576788, 4246665184, 3369289434,
#          38821512, 3317831886, 1556963808, 4001106349, 2034715039,
#        2346487210, 3999950165, 2869887823, 2969472464, 1699950534,
#        2750756662, 2162916583,  974342759, 2085085499, 1458112201,
#        4148741625, 3623869002, 1013415924, 4068692356, 2505181903,
#         777085779, 3203921298, 2389564135,   92285451, 1290987370,
#         204593895, 3154169252, 3267825934, 2911975651,  911046091,
#        3781436470, 2952742399,  392730846, 2914520144, 3931531177,
#        3519664595, 2576452695,  114834960, 3984221492, 3673657229,
#        2839238536, 2016120397, 3660021956, 3127968379, 4265491092,
#        1141801285, 3515295639, 1622145578, 3034001414, 1930340471,
#        1538722381,  604496984, 2309219849,  193795952, 3147195340,
#        1949758726, 3997128158,  544196402,  363651941, 1961960340,
#        1329723843, 1181313838, 4146458891, 3011605381, 4223458594,
#        1902130408, 2309256841, 1700248939, 2732694164, 2607899623,
#        2000441035,   79234286,  447551504, 2222341197, 1531174139,
#         329710391,  542126080, 1574335802, 1295896817,  811713885,
#        3335604371,  280059770,  735179776, 1087085337, 3265637567,
#        1195160406, 3291116459,  642270293, 2197325935, 2030685338,
#        2283772623, 2002252954, 2430844735, 2384478810, 3142455569,
#        1945838512, 1784785383, 1673967362, 3673339399,  932475150,
#        2463925688, 1984314008,  941822535, 2412340507,  472040718,
#          32234434, 2949975091, 1206354449, 1482131964, 2387931883,
#        3828230570, 1888250425, 1831062700, 2554905198, 3705370904,
#        2711072403, 1498134748,  319369499, 3584366199, 3325520217,
#        2508818474, 3520900872,  443858531,  921746559, 3900475977,
#        3659350609,  932880730, 3812513160, 1059722516,  524727900,
#        3681012106, 3294544224, 3507629382, 2281419613, 1337019933,
#        3889738584,  493151634,  628195178, 2883851194,  839488252,
#        3410954875, 2641629125, 3613702450, 3347865070, 1086435414,
#        4264951507,  707226621, 2829317475,  716922275,  308202377,
#          87877545,  502818346, 1985178110, 3346341946, 1444075448,
#         424593330, 4110811377, 1370248520,    1772458, 2571694708,
#        3045298571, 1961273246, 2963610502, 2980516403, 1021714933,
#        2674496534, 2171019070, 3389895611, 2868598277, 3315169435,
#         353287272, 1699401714, 2064644977,  731427967,  559247994,
#         560382689, 1300998102, 3253227189, 3236293571, 1057298043,
#        2750095492, 2976007235, 4215855572, 2249005424,  978490857,
#         390776316, 3653309321, 1076977786, 2957120291, 1876122202,
#        1428331505, 1137288936, 3465341880,  232659698, 1896960595,
#        1265098741, 2976546486, 1843128675, 2474526093, 2844583716,
#         920036520,  722128203,  579683930, 1174296467], dtype=uint32), 165, 0, 0.0))

# %%
#Positions of each walker as a function of the number of steps in the chain
fig, axes = plt.subplots(6, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["om", "Om", "disc-beta", "rho0", "disc-i", "B0"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number")
# Out:
# Text(0.5, 0, 'step number')

# %%
#Flat samples
flat_samples = sampler.get_chain(discard=500, thin=15, flat=True)
print(flat_samples.shape)
# Out:
# (42000, 6)

# %%
#Plotting the corner plot
fig = corner.corner(
    flat_samples, labels=labels, truths=[1.349, 3.8927, 2.264, -15.650, 0.028, 94.790]
)
#plt.savefig("MCMCNODOT.png", dpi=300, bbox_inches="tight")

# %%
#Best fit results
for i in range(ndim):
    mcmc = np.percentile(flat_samples[:, i], [16, 50, 84])
    q = np.diff(mcmc)
    txt = "\mathrm{{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{{2:.3f}}}"
    txt = txt.format(mcmc[1], q[0], q[1], labels[i])
    display(Math(txt))
# Out:
# $\displaystyle \mathrm{om} = 1.349_{-0.007}^{0.007}$
# $\displaystyle \mathrm{Om} = 3.893_{-0.000}^{0.000}$
# $\displaystyle \mathrm{disc-beta} = 2.264_{-0.001}^{0.001}$
# $\displaystyle \mathrm{rho0} = -15.650_{-0.036}^{0.037}$
# $\displaystyle \mathrm{disc-i} = 0.028_{-0.000}^{0.000}$
# $\displaystyle \mathrm{B0} = 94.790_{-7.849}^{8.254}$

# %%
#MCMC fitted parameters
i = np.deg2rad(26.32)
P = 600*24*60*60
R_star_sol = 10
M_star_sol = 28.6
Mdot_Msun_per_yr = -15
v_0_kms = 8.632
v_inf_kms = 1000
T_disc = 9000
e = 0.75
beta = 0.8
om = 1.349
Om = 3.893
beta_disc = 2.264
rho0 = -15.650
i_disc = 0.028
B0 = 94.790

# %%
#MCMC fitted RM plot

phi_plot = np.linspace(-np.pi, np.pi, 512, endpoint=False)
MCMC_RM = tot_RM_mcmc(phi=phi_plot, i=i, P=P, R_star_sol=R_star_sol, M_star_sol=M_star_sol, Mdot_Msun_per_yr=Mdot_Msun_per_yr, v_0_kms=v_0_kms, v_inf_kms=v_inf_kms, e=e, omega=om, Omega=Om, beta=beta, T_disc=T_disc, beta_disc=beta_disc, rho0=rho0, i_disc=i_disc, B0=B0)

plt.plot(phi_plot, MCMC_RM, label='MCMC Fit')
plt.errorbar(phi_data, RM, yerr=error, fmt='o', label='Data points')
plt.title('MCMC Fitted RM')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('RM ($rad m^{-2}$)')
plt.legend()

# %%
#MCMC fitted DM plot
a_Rsun = 930.283

MCMC_DM = tot_DM(phi=phi_plot, i=i, a_Rsun=a_Rsun, R_star_sol=R_star_sol, M_star_sol=M_star_sol, Mdot_Msun_per_yr=Mdot_Msun_per_yr, v_0_kms=v_0_kms, v_inf_kms=v_inf_kms, e=e, omega=om, Omega=Om, beta=beta, T_disc=T_disc, beta_disc=beta_disc, rho0=rho0, i_disc=i_disc)

plt.plot(phi_plot, MCMC_DM)
plt.title('MCMC Fitted DM')
plt.xlabel('Orbital Phase (rad)')
plt.ylabel('DM ($pc cm^{-3}$)')
# Out:
# Text(0, 0.5, 'DM ($pc cm^{-3}$)')
